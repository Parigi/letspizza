# %%
# %pip install --upgrade --quiet python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade --quiet  langchain langchain-neo4j langchain-openai langchain-experimental neo4j python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script openai.exe is installed in 'c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script langchain-server.exe is installed in 'c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_openai import AzureChatOpenAI
from langchain_core.prompts import PromptTemplate

llm = AzureChatOpenAI(temperature=0, model_name="AI-KMS-4o")

custom_prompt_template = """
Sei un sistema di estrazione di conoscenza. 
Leggi il seguente testo e individua:
1) Le entità principali (concetti, tecniche, organizzazioni, persone, ecc.) 
2) Corrispondente testo associato a ciascuna entità
3) Le relazioni tra le entità, con un tipo relazionale appropriato (es: "utilizza", "richiede", "comprende", "prevede", ecc.)
4) Per ciascuna relazione, fornisci un breve snippet che spieghi perché esiste questa relazione

Respondi in un unico oggetto JSON con questa struttura:

{{
  "nodes": [
    {{
      "id": "<nome_entita>",
      "type": "<tipo_entita>",
      "properties": {{
         "snippet": "<testo_assocciato>"
      }}
    }}
    ...
  ],
  "relationships": [
    {{
      "source": "<nome_entita_sorgente>",
      "target": "<nome_entita_destinazione>",
      "type": "<tipo_relazione>",
      "properties": {{
        "snippet": "<testo_spiegazione_relazione>"
      }}
    }}
    ...
  ]
}}

Assicurati di:
- Non inserire testi fuori contesto.
- Mantenere il campo "type" su nodi e relazioni al valore più aderente al contenuto.
- Non aggiungere ulteriori chiavi rispetto allo schema JSON specificato.

Testo da analizzare:
{input}
"""

custom_prompt = PromptTemplate(
    template=custom_prompt_template,
    input_variables=["input"]
)

llm_transformer = LLMGraphTransformer(llm=llm)#, node_properties=True, relationship_properties=True)#, additional_instructions="Try to classify correctly the relationship type, also extract the relevant text snippet and return it as a property")#, prompt=custom_prompt)

# %%
import pdfplumber

file_path = "../Hackapizza Dataset/Misc/Manuale di Cucina.pdf"

def extract_text_from_pdf(file_path):
    text = ""
    with pdfplumber.open(file_path) as pdf:
        for page in pdf.pages:
            text += page.extract_text() + "\n"
    return text

# Leggiamo il PDF
pdf_text = extract_text_from_pdf(file_path)

# Stampiamo un'anteprima
print(pdf_text[:500])  # Stampa i primi 500 caratteri
# Out:
# Introduzione
# Io sono il grande Sirius Cosmo, lo chef stellare per eccellenza. Se non mi conoscete ancora, preparatevi:
# il mio nome è sinonimo di cucina galattica. In questo manuale vi insegnerò tutto quello che serve per
# diventare veri cuochi, da Alpha Centauri fino alla Nebulosa del Granchio (dove, a proposito, non hanno
# neanche un crostaceo decente). Impareremo insieme le licenze e le abilità fondamentali per cucinare
# nello spazio senza mandare in tilt lʼintero sistema di supporto vitale della

# %%
import re

chapters = re.findall(r"Capitolo \d+", pdf_text)
chapter_3 = pdf_text[pdf_text.find("Capitolo 3") : pdf_text.find("Capitolo 4")]
len(chapter_3)
# Out:
# 14282

# %%
from langchain_core.documents import Document

text = """
Marie Curie, born in 1867, was a Polish and naturalised-French physicist and chemist who conducted pioneering research on radioactivity.
She was the first woman to win a Nobel Prize, the first person to win a Nobel Prize twice, and the only person to win a Nobel Prize in two scientific fields.
Her husband, Pierre Curie, was a co-winner of her first Nobel Prize, making them the first-ever married couple to win the Nobel Prize and launching the Curie family legacy of five Nobel Prizes.
She was, in 1906, the first woman to become a professor at the University of Paris.
"""
documents = [Document(page_content=chapter_3)]
graph_documents_bis = llm_transformer.convert_to_graph_documents(documents)
print(f"Nodes:{graph_documents_bis[0].nodes}")
print(f"Relationships:{graph_documents_bis[0].relationships}")
# Out:
# Nodes:[Node(id='Tecniche Di Preparazione', type='Concept', properties={}), Node(id='Marinatura', type='Concept', properties={}), Node(id='Affumicatura', type='Concept', properties={}), Node(id='Fermentazione', type='Concept', properties={}), Node(id='Tecniche Di Impasto', type='Concept', properties={}), Node(id='Surgelamento', type='Concept', properties={}), Node(id='Marinatura A Infusione Gravitazionale', type='Technique', properties={}), Node(id='Marinatura Temporale Sincronizzata', type='Technique', properties={}), Node(id='Marinatura Psionica', type='Technique', properties={}), Node(id="Marinatura Tramite Reazioni D'Antimateria Diluite", type='Technique', properties={}), Node(id='Marinatura Sotto Zero A Polarità Inversa', type='Technique', properties={}), Node(id='Affumicatura A Stratificazione Quantica', type='Technique', properties={}), Node(id='Affumicatura Temporale Risonante', type='Technique', properties={}), Node(id='Affumicatura Psionica Sensoriale', type='Technique', properties={}), Node(id='Affumicatura Tramite Big Bang Microcosmico', type='Technique', properties={}), Node(id='Affumicatura Polarizzata A Freddo Iperbarico', type='Technique', properties={}), Node(id='Fermentazione Quantica A Strati Multiversali', type='Technique', properties={}), Node(id='Fermentazione Temporale Sincronizzata', type='Technique', properties={}), Node(id='Fermentazione Psionica Energetica', type='Technique', properties={}), Node(id='Fermentazione Tramite Singolarità', type='Technique', properties={}), Node(id='Fermentazione Quantico Biometrica', type='Technique', properties={}), Node(id='Impasto Gravitazionale Vorticoso', type='Technique', properties={}), Node(id='Amalgamazione Sintetica Molecolare', type='Technique', properties={}), Node(id='Impasto A Campi Magnetici Dualistici', type='Technique', properties={}), Node(id='Sinergia Elettro-Osmotica Programmabile', type='Technique', properties={}), Node(id='Modellatura Onirica Tetrazionale', type='Technique', properties={}), Node(id='Cryo-Tessitura Energetica Polarizzata', type='Technique', properties={}), Node(id='Congelamento Bio-Luminiscente Sincronico', type='Technique', properties={}), Node(id='Cristallizzazione Temporale Reversiva', type='Technique', properties={}), Node(id='Congelazione Iperdimensionalmente Stratificata', type='Technique', properties={}), Node(id='Surgelamento Antimaterico A Risonanza Inversa', type='Technique', properties={})]
# Relationships:[Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Marinatura', type='Concept', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Affumicatura', type='Concept', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Fermentazione', type='Concept', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Tecniche Di Impasto', type='Concept', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Surgelamento', type='Concept', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id='Marinatura A Infusione Gravitazionale', type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id='Marinatura Temporale Sincronizzata', type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id='Marinatura Psionica', type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id="Marinatura Tramite Reazioni D'Antimateria Diluite", type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id='Marinatura Sotto Zero A Polarità Inversa', type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura A Stratificazione Quantica', type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura Temporale Risonante', type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura Psionica Sensoriale', type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura Tramite Big Bang Microcosmico', type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura Polarizzata A Freddo Iperbarico', type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Quantica A Strati Multiversali', type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Temporale Sincronizzata', type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Psionica Energetica', type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Tramite Singolarità', type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Quantico Biometrica', type='Technique', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Tecniche Di Impasto', type='Concept', properties={}), tar ...

# %%
graph_documents_bis[0].relationships
# Out:
# [Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Marinatura', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Affumicatura', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Fermentazione', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Tecniche Di Impasto', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Surgelamento', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id='Marinatura A Infusione Gravitazionale', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id='Marinatura Temporale Sincronizzata', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id='Marinatura Psionica', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id="Marinatura Tramite Reazioni D'Antimateria Diluite", type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id='Marinatura Sotto Zero A Polarità Inversa', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura A Stratificazione Quantica', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura Temporale Risonante', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura Psionica Sensoriale', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura Tramite Big Bang Microcosmico', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura Polarizzata A Freddo Iperbarico', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Quantica A Strati Multiversali', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Temporale Sincronizzata', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Psionica Energetica', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Tramite Singolarità', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Quantico Biometrica', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Impasto', type='Concept', properties={}), target=Node(id='Impasto Gravitazionale Vorticoso', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Impasto', type='Concept', properties={}), target=Node(id='Amalgamazione Sintetica Molecolare', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Impasto', type='Concept', properties={}), target=Node(id='Impasto A Campi Magnetici Dualistici', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Impasto', type='Concept', properties={}), target=Node(id='Sinergia Elettro-Osmotica Programmabile', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Impasto', type='Concept', properties={}), target=Node(id='Modellatura Onirica Tetrazionale', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Surgelamento', type='Concept', properties={}), target=Node(id='Cryo-Tessitura Energetica Polarizzata', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Surgelamento', type='Concept', properties={}), target=Node(id='Congelamento Bio-Luminiscente Sincronico', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Surgelamento', type='Concept', properties={}), target=Node(id='Cristallizzazione Temporale Reversiva', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Surgelamento', type='Concept', properties={}), target=Node(id='Congelazione Iperdimensionalmente Stratificata', type='Technique', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Surgelamento', type='Concept', properties={}), target=Node(id='Surgelamento Antimaterico A Risonanza Inversa', type='Technique', properties={}), type='INCLUDES', properties={})]

# %%
graph_documents[0].relationships
# Out:
# [Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Marinatura', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Affumicatura', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Fermentazione', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Tecniche Di Impasto', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Preparazione', type='Concept', properties={}), target=Node(id='Surgelamento', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id='Marinatura A Infusione Gravitazionale', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id='Marinatura Temporale Sincronizzata', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id='Marinatura Psionica', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id="Marinatura Tramite Reazioni D'Antimateria Diluite", type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Marinatura', type='Concept', properties={}), target=Node(id='Marinatura Sotto Zero A Polarità Inversa', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura A Stratificazione Quantica', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura Temporale Risonante', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura Psionica Sensoriale', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura Tramite Big Bang Microcosmico', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Affumicatura', type='Concept', properties={}), target=Node(id='Affumicatura Polarizzata A Freddo Iperbarico', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Quantica A Strati Multiversali', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Temporale Sincronizzata', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Psionica Energetica', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Tramite Singolarità', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Fermentazione', type='Concept', properties={}), target=Node(id='Fermentazione Quantico Biometrica', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Impasto', type='Concept', properties={}), target=Node(id='Impasto Gravitazionale Vorticoso', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Impasto', type='Concept', properties={}), target=Node(id='Amalgamazione Sintetica Molecolare', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Impasto', type='Concept', properties={}), target=Node(id='Impasto A Campi Magnetici Dualistici', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Impasto', type='Concept', properties={}), target=Node(id='Sinergia Elettro-Osmotica Programmabile', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Tecniche Di Impasto', type='Concept', properties={}), target=Node(id='Modellatura Onirica Tetrazionale', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Surgelamento', type='Concept', properties={}), target=Node(id='Cryo-Tessitura Energetica Polarizzata', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Surgelamento', type='Concept', properties={}), target=Node(id='Congelamento Bio-Luminiscente Sincronico', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Surgelamento', type='Concept', properties={}), target=Node(id='Cristallizzazione Temporale Reversiva', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Surgelamento', type='Concept', properties={}), target=Node(id='Congelazione Iperdimensionalmente Stratificata', type='Concept', properties={}), type='INCLUDES', properties={}),
#  Relationship(source=Node(id='Surgelamento', type='Concept', properties={}), target=Node(id='Surgelamento Antimaterico A Risonanza Inversa', type='Concept', properties={}), type='INCLUDES', properties={})]

# %%
help(llm_transformer.convert_to_graph_documents)
# Out:
# Help on method convert_to_graph_documents in module langchain_experimental.graph_transformers.llm:
#
# convert_to_graph_documents(documents: Sequence[langchain_core.documents.base.Document], config: Optional[langchain_core.runnables.config.RunnableConfig] = None) -> List[langchain_community.graphs.graph_document.GraphDocument] method of langchain_experimental.graph_transformers.llm.LLMGraphTransformer instance
#     Convert a sequence of documents into graph documents.
#
#     Args:
#         documents (Sequence[Document]): The original documents.
#         kwargs: Additional keyword arguments.
#
#     Returns:
#         Sequence[GraphDocument]: The transformed documents as graphs.

# %%
help(llm_transformer)
# Out:
# Help on LLMGraphTransformer in module langchain_experimental.graph_transformers.llm object:
#
# class LLMGraphTransformer(builtins.object)
#  |  LLMGraphTransformer(llm: langchain_core.language_models.base.BaseLanguageModel, allowed_nodes: List[str] = [], allowed_relationships: Union[List[str], List[Tuple[str, str, str]]] = [], prompt: Optional[langchain_core.prompts.chat.ChatPromptTemplate] = None, strict_mode: bool = True, node_properties: Union[bool, List[str]] = False, relationship_properties: Union[bool, List[str]] = False, ignore_tool_usage: bool = False, additional_instructions: str = '') -> None
#  |
#  |  Transform documents into graph-based documents using a LLM.
#  |
#  |  It allows specifying constraints on the types of nodes and relationships to include
#  |  in the output graph. The class supports extracting properties for both nodes and
#  |  relationships.
#  |
#  |  Args:
#  |      llm (BaseLanguageModel): An instance of a language model supporting structured
#  |        output.
#  |      allowed_nodes (List[str], optional): Specifies which node types are
#  |        allowed in the graph. Defaults to an empty list, allowing all node types.
#  |      allowed_relationships (List[str], optional): Specifies which relationship types
#  |        are allowed in the graph. Defaults to an empty list, allowing all relationship
#  |        types.
#  |      prompt (Optional[ChatPromptTemplate], optional): The prompt to pass to
#  |        the LLM with additional instructions.
#  |      strict_mode (bool, optional): Determines whether the transformer should apply
#  |        filtering to strictly adhere to `allowed_nodes` and `allowed_relationships`.
#  |        Defaults to True.
#  |      node_properties (Union[bool, List[str]]): If True, the LLM can extract any
#  |        node properties from text. Alternatively, a list of valid properties can
#  |        be provided for the LLM to extract, restricting extraction to those specified.
#  |      relationship_properties (Union[bool, List[str]]): If True, the LLM can extract
#  |        any relationship properties from text. Alternatively, a list of valid
#  |        properties can be provided for the LLM to extract, restricting extraction to
#  |        those specified.
#  |      ignore_tool_usage (bool): Indicates whether the transformer should
#  |        bypass the use of structured output functionality of the language model.
#  |        If set to True, the transformer will not use the language model's native
#  |        function calling capabilities to handle structured output. Defaults to False.
#  |      additional_instructions (str): Allows you to add additional instructions
#  |        to the prompt without having to change the whole prompt.
#  |
#  |  Example:
#  |      .. code-block:: python
#  |          from langchain_experimental.graph_transformers import LLMGraphTransformer
#  |          from langchain_core.documents import Document
#  |          from langchain_openai import ChatOpenAI
#  |
#  |          llm=ChatOpenAI(temperature=0)
#  |          transformer = LLMGraphTransformer(
#  |              llm=llm,
#  |              allowed_nodes=["Person", "Organization"])
#  |
#  |          doc = Document(page_content="Elon Musk is suing OpenAI")
#  |          graph_documents = transformer.convert_to_graph_documents([doc])
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, llm: langchain_core.language_models.base.BaseLanguageModel, allowed_nodes: List[str] = [], allowed_relationships: Union[List[str], List[Tuple[str, str, str]]] = [], prompt: Optional[langchain_core.prompts.chat.ChatPromptTemplate] = None, strict_mode: bool = True, node_properties: Union[bool, List[str]] = False, relationship_properties: Union[bool, List[str]] = False, ignore_tool_usage: bool = False, additional_instructions: str = '') -> None
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  async aconvert_to_graph_documents(self, documents: Sequence[langchain_core.documents.base.Document], config: Optional[langchain_core.runnables.config.RunnableConfig] = None) -> List[langchain_community.graphs.graph_document.GraphDocument]
#  |      Asynchronously convert a sequence of documents into graph documents.
#  |
#  |  async aprocess_response(self, document: langchain_core.documents.base.Document, config: Optional[langchain_core.runnables.config.RunnableConfig] = None) -> langchain_community.graphs.graph_document.GraphDocument
#  |      Asynchronously processes a single document, transforming it into a
#  |      graph document.
#  |
#  |  convert_to_graph_documents(self, documents: Sequence[langchain_core.documents.base.Document], config: Optional[langchain_core.runnables.config.RunnableConfig] = None) -> List[langchain_community.graphs.graph_document.GraphDocument]
#  |      Convert a sequence of documents into graph documents.
#  |
#  |      Args:
#  |          documents (Sequence[Document]): The original documents.
#  |          kwargs: Additional keyword arguments.
#  |
#  |      Returns:
#  |          Sequence[GraphDocument]: The transformed documents as graphs.
#  |
#  |  process_response(self, document: langchain_core.documents.base.Document, config: Optional[langchain_core.runnables.config.RunnableConfig] = None) -> langchain_community.graphs.graph_document.GraphDocument
#  |      Processes a single document, transforming it into a graph document using
#  |      an LLM based on the model's schema and constraints.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
# %pip install llama-index-embeddings-azure-openai llama-index-llms-azure-openai
# %pip install llama-index
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: llama-index-embeddings-azure-openai in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (0.3.0)
# Requirement already satisfied: llama-index-llms-azure-openai in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (0.3.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-embeddings-azure-openai) (0.12.16.post1)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-embeddings-azure-openai) (0.3.1)
# Requirement already satisfied: azure-identity<2.0.0,>=1.15.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-llms-azure-openai) (1.16.0)
# Requirement already satisfied: httpx in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-llms-azure-openai) (0.27.0)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-llms-azure-openai) (0.3.18)
# Requirement already satisfied: azure-core>=1.23.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai) (1.30.1)
# Requirement already satisfied: cryptography>=2.5 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai) (42.0.5)
# Requirement already satisfied: msal>=1.24.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai) (1.28.0)
# Requirement already satisfied: msal-extensions>=0.3.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai) (1.1.0)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (3.9.3)
# Requirement already satisfied: dataclasses-json in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (2024.2.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\smancone\appdata\roaming\python\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (1.5.8)
# Requirement already satisfied: networkx>=3.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (3.2.1)
# Requirement already satisfied: nltk>3.8.1 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (3.9.1)
# Requirement already satisfied: numpy in c:\users\smancone\appdata\roaming\python\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (10.2.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (1.17.2)
# Requirement already satisfied: openai>=1.1.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-embeddings-openai<0.4.0,>=0.3.0->llama-index-embeddings-azure-openai) (1.51.2)
# Collecting openai>=1.1.0 (from llama-index-embeddings-openai<0.4.0,>=0.3.0->llama-index-embeddings-azure-openai)
#   Using cached openai-1.61.1-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: anyio in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from httpx->llama-index-llms-azure-openai) (4.3.0)
# Requirement already satisfied: certifi in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from httpx->llama-index-llms-azure-openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from httpx->llama-index-llms-azure-openai) (1.0.5)
# Requirement already satisfied: idna in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from httpx->llama-index-llms-azure-openai) (3.6)
# Requirement already satisfied: sniffio in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from httpx->llama-index-llms-azure-openai) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from httpcore==1.*->httpx->llama-index-llms-azure-openai) (0.14.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (1.9.4)
# Requirement already satisfied: six>=1.11.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from azure-core>=1.23.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai) (1.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.24.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai) (2.8.0)
# Requirement already satisfied: packaging in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from msal-extensions>=0.3.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai) (23.2)
# Requirement already satisfied: portalocker<3,>=1.6 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from msal-extensions>=0.3.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai) (2.8.2)
# Requirement already satisfied: click in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (8.1.7)
# Requirement already satisfied: joblib in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.4.0,>=0.3.0->llama-index-embeddings-azure-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.4.0,>=0.3.0->llama-index-embeddings-azure-openai) (0.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (2.2.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (3.0.3)
# Requirement already satisfied: colorama in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-azure-openai) (3.21.1)
# Requirement already satisfied: pycparser in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai) (2.21)
# Requirement already satisfied: pywin32>=226 in c:\users\smancone\appdata\roaming\python\python311\site-packages (from portalocker<3,>=1.6->msal-extensions>=0.3.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai) (306)
# Using cached openai-1.61.1-py3-none-any.whl (463 kB)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.51.2
#     Uninstalling openai-1.51.2:
#       Successfully uninstalled openai-1.51.2
# Successfully installed openai-1.61.1
#   WARNING: The script openai.exe is installed in 'c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting llama-indexNote: you may need to restart the kernel to use updated packages.
#   WARNING: The script llama-parse.exe is installed in 'c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script llama-parse.exe is installed in 'c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script llamaindex-cli.exe is installed in 'c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script llamaindex-cli.exe is installed in 'c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Downloading llama_index-0.12.16-py3-none-any.whl.metadata (12 kB)
# Collecting llama-index-agent-openai<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_agent_openai-0.4.5-py3-none-any.whl.metadata (727 bytes)
# Collecting llama-index-cli<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_cli-0.4.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.16 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index) (0.12.16.post1)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index) (0.3.1)
# Collecting llama-index-indices-managed-llama-cloud>=0.4.0 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.6.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index) (0.3.18)
# Collecting llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.4.3-py3-none-any.whl.metadata (726 bytes)
# Collecting llama-index-program-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_program_openai-0.3.1-py3-none-any.whl.metadata (764 bytes)
# Collecting llama-index-question-gen-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.3.0-py3-none-any.whl.metadata (783 bytes)
# Collecting llama-index-readers-file<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_readers_file-0.4.4-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse>=0.4.0 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: nltk>3.8.1 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.61.1)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.16->llama-index) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (3.9.3)
# Requirement already satisfied: dataclasses-json in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (2024.2.0)
# Requirement already satisfied: httpx in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\smancone\appdata\roaming\python\python311\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (1.5.8)
# Requirement already satisfied: networkx>=3.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (3.2.1)
# Requirement already satisfied: numpy in c:\users\smancone\appdata\roaming\python\python311\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (10.2.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-core<0.13.0,>=0.12.16->llama-index) (1.17.2)
# Collecting llama-cloud<0.2.0,>=0.1.8 (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index)
#   Downloading llama_cloud-0.1.12-py3-none-any.whl.metadata (851 bytes)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (4.12.3)
# Requirement already satisfied: pandas in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.2.1)
# Collecting pypdf<6.0.0,>=5.1.0 (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index)
#   Downloading pypdf-5.3.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading llama_parse-0.6.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: click in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from nltk>3.8.1->llama-index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from nltk>3.8.1->llama-index) (2023.12.25)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.16->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.16->llama-index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.16->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.16->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.16->llama-index) (1.9.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.5)
# Collecting certifi>=2024.7.4 (from llama-cloud<0.2.0,>=0.1.8->llama-index-indices-managed-llama-cloud>=0.4.0->llama-index)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: anyio in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.16->llama-index) (4.3.0)
# Requirement already satisfied: httpcore==1.* in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.16->llama-index) (1.0.5)
# Requirement already satisfied: idna in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.16->llama-index) (3.6)
# Requirement already satisfied: sniffio in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.16->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.16->llama-index) (0.14.0)
# Collecting llama-cloud-services (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading llama_cloud_services-0.6.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (0.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.16->llama-index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.16->llama-index) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.16->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.16->llama-index) (2.2.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.16->llama-index) (3.0.3)
# Requirement already satisfied: colorama in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.13.0,>=0.12.16->llama-index) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.16->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.16->llama-index) (3.21.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2024.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.16->llama-index) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (1.16.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in c:\users\smancone\onedrive - business integration partners spa\desktop\progetti\2402_prysmian\.conda\lib\site-packages (from llama-cloud-services->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.0.1)
# Downloading llama_index-0.12.16-py3-none-any.whl (6.9 kB)
# Downloading llama_index_agent_openai-0.4.5-py3-none-any.whl (13 kB)
# Downloading llama_index_cli-0.4.0-py3-none-any.whl (27 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.6.4-py3-none-any.whl (13 kB)
# Downloading llama_index_multi_modal_llms_openai-0.4.3-py3-none-any.whl (5.9 kB)
# Downloading llama_index_program_openai-0.3.1-py3-none-any.whl (5.3 kB)
# Downloading llama_index_question_gen_openai-0.3.0-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.4.4-py3-none-any.whl (39 kB)
# Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl (2.5 kB)
# Downloading llama_cloud-0.1.12-py3-none-any.whl (252 kB)
#    ---------------------------------------- 0.0/253.0 kB ? eta -:--:--
#    ---------------------------------------- 253.0/253.0 kB 7.8 MB/s eta 0:00:00
# Downloading llama_parse-0.6.0-py3-none-any.whl (4.8 kB)
# Downloading pypdf-5.3.0-py3-none-any.whl (300 kB)
#    ---------------------------------------- 0.0/300.7 kB ? eta -:--:--
#    --------------------------------------- 300.7/300.7 kB 19.4 MB/s eta 0:00:00
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
#    ---------------------------------------- 0.0/166.4 kB ? eta -:--:--
#    ---------------------------------------- 166.4/166.4 kB 9.8 MB/s eta 0:00:00
# Downloading llama_cloud_services-0.6.0-py3-none-any.whl (22 kB)
# Installing collected packages: striprtf, pypdf, certifi, llama-cloud, llama-index-readers-file, llama-index-indices-managed-llama-cloud, llama-cloud-services, llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-readers-llama-parse, llama-index-program-openai, llama-index-question-gen-openai, llama-index
#   Attempting uninstall: pypdf
#     Found existing installation: pypdf 5.0.1
#     Uninstalling pypdf-5.0.1:
#       Successfully uninstalled pypdf-5.0.1
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.2.2
#     Uninstalling certifi-2024.2.2:
#       Successfully uninstalled certifi-2024.2.2
# Successfully installed certifi-2025.1.31 llama-cloud-0.1.12 llama-cloud-services-0.6.0 llama-index-0.12.16 llama-index-agent-openai-0.4.5 llama-index-cli-0.4.0 llama-index-indices-managed-llama-cloud-0.6.4 llama-index-multi-modal-llms-openai-0.4.3 llama-index-program-openai-0.3.1 llama-index-question-gen-openai-0.3.0 llama-index-readers-file-0.4.4 llama-index-readers-llama-parse-0.4.0 llama-parse-0.6.0 pypdf-5.3.0 striprtf-0.0.26

# %%
from llama_index.llms.azure_openai import AzureOpenAI
from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.core.llms import ChatMessage

import logging
import sys

api_key = os.getenv("OPENAI_API_KEY")
azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
api_version = os.getenv("OPENAI_API_VERSION")

llm = AzureOpenAI(
    model="gpt-4o",
    deployment_name="AI-KMS-4o",
    api_key=api_key,
    azure_endpoint=azure_endpoint,
    api_version=api_version,
)

Settings.llm = llm
Settings.chunk_size = 512

# %%
#llm.chat({"type":"user", "input_value":"What is the capital of France?"})
#Error: Input should be a valid list [type=list_type, input_value={'type': 'user', 'input_v...the capital of France?'}, input_type=dict]
# correct input
response = llm.chat([
    ChatMessage(role="user", content="What is the capital of France?")
])

# %%
response
# Out:
# ChatResponse(message=ChatMessage(role=<MessageRole.ASSISTANT: 'assistant'>, additional_kwargs={}, blocks=[TextBlock(block_type='text', text='The capital of France is **Paris**.')]), raw=ChatCompletion(id='chatcmpl-AzMcXtYQTnfDU7Fl98yxdAhng1NMv', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The capital of France is **Paris**.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})], created=1739188325, model='gpt-4o-2024-11-20', object='chat.completion', service_tier=None, system_fingerprint='fp_f3927aa00d', usage=CompletionUsage(completion_tokens=9, prompt_tokens=14, total_tokens=23, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)), prompt_filter_results=[{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}]), delta=None, logprobs=None, additional_kwargs={'prompt_tokens': 14, 'completion_tokens': 9, 'total_tokens': 23})

# %%
from llama_index.core import SimpleDirectoryReader, KnowledgeGraphIndex
from llama_index.core.graph_stores import SimpleGraphStore

from llama_index.llms.openai import OpenAI
from llama_index.core import Settings
from IPython.display import Markdown, display

# %%
help(SimpleDirectoryReader.load_data)
# Out:
# Help on function load_data in module llama_index.core.readers.file.base:
#
# load_data(self, show_progress: 'bool' = False, num_workers: 'int | None' = None, fs: 'fsspec.AbstractFileSystem | None' = None) -> 'list[Document]'
#     Load data from the input directory.
#
#     Args:
#         show_progress (bool): Whether to show tqdm progress bars. Defaults to False.
#         num_workers  (Optional[int]): Number of workers to parallelize data-loading over.
#         fs (Optional[fsspec.AbstractFileSystem]): File system to use. If fs was specified
#             in the constructor, it will override the fs parameter here.
#
#     Returns:
#         List[Document]: A list of documents.

# %%
docs = SimpleDirectoryReader("../Hackapizza Dataset/Misc/").load_data()

# %%
docs
# Out:
# [Document(id_='b5392819-b26c-49fb-a3f7-7505c388c467', embedding=None, metadata={'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\dish_mapping.json', 'file_name': 'dish_mapping.json', 'file_type': 'application/json', 'file_size': 12993, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='{\r\n    "Alternate Realities Risotto": 0,\r\n    "Antipasto Celestiale": 1,\r\n    "Antipasto Stellare dell\'Eterna Armonia": 2,\r\n    "Armonia Cosmica alla Tavola d\'Oro": 3,\r\n    "Armonia Cosmica della Fenice": 4,\r\n    "Astro-Risotto alle Onde Temporali": 5,\r\n    "Aurora del Cosmo": 6,\r\n    "Bistecca Cacofonica dell\'Infinito": 7,\r\n    "Concordanza Cosmica": 8,\r\n    "Cosmic Harmony": 9,\r\n    "Cosmic Harmony Infusion": 10,\r\n    "Cosmic Harmony Risotto": 11,\r\n    "Cosmic Rhapsody": 12,\r\n    "Cosmic Serenade": 13,\r\n    "Cosmic Symphony di Ghiaccio e Fuoco": 14,\r\n    "Cosmic Synchrony: Il Destino di Pulsar": 15,\r\n    "Cosmo Sferico di Sogni Rigenerativi": 16,\r\n    "Cosmofantasia di Terra e Mare nel Vortice delle Stelle": 17,\r\n    "Cosmologia Terrestre: Viaggio in Otto Dimensioni": 18,\r\n    "Cosmopastico di Meraviglie Celesti": 19,\r\n    "Cosmopolis delle Galassie Perdute": 20,\r\n    "Cosmos Culinary Symphony": 21,\r\n    "Cosmos Quantum Fusion": 22,\r\n    "Cosmos Risotto Reale": 23,\r\n    "Cosmos in Tavola": 24,\r\n    "Creazione Celestiale: L\'Alba del Cosmo": 25,\r\n    "Crescendo Cosmico": 26,\r\n    "Danza Cosmica al Crepuscolo": 27,\r\n    "Danza Luminosa del Multiverso": 28,\r\n    "Delizia Astrale all\'Essenza del Multiverso": 29,\r\n    "Dimensioni del Mare Stellato": 30,\r\n    "Dimensioni di Sapori Infusi": 31,\r\n    "Echi del Cosmo": 32,\r\n    "Echi del Mare Eterno": 33,\r\n    "Eclissi Armonica di Sapori": 34,\r\n    "Eclissi Quantica: Viaggio nei Reami del Gusto": 35,\r\n    "Eclissi del Drago nell\'Abbraccio del Kraken": 36,\r\n    "Ecosistema Celeste": 37,\r\n    "Enigma Celeste": 38,\r\n    "Entropia Eterna": 39,\r\n    "Essenze dell\'Infinito": 40,\r\n    "Eterea Sinfonia di Gravit\\u00e0 con Infusione Temporale": 41,\r\n    "Etereo Crepuscolare": 42,\r\n    "Eterna Sinfonia del Cosmo": 43,\r\n    "Ethereal Temporal Elixir": 44,\r\n    "Euforia Cosmica": 45,\r\n    "Evanescenza Cosmica": 46,\r\n    "Evanescenza Quantica": 47,\r\n    "Falso Risotto dell\'Infinito Multiverso": 48,\r\n    "Fenice Galattica": 49,\r\n    "Fenice sull\'Orizzonte degli Eventi": 50,\r\n    "Fusione Celeste": 51,\r\n    "Galassia Ardente": 52,\r\n    "Galassia Aurorale": 53,\r\n    "Galassia Commovente di Stellari": 54,\r\n    "Galassia Incantata: Un Viaggio Attraverso l\'Infinito": 55,\r\n    "Galassia Infinita: Viaggio tra Memorie e Stelle": 56,\r\n    "Galassia Riflessa": 57,\r\n    "Galassia Rinascente": 58,\r\n    "Galassia Risvegliata": 59,\r\n    "Galassia Sensoriale": 60,\r\n    "Galassia Speculare": 61,\r\n    "Galassia Suprema": 62,\r\n    "Galassia a Tavola: Sinfonia di Tempeste Cosmiche": 63,\r\n    "Galassia d\'Aromi Perduti": 64,\r\n    "Galassia di Celestial Delight": 65,\r\n    "Galassia di Cosmo-Delizie": 66,\r\n    "Galassia di Fusilli Sferici alla Risonanza Crononica": 67,\r\n    "Galassia di Sapore": 68,\r\n    "Galassia di Sapore Interdimensionale": 69,\r\n    "Galassia di Sapore Interstellare": 70,\r\n    "Galassia di Sapore Quantico": 71,\r\n    "Galassia di Sapore Quantum": 72,\r\n    "Galassia di Sapori": 73,\r\n    "Galassia di Sapori Eterei": 74,\r\n    "Galassia di Sapori Interstellari": 75,\r\n ...
#  Document(id_='fd38c42a-63e1-4cea-8454-23a8662c9684', embedding=None, metadata={'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Distanze.csv', 'file_name': 'Distanze.csv', 'file_type': 'application/vnd.ms-excel', 'file_size': 557, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Tatooine, 0, 695, 641, 109, 661, 1130, 344, 835, 731, 530\nAsgard, 695, 0, 550, 781, 188, 473, 493, 156, 240, 479\nNamecc, 641, 550, 0, 651, 367, 987, 728, 688, 767, 845\nArrakis, 109, 781, 651, 0, 727, 1227, 454, 926, 834, 640\nKrypton, 661, 188, 367, 727, 0, 626, 557, 321, 422, 599\nPandora, 1130, 473, 987, 1227, 626, 0, 847, 317, 413, 731\nCybertron, 344, 493, 728, 454, 557, 847, 0, 594, 434, 186\nEgo, 835, 156, 688, 926, 321, 317, 594, 0, 215, 532\nMontressosr, 731, 240, 767, 834, 422, 413, 434, 215, 0, 331\nKlyntar, 530, 479, 845, 640, 599, 731, 186, 532, 331, 0', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='8ff9018f-a74d-4550-9ff5-c312e5167143', embedding=None, metadata={'page_label': '1', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Introduzione\nIo sono il grande Sirius Cosmo, lo chef stellare per eccellenza. Se non mi conoscete ancora, preparatevi:\nil mio nome è sinonimo di cucina galattica. In questo manuale vi insegnerò tutto quello che serve per\ndiventare veri cuochi, da Alpha Centauri fino alla Nebulosa del Granchio (dove, a proposito, non hanno\nneanche un crostaceo decente). Impareremo insieme le licenze e le abilità fondamentali per cucinare\nnello spazio senza mandare in tilt lʼintero sistema di supporto vitale della nave — perché diciamocelo, un\nbuon brasato non vale una depressurizzazione dʼemergenza.\nVi guiderò passo passo tra tecniche di cucina gravitazionali, segreti per friggere senza far esplodere la\ncabina e trucchi per ottenere il perfetto soufflé orbitale.\nSpoiler: Sì, si può montare una maionese in assenza di gravità — basta avere il giusto polso e un poʼ di\npazienza, cose che non si insegnano nei manuali tecnici ma che io, Sirius Cosmo, sono qui per\ntrasmettervi.\nPronti a decollare? Mettete il grembiule, astronauti del sapore: si parte per un viaggio culinario!\nCapitolo 1: Abilità e Licenze Richieste\nPrima di iniziare a cucinare nello spazio, è fondamentale ottenere le giuste autorizzazioni e raggiungere le\ngiuste abilità. Non ci si può semplicemente mettere ai fornelli gravitazionali senza essere certificati: ci\nsono normative severe che regolano ogni fase della preparazione e gestione del cibo a bordo di una nave\nspaziale. Ovviamente, non ho mai cucinato senza la giusta licenza (non lo farei mai per nessun motivo).\nVediamo insieme le principali categorie e le relative licenze richieste.\nPsionica (P)\nLivello 0: Posseduta da tutti se non diversamente specificato. Tipica degli esseri senzienti.\nLivello I: lettura pensiero, telecinesi e teletrasporto di oggetti di massa inferiore a 5 kg,\nprecognizione e visione del passato fino a 5 minuti\nLivello II: manipolazione della probabilità, telecinesi e teletrasporto di oggetti di massa inferiore a\n20 kg, manipolazione delle forze fondamentali dellʼuniverso\nLivello III: capacità di donare la coscienza e lʼintelletto ad oggetti, manipolazione della realtà\ncircoscritta a stanze, teletrasporto senza errore in qualsiasi dimensione temporale, comunione con\nentità di altri piani\nLivello IV: proiezione astrale, riscrittura di realtà circoscritta a piccole nazioni o asteroidi\nLivello V: riscrittura di realtà di intere linee temporali o galassie. Questo livello è equivalente al\nGrado di influenza di livello tecnologico III (LTK III)\nTemporale (t)\nLivello I: effetti temporali relativi al presente come dilatazione o accelerazione del tempo\nLivello II: Livello I + effetti temporali che riguardano linee temporali future\nLivello III: Livello II + effetti temporali che riguardano linee temporali passate\nGravitazionale (G)', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='4a2fdb0c-3564-47eb-8dbf-482da4935531', embedding=None, metadata={'page_label': '2', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Livello 0: 5 < G ≤ 10, posseduta da tutti se non diversamente specificato\nLivello I: 0 < G ≤ 100\nLivello II: 0 < G ≤ 10^6\nLivello III: G > 10^6\nAntimateria (e+)\nLivello 0: particelle, posseduta da tutti se non diversamente specificato\nLivello I: antiparticelle\nMagnetica (Mx)\nLivello 0: Polo nord e sud, posseduta da tutti se non diversamente specificato\nLivello I: Mono-polo\nQuantistica (Q)\nLivello n: Numero di stati in superposizione dove n è il numero di stati\nLuce (c)\nLivello I: Solo colori primari (RGB)\nLivello II: Tutto lo spettro visibile umano\nLivello III: Tutte le frequenze\nLivello di Sviluppo Tecnologico (LTK)\nLivello I: Planetario\nLivello II: Sistema Stellare\nLivello III: Galassia\nLivello IV: Superamasso di Galassie\nLivello V: Intero Universo\nLivello VI: Universi multipli\nLivello VI+: Tutte le fonti energia\nCapitolo 2: Gli Ordini\nQui di seguito vi illustro i diversi ordini presenti nel nostro universo. FONDAMENTALE leggere.\n🪐  Ordine della Galassia di Andromeda\nCari pionieri del gusto cosmico, preparatevi a una sfida da veri fuoriclasse: cucinare per gli abitanti di\nAndromeda! Qui non parliamo solo di tecnica stellare, ma di pura diplomazia culinaria intergalattica. La\nparticolarità? Ogni piatto devʼessere rigorosamente privo di lattosio — non un goccio, nemmeno lʼombra\ndi una molecola originaria della Via Lattea. Se pensate che il formaggio sia lʼunica via per la felicità, è\ntempo di ripensare il vostro approccio. Imparerete a creare sapori complessi senza latte, burro o panna,\nconquistando palati alieni con alternative che sfidano le leggi della gastronomia universale.\n🌱  Ordine dei Naturalisti', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='4f1de363-c9af-432d-bd96-1f804137b97a', embedding=None, metadata={'page_label': '3', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Per gli adepti dellʼOrdine dei Naturalisti, la cucina è molto più che creatività: è un atto di riverenza verso\nla natura. Qui si celebra lʼessenza primordiale di ogni ingrediente, custodendone la purezza come un\nprezioso segreto galattico. Nessuna trasformazione drastica, niente manipolazioni invasive: solo il\n“Principio di Non Alterazione”. Questo significa che se una carota vuol essere una carota, dovrà restare\ntale, anche quando diventa arte culinaria. La sfida? Esaltare la semplicità con maestria, senza mai tradire\nlʼidentità autentica del cibo.\n🌈  Ordine degli Armonisti\nGli Armonisti sono più che semplici chef: sono veri maestri del flusso emozionale gastronomico. Il loro\ndono è trasformare il cibo in una sinfonia che risuona con lʼanima di chi lo assapora. Non si tratta solo di\nsapori, ma di vibrazioni sottili che si sintonizzano sullo stato dʼanimo degli ospiti. Un pranzo può calmare,\nispirare o persino risvegliare ricordi dimenticati. La missione? Creare piatti che parlano al cuore,\nadattandosi alle frequenze emotive del momento. Perché qui, il cibo non si gusta: si vive.\nCapitolo 3: Tecniche di Preparazione\nNel vasto universo della cucina spaziale, la preparazione è la chiave per ogni grande piatto. In questo\ncapitolo, esploreremo le tecniche che trasformano gli ingredienti da semplici materie prime a protagonisti\ndi un'esperienza culinaria stellare. Ogni passaggio è fondamentale per creare la base perfetta per la\ncottura. Preparatevi a scoprire come l'arte della preparazione, nel cosmo, richieda precisione e ingegno,\nma soprattutto visione.\nMarinatura\nLa marinatura spaziale è un'arte che sfrutta il tempo e lo spazio, dove ogni condimento si mescola in\nperfetta armonia con gli ingredienti. In assenza di gravità, le molecole si distribuiscono in modo unico,\namplificando sapori e aromi. Imparare a marinare nel vuoto cosmico è fondamentale per ottenere piatti\nche sfidano ogni legge della fisica culinaria, rivelando gusti straordinari in ogni morso.\nMarinatura a Infusione Gravitazionale\nCome funziona: il cibo è collocato in una camera a gravità alternata, che intensifica lʼassorbimento della\nmarinata nei tessuti alimentari.\nVantaggi: il sapore penetra in profondità per una marinatura uniforme e intensa.\nSvantaggi: necessita di un “Grav-Infuser” di alta precisione, con un dispendio energetico significativo.\nMarinatura Temporale Sincronizzata\nCome funziona: sfrutta una bolla temporale sincronizzata per accelerare il processo di marinatura,\ncomprimendo ore in minuti.\nVantaggi: marinatura completa in un tempo minimo, senza compromessi sulla qualità.\nSvantaggi: rischi di interferenze temporali minori; vietata per uso domestico senza supervisione.\nMarinatura Psionica", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='1b8f61bf-5f67-43af-9bc7-f86e166b6303', embedding=None, metadata={'page_label': '4', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Come funziona: uno chef telepate concentra la propria energia mentali per manipolare le molecole della\nmarinata, fondendole con l'alimento.\nVantaggi: sapori unici e personalizzati ottenuti attraverso la fusione creativa tra mente e ingredienti.\nSvantaggi: richiede chef con competenze psioniche avanzate\nMarinatura tramite Reazioni d'Antimateria Diluite\nCome funziona: micro-quantità di antimateria generano reazioni controllate che ionizzano la marinata,\nincrementando lʼassorbimento attraverso la tensione superficiale.\nVantaggi: penetrazione rapida della marinata anche negli alimenti più densi, con un caratteristico\nretrogusto “cosmico”.\nSvantaggi: manipolazione rischiosa che richiede per legge ambienti protetti.\nMarinatura Sotto Zero a Polarità Inversa\nCome funziona: gli alimenti sono immersi in soluzioni marinate a temperatura sub-critica, mentre una\npolarità magnetica inversa aiuta lʼassorbimento dei sapori.\nVantaggi: conserva al massimo i profumi e le caratteristiche volatili della marinata.\nSvantaggi: richiede tecnologia avanzata per regolare con precisione le condizioni polari.\nAffumicatura\nL'affumicatura è una tecnica che va ben oltre la semplice espressione di fumo. Qui, lʼarte di infondere\nsapore sfrutta il vuoto cosmico per distribuire il fumo in modo uniforme e affascinante, regalando ai piatti\nun aroma profondo che si espande in modo inaspettato. La gestione della temperatura e del flusso di\nfumo è fondamentale per ottenere un affumicato perfetto, che aggiunga una dimensione nuova e\nsorprendente a ogni ingrediente, senza alterarne la qualità. Un processo che, se eseguito correttamente,\nporta il cibo a nuove vette di complessità e intensità.\nAffumicatura a Stratificazione Quantica\nCome funziona: il cibo viene posizionato in una camera che alterna strati quantici, permettendo a\nparticelle di fumo quantisticamente compresse di penetrare attraverso i livelli molecolari dell'alimento.\nVantaggi: penetrazione uniforme del sapore affumicato, con un aroma che sembra provenire dall'interno\ndell'alimento stesso. Svantaggi: può causare una leggera variazione del sapore se non calibrato con\nprecisione, rendendo l'affumicatura imprevedibile senza un operatore esperto.\nAffumicatura Temporale Risonante\nCome funziona: sfrutta la risonanza temporale per infondere i sapori del fumo nel cibo attraverso onde\ncroniche, condensando anni di affumicatura in pochi istanti.\nVantaggi: sapore profondo e complesso, ottenuto in modo efficace e veloce.\nSvantaggi: necessita di apparecchiature sofisticate per il controllo delle onde croniche, con potenziali\nrischi di disallineamento temporale.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='5c838fcb-6052-420f-9a14-20931d9609c3', embedding=None, metadata={'page_label': '5', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Affumicatura Psionica Sensoriale\nCome funziona: uno chef telepate genera un campo psionico sensoriale che simula lʼeffetto del fumo\ncon la mente e attiva i recettori gustativi in modo mirato.\nVantaggi: sapore affumicato personalizzato e adattabile ai gusti individuali.\nSvantaggi: richiede esperti psionici capaci di mantenere l'integrità sensoriale durante il processo.\nAffumicatura tramite Big Bang Microcosmico\nCome funziona: una minima quantità di energia simula un piccolo big bang, creando particelle\nsubatomiche di fumo che si fondono con lʼalimento a livello nucleare.\nVantaggi: intensità di sapore senza eguali, con un caratteristico tocco “universale”.\nSvantaggi: operazione estremamente rischiosa, eseguibile solo in ambienti altamente controllati.\nAffumicatura Polarizzata a Freddo Iperbarico\nCome funziona: lʼalimento è posto in ambienti iperbarici a bassissima temperatura dove flussi di fumo\nvengono polarizzati per attrarre molecole d'aroma all'interno del cibo.\nVantaggi: sapore affumicato ricco e ben conservato, che preserva anche le note aromatiche più delicate.\nSvantaggi: Nessuna in particolare\nFermentazione\nLa fermentazione galattica è una danza di batteri e microrganismi che trasformano gli ingredienti in\nprelibatezze inaspettate. Nel profondo dello spazio, dove l'ossigeno è limitato, questi piccoli fermenti\nlavorano con la stessa precisione di un orologio stellare. Conoscere la fermentazione significa aprire la\nporta a sapori complessi e sorprendenti, che si evolvono in modi che solo l'universo potrebbe ispirare.\nFermentazione Quantica a Strati Multiversali\nCome funziona: il cibo viene posizionato in un dispositivo di fermentazione che sfrutta strati quantici\nprovenienti da diversi universi paralleli, facilitando l'interazione di enzimi transdimensionali con la materia\norganica.\nVantaggi: fermentazione rapida ed efficiente, con la possibilità di ottenere sapori unici e mai\nsperimentati nel nostro universo.\nSvantaggi: richiede calibrazioni precise per evitare l'ingresso di invasioni aliene da altri universi.\nFermentazione Temporale Sincronizzata\nCome funziona: utilizza flussi di tempo sincronizzati per accelerare o rallentare il processo fermentativo,\nmodificando la percezione temporale degli ingredienti per ottenere immediatamente maturità e\ncomplessità dei sapori.\nVantaggi: riduce drasticamente i tempi tradizionali di fermentazione pur mantenendo profili aromatici\nprofondi.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='a6352aad-1ff8-4422-8686-86768cf5efae', embedding=None, metadata={'page_label': '6', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Svantaggi: richiede una tecnologia avanzata di controllo temporale con possibilità di instabilità\ncronologica.\nFermentazione Psionica Energetica\nCome funziona: uno chef telepate concentra campi energetici psionici per guidare e migliorare il\nprocesso naturale di fermentazione, manipolando gli enzimi grazie al potere del pensiero.\nVantaggi: personalizzazione estrema dei sapori e dei profili aromatici in base alle preferenze individuali\ndellʼutente.\nSvantaggi: esige lʼabilità rarefatta di esperti psionici per evitare squilibri gustativi.\nFermentazione tramite Singolarità\nCome funziona: sfrutta le radiazioni di Hawking di una piccola singolarità quantum-confinata che\ncatalizza i processi fermentativi su scala molecolare\nVantaggi: crea intensi sapori e texture complesse mai viste prima, grazie all'influenza gravitazionale\nunica.\nSvantaggi: operazione altamente rischiosa, richiede controlli estremamente scrupolosi.\nFermentazione Quantico Biometrica\nCome funziona: gli ingredienti sono posti in ambienti sotto un elevato campo quantistico-metabolico\ndove una biometria avanzata regola i processi enzimatici per assicurare risultati costanti e prevedibili.\nVantaggi: mantiene la freschezza del prodotto finale con un gusto complesso ma ben equilibrato, adatto\nanche ai palati più fini.\nSvantaggi: Alcune volte i campi quantistici rischiano di distruggere la realtà attuale. Tuttavia lʼeffetto è\ntemporaneo, lʼunica precauzione è quella di tenere lontano dalla portata e vista delle donne incinta.\nTecniche di Impasto\nLʼimpasto richiede abilità e precisione, poiché la gravità zero cambia completamente il modo in cui\nlavoriamo farina, acqua e lievito. Che si tratti di una pasta perfetta o di un pane che cresce nel vuoto,\nlʼimpasto nello spazio è una questione di tempo e coordinazione. Ogni movimento deve essere calibrato\nper garantire la giusta consistenza e il giusto equilibrio, trasformando ogni impasto in una creazione che\nlievita più velocemente di una navetta interstellare.\nImpasto Gravitazionale Vorticoso\nCome funziona: utilizza campi gravitazionali artificialmente generati per creare vortici che mescolano gli\ningredienti in modo uniforme, sfruttando la rotazione a spirale per incorporare facilmente aria e umidità.\nVantaggi: raggiunge una consistenza perfetta e omogenea senza il rischio di sovraccarico meccanico;\nideale per impasti leggeri come soufflé e torte.\nSvantaggi: richiede unʼaccurata regolazione delle forze gravitazionali per evitare eruzioni improvvise di\nmateriale nell'ambiente di lavoro.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='a8aadceb-e46a-494c-900f-1adc4ab6af24', embedding=None, metadata={'page_label': '7', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Amalgamazione Sintetica Molecolare\nCome funziona: manipola direttamente le catene molecolari degli ingredienti attraverso catalizzatori\nsintetici, promuovendo la coesione spontanea e naturale dell'impasto.\nVantaggi: garantisce una perfetta fusione dei sapori e delle texture, permettendo esperimenti creativi\ncon nuovi tipi di farine e composti proteici.\nSvantaggi: esige la comprensione delle interazioni chimiche intricate; gli errori possono alterare\nirreversibilmente il gusto finale.\nImpasto a Campi Magnetici Dualistici\nCome funziona: sfrutta poli magnetici opposti per modellare vari strati di ingredienti, creando strutture\nlaminari straordinariamente sottili e accoppiate senza necessità fisica di pressione.\nVantaggi: ideale per preparazioni a strati complessi come i croissant, dove è richiesta una\ndifferenziazione di texture estremamente precisa.\nSvantaggi: controllare lʼintensità magnetica è cruciale; campi troppo potenti possono disintegrare\nl'impasto anziché comporlo.\nSinergia Elettro-Osmotica Programmabile\nCome funziona: questa tecnica avanza utilizza moduli elettro-osmotici che programmano sequenze\nprecise di innesto dei liquidi nei solidi, ottimizzando la distribuzione idrica nell'impasto.\nVantaggi: permette il controllo totale sullʼidratamento, prevenendo eccedenze dʼacqua o indesiderate\nsecchezze in impasti delicati come quelli della pasta fresca.\nSvantaggi: esige monitoraggio continuo dei parametri elettro-osmotici per mantenere la meraviglia tech\nsotto stretto controllo operativo.\nModellatura Onirica Tetrazionale\nCome funziona: ispirata ai misteriosi mondi al confine del sogno, questa tecnica consente agli\ningredienti di intessere tessiture nellʼeterea matrice cosmica tramite una sfera onirico-mistica in cui\ntempo e spazio fluttuano in narrativa fluida ed arcana.\nVantaggi: apre a creazioni culinarie dai sapori altrettanto effimeri quanto profondamente evocativi,\nimpossibili da replicare con mezzi convenzionali.\nSvantaggi: richiede manipolatori specializzati dellʼonirismo culinario capaci di fissare coscienze materiali\nsenza far smarrire gli elementi nelle dimensioni del subconscio.\nSurgelamento\nNel cosmo, il surgelamento non è solo un metodo di conservazione, ma una tecnica che sfrutta il gelo\nspaziale per bloccare i sapori nel loro stato migliore. Il congelamento permette di mantenere intatte\nfreschezza e qualità, creando piatti che sembrano appena usciti dal cuore di un pianeta lontano, pronti a\nstupire con ogni dettaglio perfettamente conservato.\nCryo-Tessitura Energetica Polarizzata", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='fef519c3-a5ca-446a-8dc0-2ec52d304ee3', embedding=None, metadata={'page_label': '8', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Come funziona: sfrutta campi energetici polarizzati per intrappolare il calore residuo e indurre un\nsurgelamento immediato, mantenendo la struttura molecolare degli alimenti intatta.\nVantaggi: consente un raffreddamento ultra-rapido che preserva perfettamente la freschezza dei sapori\ne le vitamine; ideale per frutta e verdura.\nSvantaggi: richiede una sincronizzazione esatta delle onde energetiche per prevenire la cristallizzazione\nindesiderata che potrebbe compromettere la texture.\nCongelamento Bio-Luminiscente Sincronico\nCome funziona: utilizza bioluminescenza naturale in combinazione con impulsi freddi, generando una\nmatrice congelante uniforme che avvolge ogni food element in un abbraccio brillante e scintillante.\nVantaggi: offre un surgelamento visivamente affascinante che mantiene intatti colore e gusto, senza\nricorrere a sostanze chimiche artificiali.\nSvantaggi: lʼimplementazione efficiente di questa tecnica richiede condizioni ambientali specifiche per\nevitare dispersioni luminose inefficaci.\nCristallizzazione Temporale Reversiva\nCome funziona: proietta gli alimenti attraverso un campo di distorsione temporale controllata, bloccando\nistanti di tempo nel ghiaccio senza alterare la realtà circostante.\nVantaggi: offre un congelamento ritardato inverso che preserva i nutrienti intatti come se il tempo non\nfosse passato, ideale per piatti preparati con anticipo.\nSvantaggi: deve monitorare attentamente i flussi temporali per evitare paradossi o collisioni temporali\nindesiderate.\nCongelazione Iperdimensionalmente Stratificata\nCome funziona: colloca gli alimenti in compartimenti multidimensionali dove ogni strato di consistenza\nviene congelato separatamente da flussi termodinamici indipendenti.\nVantaggi: permette una preservazione concentrica specifica che massimizza gli elementi gustativi dei\ncibi strutturati come mousse o dessert stratificati.\nSvantaggi: esige lʼuso di complessi algoritmi spatial-metric per garantire lʼequilibrio dimensionale\nnecessario.\nSurgelamento Antimaterico a Risonanza Inversa\nCome funziona: utilizza fluttuazioni controllate di antimateria per instaurare uno stato di superposizione\nrisonante che neutralizza energia termica a livello quantistico.\nVantaggi: conserva le qualità organolettiche al di là delle possibilità dei metodi tradizionali; applicabile a\ndelikatessen ultra-fini e prelibatezze delicate oltre confini spaziali ordinari.\nSvantaggi: manipolazioni sul filo dell'antimateria richiedono precauzioni estreme per evitare\ndisintegrazioni o cataclismi subatomici imprevedibili.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='d1d5adb6-c5b8-4401-ae6d-dac40bccb10a', embedding=None, metadata={'page_label': '9', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Capitolo 4: Tecniche di Cottura\nLa cottura è un campo dove la scienza e l'arte si incontrano in un perfetto equilibrio. Qui, le leggi della\nfisica possono essere tanto flessibili quanto il nostro approccio al calore e alla temperatura. In questo\ncapitolo, esploreremo le diverse tecniche di cottura, dal vapore al sottovuoto, dalla grigliatura alle\nmeraviglie della cottura al forno, adattate alle sfide uniche della gravità zero. Ogni metodo è progettato\nper ottenere piatti perfetti, mantenendo l'integrità degli ingredienti, ma spingendo le potenzialità del\ngusto e della consistenza verso nuove frontiere.\nBollitura\nLa bollitura è un'arte che va oltre l'acqua in ebollizione: è un processo di controllo preciso della\ntemperatura, che sfrutta l'assenza di gravità per ottenere risultati che sembrano impossibili sulla Terra.\nLa sfida è mantenere una temperatura costante e uniforme, riuscendo a cuocere ogni ingrediente al\npunto giusto, senza comprometterne sapore e consistenza. Unʼabilità fondamentale per ogni astronauta\ndel gusto.\nEbollizione Magneto-Cinetica Pulsante\nCome funziona: utilizza campi magnetici pulsanti che esaltano il movimento cinetico delle molecole\nd'acqua, generando un'ebollizione uniforme e controllata senza contatto diretto con la fonte di calore.\nVantaggi: assicura una distribuzione termica omogenea che preserva i sapori naturali degli ingredienti;\nideale per preparazioni delicate come infusi o brodi leggeri.\nSvantaggi: richiede un coordinamento preciso della frequenza dei campi magnetici per evitare\nturbolenze che potrebbero compromettere la consistenza.\nBollitura Infrasonica Armonizzata\nCome funziona: impiega onde sonore infrasoniche per eccitare risonanze molecolari nell'acqua,\ninducendo una bollitura ad elevata profondità sonora che infonde gli alimenti con vibrazioni nutrienti.\nVantaggi: produce un risultato aromatico particolarmente ricco che valorizza lʼessenza degli ingredienti\nsenza richiedere additivi esterni.\nSvantaggi: richiede ambienti schermati acusticamente per mantenere stabile la risonanza e prevenire\ninterferenze indesiderate.\nBollitura Termografica a Rotazione Veloce\nCome funziona: combina rotazioni rapide con mappature termografiche dinamiche per dirigere flussi di\ncalore concentrici, creando vortici di ebollizione che abbracciano il cibo in coreografie riscaldanti.\nVantaggi: permette una cottura precisa e scenografica, dove il controllo visivo del termogramma\ngarantisce risultati impeccabili anche per piatti complessi come zuppe dense o salse raffinate.\nSvantaggi: necessita di sensibili sistemi di rilevamento termico per mantenere lʼequilibrio vortex continuo\ned evitare zone di sovracottura.\nBollitura Entropica Sincronizzata", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='fc9fc131-6d2a-4809-b02e-fa3df261c035', embedding=None, metadata={'page_label': '10', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Come funziona: sincronizza flussi entropici modulati che manipolano il disordine a livello atomico\ngenerando microscopiche sacche di ebollizione progressiva in sequenza temporale calibrata.\nVantaggi: offre una metodologia rivoluzionaria che cucina a livelli subatomici preservando perfettamente\nle qualità nutritive; applicabile a pietanze ad alta quota o ambienti a pressione variabile.\nSvantaggi: richiede continua analisi entropica per monitorare variazioni reattive e prevenire collassi\nstrutturali.\nIdro-Cristallizzazione Sonora Quantistica\nCome funziona: integra impulsi sonori quantistici nei vapori dʼacqua per orchestrare reticoli cristallini\nche avvolgono ogni molecola culinaria in unʼarmoniosa danza bollente.\nVantaggi: conserva la consistenza ottimale anche negli elementi più delicati; adattabile alla creazione\nd'innovativi piatti gourmet che sfidano la tradizionale concezione della bollitura.\nSvantaggi: richiede sofisticate apparecchiature sincronizzate capillarmente al soundscape quantistico\nper evitare dissonanze destabilizzanti.\nGrigliare\nGrigliare nello spazio non è solo un atto di cuocere: è un'esperienza che sfrutta il calore radiante delle\nstelle o l'intensità dei campi elettromagnetici. Il risultato è un piatto perfettamente arrostito, con una\ncrosticina che cattura il meglio di ogni ingrediente, senza mai compromettere il cuore del sapore.\nGrigliatura spaziale significa ottenere il massimo dal calore, sia che provenga da un fornello ionico o da\nuna stella in fusione.\nGrigliatura a Energia Stellare DiV\nCome funziona: utilizza energia raccolta e incanalata direttamente da una stella di Tipo G tramite\nstrutture di Dyson a livello planetario, convertendo la potenza cosmica in calore grigliato su scala\nsubatomica.\nVantaggi: garantisce una cottura uniforme con un'energia immensa che esalta simultaneamente ogni\nsfumatura organolettica; perfetto per carni spesse e tagli pregiati senza alterare le loro proprietà\nintrinseche.\nSvantaggi: richiede un'infrastruttura avanzata e il controllo astrofisico per prevenire fluttuazioni termiche\nimpreviste generate dalla variabilità stellare.\nGrigliatura Plasma Sintetico Risonante\nCome funziona: impiega reti di plasma sintetico che emettono frequenze risonanti capaci di interagire\ncon la struttura molecolare degli alimenti, generando un calore profondo e penetrante.\nVantaggi: permette una caramellizzazione perfetta delle superfici esterne mentre l'interno rimane\nsuccoso, ideale per pesce delicato e verdure croccanti.\nSvantaggi: necessita di camere di contenimento allo stato dellʼarte per mantenere stabile il plasma ed\nevitare dispersioni energetiche.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='4b835509-abb7-47ae-a256-73346a729e60', embedding=None, metadata={'page_label': '11', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Grigliatura Eletro-Molecolare a Spaziatura Variabile\nCome funziona: sfrutta matrici elettromagnetiche a spaziatura variabile per incapsulare gli ingredienti in\ncampi di energia compressa che grigliano uniformemente mediante modulazione direzionale del calore.\nVantaggi: consente una grigliatura mirata a strati multipli, rendendolo perfetto per composizioni culinarie\ncomplesse o gourmet stratificate come terrine o millefoglie salate.\nSvantaggi: richiede aggiornamenti costanti alle impostazioni dei campi per adattarsi ai diversi tipi di\ningredienti e strutture alimentari.\nGrigliatura Tachionica Refrattaria\nCome funziona: utilizza particelle tachioniche per trasferire energia attraverso zone infratemporali,\npermettendo una cottura dal futuro al passato in sincronia vibrante con l'attuale momento grigliatore.\nVantaggi: mantiene gli alimenti allo stato ottimale anche prima della cottura effettiva; rivoluzionaria per\nesperimenti avanguardistici in cucina temporale.\nSvantaggi: richiede complessi calcoli spazio-temporali per allineare con precisione i momenti paralleli ed\nevitare anomalie cronologiche.\nGrigliatura Psionica Dinamica Ritmica\nCome funziona: sfrutta energie psioniche attraverso il controllo mentale avanzato sincronizzato a onde\ncerebrali collettive, irradia concentrazioni focalizzate di calore su tele piezoelettriche adattive.\nVantaggi: crea una connessione armoniosa tra lʼenergia mentale e il processo di grigliatura, permettendo\nall'estro culinario intuitivo di dirigere la danza del fuoco all'istante; ideale per esperienze gastronomiche\nimmersive e personalizzate.\nSvantaggi: richiede individui altamente addestrati nell'utilizzo psionico e ambienti sereni che favoriscano\nconcentrazione indotta, oltre a evitare distrazioni mentali esterne che potrebbero compromettere i\nrisultati finali.\nForno\nCuocere nel forno è un'avventura termica che sfida ogni convenzione terrestre. Grazie a tecnologie\navanzate, il calore viene distribuito con una precisione che trasforma ogni piatto in un capolavoro. La\ncottura perfetta dipende dal controllo del tempo e della temperatura, due fattori cruciali per ottenere\nrisultati stellari in ogni creazione, dal pane alle pietanze più complesse.\nCottura al Forno con Paradosso Temporale Cronospeculare\nCome funziona: manipola anomalie temporali utilizzando riflessi temporanei per creare un ciclo infinito di\ncalore tra passato e futuro, consentendo una cottura perfetta in ogni istante cronologico.\nVantaggi: assicura che i dolci e le torte raggiungano la consistenza ideale sia all'interno che all'esterno,\npoiché il tempo stesso diventa un ingrediente che raffina sapori e texture; perfetto per creazioni come\nsoufflé e crostate complesse.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='066a44a7-a70d-4e72-9ac2-23143847e231', embedding=None, metadata={'page_label': '12', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Svantaggi: necessita di algoritmi temporali di precisione per evitare deviazioni fra i flussi cronologici,\nriducendo il rischio di loop paradossali che potrebbero alterare il risultato finale.\nCottura al Forno con Paradosso Temporale Cronospeculare\nCome funziona: manipola anomalie temporali utilizzando riflessi temporali per creare un ciclo infinito di\ncalore tra futuro e passato, permettendo una cottura perfetta in ogni attimo cronologico.\nVantaggi: assicura che i pani e pizze raggiungano la consistenza ideale sia all'interno che all'esterno,\npoiché il tempo stesso diventa un ingrediente che raffina sapori e texture; perfetto per creazioni come\nbrioche e calzoni semplici.\nSvantaggi: necessita di algoritmi temporali di precisione per evitare deviazioni fra i flussi cronologici,\nriducendo il rischio di loop paradossali che potrebbero alterare il risultato finale.\nCottura con Microonde Entropiche Sincronizzate\nCome funziona: utilizza microonde entropiche che modulano l'energia in armonia con le strutture\nmolecolari dei cibi, trasmettendo calore profondo che completa l'interazione termica con una rapidità\nsorprendente.\nVantaggi: garantisce una doratura omogenea delle superfici esterne mantenendo l'umidità interna\nintatta; ideale per pasticceria croccante e focacce multisemi.\nSvantaggi: richiede un bilanciamento meticoloso tra frequenze entropiche per evitare sovraccarichi\ntermici locali e dispersioni energetiche.\nCottura a Forno Dinamico Inversionale\nCome funziona: impiega forni capaci di invertire campi termici attraverso valvolazioni multidirezionali,\nadattandosi alle esigenze specifiche della ricetta tramite variazioni ioniche controllate.\nVantaggi: consente stratificazioni precise del calore per piatti complessi come lasagne a più livelli o pane\nmultistrato, esaltando singolarmente ogni elemento compositivo.\nSvantaggi: esige regolazioni continue delle impostazioni di valvolazione per rispondere efficacemente\nalla natura variabile degli ingredienti.\nCottura Olografica Quantum Fluttuante\nCome funziona: sfrutta proiezioni olografiche quantistiche per simulare ambienti cotturieri\npersonalizzati, generando calore elevato tramite residenze energetiche precise nel reticolo molecolare\nalimentare.\nVantaggi: offre versatilità infinita nella cottura dei cibi grazie a ambienti personalizzabili virtualmente;\nottimo per cucine molecolari celebrate o fusioni azzardate di tradizioni culinarie diverse.\nSvantaggi: richiede software sofisticati per modellare correttamente gli spazi olografici e prevenire\ninterferenze ambientali esterne.\nCottura Geomagnetica Psicosincronizzata", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
# ...
#  Document(id_='550c4208-f932-42ae-a9b2-1a116ae0447f', embedding=None, metadata={'page_label': '17', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Nel cuore della cucina, le tecniche avanzate sono quelle che separano i cuochi stellari dai semplici\nastronauti del sapore. In questo capitolo, esploreremo tecniche sofisticate come la decostruzione, la\nsferificazione e l'affumicatura spaziale, che richiedono abilità, creatività e una perfetta comprensione\ndelle leggi fisiche che regolano l'universo. Queste tecniche avanzate sono per chi ha già padroneggiato le\nbasi e ora desidera spingersi oltre, alla ricerca di nuove dimensioni di sapore e innovazione. Preparatevi a\nentrare nel futuro della cucina spaziale, dove ogni piatto è una scoperta.\nDecostruzione\nLa decostruzione è l'arte di smontare un piatto e ricomporlo in modo inaspettato. Nello spazio, dove la\ngravitazione può rendere instabile la presentazione, ogni componente deve essere pensato come una\nparte di un puzzle galattico. Ogni elemento del piatto è trattato separatamente, per poi essere ricostruito\nin un'armonia che trascende la semplice ricetta, offrendo unʼesperienza sensoriale unica e sorprendente.\nDecostruzione Atomica a Strati Energetici\nCome funziona: il cibo viene suddiviso a livello atomico utilizzando campi energetici concentrati che\nridistribuiscono gli atomi su geometrie alimentari innovative, mantenendo i legami molecolari intatti\nmentre cambiano la struttura.\nVantaggi: permette la creazione di texture e forme impossibili con metodi tradizionali, offrendo\nun'esperienza culinaria unica.\nSvantaggi: le alte energie coinvolte richiedono un uso responsabile per evitare reazioni indesiderate\ncome esplosioni culinarie.\nDecostruzione Magnetica Risonante\nCome funziona: utilizza campi magnetici a frequenze risonanti che separano e ricombinano i\ncomponenti del cibo attraverso vibrazioni microstrutturali, consentendo una dissezione granulare e\nprecisa.\nVantaggi: precisione estrema in ogni elemento sapore e consistenza, permettendo variazioni sottili ma\nsignificative per piatti sensorialmente armonizzati.\nSvantaggi: richiede una strumentazione complessa ed è sensibile ai disturbi elettromagnetici esterni.\nDecostruzione Bio-Fotonica Emotiva\nCome funziona: combinando biofotoni emessi dalle cellule alimentari con lʼinfluenza delle emozioni, si\nopera unʼanalisi destrutturante basata sullo stato emotivo del cliente.\nVantaggi: personalizzazione emotiva dei piatti, creando connessioni profonde tra l'esperienza gustativa\ne lo stato dʼanimo dei commensali.\nSvantaggi: richiede chef dotati di competenze empatiche elevate per guidare correttamente il processo\nsenza perdere coerenza gustativa.\nDecostruzione Ancestrale\nCome funziona: risveglia le essenze perdute dei cibi usando le memorie storiche degli antenati del\ncliente, ricontestualizzando sapori dimenticati lungo linee temporali passate.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='82802e79-2133-430d-8d78-9d4247cc54d1', embedding=None, metadata={'page_label': '18', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Vantaggi: fornisce accesso a sapori di epoche passate, riportando alla luce tradizioni culinarie\nscomparse.\nSvantaggi: ricordare le memorie ancestrali può provocare perdita della propria identità, si consiglia,\nsebbene non necessario, di avere un ancora emotiva vicino.\nDecostruzione Interdimensionale Lovecraftiana\nCome funziona: sfrutta aperture interdimensionali verso realtà oscure e oniriche, ispirate ai miti di\nCthulhu, per attirare frammenti elementali dai regni oltre il nostro concepimento umano nella de-\nstrutturazione degli ingredienti.\nVantaggi: produce profili gustativi alieni e inaspettati che evocano il terrore inconcepibile\ndell'indescrivibile.\nSvantaggi: ę̵͉͈̓̈̅̈l̶̜̮̥̠̉͐̀͝e̷̢͓̜̬̎̊̄v̵͇̻̲͗͛͂̾a̷̠̟̪̅̇t̵͕̂̈́̍̎̒\nõ̶̧͈̠ ̸̗͓͚̤̲̔͂͌ r̸̺̕ i̵̮̫͠s̴̯̅̏c̸̝̟̲̙̈̍͒̆h̵̦̭̠͑̅̈i̵̡͉͓̼͗̔́̋o̵͚͌̔ ̸̘̫͇̻̈́̋̅d̴̼͒̉̆i̸̬̰̜̞͑̚ ̷̛̞͛m̸̰͛a̸̙̱̺͇̒n̸̟͎̩̓̏̏͗̅i̴͉̺͍̝͓\n͂̑͆͂͑f̶̢̦͙͖͆̋̄͛͘e̵̼̥̞̟̅̍̅ ͝s̸̬̟̩ ͠t̷̘̀̿̇͂͌ȧ̴̩̻͇̘\n̓̃͛̑z̶̜̙̥͋ ̕͜į̶̪̺̇͜ͅọ̵̣͇͎̰͒͌̆ n̴̺̬̓̈̓ i̴̢̥͕͐̊ ̴̝̪͇̱̬̈́̑̍͌̄i̴̬͓̱̐͝n̴̟̻̬̐n̴̯̯͍̝̭͒͂̄å̶̤͎ ͜͝t̵͕͇̫̰͕\n̆͒̎u̸͎̰͆̇̑̏̈́r̵̉̏̄̃͝ͅa̵̭͕̩̯̍ ͜͝l̷̅̈͐̇ͅḯ̵͚̗͎̙\n̅̚ ̸͕̠̍̚e̶̗̜̙̮̒̒͂ ͜ ̷̥̫̟͚͆̂͋͝c̷̦̠͕̹̓̅́̎ ͝o̷̦̦͗̊͌̚ŗ̴̟̬͙͍\n̎̋̀r̸͎̰͕̜̒̚͘ ͜u̸͔̫͕̬̪\n͑̐̆̈z̵̨̢͇̫̎͑i̸͍͍̙̓́͂͝ọ̶̀ͅǹ̴̝̇͛ ẽ̷̙̀  ̶͈͎̲̀̃̚ d̵̘̱̺̟̄̂̆͝e̴̞̱̓ ļ̵͛̌̑ ḻ̷̭̙̑̋ a̴̯͋ ̸̳̼̱̽͝p̷͙͙̯̐̎̉ȩ̷̭͍̈ṙ̶͇̖̇̇͑c̶͙̥̾͑̍ë̵͙̪͚̌̒ẕ̵̢̢̃͆̾̋̈í̶̼̹̺̿́̓̇ő̶͙̳͓͈̟\n͋̀n̷̯͑́́̓ͅȩ̴̛̤͓̬̣͌͌ ̴̼̥̑͋͋̒͜ d̸̦̩̩̉ ḙ̸̞̟͎̲\n͑͂l̷̢̤̫̩̺̉̅͆l̴̘̱̲̑̽͘ ͝a̷͓̖͖̋̓ ͝͝ ̸͔̠̦̹͆̐̿̒r̴̤̦̲̻̱͂͗̎ê̸̠̽̀́ ͠ḁ̶̬̻̣̳̑̑l̶͔̯̹͎̜\n̾̔͠t̶̘͎͋̈́̆̚͠à̴̤͈̎͗;̸͚͑̿\n̶̻͎̓ṟ̴͚͘ạ̶̐̋͑̄c̸̡̣̿c̷̀̈͗͑ͅo̸͙̗̗̮̯\n̒̃̉m̵͖̩̣̈́̋ ̕ a̴̞̟̓̏ ñ̸̡̤̳̌͌̚d̸̘̫̎̅̏̚͜ͅā̶͚̟̙̤̫\n̎t̴̗͚̆͐ȏ̸̲̭̼̩͆̌́ͅ ̶̹͂͗͋̏̚͜s̵̟̘̅̋̈͐o̴͉ ͝l̶̡̨̻͔̲̈͠ó̵̹͔͐ ͜͝ ̴̣͐̎̕͝p̴̱̬̽́̍̒͗e̸̮͋͑ŗ̸̣̤̮̘̔͂́̌͠  ̸̘̓ e̵̦̲̝͗ŝ̶̥̮̩p̴̖̰̪̅͘e̴̢͈͗̌ ̕r̴̯͇̟͔̔́̌̍ẗ̶̛̥̲͒̿i̸̫͗ ̵͚́̈́̅è̸͇̲̿͑̇͌s̴͇͕̤̊̌̈́o̸̘̬͐́̾́̚͜t̶̜̘̻̦̂͗̓̓e̵̩͋ ̕r̵̡̤̣̹̾̏́î̵̠̔̂c̶̛̣̝̳̀ ͠í̵̢̍̐ ̸͚̝̬̟̪̌̐á̸̳̽́̓̉d̸̥̙̍̾̽e̷̛̞͇̥͆͒̈ ͜p̶̺̰͚͇̼\n̊̎t̶̹̥͔͌̽į̶̡̗͔̿͝ ̸̮̦͉̼̈́ņ̷̗̹̤̝̇̌̄e̵̹͊́͌̿ ḻ̷́ l̶̫̞͓͈\n̓͌͜͝e̶̤̊̌ ͜ ̸̧͖͍͖̏̄̕͝a̸̢͇̫̖͋ṙ̸̖̖͜ͅt̶͔̻̘͑̋i̷̛̼͋̀́̈́\n  ̴̪̏̆̊ a̷̢̲̮̻ ̕r̸̨̻͖̭̄c̵̦̮̪͍̈́͑̀̾̚a̵͆ ͝ͅn̸͖͕̞̘̫\n̋̄̌e̵̜̰̝̲͖\n̿̓̌ ͝ ̵̫̃̔͝p̵̨̘͕̱̺̎̊̊̋͑r̷̜̻̺̉͂͌͝ǫ̴͔̥̿̊̈͌f̵̝̥̗̬̹\n͆̏o̷̢̼̳͛n̵͉͍̥̠̲̈́̀̿̄̀d̵̢̡͍̖̼́͊̈́̉̚e̶̹̭͕̥͕\n͝.̶̹̪̉̽̈́͐\n̕\nSferificazione\nLa sferificazione porta la cucina in una dimensione oltre la semplice chimica. Creare sfere di sapore in\nassenza di gravità richiede precisione, tecnica e una conoscenza avanzata delle reazioni chimiche tra\nliquidi e gelificanti. Nel vuoto cosmico, queste piccole perle esplodono in bocca, rivelando sapori intensi\ne sorprendenti che sembrano provenire da un altro universo.\nSferificazione a Gravità Psionica Variabile\nCome funziona: un telepate sospende gli ingredienti in un campo a gravità variabile per poi modulare la\nforza gravitazionale per manipolare le tensioni superficiali dei liquidi, formando sfere perfette.\nVantaggi: consente la creazione di sfere con consistenze e diametri personalizzati, dal micro al macro,\nsenza mai comprometterne l'integrità.\nSvantaggi: necessita di un controllo preciso della gravità per evitare deformazioni o collassi delle sfere.\nSferificazione Filamentare a Molecole Vibrazionali\nCome funziona: si utilizzano filamenti vibrazionali microscopici che allineano le molecole dei liquidi in\nschemi geometrici intricati prima di solidificarsi in forma sferica.\nVantag ...
#  Document(id_='fa495800-8000-48b5-a747-1a774422a75f', embedding=None, metadata={'page_label': '19', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Svantaggi: una mancata sincronizzazione tra i piani potrebbe risultare in instabilità strutturali delle sfere.\nSferificazione con Campi Magnetici Entropici\nCome funziona: campi magnetici specificamente configurati generano entropie controllate nei liquidi,\ncreando sfere attraverso flussi caotici che si auto-raccolgono.\nVantaggi: produce sfere con variazioni naturali nella texture, ideale per esperienze culinarie dinamiche e\nsempre cangianti.\nSvantaggi: gestione complessa del campo magnetico per prevenire effetti collaterali imprevedibili negli\ningredienti circostanti.\nSferificazione tramite Matrici Biofotiche\nCome funziona: impiega matrici biofotiche che assorbono luce ambientale per catalizzare reazioni di\nsferificazione nel fluido base, formando strutture luminescenti.\nVantaggi: le sfere brillano in modo sottile o intenso a seconda della luce assorbita, offrendo\nun'esperienza multisensoriale ai commensali.\nSvantaggi: richiede fonti luminose adeguate per ottimizzare il processo; un'illuminazione scorretta può\ncompromettere l'effetto luminescente finale.\nTecniche di Taglio\nIl taglio non è solo una questione di precisione: è un'abilità che va affinata per affrontare le sfide della\ngravità zero. Ogni ingrediente, dalla carne alle verdure, deve essere trattato con il giusto approccio per\nottenere fette e forme perfette. Il taglio spaziale implica tecnica, attenzione e il giusto angolo, poiché\nogni porzione deve essere equilibrata per una cottura perfetta e una presentazione galattica.\nTaglio Dimensionale a Lame Fotofiliche\nCome funziona: questo metodo utilizza lame composte da fasci fotonici compressi, capaci di tagliare\nattraverso la materia aprendo temporaneamente una breccia in dimensioni superiori.\nVantaggi: consente tagli incredibilmente precisi e puliti che non disturbano la struttura molecolare degli\nalimenti, mantenendo aromi e sapori intatti.\nSvantaggi: richiede un allineamento esatto delle dimensioni durante il taglio per evitare la dissezione\ninvolontaria di spazio-tempo.\nTaglio a Risonanza Sonica Rigenerativa\nCome funziona: emettitori sonori creano frequenze che separano delicatamente le tessiture cellulari\ndegli alimenti senza l'uso di strumenti fisici, facilitando un taglio netto.\nVantaggi: preserva la freschezza e le proprietà nutritive grazie alla riduzione dello stress meccanico sui\ntessuti alimentari.\nSvantaggi: è essenziale controllare l'intensità e la frequenza per evitare danni ai componenti più delicati\ndei cibi.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='ea744935-0261-41e3-9445-33d126135b58', embedding=None, metadata={'page_label': '20', 'file_name': 'Manuale di Cucina.pdf', 'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\Manuale di Cucina.pdf', 'file_type': 'application/pdf', 'file_size': 458127, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Affettamento a Pulsazioni Quantistiche\nCome funziona: si utilizzano pulsazioni quantistiche per manipolare i legami atomici, effettuando tagli\nche permettono una frammentazione controllata e precisa dei materiali.\nVantaggi: rende possibile la creazione di fette estremamente sottili senza compromettere la consistenza\ninterna.\nSvantaggi: richiede un'accurata calibrazione del campo quantico per evitare mutamenti imprevedibili\nnella struttura molecolare.\nTaglio Sinaptico Biomimetico\nCome funziona: questa tecnica sfrutta dispositivi biomimetici che imitano i processi naturali a livello\nsinaptico, traducendo segnali nervosi in azioni di taglio compatibili con ogni tipo di tessuto alimentare.\nVantaggi: offre un controllo intuitivo del processo di taglio attraverso interfacce neurali dirette,\naumentando l'efficienza operativa.\nSvantaggi: richiede formazione specializzata per sincronizzare perfettamente il dispositivo con il sistema\nnervoso dell'operatore.\nIncisione Elettromagnetica Plasmica\nCome funziona: questa tecnica avanzata utilizza bisturi plasmatici governati da campi elettromagnetici\nconcentrati per incidere gli alimenti con precisione e raffinatezza chirurgica.\nVantaggi: ideale per lavorazioni sofisticate e decorative su superfici alimentari complesse, esaltando\nl'estetica culinaria.\nSvantaggi: necessita di una fonte continua di energia plasmatica; malfunzionamenti energetici possono\nalterare l'integrità delle incisioni realizzate.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  ImageDocument(id_='561910a7-a75b-471f-930a-f995958f56df', embedding=None, metadata={'file_path': 'c:\\Users\\smancone\\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\\Desktop\\kaggle\\letspizza\\Hackapizza Dataset\\Misc\\pizzaverse.png', 'file_name': 'pizzaverse.png', 'file_type': 'image/png', 'file_size': 3964061, 'creation_date': '2025-02-09', 'last_modified_date': '2025-02-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='', path=None, url=None, mimetype=None), image_resource=MediaResource(embeddings=None, data=None, text=None, path=WindowsPath('c:/Users/smancone/OneDrive - BUSINESS INTEGRATION PARTNERS SPA/Desktop/kaggle/letspizza/Hackapizza Dataset/Misc/pizzaverse.png'), url=None, mimetype='image/png'), audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')]

# %%
from llama_index.core import StorageContext

graph_store = SimpleGraphStore()
storage_context = StorageContext.from_defaults(graph_store=graph_store)

# NOTE: can take a while!
index = KnowledgeGraphIndex.from_documents(
    docs,
    max_triplets_per_chunk=2,
    storage_context=storage_context,
)

# %%
dir(index)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_index_from_nodes',
#  '_callback_manager',
#  '_delete_node',
#  '_docstore',
#  '_embed_model',
#  '_extract_triplets',
#  '_graph_store',
#  '_index_struct',
#  '_insert',
#  '_is_protocol',
#  '_kg_triplet_extract_fn',
#  '_llm',
#  '_llm_extract_triplets',
#  '_max_object_length',
#  '_object_map',
#  '_parse_triplet_response',
#  '_show_progress',
#  '_storage_context',
#  '_transformations',
#  '_vector_store',
#  'add_node',
#  'as_chat_engine',
#  'as_query_engine',
#  'as_retriever',
#  'build_index_from_nodes',
#  'delete',
#  'delete_nodes',
#  'delete_ref_doc',
#  'docstore',
#  'from_documents',
#  'get_networkx_graph',
#  'graph_store',
#  'include_embeddings',
#  'index_id',
#  'index_struct',
#  'index_struct_cls',
#  'insert',
#  'insert_nodes',
#  'kg_triplet_extract_template',
#  'max_triplets_per_chunk',
#  'query_context',
#  'ref_doc_info',
#  'refresh',
#  'refresh_ref_docs',
#  'set_index_id',
#  'storage_context',
#  'summary',
#  'update',
#  'update_ref_doc',
#  'upsert_triplet',
#  'upsert_triplet_and_node']

# %%
index.graph_store.to_dict()
# Out:
# {'graph_dict': {'Alternate realities risotto': [['Has id', '0']],
#   'Cosmofantasia di terra e mare nel vortice delle stelle': [['Has id', '17']],
#   'Eclissi armonica di sapori': [['Has id', '34']],
#   "Fenice sull'orizzonte degli eventi": [['Has id', '50']],
#   'Galassia di fusilli sferici alla risonanza crononica': [['Has id', '67']],
#   'Galassia nel piatto: sinfonia universale di aromi e sapori': [['Has id',
#     '83']],
#   'Il risveglio del drago celeste': [['Has id', '96']],
#   'La balena sputafuoco': [['Has id', '112']],
#   'Nebulosa celestiale di sogni quantici': [['Has id', '128']],
#   'Odissea celestiale': [['Has id', '143']],
#   'Pizza gio': [['Has id', '160']],
#   'Pizza luca': [['Has id', '161']],
#   'Portale di sapori arcani': [['Has id', '175']],
#   'Sassi e sassolini': [['Has id', '190']],
#   "Sinfonia cosmica all'alba di fenice": [['Has id', '205']],
#   'Sinfonia cosmica ma fatta bene': [['Has id', '220']],
#   'Sinfonia interstellare di fusilli del vento con nettare di sirena': [['Has id',
#     '235']],
#   'Sinfonia dei ricordi celesti': [['Has id', '249']],
#   'Sinfonia di stagioni stellari': [['Has id', '265']],
#   'File_path': [['Is',
#     'C:\\users\\smancone\\onedrive - business integration partners spa\\desktop\\kaggle\\letspizza\\hackapizza dataset\\misc\\distanze.csv'],
#    ['Is',
#     'C:\\users\\smancone\\onedrive - business integration partners spa\\desktop\\kaggle\\letspizza\\hackapizza dataset\\misc\\pizzaverse.png']],
#   'Tatooine': [['Distance to', 'Asgard: 695']],
#   'Sirius cosmo': [['Is', 'Chef stellare']],
#   'Manuale': [['Insegna', 'Cucinare nello spazio']],
#   'Psionica': [['Possiede', 'Livello 0']],
#   'Livello i': [['Include', 'Lettura pensiero'],
#    ['Riguarda', 'Effetti temporali relativi al presente']],
#   'Livello iii': [['Riguarda',
#     'Effetti temporali che riguardano linee temporali passate']],
#   'Ordine della galassia di andromeda': [['Richiede',
#     'Piatti privi di lattosio'],
#    ['Cucinare per', 'Abitanti di andromeda']],
#   'Livello di sviluppo tecnologico': [['Include', 'Universi multipli']],
#   'Piatto': [["Dev'essere privo di", 'Lattosio']],
#   'Adepti': [['Celebrano', 'Essenza primordiale']],
#   'Armonisti': [['Trasformano', 'Cibo in sinfonia']],
#   'Marinatura spaziale': [['Amplifica', 'Sapori e aromi']],
#   'Cibo': [['Collocato in', 'Camera a gravità alternata'],
#    ['È collocato', 'Camera a gravità alternata'],
#    ['Suddiviso a livello', 'Atomico'],
#    ['Suddiviso a', 'Livello atomico']],
#   'Molecole': [['Si distribuiscono', 'Modo unico']],
#   'Chef telepate': [['Manipola', 'Molecole della marinata'],
#    ['Genera', 'Campo psionico sensoriale'],
#    ['Concentra', 'Campi energetici psionici']],
#   'Affumicatura': [['Sfrutta', 'Vuoto cosmico'], ['È', 'Tecnica']],
#   'Affumicatura temporale risonante': [['Sfrutta', 'Risonanza temporale'],
#    ['Sfrutta', 'Risonanza temporale'],
#    ['Infonde sapori', 'Cibo']],
#   'Energia': [['Simula', 'Piccolo big bang']],
#   'Affumicatura polarizzata a freddo iperbarico': [['Utilizza',
#     'Ambienti iperbarici']],
#   'Fermentazione quantica a strati multiversali': [['Sfrutta',
#     'Strati quantici']],
#   'Fermentazione': [['È', 'Rapida ed efficiente']],
#   'Fermentazione temporale sincronizzata': [['Utilizza',
#     'Flussi di tempo sincronizzati']],
#   'Fermentazione tramite singolarità': [['Sfrutta', 'Radiazioni di hawking']],
#   'Ingredienti': [['Posti in',
#     'Ambienti sotto elevato campo quantistico-metabolico'],
#    ['Acquisiscono', 'Qualità cromatiche']],
#   'Impasto gravitazionale vorticoso': [['Utilizza',
#     'Campi gravitazionali artificialmente generati'],
#    ['Utilizza', 'Campi gravitazionali artificiali'],
#    ['Crea', 'Vortici']],
#   'Amalgamazione sintetica molecolare': [['Manipola', 'Catene molecolari']],
#   'Impasto a campi magnetici dualistici': [['Sfrutta',
#     'Poli magnetici opposti']],
#   'Sinergia elettro-osmotica programmabile': [['Ottimizza',
#     'Distribuzione idrica']],
#   'Surgelamento': [['Sfrutta', 'Gelo spaziale'], ['Sfrutta', 'Gelo spaziale']],
#   'Congelamento': [['Mantiene', 'Freschezza e qualità']],
#   'Congelamento bio-luminiscente sincronico': [['Utilizza',
#     'Bioluminescenza naturale']],
#   'Cristallizzazione temporale reversiva': [['Proietta',
#     'Alimenti attraverso campo di distorsione temporale'],
#    ['Proietta', 'Alimenti']],
#   'Congelazione iperdimensionalmente stratificata': [['Colloca', 'Alimenti']],
#   'Surgelamento antimaterico a risonanza inversa': [['Utilizza',
#     'Fluttuazioni controllate di antimateria'],
#    ['Neutralizza', 'Energia termica']],
#   'Cottura': [['È', 'Campo']],
#   'Ebollizione magneto-cinetica pulsante': [['Utilizza',
#     'Campi magnetici pulsanti'],
#    ['Utilizza', 'Campi magnetici pulsanti']],
#   'Bollitura infrasonica armonizzata': [['Impiega',
#     'Onde sonore infrasoniche']],
#   'Bollitura termografica a rotazione veloce': [['Combina',
#     'Rotazioni rapide'],
#    ['Crea', 'Vortici di ebollizione']],
#   'Sincronizza flussi entropici': [['Manipolano',
#     'Disordine a livello atomico']],
#   'Grigliatura spaziale': [['Sfrutta', 'Calore radiante delle stelle'],
#    ['Sfrutta', 'Calore radiante delle stelle']],
#   'Grigliatura a energia stellare div': [['Utilizza',
#     'Energia raccolta da stella di tipo g']],
#   'Grigliatura plasma sintetico risonante': [['Impiega',
#     'Reti di plasma sintetico']],
#   'Reti di plasma sintetico': [['Emettono', 'Frequenze risonanti']],
#   'Grigliatura eletro-molecolare': [['Sfrutta', 'Matrici elettromagnetiche']],
#   'Grigliatura tachionica refrattaria': [['Utilizza',
#     'Particelle tachioniche']],
#   'Grigliatura psionica dinamica ritmica': [['Sfrutta', 'Energie psioniche']],
#   'Cottura al forno con paradosso temporale cronospeculare': [['Manipola',
#     'Anomalie temporali'],
#    ['Manipola', 'Anomalie temporali']],
#   'Forno': [['Distribuisce', 'Calore']],
#   'Cottura al forno': [['Manipola', 'Anomalie temporali']],
#   'Cottura con microonde entropiche sincronizzate': [['Utilizza',
#     'Microonde entropiche']],
#   'Microonde entropiche sincronizzate': [['Modulano', 'Energia']],
#   'Cottura olografica quantum fluttuante': [['Sfrutta',
#     'Proiezioni olografiche quantistiche'],
#    ['Sfrutta', 'Proiezioni olografiche quantistiche'],
#    ['Genera', 'Calore elevato']],
#   'Cuocere con vapore': [['Sfrutta', 'Energia termica']],
#   'Cottura a vapore': [['Preserva', 'Vitamine'], ['Preserva', 'Vitamine']],
#   'Controllo': [['È essenziale per', 'Cottura uniforme']],
#   'Cottura a vapore risonante simbiotico': [['Utilizza',
#     'Campi risonanti simbiotici']],
#   'Campi risonanti simbiotici': [['Interagiscono con', 'Proteine alimentari']],
#   'Cottura a vapore termocinetica multipla': [['Combina',
#     'Movimenti termocinetici simultanei']],
#   'Cottura idrodinamica autoregolante': [['Impiega',
#     'Sensori idrodinamici interni']],
#   'Sottovuoto': [['Permette', 'Isolare ingredienti']],
#   'Cottura sottovuoto antimateria': [['Impiega',
#     'Reazioni controllate di antimateria']],
#   'Cottura sottovuoto multirealità collassante': [['Sfrutta',
#     'Creazione temporanea di realtà parallele'],
#    ['Consente', 'Accesso a spettro infinito di combinazioni culinarie']],
#   'Cottura sottovuoto frugale': [['Utilizza', 'Fluttuazioni quantistiche']],
#   'Cottura sottovuoto pulsar magnetica': [['Utilizza',
#     'Campi magnetici pulsanti']],
#   'Cottura sottovuoto bioma sintetico': [['Crea',
#     'Ecosistema artificiale autoregolante']],
#   'Saltare in padella': [['Richiede',
#     'Equilibrio tra calore intenso e movimento rapido'],
#    ['È', 'Gioco di velocità e precisione']],
#   'Big bang termico': [['Sfrutta', 'Radiazione di fondo del big bang']],
#   'Saltare in padella realtà energetiche parallele': [['Raccoglie energia da',
#     'Infinite possibilità culinarie']],
#   'Saltare in padella singolarità inversa': [['Utilizza', 'Micro buco nero'],
#    ['Utilizza', 'Micro buco nero']],
#   'Saltare in padella sinergia psionica': [['Concentra',
#     'Energia mentale psionica']],
#   'Saltare in padella classica': [['Utilizza',
#     'Metodo tradizionale di riscaldamento'],
#    ['Consente', 'Cuochi di saltare ingredienti manualmente']],
#   'Decostruzione': [['È', 'Arte di smontare un piatto']],
#   'Campi energetici': [['Ridistribuiscono', 'Atomi']],
#   'Decostruzione bio-fotonica emotiva': [['Combina',
#     'Biofotoni emessi dalle cellule alimentari']],
#   'Decostruzione ancestrale': [['Risveglia', 'Essenze perdute dei cibi']],
#   'Decostruzione interdimensionale lovecraftiana': [['Sfrutta',
#     'Aperture interdimensionali']],
#   'Aperture interdimensionali': [['Ispirate a', 'Miti di cthulhu']],
#   'Page_label': [['Is', '18'], ['Is', '18'], ['Is', '18'], ['Is', '18']],
#   'Sferificazione': [['Porta', 'Cucina']],
#   'Telepate': [['Sospende', 'Ingredienti'], ['Sospende', 'Ingredienti']],
#   'Campi magnetici': [['Generano', 'Entropie controllate']],
#   'Matrici biofotiche': [['Assorbono', 'Luce ambientale']],
#   'Taglio dimensionale a lame fotofiliche': [['Utilizza',
#     'Lame composte da fasci fotonici compressi']],
#   'Taglio a risonanza sonica rigenerativa': [['Emettitori sonori creano',
#     'Frequenze che separano tessiture cellulari']],
#   'Affettamento a pulsazioni quantistiche': [['Utilizza',
#     'Pulsazioni quantistiche']],
#   'Taglio sinaptico biomimetico': [['Sfrutta', 'Dispositivi biomimetici']]}}
