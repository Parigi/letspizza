# %% [markdown]
# ## CONFIG

# %%
import pdfplumber
import re
import json
import os
import html
import PyPDF2
import pandas as pd
from bs4 import BeautifulSoup



from collections import Counter

from dotenv import load_dotenv
from neo4j import GraphDatabase
from py2neo import Graph, Node, Relationship
from langchain_openai import AzureChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from typing import List, Dict, Tuple

# %%
codice_galattico = "../Hackapizza Dataset/Codice Galattico/Codice Galattico.pdf"
manuale_cucina = "../Hackapizza Dataset/Misc/Manuale di Cucina.pdf"

domande = "../Hackapizza Dataset/domande.csv"
piatti = "../Hackapizza Dataset/Misc/dish_mapping.json"
pianeti = "../Hackapizza Dataset/Misc/Distanze.csv"

blog_1 = "../Hackapizza Dataset/Blogpost/blog_etere_del_gusto.html"
blog_2 = "../Hackapizza Dataset/Blogpost/blog_sapore_del_dune.html"


load_dotenv()
# Recupera endpoint e chiave dalle variabili d'ambiente
api_base = os.getenv("AZURE_OPENAI_API_BASE")
api_key = os.getenv("AZURE_OPENAI_API_KEY")

# neo4j first instance parameters
NEO4J_URI= "neo4j+s://0482640f.databases.neo4j.io"
NEO4J_USERNAME= "neo4j"
NEO4J_PASSWORD= "PNvdaZlk326-ja2hRD1K97ZUUMnD4mj0NsecZNu5-9k"
AURA_INSTANCEID= "0482640f"
AURA_INSTANCENAME= "Instance01"

driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %%
def crea_llm(api_key: str, api_base: str) -> AzureChatOpenAI:
    """
    Crea un'istanza del modello linguistico Azure OpenAI.
    
    Args:
        api_key (str): La chiave API di Azure
        api_base (str): L'URL base dell'API Azure
        
    Returns:
        AzureChatOpenAI: Istanza configurata del modello
    """
    return AzureChatOpenAI(
        openai_api_version="2024-08-01-preview",
        azure_deployment="o1-mini",
        azure_endpoint=api_base,
        api_key=api_key,
        temperature=1
    )

llm = crea_llm(api_key, api_base)

# %%
def estrai_testo_pdf(percorso_pdf):
    with open(percorso_pdf, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        testo = ""
        for pagina in reader.pages:
            testo += pagina.extract_text()
    return testo

def estrai_testo_html(percorso_html):
    """Estrae il testo da un file HTML."""
    with open(percorso_html, "r", encoding="utf-8") as file:
        soup = BeautifulSoup(file, "html.parser")
        return soup.get_text(separator=" ", strip=True)

# %% [markdown]
# ## METODI

# %%
def estrai_valorizzazioni(testo, categoria, llm, driver):
    """
    Estrae le valorizzazioni di entità di una specifica categoria dal testo,
    assicurando che rispettino lo schema del database.
    """
    # Definizione delle proprietà ammesse per ogni tipo di entità
    proprieta_per_categoria = {
        "Tecnica": ["nome", "tipo", "caratteristica", "uso", "applicazione", "effetto", 
                   "descrizione", "Svantaggi", "Vantaggi", "Tipo", "comeFunziona"],
        "Ristorante": ["nome", "Chef", "Location", "description", "cucina", "voto"],
        "Piatto": ["nome", "numero"],
        "Ingrediente": ["nome", "tipo", "origine", "sapore", "Aspetto", "Proprietà"],
        "Licenza": ["nome", "Livello", "Descrizione"],
        "Pianeta": ["nome", "ambiente", "clima", "intolleranzaLattosio", "intolleranza", 
                    "descrizione", "caratteristiche", "biomi", "magia"]
    }
    
    # Verifica che la categoria sia valida
    if categoria not in proprieta_per_categoria:
        print(f"Errore: la categoria '{categoria}' non è valida.")
        return []
    
    # Ottieni le proprietà valide per questa categoria
    proprieta_valide = proprieta_per_categoria[categoria]
    proprieta_str = ", ".join(proprieta_valide)
    
    # Genera un prompt più preciso in base allo schema
    prompt = f"""
    Contesto: questo testo rientra in una collezione di documenti che parlano di Ristoranti nello spazio (su Pianeti) e sui loro Menu, Piatti, Ingredienti, Tecniche e Licenze.
    
    Il testo seguente potrebbe contenere informazioni su entità di tipo '{categoria}'.
    
    In output voglio tutte le possibili istanze di '{categoria}' come entità da caricare su neo4j.
    
    Per ogni '{categoria}' recupera SOLO ed ESCLUSIVAMENTE queste proprietà (se presenti nel testo):
    {proprieta_str}
    
    NOTE IMPORTANTI:
    1. Non inventare proprietà che non sono nell'elenco fornito
    2. Non modificare i nomi delle proprietà
    3. Per la proprietà 'nome' usa SEMPRE una stringa singola, NON una lista
    4. Se "{categoria}" ha "Livello" o "numero", questi devono essere valori numerici interi
    
    Restituisci SOLO il JSON valido e completo, senza formattazione markdown o decoratori.
    Il formato deve essere:
    [
      {{"nome": "nome_entità", "proprietà2": "valore2", ...}}
    ]
    
    Testo:
    {testo}
    """
    
    # Chiamata al modello LLM per ottenere la valorizzazione delle entità
    response = llm.invoke(prompt)
    content = response.content.strip()
    
    # Pulizia del JSON
    if content.startswith('```') and content.endswith('```'):
        content = '\n'.join(content.split('\n')[1:-1])
    if content.startswith('```json'):
        content = content[7:].strip()
    elif content.startswith('json'):
        content = content[4:].strip()
    
    # Tentativo di riparare il JSON
    try:
        valorizzazioni = json.loads(content)
    except json.JSONDecodeError as e:
        print(f"Errore nel parsing JSON per entità {categoria}: {str(e)}")
        try:
            valorizzazioni = json.loads(repair_json(content))
        except Exception:
            # Fallback con richiesta all'LLM
            prompt_repair = f"""
            Correggi questo JSON per Neo4j e assicurati che sia valido e completo.
            Ogni entità deve avere almeno la proprietà 'nome'.
            Le proprietà valide per '{categoria}' sono: {proprieta_str}.
            Assicurati che 'nome' sia sempre una stringa singola e non una lista.
            
            JSON da correggere:
            {content}
            """
            repaired = llm.invoke(prompt_repair).content.strip()
            
            # Pulizia del JSON riparato
            if repaired.startswith('```') and repaired.endswith('```'):
                repaired = '\n'.join(repaired.split('\n')[1:-1])
            if repaired.startswith('```json'):
                repaired = repaired[7:].strip()
            elif repaired.startswith('json'):
                repaired = repaired[4:].strip()
                
            try:
                valorizzazioni = json.loads(repaired)
            except:
                print(f"Impossibile riparare il JSON per le entità di tipo {categoria}")
                valorizzazioni = []
    
    # Assicurati che il risultato sia una lista
    if not isinstance(valorizzazioni, list):
        valorizzazioni = [valorizzazioni]
    
    # Validazione e pulizia delle entità estratte
    entita_valide = []
    for entita in valorizzazioni:
        # Verifica che ci sia la proprietà 'nome'
        if 'nome' not in entita:
            continue
        
        # Verifica che nome sia una stringa e non una lista
        if isinstance(entita['nome'], list):
            entita['nome'] = entita['nome'][0] if entita['nome'] else ""
        
        # Rimuovi proprietà non valide
        entita_pulita = {'nome': entita['nome']}
        for prop in proprieta_valide:
            if prop in entita and prop != 'nome':
                # Converti i valori numerici se necessario
                if prop in ['Livello', 'numero'] and categoria in ['Licenza', 'Piatto']:
                    try:
                        entita_pulita[prop] = int(entita[prop])
                    except (ValueError, TypeError):
                        if isinstance(entita[prop], str) and entita[prop].strip():
                            entita_pulita[prop] = 1  # Default value
                else:
                    entita_pulita[prop] = entita[prop]
        
        entita_valide.append(entita_pulita)
    
    return entita_valide


def estrai_valorizzazioni_relazioni(testo, nome_relazione, tipo_entita1, tipo_entita2, entita1, entita2, llm, driver):
    """
    Estrae le relazioni specifiche tra entità di due tipi, rispettando lo schema del database.
    """
    # Definizione delle relazioni valide e loro proprietà
    relazioni_valide = {
        "OFFERTA": {"origine": "Ristorante", "destinazione": "Piatto", "proprieta": []},
        "CONTIENE": {"origine": "Piatto", "destinazione": "Ingrediente", "proprieta": []},
        "PREPARATO": {"origine": "Piatto", "destinazione": "Tecnica", "proprieta": []},
        "SITUATO": {"origine": "Ristorante", "destinazione": "Pianeta", "proprieta": ["descrizione"]},
        "HA": {"origine": "Ristorante", "destinazione": "Licenza", "proprieta": ["Livello"]},
        "DISTANZA": {"origine": "Pianeta", "destinazione": "Pianeta", "proprieta": ["km"]}
    }
    
    # Verifica che la relazione sia valida
    if nome_relazione not in relazioni_valide:
        print(f"Errore: la relazione '{nome_relazione}' non è valida.")
        return []
    
    # Verifica che i tipi di entità corrispondano alla relazione
    rel_info = relazioni_valide[nome_relazione]
    if rel_info["origine"] != tipo_entita1 or rel_info["destinazione"] != tipo_entita2:
        print(f"Errore: la relazione '{nome_relazione}' deve essere tra '{rel_info['origine']}' e '{rel_info['destinazione']}'.")
        return []
    
    # Ottieni le proprietà valide per questa relazione
    proprieta_valide = rel_info["proprieta"]
    proprieta_str = ", ".join(proprieta_valide) if proprieta_valide else "nessuna"
    
    # Preparazione delle entità per il prompt
    entita1_nomi = [e.get("nome", "") for e in (entita1 if isinstance(entita1, list) else [entita1]) if e.get("nome")]
    entita2_nomi = [e.get("nome", "") for e in (entita2 if isinstance(entita2, list) else [entita2]) if e.get("nome")]
    
    # Stringa con le proprietà e i loro tipi
    proprieta_info = ""
    if "km" in proprieta_valide:
        proprieta_info += "\n- 'km' deve essere un numero intero"
    if "Livello" in proprieta_valide:
        proprieta_info += "\n- 'Livello' deve essere un numero intero"
    if "descrizione" in proprieta_valide:
        proprieta_info += "\n- 'descrizione' deve essere una stringa"
    
    # Genera un prompt per estrarre le relazioni
    prompt = f"""
    Contesto: questo testo rientra in una collezione di documenti che parlano di Ristoranti nello spazio (su Pianeti) e sui loro Menu, Piatti, Ingredienti, Tecniche e Licenze.
    
    Il testo seguente potrebbe contenere informazioni su relazioni di tipo '{nome_relazione}' tra entità di tipo '{tipo_entita1}' e '{tipo_entita2}'.
    
    In output voglio tutte le relazioni di tipo '{nome_relazione}' come triple da caricare su neo4j.
    
    Per ogni relazione recupera:
    - origine: nome dell'entità di tipo '{tipo_entita1}'
    - destinazione: nome dell'entità di tipo '{tipo_entita2}'
    - proprietà: {proprieta_str} {proprieta_info}
    
    Ecco le entità di tipo '{tipo_entita1}' già identificate:
    {entita1_nomi}
    
    Ecco le entità di tipo '{tipo_entita2}' già identificate:
    {entita2_nomi}
    
    NOTE IMPORTANTI:
    1. Identifica SOLO relazioni tra entità presenti negli elenchi forniti
    2. Se non ci sono relazioni evidenti, restituisci un array vuoto
    
    Restituisci SOLO il JSON valido e completo, senza formattazione markdown o decoratori.
    Il formato deve essere:
    [
      {{"origine": "nome_entita1", "destinazione": "nome_entita2", "proprietà": {{{proprieta_str}}}}},
    ]
    
    Testo:
    {testo}
    """
    
    # Chiamata al modello LLM per ottenere la valorizzazione delle relazioni
    response = llm.invoke(prompt)
    content = response.content.strip()
    
    # Pulizia del JSON
    if content.startswith('```') and content.endswith('```'):
        content = '\n'.join(content.split('\n')[1:-1])
    if content.startswith('```json'):
        content = content[7:].strip()
    elif content.startswith('json'):
        content = content[4:].strip()
    
    # Tentativo di riparare il JSON
    try:
        relazioni = json.loads(content)
    except json.JSONDecodeError as e:
        print(f"Errore nel parsing JSON delle relazioni {nome_relazione}: {str(e)}")
        try:
            relazioni = json.loads(repair_json(content))
        except Exception:
            # Fallback con richiesta all'LLM
            prompt_repair = f"""
            Correggi questo JSON per Neo4j e assicurati che sia valido e completo.
            Ogni relazione deve avere 'origine', 'destinazione', e le seguenti proprietà se richieste: {proprieta_str}.
            
            JSON da correggere:
            {content}
            """
            repaired = llm.invoke(prompt_repair).content.strip()
            
            # Pulizia del JSON riparato
            if repaired.startswith('```') and repaired.endswith('```'):
                repaired = '\n'.join(repaired.split('\n')[1:-1])
            if repaired.startswith('```json'):
                repaired = repaired[7:].strip()
            elif repaired.startswith('json'):
                repaired = repaired[4:].strip()
                
            try:
                relazioni = json.loads(repaired)
            except:
                print(f"Impossibile riparare il JSON delle relazioni {nome_relazione}")
                relazioni = []
    
    # Assicurati che il risultato sia una lista
    if not isinstance(relazioni, list):
        relazioni = [relazioni]
    
    # Validazione e pulizia delle relazioni estratte
    relazioni_valide_lista = []
    for rel in relazioni:
        # Verifica che ci siano origine e destinazione
        if 'origine' not in rel or 'destinazione' not in rel:
            continue
        
        # Verifica che origine e destinazione siano nelle liste fornite
        if rel['origine'] not in entita1_nomi or rel['destinazione'] not in entita2_nomi:
            continue
        
        # Crea la relazione pulita
        rel_pulita = {
            'origine': rel['origine'],
            'destinazione': rel['destinazione']
        }
        
        # Aggiungi solo le proprietà valide
        if proprieta_valide:
            proprieta = {}
            for prop in proprieta_valide:
                if prop in rel.get('proprietà', {}):
                    if prop == 'km' or prop == 'Livello':
                        try:
                            proprieta[prop] = int(rel['proprietà'][prop])
                        except (ValueError, TypeError):
                            proprieta[prop] = 0  # Default value
                    else:
                        proprieta[prop] = rel['proprietà'][prop]
            
            rel_pulita['proprietà'] = proprieta
        
        relazioni_valide_lista.append(rel_pulita)
    
    return relazioni_valide_lista

# %%
import json
from json_repair import repair_json

def estrai_relazioni(testo, relazioni_info, llm, driver):
    """
    Estrae entità e relazioni tra di esse da un testo.
    
    Args:
        testo: Il testo da cui estrarre le relazioni
        relazioni_info: Dizionario nella forma {'NOME_RELAZIONE': ['Tipo_Entità1', 'Tipo_Entità2']}
        llm: Modello di linguaggio da utilizzare
        driver: Driver Neo4j
        
    Returns:
        Dizionario contenente entità e relazioni estratte
    """
    risultati = {}
    entita_tipi = set()
    
    # Raccogli tutti i tipi di entità unici dalle relazioni
    for _, [tipo_entita1, tipo_entita2] in relazioni_info.items():
        entita_tipi.add(tipo_entita1)
        entita_tipi.add(tipo_entita2)
    
    # Estrai tutte le entità una sola volta per tipo
    for tipo_entita in entita_tipi:
        print(f"Estraendo entità di tipo '{tipo_entita}'...")
        entita = estrai_valorizzazioni(testo, tipo_entita, llm, driver)
        risultati[tipo_entita] = entita
    
    # Ora estrai le relazioni
    for nome_relazione, [tipo_entita1, tipo_entita2] in relazioni_info.items():
        print(f"Estraendo relazioni '{nome_relazione}' tra '{tipo_entita1}' e '{tipo_entita2}'...")
        
        # Estrai le relazioni tra entità1 e entità2
        relazioni = estrai_valorizzazioni_relazioni(
            testo, 
            nome_relazione, 
            tipo_entita1, 
            tipo_entita2, 
            risultati[tipo_entita1], 
            risultati[tipo_entita2], 
            llm, 
            driver
        )
        
        # Salva le relazioni nel risultato
        risultati[nome_relazione] = relazioni
        
    return risultati

# %%
def carica_entita_e_relazioni_su_neo4j(risultati, relazioni_info, driver):
    """
    Carica entità e relazioni su Neo4j gestendo strutture dati nidificate
    
    Args:
        risultati: Dizionario contenente entità e relazioni
        relazioni_info: Dizionario delle relazioni come riferimento
        driver: Driver Neo4j
    """
    # Crea un set di tutti i tipi di relazione
    tipi_relazione = set(relazioni_info.keys())
    
    # Contatori per verifica
    entita_create = 0
    relazioni_create = 0
    
    # Verifica preliminare che il driver sia connesso
    try:
        with driver.session() as session:
            result = session.run("RETURN 1 AS test")
            test_value = result.single()["test"]
            if test_value != 1:
                print("ERRORE: Connessione al database non funzionante")
                return
            print("Connessione al database verificata con successo")
    except Exception as e:
        print(f"ERRORE: Impossibile connettersi al database: {str(e)}")
        return
    
    # Carica le entità
    for tipo_entita, entita_data in risultati.items():
        # Salta le chiavi che sono nomi di relazione
        if tipo_entita in tipi_relazione:
            continue
        
        print(f"Elaborazione per tipo: {tipo_entita}")
        print(f"Tipo di dato: {type(entita_data).__name__}")
        
        # Gestione speciale per struttura dati nidificata
        if isinstance(entita_data, dict) and tipo_entita in entita_data:
            print(f"Rilevata struttura nidificata per {tipo_entita}")
            if isinstance(entita_data[tipo_entita], list):
                entita_list = entita_data[tipo_entita]
            else:
                entita_list = [entita_data[tipo_entita]]
            print(f"Estratti {len(entita_list)} elementi dalla struttura nidificata")
        elif isinstance(entita_data, list):
            entita_list = entita_data
        elif isinstance(entita_data, dict) and "NOME" in entita_data:  # caso di singolo oggetto
            entita_list = [entita_data]
        else:
            print(f"ERRORE: Formato non supportato per {tipo_entita}: {entita_data}")
            continue
        
        print(f"Caricando {len(entita_list)} entità di tipo {tipo_entita}...")
        
        for entita in entita_list:
            print(f"Debug: Entità esaminata: {entita}")  # Aggiungi un log per vedere l'intera entità
            
            # Verifica l'accesso alla chiave "nome"
            if "nome" in entita:
                print(f"DEBUG: Trovata chiave 'nome' con valore: {entita['nome']}")
            else:
                print(f"ERRORE: Chiave 'nome' non trovata nella entità: {entita}")
            
            nome = entita.get("nome", "").strip()  # Accedi alla chiave "nome" in modo case-insensitive
            
            # Debug: Mostra se il nome è stato trovato
            if not nome:
                print(f"ERRORE: Entità di tipo {tipo_entita} senza nome: {entita}")
                continue
            
            parametri = entita.get("PARAMETRI", {})
            
            print(f"Creazione entità: {nome} (tipo: {tipo_entita})")
            
            # Usa una transazione esplicita
            with driver.session() as session:
                tx = session.begin_transaction()
                try:
                    # Crea la query base
                    query = f"MERGE (e:{tipo_entita} {{nome: $nome}})"
                    
                    # Se ci sono parametri, aggiungi SET
                    if parametri:
                        query += " SET "
                        set_clauses = []
                        for k in parametri.keys():
                            # Gestione speciale per parametri che sono dizionari
                            if isinstance(parametri[k], dict):
                                # Converti sotto-dizionari in formato JSON o string
                                set_clauses.append(f"e.{k} = $param_{k}")
                            else:
                                set_clauses.append(f"e.{k} = ${k}")
                        query += ", ".join(set_clauses)
                    
                    query += " RETURN e"  # Ritorna il nodo per conferma
                    
                    # Prepara i parametri per la query
                    params = {"nome": nome}
                    for k, v in parametri.items():
                        if isinstance(v, dict):
                            params[f"param_{k}"] = v  # Neo4j supporta JSON per le proprietà
                        else:
                            params[k] = v
                    
                    print(f"Esecuzione query: {query}")
                    result = tx.run(query, **params)
                    record = result.single()
                    if record:
                        node = record.get("e")
                        print(f"Entità creata e confermata: {nome} di tipo {tipo_entita}")
                        entita_create += 1
                    else:
                        print(f"ATTENZIONE: Entità {nome} non confermata dopo l'esecuzione della query")
                    
                    # Esplicita conferma della transazione
                    tx.commit()
                except Exception as e:
                    tx.rollback()
                    print(f"ERRORE nel caricamento dell'entità {nome}: {str(e)}")
                    print(f"Query: {query}")
                    print(f"Parametri: {params}")
    
    # Resto del codice per caricare le relazioni...

# %%
import re

def chunk_text(text, max_chars=3000, overlap=300):
    """
    Divide un testo in chunk di massimo `max_chars` caratteri, con `overlap` tra i chunk.
    
    Args:
        text (str): Il testo da spezzare in chunk.
        max_chars (int): Numero massimo di caratteri per chunk.
        overlap (int): Numero di caratteri di sovrapposizione tra i chunk.
    
    Returns:
        list: Lista di chunk di testo.
    """
    # Pulizia del testo per evitare problemi di spazi extra
    text = re.sub(r'\n+', '\n', text.strip())

    chunks = []
    start = 0
    while start < len(text):
        end = start + max_chars
        chunk = text[start:end]
        chunks.append(chunk)
        start = end - overlap  # Sposta l'inizio del prossimo chunk per avere overlap
    
    return chunks

# %% [markdown]
# ## MAIN

# %%
# Carica il file CSV
df_domande = pd.read_csv(domande)
testo_domande = df_domande.to_string()  # Converti il CSV in testo

# Carica il file CSV
df_pianeti = pd.read_csv(pianeti)
testo_pianeti = df_pianeti.to_string()  # Converti il CSV in testo

# Esegui l'analisi del PDF
testo_manuale = estrai_testo_pdf(manuale_cucina)
# Esegui l'analisi del PDF
testo_codice = estrai_testo_pdf(codice_galattico)
# Esempio di utilizzo:
testo_blog1 = estrai_testo_html(blog_1)
# Esempio di utilizzo:
testo_blog2 = estrai_testo_html(blog_2)

# %%
relazioni = {'CONTIENE': ['Piatto', 'Ingrediente'], 'PREPARATO': ['Piatto', 'Tecnica'], 'OFFERTA': ['Ristorante', 'Piatto'], 'SITUATO': ['Ristorante', 'Pianeta'], 'HA': ['Ristorante', 'Licenza']}

# %%
# Estrai entità e relazioni
chunks = chunk_text(testo_manuale, 3000, 400)
for chunk in chunks:
    risultati = estrai_relazioni(chunk, relazioni, llm, driver)
    carica_entita_e_relazioni_su_neo4j(risultati, relazioni, driver)
# Out:
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 0 entità di tipo Pianeta...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 14 entità di tipo Licenza...
# Debug: Entità esaminata: {'nome': 'Psionica', 'Livello': 0, 'Descrizione': 'Posseduta da tutti se non diversamente specificato. Tipica degli esseri senzienti.'}
# ERRORE: Entità di tipo Licenza senza nome: {'nome': 'Psionica', 'Livello': 0, 'Descrizione': 'Posseduta da tutti se non diversamente specificato. Tipica degli esseri senzienti.'}
# Debug: Entità esaminata: {'nome': 'Psionica', 'Livello': 1, 'Descrizione': 'lettura pensiero, telecinesi e teletrasporto di oggetti di massa inferiore a 5 kg, precognizione e visione del passato fino a 5 minuti'}
# ERRORE: Entità di tipo Licenza senza nome: {'nome': 'Psionica', 'Livello': 1, 'Descrizione': 'lettura pensiero, telecinesi e teletrasporto di oggetti di massa inferiore a 5 kg, precognizione e visione del passato fino a 5 minuti'}
# Debug: Entità esaminata: {'nome': 'Psionica', 'Livello': 2, 'Descrizione': 'manipolazione della probabilità, telecinesi e teletrasporto di oggetti di massa inferiore a 20 kg, manipolazione delle forze fondamentali dellʼuniverso'}
# ERRORE: Entità di tipo Licenza senza nome: {'nome': 'Psionica', 'Livello': 2, 'Descrizione': 'manipolazione della probabilità, telecinesi e teletrasporto di oggetti di massa inferiore a 20 kg, manipolazione delle forze fondamentali dellʼuniverso'}
# Debug: Entità esaminata: {'nome': 'Psionica', 'Livello': 3, 'Descrizione': 'capacità di donare la coscienza e lʼintelletto ad oggetti, manipolazione della realtà circoscritta a stanze, teletrasporto senza errore in qualsiasi dimensione temporale, comunione con entità di altri piani'}
# ERRORE: Entità di tipo Licenza senza nome: {'nome': 'Psionica', 'Livello': 3, 'Descrizione': 'capacità di donare la coscienza e lʼintelletto ad oggetti, manipolazione della realtà circoscritta a stanze, teletrasporto senza errore in qualsiasi dimensione temporale, comunione con entità di altri piani'}
# Debug: Entità esaminata: {'nome': 'Psionica', 'Livello': 4, 'Descrizione': 'proiezione astrale, riscrittura di realtà circoscritta a piccole nazioni o asteroidi'}
# ERRORE: Entità di tipo Licenza senza nome: {'nome': 'Psionica', 'Livello': 4, 'Descrizione': 'proiezione astrale, riscrittura di realtà circoscritta a piccole nazioni o asteroidi'}
# Debug: Entità esaminata: {'nome': 'Psionica', 'Livello': 5, 'Descrizione': 'riscrittura di realtà di intere linee temporali o galassie. Questo livello è equivalente al Grado di influenza di livello tecnologico III (LTK III)'}
# ERRORE: Entità di tipo Licenza senza nome: {'nome': 'Psionica', 'Livello': 5, 'Descrizione': 'riscrittura di realtà di intere linee temporali o galassie. Questo livello è equivalente al Grado di influenza di livello tecnologico III (LTK III)'}
# Debug: Entità esaminata: {'nome': 'Temporale', 'Livello': 1, 'Descrizione': 'effetti temporali relativi al presente come dilatazione o accelerazione del tempo'}
# ERRORE: Entità di tipo Licenza senza nome: {'nome': 'Temporale', 'Livello': 1, 'Descrizione': 'effetti temporali relativi al presente come dilatazione o accelerazione del tempo'}
# Debug: Entità esaminata: {'nome': 'Temporale', 'Livello': 2, 'Descrizione': 'Livello I + effetti temporali che riguardano linee temporali future'}
# ERRORE: Entità di tipo Licenza senza nome: {'nome': 'Temporale', 'Livello': 2, 'Descrizione': 'Livello I + effetti temporali che riguardano linee temporali future'}
# Debug: Entità esaminata: {'nome': 'Temporale', 'Livello': 3, 'Descrizione': 'Livello II + effetti temporali che riguardano linee temporali passate'}
# ERRORE: Entità di tipo Licenza senza nome: {'nome': 'Temporale', 'Livello': 3, 'Descrizione': 'Livello II + effetti temporali che riguardano linee temporali passate'}
# Debug: Entità esaminata: {'nome': 'Gravitazionale', 'Livello': 0, 'Descrizione': '5 < G ≤ 10, posseduta da tutti se non diversamente specificato'}
# ERRORE: Entità di tipo Licenza senza nome: {'nome': 'Gravitazionale', 'Livello': 0, 'Descrizione': '5 < G ≤ 10, posseduta da tutti se non diversamente specificato'}
# Debug: Entità esaminata: {'nome': 'Gravitazionale', 'Livello': 1, 'Descrizione': '0 < G ≤ 100'}
# ERRORE: Entità di tipo Licenza senza nome: {'nome': 'Gravitazionale', 'Livello': 1, 'Descrizione': '0 < G ≤ 100'}
# Debug: Entità esaminata: {'nome': 'Gravitazionale', 'Livello': 2, 'Descrizione': '0 < G ≤ 10^6'}
# ERRORE: Entità di tipo Licenza senza nome: {'nome': 'Gravitazionale', 'Livello': 2, 'Descrizione': '0 < G ≤ 10^6'}
# Debug: Entità esaminata: {'nome': 'Gravitazionale', 'Livello': 3, 'Descrizione': 'G > 10^6'}
# ERRORE: Entità di tipo Licenza senza nome: {'nome': 'Gravitazionale', 'Livello': 3, 'Descrizione': 'G > 10^6'}
# Debug: Entità esaminata: {'nome': 'Antimateria', 'Livello': 0, 'Descrizione': 'particelle, posseduta da tutti se non div'}
# ERRORE: Entità di tipo Licenza senza nome: {'nome': 'Antimateria', 'Livello': 0, 'Descrizione': 'particelle, posseduta da tutti se non div'}
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 3 entità di tipo Piatto...
# Debug: Entità esaminata: {'nome': 'brasato'}
# ERRORE: Entità di tipo Piatto senza nome: {'nome': 'brasato'}
# Debug: Entità esaminata: {'nome': 'maionese'}
# ERRORE: Entità di tipo Piatto senza nome: {'nome': 'maionese'}
# Debug: Entità esaminata: {'nome': 'soufflé orbitale'}
# ERRORE: Entità di tipo Piatto senza nome: {'nome': 'soufflé orbitale'}
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 4 entità di tipo Tecnica...
# Debug: Entità esaminata: {'nome': 'tecniche di cucina gravitazionali'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'tecniche di cucina gravitazionali'}
# Debug: Entità esaminata: {'nome': 'segreti per friggere senza far esplodere la cabina'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'segreti per friggere senza far esplodere la cabina'}
# Debug: Entità esaminata: {'nome': 'trucchi per ottenere il perfetto soufflé orbitale'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'trucchi per ottenere il perfetto soufflé orbitale'}
# Debug: Entità esaminata: {'nome': 'montare una maionese in assenza di gravità'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'montare una maionese in assenza di gravità'}
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 0 entità di tipo Ristorante...
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 0 entità di tipo Ingrediente...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 0 entità di tipo Pianeta...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 0 entità di tipo Licenza...
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 0 entità di tipo Piatto...
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 3 entità di tipo Tecnica...
# Debug: Entità esaminata: {'nome': 'tecnica stellare', 'descrizione': 'Qui non parliamo solo di tecnica stellare, ma di pura diplomazia culinaria intergalattica.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'tecnica stellare', 'descrizione': 'Qui non parliamo solo di tecnica stellare, ma di pura diplomazia culinaria intergalattica.'}
# Debug: Entità esaminata: {'nome': 'Principio di Non Alterazione', 'descrizione': 'Nessuna trasformazione drastica, niente manipolazioni invasive: solo il “Principio di Non Alterazione”. Questo significa che se una carota vuol essere una carota, dovrà restare tale, anche quando diventa arte culinaria.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Principio di Non Alterazione', 'descrizione': 'Nessuna trasformazione drastica, niente manipolazioni invasive: solo il “Principio di Non Alterazione”. Questo significa che se una carota vuol essere una carota, dovrà restare tale, anche quando diventa arte culinaria.'}
# Debug: Entità esaminata: {'nome': 'flusso emozionale gastronomico', 'applicazione': 'Creare piatti che parlano al cuore, adattandosi alle frequenze emotive del momento.', 'effetto': 'Un pranzo può calmare, ispirare o persino risvegliare ricordi dimenticati.', 'descrizione': 'Il loro dono è trasformare il cibo in una sinfonia che risuona con lʼanima di chi lo assapora.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'flusso emozionale gastronomico', 'applicazione': 'Creare piatti che parlano al cuore, adattandosi alle frequenze emotive del momento.', 'effetto': 'Un pranzo può calmare, ispirare o persino risvegliare ricordi dimenticati.', 'descrizione': 'Il loro dono è trasformare il cibo in una sinfonia che risuona con lʼanima di chi lo assapora.'}
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 3 entità di tipo Ristorante...
# Debug: Entità esaminata: {'nome': 'Ordine della Galassia di Andromeda', 'description': 'Cari pionieri del gusto cosmico, preparatevi a una sfida da veri fuoriclasse: cucinare per gli abitanti di Andromeda! Qui non parliamo solo di tecnica stellare, ma di pura diplomazia culinaria intergalattica. La particolarità? Ogni piatto devʼessere rigorosamente privo di lattosio — non un goccio, nemmeno lʼombra di una molecola originaria della Via Lattea. Se pensate che il formaggio sia lʼunica via per la felicità, è tempo di ripensare il vostro approccio. Imparerete a creare sapori complessi senza latte, burro o panna, conquistando palati alieni con alternative che sfidano le leggi della gastronomia universale.'}
# ERRORE: Entità di tipo Ristorante senza nome: {'nome': 'Ordine della Galassia di Andromeda', 'description': 'Cari pionieri del gusto cosmico, preparatevi a una sfida da veri fuoriclasse: cucinare per gli abitanti di Andromeda! Qui non parliamo solo di tecnica stellare, ma di pura diplomazia culinaria intergalattica. La particolarità? Ogni piatto devʼessere rigorosamente privo di lattosio — non un goccio, nemmeno lʼombra di una molecola originaria della Via Lattea. Se pensate che il formaggio sia lʼunica via per la felicità, è tempo di ripensare il vostro approccio. Imparerete a creare sapori complessi senza latte, burro o panna, conquistando palati alieni con alternative che sfidano le leggi della gastronomia universale.'}
# Debug: Entità esaminata: {'nome': 'Ordine dei Naturalisti', 'description': 'Per gli adepti dellʼOrdine dei Naturalisti, la cucina è molto più che creatività: è un atto di riverenza verso la natura. Qui si celebra lʼessenza primordiale di ogni ingrediente, custodendone la purezza come un prezioso segreto galattico. Nessuna trasformazione drastica, niente manipolazioni invasive: solo il “Principio di Non Alterazione”. Questo significa che se una carota vuol essere una carota, dovrà restare tale, anche quando diventa arte culinaria. La sfida? Esaltare la semplicità con maestria, senza mai tradire lʼidentità autentica del cibo.'}
# ERRORE: Entità di tipo Ristorante senza nome: {'nome': 'Ordine dei Naturalisti', 'description': 'Per gli adepti dellʼOrdine dei Naturalisti, la cucina è molto più che creatività: è un atto di riverenza verso la natura. Qui si celebra lʼessenza primordiale di ogni ingrediente, custodendone la purezza come un prezioso segreto galattico. Nessuna trasformazione drastica, niente manipolazioni invasive: solo il “Principio di Non Alterazione”. Questo significa che se una carota vuol essere una carota, dovrà restare tale, anche quando diventa arte culinaria. La sfida? Esaltare la semplicità con maestria, senza mai tradire lʼidentità autentica del cibo.'}
# Debug: Entità esaminata: {'nome': 'Ordine degli Armonisti', 'description': 'Gli Armonisti sono più che semplici chef: sono veri maestri del flusso emozionale gastronomico. Il loro dono è trasformare il cibo in una sinfonia che risuona con lʼanima di chi lo assapora. Non si tratta solo di sapori, ma di vibrazioni sottili che si sintonizzano sullo stato dʼanimo degli ospiti. Un pranzo può calmare, ispirare o persino risvegliare ricordi dimenticati. La missione? Creare piatti che parlano al cuore, adattandosi alle frequenze emotive del momento. Perché qui, il cibo non si gusta: si vive.'}
# ERRORE: Entità di tipo Ristorante senza nome: {'nome': 'Ordine degli Armonisti', 'description': 'Gli Armonisti sono più che semplici chef: sono veri maestri del flusso emozionale gastronomico. Il loro dono è trasformare il cibo in una sinfonia che risuona con lʼanima di chi lo assapora. Non si tratta solo di sapori, ma di vibrazioni sottili che si sintonizzano sullo stato dʼanimo degli ospiti. Un pranzo può calmare, ispirare o persino risvegliare ricordi dimenticati. La missione? Creare piatti che parlano al cuore, adattandosi alle frequenze emotive del momento. Perché qui, il cibo non si gusta: si vive.'}
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 1 entità di tipo Ingrediente...
# Debug: Entità esaminata: {'nome': 'carota', 'Proprietà': 'Principio di Non Alterazione'}
# ERRORE: Entità di tipo Ingrediente senza nome: {'nome': 'carota', 'Proprietà': 'Principio di Non Alterazione'}
# Estraendo entità di tipo 'Pianeta'...
# Errore nel parsing JSON per entità Pianeta: Extra data: line 2 column 1 (char 3)
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 0 entità di tipo Pianeta...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 0 entità di tipo Licenza...
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 0 entità di tipo Piatto...
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 5 entità di tipo Tecnica...
# Debug: Entità esaminata: {'nome': 'Marinatura a Infusione Gravitazionale', 'Svantaggi': 'necessita di un “Grav-Infuser” di alta precisione, con un dispendio energetico significativo.', 'Vantaggi': 'il sapore penetra in profondità per una marinatura uniforme e intensa.', 'comeFunziona': 'il cibo è collocato in una camera a gravità alternata, che intensifica lʼassorbimento della marinata nei tessuti alimentari.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Marinatura a Infusione Gravitazionale', 'Svantaggi': 'necessita di un “Grav-Infuser” di alta precisione, con un dispendio energetico significativo.', 'Vantaggi': 'il sapore penetra in profondità per una marinatura uniforme e intensa.', 'comeFunziona': 'il cibo è collocato in una camera a gravità alternata, che intensifica lʼassorbimento della marinata nei tessuti alimentari.'}
# Debug: Entità esaminata: {'nome': 'Marinatura Temporale Sincronizzata', 'Svantaggi': 'rischi di interferenze temporali minori; vietata per uso domestico senza supervisione.', 'Vantaggi': 'marinatura completa in un tempo minimo, senza compromessi sulla qualità.', 'comeFunziona': 'sfrutta una bolla temporale sincronizzata per accelerare il processo di marinatura, comprimendo ore in minuti.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Marinatura Temporale Sincronizzata', 'Svantaggi': 'rischi di interferenze temporali minori; vietata per uso domestico senza supervisione.', 'Vantaggi': 'marinatura completa in un tempo minimo, senza compromessi sulla qualità.', 'comeFunziona': 'sfrutta una bolla temporale sincronizzata per accelerare il processo di marinatura, comprimendo ore in minuti.'}
# Debug: Entità esaminata: {'nome': 'Marinatura Psionica', 'Svantaggi': 'richiede chef con competenze psioniche avanzate', 'Vantaggi': 'sapori unici e personalizzati ottenuti attraverso la fusione creativa tra mente e ingredienti.', 'comeFunziona': "uno chef telepate concentra la propria energia mentali per manipolare le molecole della marinata, fondendole con l'alimento."}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Marinatura Psionica', 'Svantaggi': 'richiede chef con competenze psioniche avanzate', 'Vantaggi': 'sapori unici e personalizzati ottenuti attraverso la fusione creativa tra mente e ingredienti.', 'comeFunziona': "uno chef telepate concentra la propria energia mentali per manipolare le molecole della marinata, fondendole con l'alimento."}
# Debug: Entità esaminata: {'nome': "Marinatura tramite Reazioni d'Antimateria Diluite", 'Svantaggi': 'manipolazione rischiosa che richiede per legge ambienti protetti.', 'Vantaggi': 'penetrazione rapida della marinata anche negli alimenti più densi, con un caratteristico retrogusto “cosmico”.', 'comeFunziona': 'micro-quantità di antimateria generano reazioni controllate che ionizzano la marinata, incrementando lʼassorbimento attraverso la tensione superficiale.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': "Marinatura tramite Reazioni d'Antimateria Diluite", 'Svantaggi': 'manipolazione rischiosa che richiede per legge ambienti protetti.', 'Vantaggi': 'penetrazione rapida della marinata anche negli alimenti più densi, con un caratteristico retrogusto “cosmico”.', 'comeFunziona': 'micro-quantità di antimateria generano reazioni controllate che ionizzano la marinata, incrementando lʼassorbimento attraverso la tensione superficiale.'}
# Debug: Entità esaminata: {'nome': 'Marinatura Sotto Zero a Polarità Inversa', 'Svantaggi': 'richiede tecnologia avanzata per regolare con precis', 'Vantaggi': 'conserva al massimo i profumi e le caratteristiche volatili della marinata.', 'comeFunziona': 'gli alimenti sono immersi in soluzioni marinate a temperatura sub-critica, mentre una polarità magnetica inversa aiuta lʼassorbimento dei sapori.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Marinatura Sotto Zero a Polarità Inversa', 'Svantaggi': 'richiede tecnologia avanzata per regolare con precis', 'Vantaggi': 'conserva al massimo i profumi e le caratteristiche volatili della marinata.', 'comeFunziona': 'gli alimenti sono immersi in soluzioni marinate a temperatura sub-critica, mentre una polarità magnetica inversa aiuta lʼassorbimento dei sapori.'}
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 0 entità di tipo Ristorante...
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 1 entità di tipo Ingrediente...
# Debug: Entità esaminata: {'nome': 'antimateria'}
# ERRORE: Entità di tipo Ingrediente senza nome: {'nome': 'antimateria'}
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Errore nel parsing JSON per entità Ristorante: Extra data: line 2 column 1 (char 3)
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Errore nel parsing JSON delle relazioni CONTIENE: Extra data: line 2 column 1 (char 3)
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 0 entità di tipo Pianeta...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 0 entità di tipo Licenza...
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 0 entità di tipo Piatto...
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 6 entità di tipo Tecnica...
# Debug: Entità esaminata: {'nome': 'Marinatura Sotto Zero a Polarità Inversa', 'Svantaggi': 'richiede tecnologia avanzata per regolare con precisione le condizioni polari.', 'Vantaggi': 'conserva al massimo i profumi e le caratteristiche volatili della marinata.', 'comeFunziona': 'gli alimenti sono immersi in soluzioni marinate a temperatura sub-critica, mentre una polarità magnetica inversa aiuta lʼassorbimento dei sapori.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Marinatura Sotto Zero a Polarità Inversa', 'Svantaggi': 'richiede tecnologia avanzata per regolare con precisione le condizioni polari.', 'Vantaggi': 'conserva al massimo i profumi e le caratteristiche volatili della marinata.', 'comeFunziona': 'gli alimenti sono immersi in soluzioni marinate a temperatura sub-critica, mentre una polarità magnetica inversa aiuta lʼassorbimento dei sapori.'}
# Debug: Entità esaminata: {'nome': 'Affumicatura a Stratificazione Quantica', 'Svantaggi': "può causare una leggera variazione del sapore se non calibrato con precisione, rendendo l'affumicatura imprevedibile senza un operatore esperto.", 'Vantaggi': "penetrazione uniforme del sapore affumicato, con un aroma che sembra provenire dall'interno dell'alimento stesso.", 'comeFunziona': "il cibo viene posizionato in una camera che alterna strati quantici, permettendo a particelle di fumo quantisticamente compresse di penetrare attraverso i livelli molecolari dell'alimento."}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Affumicatura a Stratificazione Quantica', 'Svantaggi': "può causare una leggera variazione del sapore se non calibrato con precisione, rendendo l'affumicatura imprevedibile senza un operatore esperto.", 'Vantaggi': "penetrazione uniforme del sapore affumicato, con un aroma che sembra provenire dall'interno dell'alimento stesso.", 'comeFunziona': "il cibo viene posizionato in una camera che alterna strati quantici, permettendo a particelle di fumo quantisticamente compresse di penetrare attraverso i livelli molecolari dell'alimento."}
# Debug: Entità esaminata: {'nome': 'Affumicatura Temporale Risonante', 'Svantaggi': 'necessita di apparecchiature sofisticate per il controllo delle onde croniche, con potenziali rischi di disallineamento temporale.', 'Vantaggi': 'sapore profondo e complesso, ottenuto in modo efficace e veloce.', 'comeFunziona': 'sfrutta la risonanza temporale per infondere i sapori del fumo nel cibo attraverso onde croniche, condensando anni di affumicatura in pochi istanti.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Affumicatura Temporale Risonante', 'Svantaggi': 'necessita di apparecchiature sofisticate per il controllo delle onde croniche, con potenziali rischi di disallineamento temporale.', 'Vantaggi': 'sapore profondo e complesso, ottenuto in modo efficace e veloce.', 'comeFunziona': 'sfrutta la risonanza temporale per infondere i sapori del fumo nel cibo attraverso onde croniche, condensando anni di affumicatura in pochi istanti.'}
# Debug: Entità esaminata: {'nome': 'Affumicatura Psionica Sensoriale', 'Svantaggi': "richiede esperti psionici capaci di mantenere l'integrità sensoriale durante il processo.", 'Vantaggi': 'sapore affumicato personalizzato e adattabile ai gusti individuali.', 'comeFunziona': 'uno chef telepate genera un campo psionico sensoriale che simula lʼeffetto del fumo con la mente e attiva i recettori gustativi in modo mirato.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Affumicatura Psionica Sensoriale', 'Svantaggi': "richiede esperti psionici capaci di mantenere l'integrità sensoriale durante il processo.", 'Vantaggi': 'sapore affumicato personalizzato e adattabile ai gusti individuali.', 'comeFunziona': 'uno chef telepate genera un campo psionico sensoriale che simula lʼeffetto del fumo con la mente e attiva i recettori gustativi in modo mirato.'}
# Debug: Entità esaminata: {'nome': 'Affumicatura tramite Big Bang Microcosmico', 'Svantaggi': 'operazione estremamente rischiosa, eseguibile solo in ambienti altamente controllati.', 'Vantaggi': 'intensità di sapore senza eguali, con un caratteristico tocco “universale”.', 'comeFunziona': 'una minima quantità di energia simula un piccolo big bang, creando particelle subatomiche di fumo che si fondono con lʼalimento a livello nucleare.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Affumicatura tramite Big Bang Microcosmico', 'Svantaggi': 'operazione estremamente rischiosa, eseguibile solo in ambienti altamente controllati.', 'Vantaggi': 'intensità di sapore senza eguali, con un caratteristico tocco “universale”.', 'comeFunziona': 'una minima quantità di energia simula un piccolo big bang, creando particelle subatomiche di fumo che si fondono con lʼalimento a livello nucleare.'}
# Debug: Entità esaminata: {'nome': 'Affumicatura Polarizzata a Freddo Iperbarico', 'Vantaggi': 'sapore affumicato ricco e ben conservato, che preserva anche le not', 'comeFunziona': "lʼalimento è posto in ambienti iperbarici a bassissima temperatura dove flussi di fumo vengono polarizzati per attrarre molecole d'aroma all'interno del cibo."}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Affumicatura Polarizzata a Freddo Iperbarico', 'Vantaggi': 'sapore affumicato ricco e ben conservato, che preserva anche le not', 'comeFunziona': "lʼalimento è posto in ambienti iperbarici a bassissima temperatura dove flussi di fumo vengono polarizzati per attrarre molecole d'aroma all'interno del cibo."}
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 0 entità di tipo Ristorante...
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 0 entità di tipo Ingrediente...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 0 entità di tipo Pianeta...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 0 entità di tipo Licenza...
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 0 entità di tipo Piatto...
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 6 entità di tipo Tecnica...
# Debug: Entità esaminata: {'nome': 'Affumicatura Polarizzata a Freddo Iperbarico', 'Svantaggi': 'Nessuna in particolare', 'Vantaggi': 'sapore affumicato ricco e ben conservato, che preserva anche le note aromatiche più delicate.', 'comeFunziona': "lʼalimento è posto in ambienti iperbarici a bassissima temperatura dove flussi di fumo vengono polarizzati per attrarre molecole d'aroma all'interno del cibo."}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Affumicatura Polarizzata a Freddo Iperbarico', 'Svantaggi': 'Nessuna in particolare', 'Vantaggi': 'sapore affumicato ricco e ben conservato, che preserva anche le note aromatiche più delicate.', 'comeFunziona': "lʼalimento è posto in ambienti iperbarici a bassissima temperatura dove flussi di fumo vengono polarizzati per attrarre molecole d'aroma all'interno del cibo."}
# Debug: Entità esaminata: {'nome': 'Fermentazione Quantica a Strati Multiversali', 'Svantaggi': "richiede calibrazioni precise per evitare l'ingresso di invasioni aliene da altri universi.", 'Vantaggi': 'fermentazione rapida ed efficiente, con la possibilità di ottenere sapori unici e mai sperimentati nel nostro universo.', 'comeFunziona': "il cibo viene posizionato in un dispositivo di fermentazione che sfrutta strati quantici provenienti da diversi universi paralleli, facilitando l'interazione di enzimi transdimensionali con la materia organica."}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Fermentazione Quantica a Strati Multiversali', 'Svantaggi': "richiede calibrazioni precise per evitare l'ingresso di invasioni aliene da altri universi.", 'Vantaggi': 'fermentazione rapida ed efficiente, con la possibilità di ottenere sapori unici e mai sperimentati nel nostro universo.', 'comeFunziona': "il cibo viene posizionato in un dispositivo di fermentazione che sfrutta strati quantici provenienti da diversi universi paralleli, facilitando l'interazione di enzimi transdimensionali con la materia organica."}
# Debug: Entità esaminata: {'nome': 'Fermentazione Temporale Sincronizzata', 'Svantaggi': 'richiede una tecnologia avanzata di controllo temporale con possibilità di instabilità cronologica.', 'Vantaggi': 'riduce drasticamente i tempi tradizionali di fermentazione pur mantenendo profili aromatici profondi.', 'comeFunziona': 'utilizza flussi di tempo sincronizzati per accelerare o rallentare il processo fermentativo, modificando la percezione temporale degli ingredienti per ottenere immediatamente maturità e complessità dei sapori.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Fermentazione Temporale Sincronizzata', 'Svantaggi': 'richiede una tecnologia avanzata di controllo temporale con possibilità di instabilità cronologica.', 'Vantaggi': 'riduce drasticamente i tempi tradizionali di fermentazione pur mantenendo profili aromatici profondi.', 'comeFunziona': 'utilizza flussi di tempo sincronizzati per accelerare o rallentare il processo fermentativo, modificando la percezione temporale degli ingredienti per ottenere immediatamente maturità e complessità dei sapori.'}
# Debug: Entità esaminata: {'nome': 'Fermentazione Psionica Energetica', 'Svantaggi': 'esige lʼabilità rarefatta di esperti psionici per evitare squilibri gustativi.', 'Vantaggi': 'personalizzazione estrema dei sapori e dei profili aromatici in base alle preferenze individuali dellʼutente.', 'comeFunziona': 'uno chef telepate concentra campi energetici psionici per guidare e migliorare il processo naturale di fermentazione, manipolando gli enzimi grazie al potere del pensiero.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Fermentazione Psionica Energetica', 'Svantaggi': 'esige lʼabilità rarefatta di esperti psionici per evitare squilibri gustativi.', 'Vantaggi': 'personalizzazione estrema dei sapori e dei profili aromatici in base alle preferenze individuali dellʼutente.', 'comeFunziona': 'uno chef telepate concentra campi energetici psionici per guidare e migliorare il processo naturale di fermentazione, manipolando gli enzimi grazie al potere del pensiero.'}
# Debug: Entità esaminata: {'nome': 'Fermentazione tramite Singolarità', 'Svantaggi': 'operazione altamente rischiosa, richiede controlli estremamente scrupolosi.', 'Vantaggi': "crea intensi sapori e texture complesse mai viste prima, grazie all'influenza gravitazionale unica.", 'comeFunziona': 'sfrutta le radiazioni di Hawking di una piccola singolarità quantum-confinata che catalizza i processi fermentativi su scala molecolare'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Fermentazione tramite Singolarità', 'Svantaggi': 'operazione altamente rischiosa, richiede controlli estremamente scrupolosi.', 'Vantaggi': "crea intensi sapori e texture complesse mai viste prima, grazie all'influenza gravitazionale unica.", 'comeFunziona': 'sfrutta le radiazioni di Hawking di una piccola singolarità quantum-confinata che catalizza i processi fermentativi su scala molecolare'}
# Debug: Entità esaminata: {'nome': 'Fermentazione Quantico Biometrica', 'Vantaggi': 'mantiene la freschezza del prodotto finale con un gusto c', 'comeFunziona': 'gli ingredienti sono posti in ambienti sotto un elevato campo quantistico-metabolico dove una biometria avanzata regola i processi enzimatici per assicurare risultati costanti e prevedibili.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Fermentazione Quantico Biometrica', 'Vantaggi': 'mantiene la freschezza del prodotto finale con un gusto c', 'comeFunziona': 'gli ingredienti sono posti in ambienti sotto un elevato campo quantistico-metabolico dove una biometria avanzata regola i processi enzimatici per assicurare risultati costanti e prevedibili.'}
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 0 entità di tipo Ristorante...
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 1 entità di tipo Ingrediente...
# Debug: Entità esaminata: {'nome': 'sale'}
# ERRORE: Entità di tipo Ingrediente senza nome: {'nome': 'sale'}
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo entità di tipo 'Ingrediente'...
# Errore nel parsing JSON per entità Ingrediente: Expecting value: line 2 column 1 (char 2)
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 0 entità di tipo Pianeta...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 0 entità di tipo Licenza...
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 3 entità di tipo Piatto...
# Debug: Entità esaminata: {'nome': 'soufflé'}
# ERRORE: Entità di tipo Piatto senza nome: {'nome': 'soufflé'}
# Debug: Entità esaminata: {'nome': 'torte'}
# ERRORE: Entità di tipo Piatto senza nome: {'nome': 'torte'}
# Debug: Entità esaminata: {'nome': 'croissant'}
# ERRORE: Entità di tipo Piatto senza nome: {'nome': 'croissant'}
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 5 entità di tipo Tecnica...
# Debug: Entità esaminata: {'nome': 'Fermentazione Quantico Biometrica', 'Svantaggi': 'Alcune volte i campi quantistici rischiano di distruggere la realtà attuale. Tuttavia lʼeffetto è temporaneo, lʼunica precauzione è quella di tenere lontano dalla portata e vista delle donne incinta.', 'Vantaggi': 'mantiene la freschezza del prodotto finale con un gusto complesso ma ben equilibrato, adatto anche ai palati più fini.', 'comeFunziona': 'gli ingredienti sono posti in ambienti sotto un elevato campo quantistico-metabolico dove una biometria avanzata regola i processi enzimatici per assicurare risultati costanti e prevedibili.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Fermentazione Quantico Biometrica', 'Svantaggi': 'Alcune volte i campi quantistici rischiano di distruggere la realtà attuale. Tuttavia lʼeffetto è temporaneo, lʼunica precauzione è quella di tenere lontano dalla portata e vista delle donne incinta.', 'Vantaggi': 'mantiene la freschezza del prodotto finale con un gusto complesso ma ben equilibrato, adatto anche ai palati più fini.', 'comeFunziona': 'gli ingredienti sono posti in ambienti sotto un elevato campo quantistico-metabolico dove una biometria avanzata regola i processi enzimatici per assicurare risultati costanti e prevedibili.'}
# Debug: Entità esaminata: {'nome': 'Impasto Gravitazionale Vorticoso', 'Svantaggi': "richiede unʼaccurata regolazione delle forze gravitazionali per evitare eruzioni improvvise di materiale nell'ambiente di lavoro.", 'Vantaggi': 'raggiunge una consistenza perfetta e omogenea senza il rischio di sovraccarico meccanico; ideale per impasti leggeri come soufflé e torte.', 'comeFunziona': 'utilizza campi gravitazionali artificialmente generati per creare vortici che mescolano gli ingredienti in modo uniforme, sfruttando la rotazione a spirale per incorporare facilmente aria e umidità.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Impasto Gravitazionale Vorticoso', 'Svantaggi': "richiede unʼaccurata regolazione delle forze gravitazionali per evitare eruzioni improvvise di materiale nell'ambiente di lavoro.", 'Vantaggi': 'raggiunge una consistenza perfetta e omogenea senza il rischio di sovraccarico meccanico; ideale per impasti leggeri come soufflé e torte.', 'comeFunziona': 'utilizza campi gravitazionali artificialmente generati per creare vortici che mescolano gli ingredienti in modo uniforme, sfruttando la rotazione a spirale per incorporare facilmente aria e umidità.'}
# Debug: Entità esaminata: {'nome': 'Amalgamazione Sintetica Molecolare', 'Svantaggi': 'esige la comprensione delle interazioni chimiche intricate; gli errori possono alterare irreversibilmente il gusto finale.', 'Vantaggi': 'garantisce una perfetta fusione dei sapori e delle texture, permettendo esperimenti creativi con nuovi tipi di farine e composti proteici.', 'comeFunziona': "manipola direttamente le catene molecolari degli ingredienti attraverso catalizzatori sintetici, promuovendo la coesione spontanea e naturale dell'impasto."}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Amalgamazione Sintetica Molecolare', 'Svantaggi': 'esige la comprensione delle interazioni chimiche intricate; gli errori possono alterare irreversibilmente il gusto finale.', 'Vantaggi': 'garantisce una perfetta fusione dei sapori e delle texture, permettendo esperimenti creativi con nuovi tipi di farine e composti proteici.', 'comeFunziona': "manipola direttamente le catene molecolari degli ingredienti attraverso catalizzatori sintetici, promuovendo la coesione spontanea e naturale dell'impasto."}
# Debug: Entità esaminata: {'nome': 'Impasto a Campi Magnetici Dualistici', 'Svantaggi': "controllare lʼintensità magnetica è cruciale; campi troppo potenti possono disintegrare l'impasto anziché comporlo.", 'Vantaggi': 'ideale per preparazioni a strati complessi come i croissant, dove è richiesta una differenziazione di texture estremamente precisa.', 'comeFunziona': 'sfrutta poli magnetici opposti per modellare vari strati di ingredienti, creando strutture laminari straordinariamente sottili e accoppiate senza necessità fisica di pressione.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Impasto a Campi Magnetici Dualistici', 'Svantaggi': "controllare lʼintensità magnetica è cruciale; campi troppo potenti possono disintegrare l'impasto anziché comporlo.", 'Vantaggi': 'ideale per preparazioni a strati complessi come i croissant, dove è richiesta una differenziazione di texture estremamente precisa.', 'comeFunziona': 'sfrutta poli magnetici opposti per modellare vari strati di ingredienti, creando strutture laminari straordinariamente sottili e accoppiate senza necessità fisica di pressione.'}
# Debug: Entità esaminata: {'nome': 'Sinergia Elettro-Osmotica Programmabile', 'Vantaggi': 'permite il controllo totale sullʼidratamento, prevenendo eccedenze dʼacqua', 'comeFunziona': "questa tecnica avanza utilizza moduli elettro-osmotici che programmano sequenze precise di innesto dei liquidi nei solidi, ottimizzando la distribuzione idrica nell'impasto."}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Sinergia Elettro-Osmotica Programmabile', 'Vantaggi': 'permite il controllo totale sullʼidratamento, prevenendo eccedenze dʼacqua', 'comeFunziona': "questa tecnica avanza utilizza moduli elettro-osmotici che programmano sequenze precise di innesto dei liquidi nei solidi, ottimizzando la distribuzione idrica nell'impasto."}
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 0 entità di tipo Ristorante...
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 4 entità di tipo Ingrediente...
# Debug: Entità esaminata: {'nome': 'farina'}
# ERRORE: Entità di tipo Ingrediente senza nome: {'nome': 'farina'}
# Debug: Entità esaminata: {'nome': 'acqua'}
# ERRORE: Entità di tipo Ingrediente senza nome: {'nome': 'acqua'}
# Debug: Entità esaminata: {'nome': 'lievito'}
# ERRORE: Entità di tipo Ingrediente senza nome: {'nome': 'lievito'}
# Debug: Entità esaminata: {'nome': 'composti proteici'}
# ERRORE: Entità di tipo Ingrediente senza nome: {'nome': 'composti proteici'}
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Errore nel parsing JSON per entità Ristorante: Extra data: line 2 column 1 (char 3)
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 0 entità di tipo Pianeta...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 0 entità di tipo Licenza...
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 0 entità di tipo Piatto...
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 6 entità di tipo Tecnica...
# Debug: Entità esaminata: {'nome': 'Sinergia Elettro-Osmotica Programmabile', 'Svantaggi': 'esige monitoraggio continuo dei parametri elettro-osmotici per mantenere la meraviglia tech sotto stretto controllo operativo.', 'Vantaggi': 'permette il controllo totale sullʼidratamento, prevenendo eccedenze dʼacqua o indesiderate secchezze in impasti delicati come quelli della pasta fresca.', 'comeFunziona': "questa tecnica avanza utilizza moduli elettro-osmotici che programmano sequenze precise di innesto dei liquidi nei solidi, ottimizzando la distribuzione idrica nell'impasto."}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Sinergia Elettro-Osmotica Programmabile', 'Svantaggi': 'esige monitoraggio continuo dei parametri elettro-osmotici per mantenere la meraviglia tech sotto stretto controllo operativo.', 'Vantaggi': 'permette il controllo totale sullʼidratamento, prevenendo eccedenze dʼacqua o indesiderate secchezze in impasti delicati come quelli della pasta fresca.', 'comeFunziona': "questa tecnica avanza utilizza moduli elettro-osmotici che programmano sequenze precise di innesto dei liquidi nei solidi, ottimizzando la distribuzione idrica nell'impasto."}
# Debug: Entità esaminata: {'nome': 'Modellatura Onirica Tetrazionale', 'Svantaggi': 'richiede manipolatori specializzati dellʼonirismo culinario capaci di fissare coscienze materiali senza far smarrire gli elementi nelle dimensioni del subconscio.', 'Vantaggi': 'apre a creazioni culinarie dai sapori altrettanto effimeri quanto profondamente evocativi, impossibili da replicare con mezzi convenzionali.', 'comeFunziona': 'ispirata ai misteriosi mondi al confine del sogno, questa tecnica consente agli ingredienti di intessere tessiture nellʼeterea matrice cosmica tramite una sfera onirico-mistica in cui tempo e spazio fluttuano in narrativa fluida ed arcana.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Modellatura Onirica Tetrazionale', 'Svantaggi': 'richiede manipolatori specializzati dellʼonirismo culinario capaci di fissare coscienze materiali senza far smarrire gli elementi nelle dimensioni del subconscio.', 'Vantaggi': 'apre a creazioni culinarie dai sapori altrettanto effimeri quanto profondamente evocativi, impossibili da replicare con mezzi convenzionali.', 'comeFunziona': 'ispirata ai misteriosi mondi al confine del sogno, questa tecnica consente agli ingredienti di intessere tessiture nellʼeterea matrice cosmica tramite una sfera onirico-mistica in cui tempo e spazio fluttuano in narrativa fluida ed arcana.'}
# Debug: Entità esaminata: {'nome': 'Surgelamento', 'descrizione': 'Nel cosmo, il surgelamento non è solo un metodo di conservazione, ma una tecnica che sfrutta il gelo spaziale per bloccare i sapori nel loro stato migliore. Il congelamento permette di mantenere intatte freschezza e qualità, creando piatti che sembrano appena usciti dal cuore di un pianeta lontano, pronti a stupire con ogni dettaglio perfettamente conservato.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Surgelamento', 'descrizione': 'Nel cosmo, il surgelamento non è solo un metodo di conservazione, ma una tecnica che sfrutta il gelo spaziale per bloccare i sapori nel loro stato migliore. Il congelamento permette di mantenere intatte freschezza e qualità, creando piatti che sembrano appena usciti dal cuore di un pianeta lontano, pronti a stupire con ogni dettaglio perfettamente conservato.'}
# Debug: Entità esaminata: {'nome': 'Cryo-Tessitura Energetica Polarizzata', 'Svantaggi': 'richiede una sincronizzazione esatta delle onde energetiche per prevenire la cristallizzazione indesiderata che potrebbe compromettere la texture.', 'Vantaggi': 'consente un raffreddamento ultra-rapido che preserva perfettamente la freschezza dei sapori e le vitamine; ideale per frutta e verdura.', 'comeFunziona': 'sfrutta campi energetici polarizzati per intrappolare il calore residuo e indurre un surgelamento immediato, mantenendo la struttura molecolare degli alimenti intatta.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Cryo-Tessitura Energetica Polarizzata', 'Svantaggi': 'richiede una sincronizzazione esatta delle onde energetiche per prevenire la cristallizzazione indesiderata che potrebbe compromettere la texture.', 'Vantaggi': 'consente un raffreddamento ultra-rapido che preserva perfettamente la freschezza dei sapori e le vitamine; ideale per frutta e verdura.', 'comeFunziona': 'sfrutta campi energetici polarizzati per intrappolare il calore residuo e indurre un surgelamento immediato, mantenendo la struttura molecolare degli alimenti intatta.'}
# Debug: Entità esaminata: {'nome': 'Congelamento Bio-Luminiscente Sincronico', 'Svantaggi': 'lʼimplementazione efficiente di questa tecnica richiede condizioni ambientali specifiche per evitare dispersioni luminose inefficaci.', 'Vantaggi': 'offre un surgelamento visivamente affascinante che mantiene intatti colore e gusto, senza ricorrere a sostanze chimiche artificiali.', 'comeFunziona': 'utilizza bioluminescenza naturale in combinazione con impulsi freddi, generando una matrice congelante uniforme che avvolge ogni food element in un abbraccio brillante e scintillante.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Congelamento Bio-Luminiscente Sincronico', 'Svantaggi': 'lʼimplementazione efficiente di questa tecnica richiede condizioni ambientali specifiche per evitare dispersioni luminose inefficaci.', 'Vantaggi': 'offre un surgelamento visivamente affascinante che mantiene intatti colore e gusto, senza ricorrere a sostanze chimiche artificiali.', 'comeFunziona': 'utilizza bioluminescenza naturale in combinazione con impulsi freddi, generando una matrice congelante uniforme che avvolge ogni food element in un abbraccio brillante e scintillante.'}
# Debug: Entità esaminata: {'nome': 'Cristallizzazione Temporale Reversiva', 'Vantaggi': 'offre un congelamento ritardato inverso che preserva i nutrienti intatti come se il tempo non fosse passato, ideale per piatt', 'comeFunziona': 'proietta gli alimenti attraverso un campo di distorsione temporale controllata, bloccando istanti di tempo nel ghiaccio senza alterare la realtà circostante.'}
# ...
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Sferificazione a Gravità Psionica Variabile', 'Svantaggi': 'necessita di un controllo preciso della gravità per evitare deformazioni o collassi delle sfer', 'Vantaggi': "consente la creazione di sfere con consistenze e diametri personalizzati, dal micro al macro, senza mai comprometterne l'integrità.", 'comeFunziona': 'un telepate sospende gli ingredienti in un campo a gravità variabile per poi modulare la forza gravitazionale per manipolare le tensioni superficiali dei liquidi, formando sfere perfette.'}
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 0 entità di tipo Ristorante...
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 3 entità di tipo Ingrediente...
# Debug: Entità esaminata: {'nome': 'frammenti elementali'}
# ERRORE: Entità di tipo Ingrediente senza nome: {'nome': 'frammenti elementali'}
# Debug: Entità esaminata: {'nome': 'liquidi'}
# ERRORE: Entità di tipo Ingrediente senza nome: {'nome': 'liquidi'}
# Debug: Entità esaminata: {'nome': 'gelificanti'}
# ERRORE: Entità di tipo Ingrediente senza nome: {'nome': 'gelificanti'}
# Estraendo entità di tipo 'Pianeta'...
# Errore nel parsing JSON per entità Pianeta: Extra data: line 2 column 1 (char 3)
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 0 entità di tipo Pianeta...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 0 entità di tipo Licenza...
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 0 entità di tipo Piatto...
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 5 entità di tipo Tecnica...
# Debug: Entità esaminata: {'nome': 'Sferificazione Filamentare a Molecole Vibrazionali', 'Svantaggi': "l'energia vibratoria elevata può occasionalmente innescare risonanze indesiderate nel materiale sferificato.", 'Vantaggi': 'le sfere risultanti hanno strutture interne uniche e sapori stratificati che esplodono sequenzialmente al palato.', 'comeFunziona': 'si utilizzano filamenti vibrazionali microscopici che allineano le molecole dei liquidi in schemi geometrici intricati prima di solidificarsi in forma sferica.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Sferificazione Filamentare a Molecole Vibrazionali', 'Svantaggi': "l'energia vibratoria elevata può occasionalmente innescare risonanze indesiderate nel materiale sferificato.", 'Vantaggi': 'le sfere risultanti hanno strutture interne uniche e sapori stratificati che esplodono sequenzialmente al palato.', 'comeFunziona': 'si utilizzano filamenti vibrazionali microscopici che allineano le molecole dei liquidi in schemi geometrici intricati prima di solidificarsi in forma sferica.'}
# Debug: Entità esaminata: {'nome': 'Sferificazione Cromatica Interdimensionale', 'Svantaggi': 'una mancata sincronizzazione tra i piani potrebbe risultare in instabilità strutturali delle sfere.', 'Vantaggi': "permette di ottenere sfere dai colori straordinari e mai visti nel nostro spettro visivo, aumentando l'attrattiva estetica dei piatti.", 'comeFunziona': 'sfruttando una finestra cromatica multidimensionale, gli ingredienti acquisiscono qualità cromatiche da altri piani esistenziali, influenzando la formazione delle sfere e il loro aspetto visivo finale.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Sferificazione Cromatica Interdimensionale', 'Svantaggi': 'una mancata sincronizzazione tra i piani potrebbe risultare in instabilità strutturali delle sfere.', 'Vantaggi': "permette di ottenere sfere dai colori straordinari e mai visti nel nostro spettro visivo, aumentando l'attrattiva estetica dei piatti.", 'comeFunziona': 'sfruttando una finestra cromatica multidimensionale, gli ingredienti acquisiscono qualità cromatiche da altri piani esistenziali, influenzando la formazione delle sfere e il loro aspetto visivo finale.'}
# Debug: Entità esaminata: {'nome': 'Sferificazione con Campi Magnetici Entropici', 'Svantaggi': 'gestione complessa del campo magnetico per prevenire effetti collaterali imprevedibili negli ingredienti circostanti.', 'Vantaggi': 'produce sfere con variazioni naturali nella texture, ideale per esperienze culinarie dinamiche e sempre cangianti.', 'comeFunziona': 'campi magnetici specificamente configurati generano entropie controllate nei liquidi, creando sfere attraverso flussi caotici che si auto-raccolgono.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Sferificazione con Campi Magnetici Entropici', 'Svantaggi': 'gestione complessa del campo magnetico per prevenire effetti collaterali imprevedibili negli ingredienti circostanti.', 'Vantaggi': 'produce sfere con variazioni naturali nella texture, ideale per esperienze culinarie dinamiche e sempre cangianti.', 'comeFunziona': 'campi magnetici specificamente configurati generano entropie controllate nei liquidi, creando sfere attraverso flussi caotici che si auto-raccolgono.'}
# Debug: Entità esaminata: {'nome': 'Sferificazione tramite Matrici Biofotiche', 'Svantaggi': "richiede fonti luminose adeguate per ottimizzare il processo; un'illuminazione scorretta può compromettere l'effetto luminescente finale.", 'Vantaggi': "le sfere brillano in modo sottile o intenso a seconda della luce assorbita, offrendo un'esperienza multisensoriale ai commensali.", 'comeFunziona': 'impiega matrici biofotiche che assorbono luce ambientale per catalizzare reazioni di sferificazione nel fluido base, formando strutture luminescenti.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Sferificazione tramite Matrici Biofotiche', 'Svantaggi': "richiede fonti luminose adeguate per ottimizzare il processo; un'illuminazione scorretta può compromettere l'effetto luminescente finale.", 'Vantaggi': "le sfere brillano in modo sottile o intenso a seconda della luce assorbita, offrendo un'esperienza multisensoriale ai commensali.", 'comeFunziona': 'impiega matrici biofotiche che assorbono luce ambientale per catalizzare reazioni di sferificazione nel fluido base, formando strutture luminescenti.'}
# Debug: Entità esaminata: {'nome': 'Taglio Dimensionale a Lame Fotofiliche', 'comeFunziona': 'questo metodo utilizza lame composte da fasci fotonici compressi, capaci di tagliare attraverso la materia aprendo temporaneamente una breccia in dimensioni super'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Taglio Dimensionale a Lame Fotofiliche', 'comeFunziona': 'questo metodo utilizza lame composte da fasci fotonici compressi, capaci di tagliare attraverso la materia aprendo temporaneamente una breccia in dimensioni super'}
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 0 entità di tipo Ristorante...
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 2 entità di tipo Ingrediente...
# Debug: Entità esaminata: {'nome': 'carne'}
# ERRORE: Entità di tipo Ingrediente senza nome: {'nome': 'carne'}
# Debug: Entità esaminata: {'nome': 'verdure'}
# ERRORE: Entità di tipo Ingrediente senza nome: {'nome': 'verdure'}
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Errore nel parsing JSON delle relazioni PREPARATO: Extra data: line 2 column 1 (char 3)
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 0 entità di tipo Pianeta...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 0 entità di tipo Licenza...
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 0 entità di tipo Piatto...
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 5 entità di tipo Tecnica...
# Debug: Entità esaminata: {'nome': 'Taglio Dimensionale a Lame Fotofiliche', 'Svantaggi': 'richiede un allineamento esatto delle dimensioni durante il taglio per evitare la dissezione involontaria di spazio-tempo.', 'Vantaggi': 'consente tagli incredibilmente precisi e puliti che non disturbano la struttura molecolare degli alimenti, mantenendo aromi e sapori intatti.', 'comeFunziona': 'questo metodo utilizza lame composte da fasci fotonici compressi, capaci di tagliare attraverso la materia aprendo temporaneamente una breccia in dimensioni superiori.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Taglio Dimensionale a Lame Fotofiliche', 'Svantaggi': 'richiede un allineamento esatto delle dimensioni durante il taglio per evitare la dissezione involontaria di spazio-tempo.', 'Vantaggi': 'consente tagli incredibilmente precisi e puliti che non disturbano la struttura molecolare degli alimenti, mantenendo aromi e sapori intatti.', 'comeFunziona': 'questo metodo utilizza lame composte da fasci fotonici compressi, capaci di tagliare attraverso la materia aprendo temporaneamente una breccia in dimensioni superiori.'}
# Debug: Entità esaminata: {'nome': 'Taglio a Risonanza Sonica Rigenerativa', 'Svantaggi': "è essenziale controllare l'intensità e la frequenza per evitare danni ai componenti più delicati dei cibi.", 'Vantaggi': 'preserva la freschezza e le proprietà nutritive grazie alla riduzione dello stress meccanico sui tessuti alimentari.', 'comeFunziona': "emettitori sonori creano frequenze che separano delicatamente le tessiture cellulari degli alimenti senza l'uso di strumenti fisici, facilitando un taglio netto."}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Taglio a Risonanza Sonica Rigenerativa', 'Svantaggi': "è essenziale controllare l'intensità e la frequenza per evitare danni ai componenti più delicati dei cibi.", 'Vantaggi': 'preserva la freschezza e le proprietà nutritive grazie alla riduzione dello stress meccanico sui tessuti alimentari.', 'comeFunziona': "emettitori sonori creano frequenze che separano delicatamente le tessiture cellulari degli alimenti senza l'uso di strumenti fisici, facilitando un taglio netto."}
# Debug: Entità esaminata: {'nome': 'Affettamento a Pulsazioni Quantistiche', 'Svantaggi': "richiede un'accurata calibrazione del campo quantico per evitare mutamenti imprevedibili nella struttura molecolare.", 'Vantaggi': 'rende possibile la creazione di fette estremamente sottili senza compromettere la consistenza interna.', 'comeFunziona': 'si utilizzano pulsazioni quantistiche per manipolare i legami atomici, effettuando tagli che permettono una frammentazione controllata e precisa dei materiali.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Affettamento a Pulsazioni Quantistiche', 'Svantaggi': "richiede un'accurata calibrazione del campo quantico per evitare mutamenti imprevedibili nella struttura molecolare.", 'Vantaggi': 'rende possibile la creazione di fette estremamente sottili senza compromettere la consistenza interna.', 'comeFunziona': 'si utilizzano pulsazioni quantistiche per manipolare i legami atomici, effettuando tagli che permettono una frammentazione controllata e precisa dei materiali.'}
# Debug: Entità esaminata: {'nome': 'Taglio Sinaptico Biomimetico', 'Svantaggi': "richiede formazione specializzata per sincronizzare perfettamente il dispositivo con il sistema nervoso dell'operatore.", 'Vantaggi': "offre un controllo intuitivo del processo di taglio attraverso interfacce neurali dirette, aumentando l'efficienza operativa.", 'comeFunziona': 'questa tecnica sfrutta dispositivi biomimetici che imitano i processi naturali a livello sinaptico, traducendo segnali nervosi in azioni di taglio compatibili con ogni tipo di tessuto alimentare.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Taglio Sinaptico Biomimetico', 'Svantaggi': "richiede formazione specializzata per sincronizzare perfettamente il dispositivo con il sistema nervoso dell'operatore.", 'Vantaggi': "offre un controllo intuitivo del processo di taglio attraverso interfacce neurali dirette, aumentando l'efficienza operativa.", 'comeFunziona': 'questa tecnica sfrutta dispositivi biomimetici che imitano i processi naturali a livello sinaptico, traducendo segnali nervosi in azioni di taglio compatibili con ogni tipo di tessuto alimentare.'}
# Debug: Entità esaminata: {'nome': 'Incisione Elettromagnetica Plasmica', 'Svantaggi': "necessita di una fonte continua di energia plasmatica; malfunzionamenti energetici possono alterare l'integrità delle incisioni realizzate.", 'Vantaggi': "ideale per lavorazioni sofisticate e decorative su superfici alimentari complesse, esaltando l'estetica culinaria.", 'comeFunziona': 'questa tecnica avanzata utilizza bisturi plasmatici governati da campi elettromagnetici concentrati per incidere gli alimenti con precisione e raffinatezza chirurgica.'}
# ERRORE: Entità di tipo Tecnica senza nome: {'nome': 'Incisione Elettromagnetica Plasmica', 'Svantaggi': "necessita di una fonte continua di energia plasmatica; malfunzionamenti energetici possono alterare l'integrità delle incisioni realizzate.", 'Vantaggi': "ideale per lavorazioni sofisticate e decorative su superfici alimentari complesse, esaltando l'estetica culinaria.", 'comeFunziona': 'questa tecnica avanzata utilizza bisturi plasmatici governati da campi elettromagnetici concentrati per incidere gli alimenti con precisione e raffinatezza chirurgica.'}
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 0 entità di tipo Ristorante...
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 0 entità di tipo Ingrediente...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Errore nel parsing JSON delle relazioni HA: Extra data: line 2 column 1 (char 3)
# Connessione al database verificata con successo
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 1 entità di tipo Pianeta...
# Debug: Entità esaminata: {'nome': 'lizzate'}
# ERRORE: Entità di tipo Pianeta senza nome: {'nome': 'lizzate'}
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 0 entità di tipo Licenza...
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 1 entità di tipo Piatto...
# Debug: Entità esaminata: {'nome': 'lizzate'}
# ERRORE: Entità di tipo Piatto senza nome: {'nome': 'lizzate'}
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 0 entità di tipo Tecnica...
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 1 entità di tipo Ristorante...
# Debug: Entità esaminata: {'nome': 'lizzate'}
# ERRORE: Entità di tipo Ristorante senza nome: {'nome': 'lizzate'}
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 1 entità di tipo Ingrediente...
# Debug: Entità esaminata: {'nome': 'lizzate'}
# ERRORE: Entità di tipo Ingrediente senza nome: {'nome': 'lizzate'}

# %%
# Estrai entità e relazioni
chunks = chunk_text(testo_codice, 3000, 400)
for chunk in chunks:
    risultati = estrai_relazioni(chunk, relazioni, llm, driver)
    carica_entita_e_relazioni_su_neo4j(risultati, relazioni, driver)
# Out:
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 0 entità di tipo Piatto...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 2 entità di tipo Licenza...
# Creazione entità: Decreto_Supremo_789_12773 (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.ConsiglioIntergalatticoNumero = $ConsiglioIntergalatticoNumero, e.GiornoCicloCosmico = $GiornoCicloCosmico, e.Regolamentazione = $Regolamentazione RETURN e
# Entità creata e confermata: Decreto_Supremo_789_12773 di tipo Licenza
# Creazione entità: Regolamento_675_12 (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.Descrizione = $Descrizione RETURN e
# Entità creata e confermata: Regolamento_675_12 di tipo Licenza
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 1 entità di tipo Pianeta...
# Creazione entità: Andromeda (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) SET e.intolleranza = $intolleranza, e.origine = $origine RETURN e
# Entità creata e confermata: Andromeda di tipo Pianeta
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 1 entità di tipo Ingrediente...
# Creazione entità: lattosio (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.intolleranza = $intolleranza, e.origine = $origine RETURN e
# Entità creata e confermata: lattosio di tipo Ingrediente
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 3 entità di tipo Tecnica...
# Creazione entità: PrincipioNonAlterazione (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.alteration_limit = $alteration_limit RETURN e
# Entità creata e confermata: PrincipioNonAlterazione di tipo Tecnica
# Creazione entità: RisonanzaEmotiva (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.synchronization = $synchronization RETURN e
# Entità creata e confermata: RisonanzaEmotiva di tipo Tecnica
# Creazione entità: GestioneIntolleranza (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.type = $type, e.ordine = $ordine RETURN e
# Entità creata e confermata: GestioneIntolleranza di tipo Tecnica
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 0 entità di tipo Ristorante...
# Caricando 0 relazioni di tipo CONTIENE...
# Caricando 0 relazioni di tipo PREPARATO...
# Caricando 0 relazioni di tipo OFFERTA...
# Caricando 0 relazioni di tipo SITUATO...
# Caricando 0 relazioni di tipo HA...
#
# Riepilogo: create 7 entità e 0 relazioni
# Verifica finale dal database: 168 nodi e 60 relazioni presenti
#
# Esempi di nodi per tipo:
#   Tecnica: CucinaGravitazionale, FritturaSicura, SouffleOrbitale, MontareMaionese, PrincipioDiNonAlterazione
#   Licenza: Psionica, Temporale, Gravitazionale, Antimateria, Marinatura_Temporale_Sincronizzata
#   Pianeta: Andromeda
#   Piatto: brasato, soufflé orbitale, maionese, soufflé, torte
#   Ristorante: MarinaturaSottoZeroaPolaritaInversa, Affumicatura, AffumicaturaaStratificazioneQuantica, AffumicaturaTemporaleRisonante, AffumicaturaPsionicaSensoriale
#   Ingrediente: crostaceo, lattosio, latte, burro, panna
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 0 entità di tipo Piatto...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 0 entità di tipo Licenza...
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 0 entità di tipo Pianeta...
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 15 entità di tipo Ingrediente...
# Creazione entità: Erba Pipa (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.CRP = $CRP, e.IEI = $IEI RETURN e
# Entità creata e confermata: Erba Pipa di tipo Ingrediente
# Creazione entità: Cristalli di Memoria (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.CRP = $CRP, e.CDT = $CDT RETURN e
# Entità creata e confermata: Cristalli di Memoria di tipo Ingrediente
# Creazione entità: Petali di Eco (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.CRP = $CRP, e.IPM = $IPM RETURN e
# Entità creata e confermata: Petali di Eco di tipo Ingrediente
# Creazione entità: Carne di Drago (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.IPM = $IPM RETURN e
# Entità creata e confermata: Carne di Drago di tipo Ingrediente
# Creazione entità: Uova di Fenice (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.IPM = $IPM, e.CDT = $CDT RETURN e
# Entità creata e confermata: Uova di Fenice di tipo Ingrediente
# Creazione entità: Lacrime di Unicorno (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.IPM = $IPM, e.θ = $θ RETURN e
# Entità creata e confermata: Lacrime di Unicorno di tipo Ingrediente
# Creazione entità: Foglie di Mandragora (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.IBX = $IBX, e.μ = $μ RETURN e
# Entità creata e confermata: Foglie di Mandragora di tipo Ingrediente
# Creazione entità: MuNa Lunare (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.IBX = $IBX, e.μ = $μ, e.CRP = $CRP RETURN e
# Entità creata e confermata: MuNa Lunare di tipo Ingrediente
# Creazione entità: Nettare di Sirena (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.IBX = $IBX, e.μ = $μ, e.θ = $θ RETURN e
# Entità creata e confermata: Nettare di Sirena di tipo Ingrediente
# Creazione entità: Spore Quantiche (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.δQ = $δQ, e.ID = $ID RETURN e
# Entità creata e confermata: Spore Quantiche di tipo Ingrediente
# Creazione entità: Essenza di Vuoto (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.δQ = $δQ, e.ID = $ID RETURN e
# Entità creata e confermata: Essenza di Vuoto di tipo Ingrediente
# Creazione entità: Funghi dell’Etere (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.δQ = $δQ, e.ID = $ID RETURN e
# Entità creata e confermata: Funghi dell’Etere di tipo Ingrediente
# Creazione entità: Sale Temporale (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.CDT = $CDT, e.IEI = $IEI RETURN e
# Entità creata e confermata: Sale Temporale di tipo Ingrediente
# Creazione entità: Radici di Gravità (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.CDT = $CDT, e.ID = $ID RETURN e
# Entità creata e confermata: Radici di Gravità di tipo Ingrediente
# Creazione entità: Polvere di Stelle (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.CDT = $CDT, e.IPM = $IPM RETURN e
# Entità creata e confermata: Polvere di Stelle di tipo Ingrediente
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 0 entità di tipo Tecnica...
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 0 entità di tipo Ristorante...
# Caricando 0 relazioni di tipo CONTIENE...
# Caricando 0 relazioni di tipo PREPARATO...
# Caricando 0 relazioni di tipo OFFERTA...
# Caricando 0 relazioni di tipo SITUATO...
# Caricando 0 relazioni di tipo HA...
#
# Riepilogo: create 15 entità e 0 relazioni
# Verifica finale dal database: 183 nodi e 60 relazioni presenti
#
# Esempi di nodi per tipo:
#   Tecnica: CucinaGravitazionale, FritturaSicura, SouffleOrbitale, MontareMaionese, PrincipioDiNonAlterazione
#   Licenza: Psionica, Temporale, Gravitazionale, Antimateria, Marinatura_Temporale_Sincronizzata
#   Pianeta: Andromeda
#   Piatto: brasato, soufflé orbitale, maionese, soufflé, torte
#   Ristorante: MarinaturaSottoZeroaPolaritaInversa, Affumicatura, AffumicaturaaStratificazioneQuantica, AffumicaturaTemporaleRisonante, AffumicaturaPsionicaSensoriale
#   Ingrediente: crostaceo, lattosio, latte, burro, panna
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Errore nel parsing JSON delle relazioni CONTIENE: Extra data: line 2 column 1 (char 3)
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Errore nel parsing JSON delle relazioni SITUATO: Extra data: line 2 column 1 (char 3)
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 0 entità di tipo Piatto...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 15 entità di tipo Licenza...
# Creazione entità: Psionica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Psionica di tipo Licenza
# Creazione entità: Gravitazionale (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Gravitazionale di tipo Licenza
# Creazione entità: Antimateria (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Antimateria di tipo Licenza
# Creazione entità: Magnetica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Magnetica di tipo Licenza
# Creazione entità: Gravitazionale (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Gravitazionale di tipo Licenza
# Creazione entità: Temporale (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Temporale di tipo Licenza
# Creazione entità: Psionica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Psionica di tipo Licenza
# Creazione entità: Antimateria (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Antimateria di tipo Licenza
# Creazione entità: Magnetica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Magnetica di tipo Licenza
# Creazione entità: Quantistica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Quantistica di tipo Licenza
# Creazione entità: Temporale (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Temporale di tipo Licenza
# Creazione entità: Psionica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Psionica di tipo Licenza
# Creazione entità: Antimateria (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Antimateria di tipo Licenza
# Creazione entità: Quantistica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Quantistica di tipo Licenza
# Creazione entità: Magnetica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.level = $level, e.code = $code RETURN e
# Entità creata e confermata: Magnetica di tipo Licenza
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 0 entità di tipo Pianeta...
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 6 entità di tipo Ingrediente...
# Creazione entità: Xeno (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.IBX = $IBX, e.LimiteVolume = $LimiteVolume RETURN e
# Entità creata e confermata: Xeno di tipo Ingrediente
# Creazione entità: Mutazione (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.mu = $mu, e.LimiteVolume = $LimiteVolume RETURN e
# Entità creata e confermata: Mutazione di tipo Ingrediente
# Creazione entità: Quantici (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.deltaQ = $deltaQ, e.LimiteVolume = $LimiteVolume RETURN e
# Entità creata e confermata: Quantici di tipo Ingrediente
# Creazione entità: Dimensionali (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.deltaQ = $deltaQ, e.LimiteVolume = $LimiteVolume RETURN e
# Entità creata e confermata: Dimensionali di tipo Ingrediente
# Creazione entità: SpaziotemporaliAltoCDT (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.CDT = $CDT, e.LimiteMassa = $LimiteMassa RETURN e
# Entità creata e confermata: SpaziotemporaliAltoCDT di tipo Ingrediente
# Creazione entità: SpaziotemporaliBassoCDT (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.CDT = $CDT, e.LimiteMassa = $LimiteMassa RETURN e
# Entità creata e confermata: SpaziotemporaliBassoCDT di tipo Ingrediente
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 10 entità di tipo Tecnica...
# Creazione entità: MarinaturaAInfusioneGravitazionale (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello RETURN e
# Entità creata e confermata: MarinaturaAInfusioneGravitazionale di tipo Tecnica
# Creazione entità: MarinaturaTemporaleSincronizzata (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello RETURN e
# Entità creata e confermata: MarinaturaTemporaleSincronizzata di tipo Tecnica
# Creazione entità: MarinaturaPsionica (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello RETURN e
# Entità creata e confermata: MarinaturaPsionica di tipo Tecnica
# Creazione entità: MarinaturaTramiteReazioniDAntimateriaDiluite (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello RETURN e
# Entità creata e confermata: MarinaturaTramiteReazioniDAntimateriaDiluite di tipo Tecnica
# Creazione entità: MarinaturaSottoZeroAPolaritaInversa (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello, e.gradotecnologico = $gradotecnologico RETURN e
# Entità creata e confermata: MarinaturaSottoZeroAPolaritaInversa di tipo Tecnica
# Creazione entità: AumicaturaAStratificazioneQuantica (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello, e.gradotecnologico = $gradotecnologico RETURN e
# Entità creata e confermata: AumicaturaAStratificazioneQuantica di tipo Tecnica
# Creazione entità: AumicaturaTemporaleRisonante (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello, e.gradotecnologico = $gradotecnologico RETURN e
# Entità creata e confermata: AumicaturaTemporaleRisonante di tipo Tecnica
# Creazione entità: AumicaturaPsionicaSensoriale (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello, e.gradotecnologico = $gradotecnologico RETURN e
# Entità creata e confermata: AumicaturaPsionicaSensoriale di tipo Tecnica
# Creazione entità: AumicaturaTramiteBigBangMicrocosmico (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.gradotecnologico = $gradotecnologico RETURN e
# ERRORE nel caricamento dell'entità AumicaturaTramiteBigBangMicrocosmico: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{tipo -> String("Antimateria"), livello -> String("I")}.}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.gradotecnologico = $gradotecnologico RETURN e
# Parametri: {'nome': 'AumicaturaTramiteBigBangMicrocosmico', 'licenze': [{'tipo': 'Antimateria', 'livello': 'I'}, {'tipo': 'Quantistica', 'livello': '10'}], 'gradotecnologico': 'III'}
# Creazione entità: AumicaturaPolarizzataAFreddoIperbarico (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello, e.gradotecnologico = $gradotecnologico RETURN e
# Entità creata e confermata: AumicaturaPolarizzataAFreddoIperbarico di tipo Tecnica
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 15 entità di tipo Ristorante...
# Creazione entità: Psionica (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.classe = $classe, e.livello = $livello RETURN e
# Entità creata e confermata: Psionica di tipo Ristorante
# Creazione entità: Gravitazionale (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.classe = $classe, e.livello = $livello RETURN e
# Entità creata e confermata: Gravitazionale di tipo Ristorante
# Creazione entità: Antimateria (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.classe = $classe, e.livello = $livello RETURN e
# Entità creata e confermata: Antimateria di tipo Ristorante
# Creazione entità: Magnetica (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.classe = $classe, e.livello = $livello RETURN e
# Entità creata e confermata: Magnetica di tipo Ristorante
# Creazione entità: LTK (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.grado = $grado, e.livello = $livello RETURN e
# Entità creata e confermata: LTK di tipo Ristorante
# Creazione entità: InfusioneGravitazionale (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello RETURN e
# Entità creata e confermata: InfusioneGravitazionale di tipo Ristorante
# Creazione entità: TemporaleSincronizzata (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello RETURN e
# Entità creata e confermata: TemporaleSincronizzata di tipo Ristorante
# Creazione entità: Psionica (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello RETURN e
# Entità creata e confermata: Psionica di tipo Ristorante
# Creazione entità: ReazioniAntimateriaDiluite (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello RETURN e
# Entità creata e confermata: ReazioniAntimateriaDiluite di tipo Ristorante
# Creazione entità: SottoZeroPolaritàInversa (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.licenza = $licenza, e.LTK = $LTK RETURN e
# Entità creata e confermata: SottoZeroPolaritàInversa di tipo Ristorante
# Creazione entità: StratificazioneQuantica (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello, e.LTK = $LTK RETURN e
# Entità creata e confermata: StratificazioneQuantica di tipo Ristorante
# Creazione entità: TemporaleRisonante (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello, e.LTK = $LTK RETURN e
# Entità creata e confermata: TemporaleRisonante di tipo Ristorante
# Creazione entità: PsionicaSensoriale (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello, e.LTK = $LTK RETURN e
# Entità creata e confermata: PsionicaSensoriale di tipo Ristorante
# Creazione entità: BigBangMicrocosmico (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.licenza = $licenza, e.Q = $Q, e.livello = $livello, e.LTK = $LTK RETURN e
# Entità creata e confermata: BigBangMicrocosmico di tipo Ristorante
# Creazione entità: PolarizzataFreddoIperbarico (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.licenza = $licenza, e.livello = $livello, e.LTK = $LTK RETURN e
# Entità creata e confermata: PolarizzataFreddoIperbarico di tipo Ristorante
# Caricando 0 relazioni di tipo CONTIENE...
# Caricando 0 relazioni di tipo PREPARATO...
# Caricando 0 relazioni di tipo OFFERTA...
# Caricando 0 relazioni di tipo SITUATO...
# Caricando 11 relazioni di tipo HA...
# Relazione creata e confermata: InfusioneGravitazionale-[HA]->Gravitazionale
# Relazione creata e confermata: TemporaleSincronizzata-[HA]->Temporale
# Relazione creata e confermata: Psionica-[HA]->Psionica
# Relazione creata e confermata: ReazioniAntimateriaDiluite-[HA]->Antimateria
# ERRORE nel caricamento della relazione SottoZeroPolaritàInversa-[HA]->Magnetica: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'tecnologico': expected an expression, '.' or '=' (line 5, column 56 (offset: 216))
# "                     SET r.livello = $livello, r.grado tecnologico LTK = $grado tecnologico LTK RETURN r"
#                                                         ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Licenza {nome: $destinazione})
#                     MERGE (o)-[r:HA]->(d)
#                      SET r.livello = $livello, r.grado tecnologico LTK = $grado tecnologico LTK RETURN r
# Parametri: {'origine': 'SottoZeroPolaritàInversa', 'destinazione': 'Magnetica', 'livello': 'I', 'grado tecnologico LTK': 'II'}
# ERRORE nel caricamento della relazione StratificazioneQuantica-[HA]->Quantistica: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'tecnologico': expected an expression, '.' or '=' (line 5, column 56 (offset: 216))
# "                     SET r.livello = $livello, r.grado tecnologico LTK = $grado tecnologico LTK RETURN r"
#                                                         ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Licenza {nome: $destinazione})
#                     MERGE (o)-[r:HA]->(d)
#                      SET r.livello = $livello, r.grado tecnologico LTK = $grado tecnologico LTK RETURN r
# Parametri: {'origine': 'StratificazioneQuantica', 'destinazione': 'Quantistica', 'livello': '3', 'grado tecnologico LTK': 'II'}
# ERRORE nel caricamento della relazione TemporaleRisonante-[HA]->Temporale: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'tecnologico': expected an expression, '.' or '=' (line 5, column 56 (offset: 216))
# "                     SET r.livello = $livello, r.grado tecnologico LTK = $grado tecnologico LTK RETURN r"
#                                                         ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Licenza {nome: $destinazione})
#                     MERGE (o)-[r:HA]->(d)
#                      SET r.livello = $livello, r.grado tecnologico LTK = $grado tecnologico LTK RETURN r
# Parametri: {'origine': 'TemporaleRisonante', 'destinazione': 'Temporale', 'livello': 'I', 'grado tecnologico LTK': 'II'}
# ERRORE nel caricamento della relazione PsionicaSensoriale-[HA]->Psionica: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'tecnologico': expected an expression, '.' or '=' (line 5, column 56 (offset: 216))
# "                     SET r.livello = $livello, r.grado tecnologico LTK = $grado tecnologico LTK RETURN r"
#                                                         ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Licenza {nome: $destinazione})
#                     MERGE (o)-[r:HA]->(d)
#                      SET r.livello = $livello, r.grado tecnologico LTK = $grado tecnologico LTK RETURN r
# Parametri: {'origine': 'PsionicaSensoriale', 'destinazione': 'Psionica', 'livello': 'II', 'grado tecnologico LTK': 'III'}
# ERRORE nel caricamento della relazione BigBangMicrocosmico-[HA]->Antimateria: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'tecnologico': expected an expression, '.' or '=' (line 5, column 56 (offset: 216))
# "                     SET r.livello = $livello, r.grado tecnologico LTK = $grado tecnologico LTK RETURN r"
#                                                         ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Licenza {nome: $destinazione})
#                     MERGE (o)-[r:HA]->(d)
#                      SET r.livello = $livello, r.grado tecnologico LTK = $grado tecnologico LTK RETURN r
# Parametri: {'origine': 'BigBangMicrocosmico', 'destinazione': 'Antimateria', 'livello': 'I', 'grado tecnologico LTK': 'III'}
# ERRORE nel caricamento della relazione BigBangMicrocosmico-[HA]->Quantistica: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'tecnologico': expected an expression, '.' or '=' (line 5, column 56 (offset: 216))
# "                     SET r.livello = $livello, r.grado tecnologico LTK = $grado tecnologico LTK RETURN r"
#                                                         ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Licenza {nome: $destinazione})
#                     MERGE (o)-[r:HA]->(d)
#                      SET r.livello = $livello, r.grado tecnologico LTK = $grado tecnologico LTK RETURN r
# Parametri: {'origine': 'BigBangMicrocosmico', 'destinazione': 'Quantistica', 'livello': '10', 'grado tecnologico LTK': 'III'}
# ERRORE nel caricamento della relazione PolarizzataFreddoIperbarico-[HA]->Magnetica: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'tecnologico': expected an expression, '.' or '=' (line 5, column 56 (offset: 216))
# "                     SET r.livello = $livello, r.grado tecnologico LTK = $grado tecnologico LTK RETURN r"
#                                                         ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Licenza {nome: $destinazione})
#                     MERGE (o)-[r:HA]->(d)
#                      SET r.livello = $livello, r.grado tecnologico LTK = $grado tecnologico LTK RETURN r
# Parametri: {'origine': 'PolarizzataFreddoIperbarico', 'destinazione': 'Magnetica', 'livello': 'I', 'grado tecnologico LTK': 'II'}
#
# Riepilogo: create 45 entità e 4 relazioni
# Verifica finale dal database: 212 nodi e 64 relazioni presenti
#
# Esempi di nodi per tipo:
#   Tecnica: CucinaGravitazionale, FritturaSicura, SouffleOrbitale, MontareMaionese, PrincipioDiNonAlterazione
#   Licenza: Psionica, Temporale, Gravitazionale, Antimateria, Marinatura_Temporale_Sincronizzata
#   Pianeta: Andromeda
#   Piatto: brasato, soufflé orbitale, maionese, soufflé, torte
#   Ristorante: MarinaturaSottoZeroaPolaritaInversa, Affumicatura, AffumicaturaaStratificazioneQuantica, AffumicaturaTemporaleRisonante, AffumicaturaPsionicaSensoriale
#   Ingrediente: crostaceo, lattosio, latte, burro, panna
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Errore nel parsing JSON delle relazioni OFFERTA: Extra data: line 2 column 1 (char 3)
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 2 entità di tipo Piatto...
# Creazione entità: ig bang microcosmico (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.antimateria = $antimateria, e.quantistica = $quantistica, e.ltk = $ltk RETURN e
# Entità creata e confermata: ig bang microcosmico di tipo Piatto
# Creazione entità: a(umicatura polarizzata a freddo iperbarico (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.magnetica = $magnetica, e.ltk = $ltk RETURN e
# Entità creata e confermata: a(umicatura polarizzata a freddo iperbarico di tipo Piatto
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 28 entità di tipo Licenza...
# Creazione entità: antimateria (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: antimateria di tipo Licenza
# Creazione entità: quantistica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Licenza
# Creazione entità: magnetica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: magnetica di tipo Licenza
# Creazione entità: quantistica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Licenza
# Creazione entità: temporale (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: temporale di tipo Licenza
# Creazione entità: psionica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: psionica di tipo Licenza
# Creazione entità: gravitazionale (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: gravitazionale di tipo Licenza
# Creazione entità: antimateria (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: antimateria di tipo Licenza
# Creazione entità: magnetica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: magnetica di tipo Licenza
# Creazione entità: quantistica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Licenza
# Creazione entità: antimaterica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: antimaterica di tipo Licenza
# Creazione entità: quantistica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Licenza
# Creazione entità: magnetica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: magnetica di tipo Licenza
# Creazione entità: psionica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: psionica di tipo Licenza
# Creazione entità: luce (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: luce di tipo Licenza
# Creazione entità: temporale (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: temporale di tipo Licenza
# Creazione entità: quantistica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Licenza
# Creazione entità: psionica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: psionica di tipo Licenza
# Creazione entità: gravitazionale (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: gravitazionale di tipo Licenza
# Creazione entità: magnetica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: magnetica di tipo Licenza
# Creazione entità: quantistica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Licenza
# Creazione entità: luce (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: luce di tipo Licenza
# Creazione entità: magnetica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: magnetica di tipo Licenza
# Creazione entità: quantistica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Licenza
# Creazione entità: luce (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: luce di tipo Licenza
# Creazione entità: magnetica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: magnetica di tipo Licenza
# Creazione entità: quantistica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Licenza
# Creazione entità: luce (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: luce di tipo Licenza
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 0 entità di tipo Pianeta...
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 17 entità di tipo Ingrediente...
# Creazione entità: antimateria (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: antimateria di tipo Ingrediente
# Creazione entità: quantistica (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Ingrediente
# Creazione entità: magnetica (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: magnetica di tipo Ingrediente
# Creazione entità: quantistica (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Ingrediente
# Creazione entità: temporale (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: temporale di tipo Ingrediente
# Creazione entità: psionica (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: psionica di tipo Ingrediente
# Creazione entità: gravitazionale (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: gravitazionale di tipo Ingrediente
# Creazione entità: quantistica (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Ingrediente
# Creazione entità: quantistica (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Ingrediente
# Creazione entità: psionica (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: psionica di tipo Ingrediente
# Creazione entità: luce (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: luce di tipo Ingrediente
# Creazione entità: quantistica (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Ingrediente
# Creazione entità: psionica (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: psionica di tipo Ingrediente
# Creazione entità: gravitazionale (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: gravitazionale di tipo Ingrediente
# Creazione entità: quantistica (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Ingrediente
# Creazione entità: quantistica (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: quantistica di tipo Ingrediente
# Creazione entità: luce (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.code = $code, e.livello = $livello RETURN e
# Entità creata e confermata: luce di tipo Ingrediente
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 15 entità di tipo Tecnica...
# Creazione entità: fermentazione_quantica_a_strati_multiversali (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# ERRORE nel caricamento dell'entità fermentazione_quantica_a_strati_multiversali: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{tipo -> String("quantistica"), livello -> String("5")}.}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# Parametri: {'nome': 'fermentazione_quantica_a_strati_multiversali', 'licenze': [{'tipo': 'quantistica', 'livello': '5'}], 'param_grado': {'LTK': 'VI+'}}
# Creazione entità: fermentazione_temporale_sincronizzata (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# ERRORE nel caricamento dell'entità fermentazione_temporale_sincronizzata: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{tipo -> String("temporale"), livello -> String("III")}.}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# Parametri: {'nome': 'fermentazione_temporale_sincronizzata', 'licenze': [{'tipo': 'temporale', 'livello': 'III'}], 'param_grado': {'LTK': 'III'}}
# Creazione entità: fermentazione_psionica_energetica (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# ERRORE nel caricamento dell'entità fermentazione_psionica_energetica: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{tipo -> String("psionica"), livello -> String("I")}.}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# Parametri: {'nome': 'fermentazione_psionica_energetica', 'licenze': [{'tipo': 'psionica', 'livello': 'I'}], 'param_grado': {'LTK': 'III'}}
# Creazione entità: fermentazione_tramite_singolarità (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# ERRORE nel caricamento dell'entità fermentazione_tramite_singolarità: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{tipo -> String("gravitazionale"), livello -> String("III")}.}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# Parametri: {'nome': 'fermentazione_tramite_singolarità', 'licenze': [{'tipo': 'gravitazionale', 'livello': 'III'}, {'tipo': 'antimateria', 'livello': 'I'}, {'tipo': 'magnetica', 'livello': 'I'}], 'param_grado': {'LTK': 'IV'}}
# Creazione entità: fermentazione_quantico_biometrica (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# ERRORE nel caricamento dell'entità fermentazione_quantico_biometrica: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{tipo -> String("quantistica"), livello -> String("3")}.}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# Parametri: {'nome': 'fermentazione_quantico_biometrica', 'licenze': [{'tipo': 'quantistica', 'livello': '3'}], 'param_grado': {'LTK': 'II'}}
# Creazione entità: decostruzione_atomica_a_strati_energetici (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# ERRORE nel caricamento dell'entità decostruzione_atomica_a_strati_energetici: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{tipo -> String("antimaterica"), livello -> String("I")}.}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# Parametri: {'nome': 'decostruzione_atomica_a_strati_energetici', 'licenze': [{'tipo': 'antimaterica', 'livello': 'I'}, {'tipo': 'quantistica', 'livello': '1'}], 'param_grado': {'LTK': 'II'}}
# Creazione entità: decostruzione_magnetica_risonante (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# ERRORE nel caricamento dell'entità decostruzione_magnetica_risonante: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{tipo -> String("magnetica"), livello -> String("I")}.}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# Parametri: {'nome': 'decostruzione_magnetica_risonante', 'licenze': [{'tipo': 'magnetica', 'livello': 'I'}], 'param_grado': {'LTK': 'II'}}
# Creazione entità: decostruzione_bio_fotonica_emotiva (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# ERRORE nel caricamento dell'entità decostruzione_bio_fotonica_emotiva: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{tipo -> String("psionica"), livello -> String("III")}.}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# Parametri: {'nome': 'decostruzione_bio_fotonica_emotiva', 'licenze': [{'tipo': 'psionica', 'livello': 'III'}, {'tipo': 'luce', 'livello': 'III'}], 'param_grado': {'LTK': 'II'}}
# Creazione entità: decostruzione_ancestrale (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# ERRORE nel caricamento dell'entità decostruzione_ancestrale: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{tipo -> String("temporale"), livello -> String("III")}.}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# Parametri: {'nome': 'decostruzione_ancestrale', 'licenze': [{'tipo': 'temporale', 'livello': 'III'}], 'param_grado': {'LTK': 'II'}}
# Creazione entità: decostruzione_interdimensionale_lovercraftiana (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# ERRORE nel caricamento dell'entità decostruzione_interdimensionale_lovercraftiana: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{tipo -> String("quantistica"), livello -> String("7")}.}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# Parametri: {'nome': 'decostruzione_interdimensionale_lovercraftiana', 'licenze': [{'tipo': 'quantistica', 'livello': '7'}], 'param_grado': {'LTK': 'VI'}}
# Creazione entità: sferificazione_a_gravità_psionica_variabile (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# ERRORE nel caricamento dell'entità sferificazione_a_gravità_psionica_variabile: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{tipo -> String("psionica"), livello -> String("IV")}.}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# Parametri: {'nome': 'sferificazione_a_gravità_psionica_variabile', 'licenze': [{'tipo': 'psionica', 'livello': 'IV'}, {'tipo': 'gravitazionale', 'livello': 'I'}], 'param_grado': {'LTK': 'III'}}
# Creazione entità: sferificazione_filanamentare_a_molecole_vibrazionali (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# ERRORE nel caricamento dell'entità sferificazione_filanamentare_a_molecole_vibrazionali: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{tipo -> String("magnetica"), livello -> String("I")}.}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# Parametri: {'nome': 'sferificazione_filanamentare_a_molecole_vibrazionali', 'licenze': [{'tipo': 'magnetica', 'livello': 'I'}, {'tipo': 'quantistica', 'livello': '4'}], 'param_grado': {'LTK': 'II'}}
# Creazione entità: sferificazione_cromatica_interdimensionale (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# ERRORE nel caricamento dell'entità sferificazione_cromatica_interdimensionale: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{tipo -> String("quantistica"), livello -> String("6")}.}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.licenze = $licenze, e.grado = $param_grado RETURN e
# ...
#                      SET
# Parametri: {'nome': 'cottura_sottovuoto_pulsar_magnetica', 'G': 1, 'Mx': 1, 'LTK': 3}
# ERRORE nel caricamento della relazione cottura_al_forno_con_paradosso_temporale_cronospeculare-[PREPARATO]->cottura_al_forno_con_paradosso_temporale_cronospeculare: 'list' object has no attribute 'keys'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      SET
# Parametri: {'nome': 'cottura_sottovuoto_pulsar_magnetica', 'G': 1, 'Mx': 1, 'LTK': 3}
# ERRORE nel caricamento della relazione cottura_con_microonde_entropiche_sincronizzate-[PREPARATO]->cottura_con_microonde_entropiche_sincronizzate: 'list' object has no attribute 'keys'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      SET
# Parametri: {'nome': 'cottura_sottovuoto_pulsar_magnetica', 'G': 1, 'Mx': 1, 'LTK': 3}
# ERRORE: Nodo destinazione 'cottura_a_forno_dinamico_inversionale' di tipo Tecnica non trovato
# Creazione automatica del nodo destinazione...
# Nodo destinazione 'cottura_a_forno_dinamico_inversionale' creato
# ERRORE nel caricamento della relazione cottura_a_forno_dinamico_inversionale-[PREPARATO]->cottura_a_forno_dinamico_inversionale: 'list' object has no attribute 'keys'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      SET
# Parametri: {'nome': 'cottura_sottovuoto_pulsar_magnetica', 'G': 1, 'Mx': 1, 'LTK': 3}
# ERRORE nel caricamento della relazione cottura_olografica_quantum_fluttuante-[PREPARATO]->cottura_olografica_quantum_fluttuante: 'list' object has no attribute 'keys'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      SET
# Parametri: {'nome': 'cottura_sottovuoto_pulsar_magnetica', 'G': 1, 'Mx': 1, 'LTK': 3}
# ERRORE nel caricamento della relazione cottura_geomagnetica_psicosincronizzata-[PREPARATO]->cottura_geomagnetica_psicosincronizzata: 'list' object has no attribute 'keys'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      SET
# Parametri: {'nome': 'cottura_sottovuoto_pulsar_magnetica', 'G': 1, 'Mx': 1, 'LTK': 3}
# ERRORE nel caricamento della relazione cottura_a_vapore_risonante_simbiotico-[PREPARATO]->cottura_a_vapore_risonante_simbiotico: 'list' object has no attribute 'keys'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      SET
# Parametri: {'nome': 'cottura_sottovuoto_pulsar_magnetica', 'G': 1, 'Mx': 1, 'LTK': 3}
# ERRORE: Nodo destinazione 'cottura_idrodinamica_autoregolante' di tipo Tecnica non trovato
# Creazione automatica del nodo destinazione...
# Nodo destinazione 'cottura_idrodinamica_autoregolante' creato
# ERRORE nel caricamento della relazione cottura_idrodinamica_autoregolante-[PREPARATO]->cottura_idrodinamica_autoregolante: 'list' object has no attribute 'keys'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      SET
# Parametri: {'nome': 'cottura_sottovuoto_pulsar_magnetica', 'G': 1, 'Mx': 1, 'LTK': 3}
# ERRORE: Nodo destinazione 'cottura_sottovuoto_antimateria' di tipo Tecnica non trovato
# Creazione automatica del nodo destinazione...
# Nodo destinazione 'cottura_sottovuoto_antimateria' creato
# ERRORE nel caricamento della relazione cottura_sottovuoto_antimateria-[PREPARATO]->cottura_sottovuoto_antimateria: 'list' object has no attribute 'keys'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      SET
# Parametri: {'nome': 'cottura_sottovuoto_pulsar_magnetica', 'G': 1, 'Mx': 1, 'LTK': 3}
# ERRORE: Nodo destinazione 'cottura_sottovuoto_multirealta_collassante' di tipo Tecnica non trovato
# Creazione automatica del nodo destinazione...
# Nodo destinazione 'cottura_sottovuoto_multirealta_collassante' creato
# ERRORE nel caricamento della relazione cottura_sottovuoto_multirealta_collassante-[PREPARATO]->cottura_sottovuoto_multirealta_collassante: 'list' object has no attribute 'keys'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      SET
# Parametri: {'nome': 'cottura_sottovuoto_pulsar_magnetica', 'G': 1, 'Mx': 1, 'LTK': 3}
# ERRORE nel caricamento della relazione cottura_sottovuoto_frugale_energeticamente_negativa-[PREPARATO]->cottura_sottovuoto_frugale_energeticamente_negativa: 'list' object has no attribute 'keys'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      SET
# Parametri: {'nome': 'cottura_sottovuoto_pulsar_magnetica', 'G': 1, 'Mx': 1, 'LTK': 3}
# ERRORE nel caricamento della relazione cottura_sottovuoto_pulsar_magnetica-[PREPARATO]->cottura_sottovuoto_pulsar_magnetica: 'list' object has no attribute 'keys'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      SET
# Parametri: {'nome': 'cottura_sottovuoto_pulsar_magnetica', 'G': 1, 'Mx': 1, 'LTK': 3}
# Caricando 0 relazioni di tipo OFFERTA...
# Caricando 0 relazioni di tipo SITUATO...
# Caricando 0 relazioni di tipo HA...
#
# Riepilogo: create 47 entità e 0 relazioni
# Verifica finale dal database: 292 nodi e 67 relazioni presenti
#
# Esempi di nodi per tipo:
#   Tecnica: CucinaGravitazionale, FritturaSicura, SouffleOrbitale, MontareMaionese, PrincipioDiNonAlterazione
#   Licenza: Psionica, Temporale, Gravitazionale, Antimateria, Marinatura_Temporale_Sincronizzata
#   Pianeta: Andromeda
#   Piatto: brasato, soufflé orbitale, maionese, soufflé, torte
#   Ristorante: MarinaturaSottoZeroaPolaritaInversa, Affumicatura, AffumicaturaaStratificazioneQuantica, AffumicaturaTemporaleRisonante, AffumicaturaPsionicaSensoriale
#   Ingrediente: crostaceo, lattosio, latte, burro, panna
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 0 entità di tipo Piatto...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 8 entità di tipo Licenza...
# Creazione entità: Gravitazionale (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: Gravitazionale di tipo Licenza
# Creazione entità: Gravitazionale (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: Gravitazionale di tipo Licenza
# Creazione entità: Quantistica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: Quantistica di tipo Licenza
# Creazione entità: Quantistica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: Quantistica di tipo Licenza
# Creazione entità: Magnetica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: Magnetica di tipo Licenza
# Creazione entità: Psionica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: Psionica di tipo Licenza
# Creazione entità: Psionica (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: Psionica di tipo Licenza
# Creazione entità: Antimateria (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.simbolo = $simbolo, e.livello = $livello RETURN e
# Entità creata e confermata: Antimateria di tipo Licenza
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 0 entità di tipo Pianeta...
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 0 entità di tipo Ingrediente...
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 6 entità di tipo Tecnica...
# Creazione entità: cottura_sottovuoto_pulsar_magnetica (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.G = $G, e.Mx = $Mx, e.LTK = $LTK RETURN e
# Entità creata e confermata: cottura_sottovuoto_pulsar_magnetica di tipo Tecnica
# Creazione entità: cottura_sottovuoto_bioma_sintetico (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.P = $P, e.G = $G, e.LTK = $LTK RETURN e
# Entità creata e confermata: cottura_sottovuoto_bioma_sintetico di tipo Tecnica
# Creazione entità: saltare_in_padella_Big_Bang_termico (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.G = $G, e.e+ = $e+, e.LTK = $LTK RETURN e
# ERRORE nel caricamento dell'entità saltare_in_padella_Big_Bang_termico: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '+': expected an expression, '.' or '=' (line 1, column 50 (offset: 49))
# "MERGE (e:Tecnica {nome: $nome}) SET e.G = $G, e.e+ = $e+, e.LTK = $LTK RETURN e"
#                                                   ^}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.G = $G, e.e+ = $e+, e.LTK = $LTK RETURN e
# Parametri: {'nome': 'saltare_in_padella_Big_Bang_termico', 'G': 'III', 'e+': 'I', 'LTK': 'V'}
# Creazione entità: saltare_in_padella_realtà_energetiche_parallele (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.Q = $Q, e.LTK = $LTK RETURN e
# Entità creata e confermata: saltare_in_padella_realtà_energetiche_parallele di tipo Tecnica
# Creazione entità: saltare_in_padella_singolarità_inversa (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.G = $G, e.e+ = $e+, e.LTK = $LTK RETURN e
# ERRORE nel caricamento dell'entità saltare_in_padella_singolarità_inversa: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '+': expected an expression, '.' or '=' (line 1, column 50 (offset: 49))
# "MERGE (e:Tecnica {nome: $nome}) SET e.G = $G, e.e+ = $e+, e.LTK = $LTK RETURN e"
#                                                   ^}
# Query: MERGE (e:Tecnica {nome: $nome}) SET e.G = $G, e.e+ = $e+, e.LTK = $LTK RETURN e
# Parametri: {'nome': 'saltare_in_padella_singolarità_inversa', 'G': 'III', 'e+': 'I', 'LTK': 'IV'}
# Creazione entità: saltare_in_padella_sinergia_psionica (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.P = $P, e.LTK = $LTK RETURN e
# Entità creata e confermata: saltare_in_padella_sinergia_psionica di tipo Tecnica
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 0 entità di tipo Ristorante...
# Caricando 0 relazioni di tipo CONTIENE...
# Caricando 0 relazioni di tipo PREPARATO...
# Caricando 0 relazioni di tipo OFFERTA...
# Caricando 0 relazioni di tipo SITUATO...
# Caricando 0 relazioni di tipo HA...
#
# Riepilogo: create 12 entità e 0 relazioni
# Verifica finale dal database: 295 nodi e 67 relazioni presenti
#
# Esempi di nodi per tipo:
#   Tecnica: CucinaGravitazionale, FritturaSicura, SouffleOrbitale, MontareMaionese, PrincipioDiNonAlterazione
#   Licenza: Psionica, Temporale, Gravitazionale, Antimateria, Marinatura_Temporale_Sincronizzata
#   Pianeta: Andromeda
#   Piatto: brasato, soufflé orbitale, maionese, soufflé, torte
#   Ristorante: MarinaturaSottoZeroaPolaritaInversa, Affumicatura, AffumicaturaaStratificazioneQuantica, AffumicaturaTemporaleRisonante, AffumicaturaPsionicaSensoriale
#   Ingrediente: crostaceo, lattosio, latte, burro, panna
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 0 entità di tipo Piatto...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 1 entità di tipo Licenza...
# Creazione entità: derogheTemporanee (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.concessione = $concessione, e.consultazione = $consultazione RETURN e
# Entità creata e confermata: derogheTemporanee di tipo Licenza
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 0 entità di tipo Pianeta...
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 0 entità di tipo Ingrediente...
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 5 entità di tipo Tecnica...
# Creazione entità: Calcolo (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.tipo = $tipo, e.metodologia = $metodologia RETURN e
# Entità creata e confermata: Calcolo di tipo Tecnica
# Creazione entità: Cumulo (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.base = $base, e.moltiplicatori = $moltiplicatori RETURN e
# Entità creata e confermata: Cumulo di tipo Tecnica
# Creazione entità: Valutazione (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.base = $base RETURN e
# Entità creata e confermata: Valutazione di tipo Tecnica
# Creazione entità: Moltiplicatori (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.categorie = $categorie, e.gravità = $gravità, e.impatto = $impatto, e.violazione = $violazione RETURN e
# Entità creata e confermata: Moltiplicatori di tipo Tecnica
# Creazione entità: Metodologia (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.calcolo = $calcolo RETURN e
# Entità creata e confermata: Metodologia di tipo Tecnica
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 0 entità di tipo Ristorante...
# Caricando 0 relazioni di tipo CONTIENE...
# Caricando 0 relazioni di tipo PREPARATO...
# Caricando 0 relazioni di tipo OFFERTA...
# Caricando 0 relazioni di tipo SITUATO...
# Caricando 0 relazioni di tipo HA...
#
# Riepilogo: create 6 entità e 0 relazioni
# Verifica finale dal database: 301 nodi e 67 relazioni presenti
#
# Esempi di nodi per tipo:
#   Tecnica: CucinaGravitazionale, FritturaSicura, SouffleOrbitale, MontareMaionese, PrincipioDiNonAlterazione
#   Licenza: Psionica, Temporale, Gravitazionale, Antimateria, Marinatura_Temporale_Sincronizzata
#   Pianeta: Andromeda
#   Piatto: brasato, soufflé orbitale, maionese, soufflé, torte
#   Ristorante: MarinaturaSottoZeroaPolaritaInversa, Affumicatura, AffumicaturaaStratificazioneQuantica, AffumicaturaTemporaleRisonante, AffumicaturaPsionicaSensoriale
#   Ingrediente: crostaceo, lattosio, latte, burro, panna

# %%
# Estrai entità e relazioni
chunks = chunk_text(testo_blog1, 3000, 400)
for chunk in chunks:
    risultati = estrai_relazioni(chunk, relazioni, llm, driver)
    carica_entita_e_relazioni_su_neo4j(risultati, relazioni, driver)
# Out:
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 3 entità di tipo Piatto...
# Creazione entità: Risveglio del Drago Celeste (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.ingredient = $ingredient, e.percentage = $percentage RETURN e
# Entità creata e confermata: Risveglio del Drago Celeste di tipo Piatto
# Creazione entità: Cosmic Harmony Infusion (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.ingredient = $ingredient, e.percentage = $percentage RETURN e
# Entità creata e confermata: Cosmic Harmony Infusion di tipo Piatto
# Creazione entità: Sinfonia Multiversale in Otto Movimenti (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.ingredient = $ingredient, e.percentage = $percentage RETURN e
# Entità creata e confermata: Sinfonia Multiversale in Otto Movimenti di tipo Piatto
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 0 entità di tipo Licenza...
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 1 entità di tipo Pianeta...
# Creazione entità: Pandora (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) RETURN e
# Entità creata e confermata: Pandora di tipo Pianeta
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 3 entità di tipo Ingrediente...
# Creazione entità: Carne di Drago (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.percentuale = $percentuale RETURN e
# Entità creata e confermata: Carne di Drago di tipo Ingrediente
# Creazione entità: Petali di Eco (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.percentuale = $percentuale RETURN e
# Entità creata e confermata: Petali di Eco di tipo Ingrediente
# Creazione entità: Muffa Lunare (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.percentuale = $percentuale RETURN e
# Entità creata e confermata: Muffa Lunare di tipo Ingrediente
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 2 entità di tipo Tecnica...
# Creazione entità: Cotture a Vapore con Flusso di Particelle Isoarmoniche (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.flusso = $flusso RETURN e
# Entità creata e confermata: Cotture a Vapore con Flusso di Particelle Isoarmoniche di tipo Tecnica
# Creazione entità: forno a legna (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: forno a legna di tipo Tecnica
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 1 entità di tipo Ristorante...
# Creazione entità: L'Etere del Gusto (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.locale = $locale, e.chef = $chef, e.certificazioni = $certificazioni, e.status = $status, e.voto = $voto, e.tecnologia = $tecnologia, e.cucina = $cucina RETURN e
# Entità creata e confermata: L'Etere del Gusto di tipo Ristorante
# Caricando 3 relazioni di tipo CONTIENE...
# Relazione creata e confermata: Risveglio del Drago Celeste-[CONTIENE]->Carne di Drago
# Relazione creata e confermata: Cosmic Harmony Infusion-[CONTIENE]->Petali di Eco
# Relazione creata e confermata: Sinfonia Multiversale in Otto Movimenti-[CONTIENE]->Muffa Lunare
# Caricando 0 relazioni di tipo PREPARATO...
# Caricando 3 relazioni di tipo OFFERTA...
# ERRORE nel caricamento della relazione L'Etere del Gusto-[OFFERTA]->Risveglio del Drago Celeste: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'di': expected an expression, '.' or '=' (line 5, column 34 (offset: 198))
# "                     SET r.Carne di Drago = $Carne di Drago RETURN r"
#                                   ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Piatto {nome: $destinazione})
#                     MERGE (o)-[r:OFFERTA]->(d)
#                      SET r.Carne di Drago = $Carne di Drago RETURN r
# Parametri: {'origine': "L'Etere del Gusto", 'destinazione': 'Risveglio del Drago Celeste', 'Carne di Drago': '8% del volume di preparazione'}
# ERRORE nel caricamento della relazione L'Etere del Gusto-[OFFERTA]->Cosmic Harmony Infusion: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'di': expected an expression, '.' or '=' (line 5, column 35 (offset: 199))
# "                     SET r.Petali di Eco = $Petali di Eco RETURN r"
#                                    ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Piatto {nome: $destinazione})
#                     MERGE (o)-[r:OFFERTA]->(d)
#                      SET r.Petali di Eco = $Petali di Eco RETURN r
# Parametri: {'origine': "L'Etere del Gusto", 'destinazione': 'Cosmic Harmony Infusion', 'Petali di Eco': '3% del volume'}
# ERRORE nel caricamento della relazione L'Etere del Gusto-[OFFERTA]->Sinfonia Multiversale in Otto Movimenti: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'Lunare': expected an expression, '.' or '=' (line 5, column 34 (offset: 198))
# "                     SET r.Muffa Lunare = $Muffa Lunare RETURN r"
#                                   ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Piatto {nome: $destinazione})
#                     MERGE (o)-[r:OFFERTA]->(d)
#                      SET r.Muffa Lunare = $Muffa Lunare RETURN r
# Parametri: {'origine': "L'Etere del Gusto", 'destinazione': 'Sinfonia Multiversale in Otto Movimenti', 'Muffa Lunare': '2% in volume'}
# Caricando 1 relazioni di tipo SITUATO...
# Relazione creata e confermata: L'Etere del Gusto-[SITUATO]->Pandora
# Caricando 0 relazioni di tipo HA...
#
# Riepilogo: create 10 entità e 4 relazioni
# Verifica finale dal database: 309 nodi e 71 relazioni presenti
#
# Esempi di nodi per tipo:
#   Tecnica: CucinaGravitazionale, FritturaSicura, SouffleOrbitale, MontareMaionese, PrincipioDiNonAlterazione
#   Licenza: Psionica, Temporale, Gravitazionale, Antimateria, Marinatura_Temporale_Sincronizzata
#   Pianeta: Andromeda, Pandora
#   Piatto: brasato, soufflé orbitale, maionese, soufflé, torte
#   Ristorante: MarinaturaSottoZeroaPolaritaInversa, Affumicatura, AffumicaturaaStratificazioneQuantica, AffumicaturaTemporaleRisonante, AffumicaturaPsionicaSensoriale
#   Ingrediente: crostaceo, lattosio, latte, burro, panna

# %%
# Estrai entità e relazioni
chunks = chunk_text(testo_blog2, 3000, 400)
for chunk in chunks:
    risultati = estrai_relazioni(chunk, relazioni, llm, driver)
    carica_entita_e_relazioni_su_neo4j(risultati, relazioni, driver)
# Out:
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 5 entità di tipo Piatto...
# Creazione entità: Sinfonia Quantistica delle Stelle (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.SaleTemporale = $SaleTemporale, e.NettareDiSirena = $NettareDiSirena RETURN e
# Entità creata e confermata: Sinfonia Quantistica delle Stelle di tipo Piatto
# Creazione entità: Galassia di Sapore Quantico (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.PolvereDiStelle = $PolvereDiStelle, e.CarneDiDrago = $CarneDiDrago RETURN e
# Entità creata e confermata: Galassia di Sapore Quantico di tipo Piatto
# Creazione entità: Evanescenza Quantica (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.CristalliDiMemoria = $CristalliDiMemoria, e.PetaliDiEco = $PetaliDiEco RETURN e
# Entità creata e confermata: Evanescenza Quantica di tipo Piatto
# Creazione entità: Pioggia di Dimensioni Galattiche (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.EssenzaDiVuoto = $EssenzaDiVuoto, e.NettareDiSirena = $NettareDiSirena, e.PaneDegliAbissi = $PaneDegliAbissi RETURN e
# Entità creata e confermata: Pioggia di Dimensioni Galattiche di tipo Piatto
# Creazione entità: Sinfonia Galattica (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.FunghiDellEtere = $FunghiDellEtere, e.CarneDiDrago = $CarneDiDrago RETURN e
# Entità creata e confermata: Sinfonia Galattica di tipo Piatto
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 1 entità di tipo Licenza...
# Creazione entità: certificazione (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.descrizione = $descrizione RETURN e
# Entità creata e confermata: certificazione di tipo Licenza
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 1 entità di tipo Pianeta...
# Creazione entità: Dune (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) RETURN e
# Entità creata e confermata: Dune di tipo Pianeta
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 9 entità di tipo Ingrediente...
# Creazione entità: Sale Temporale (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.percentuale = $percentuale RETURN e
# Entità creata e confermata: Sale Temporale di tipo Ingrediente
# Creazione entità: Nettare di Sirena (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.percentuale = $percentuale RETURN e
# Entità creata e confermata: Nettare di Sirena di tipo Ingrediente
# Creazione entità: Polvere di Stelle (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.percentuale = $percentuale RETURN e
# Entità creata e confermata: Polvere di Stelle di tipo Ingrediente
# Creazione entità: Carne di Drago (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.percentuale = $percentuale RETURN e
# Entità creata e confermata: Carne di Drago di tipo Ingrediente
# Creazione entità: Cristalli di Memoria (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.percentuale = $percentuale RETURN e
# Entità creata e confermata: Cristalli di Memoria di tipo Ingrediente
# Creazione entità: Petali di Eco (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.percentuale = $percentuale RETURN e
# Entità creata e confermata: Petali di Eco di tipo Ingrediente
# Creazione entità: Essenza di Vuoto (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.percentuale = $percentuale RETURN e
# Entità creata e confermata: Essenza di Vuoto di tipo Ingrediente
# Creazione entità: Funghi dell'Etere (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.percentuale = $percentuale RETURN e
# Entità creata e confermata: Funghi dell'Etere di tipo Ingrediente
# Creazione entità: pane degli abissi (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: pane degli abissi di tipo Ingrediente
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 2 entità di tipo Tecnica...
# Creazione entità: cucina molecolare (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: cucina molecolare di tipo Tecnica
# Creazione entità: Cottura Sottovuoto Frugale Energeticamente Negati (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Cottura Sottovuoto Frugale Energeticamente Negati di tipo Tecnica
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 1 entità di tipo Ristorante...
# Creazione entità: Sapore del Dune (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) RETURN e
# Entità creata e confermata: Sapore del Dune di tipo Ristorante
# Caricando 11 relazioni di tipo CONTIENE...
# Relazione creata e confermata: Sinfonia Quantistica delle Stelle-[CONTIENE]->Sale Temporale
# Relazione creata e confermata: Sinfonia Quantistica delle Stelle-[CONTIENE]->Nettare di Sirena
# Relazione creata e confermata: Galassia di Sapore Quantico-[CONTIENE]->Polvere di Stelle
# Relazione creata e confermata: Galassia di Sapore Quantico-[CONTIENE]->Carne di Drago
# Relazione creata e confermata: Evanescenza Quantica-[CONTIENE]->Cristalli di Memoria
# Relazione creata e confermata: Evanescenza Quantica-[CONTIENE]->Petali di Eco
# Relazione creata e confermata: Pioggia di Dimensioni Galattiche-[CONTIENE]->Essenza di Vuoto
# Relazione creata e confermata: Pioggia di Dimensioni Galattiche-[CONTIENE]->Nettare di Sirena
# Relazione creata e confermata: Pioggia di Dimensioni Galattiche-[CONTIENE]->pane degli abissi
# Relazione creata e confermata: Sinfonia Galattica-[CONTIENE]->Funghi dell'Etere
# Relazione creata e confermata: Sinfonia Galattica-[CONTIENE]->Carne di Drago
# Caricando 5 relazioni di tipo PREPARATO...
# Relazione creata e confermata: Sinfonia Quantistica delle Stelle-[PREPARATO]->cucina molecolare
# Relazione creata e confermata: Galassia di Sapore Quantico-[PREPARATO]->cucina molecolare
# Relazione creata e confermata: Evanescenza Quantica-[PREPARATO]->cucina molecolare
# Relazione creata e confermata: Pioggia di Dimensioni Galattiche-[PREPARATO]->cucina molecolare
# Relazione creata e confermata: Sinfonia Galattica-[PREPARATO]->cucina molecolare
# Caricando 5 relazioni di tipo OFFERTA...
# ERRORE nel caricamento della relazione Sapore del Dune-[OFFERTA]->Sinfonia Quantistica delle Stelle: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'Temporale': expected an expression, '.' or '=' (line 5, column 33 (offset: 197))
# "                     SET r.Sale Temporale = $Sale Temporale, r.Nettare di Sirena = $Nettare di Sirena RETURN r"
#                                  ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Piatto {nome: $destinazione})
#                     MERGE (o)-[r:OFFERTA]->(d)
#                      SET r.Sale Temporale = $Sale Temporale, r.Nettare di Sirena = $Nettare di Sirena RETURN r
# Parametri: {'origine': 'Sapore del Dune', 'destinazione': 'Sinfonia Quantistica delle Stelle', 'Sale Temporale': '1%', 'Nettare di Sirena': '0.1%'}
# ERRORE nel caricamento della relazione Sapore del Dune-[OFFERTA]->Galassia di Sapore Quantico: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'di': expected an expression, '.' or '=' (line 5, column 36 (offset: 200))
# "                     SET r.Polvere di Stelle = $Polvere di Stelle, r.Carne di Drago = $Carne di Drago RETURN r"
#                                     ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Piatto {nome: $destinazione})
#                     MERGE (o)-[r:OFFERTA]->(d)
#                      SET r.Polvere di Stelle = $Polvere di Stelle, r.Carne di Drago = $Carne di Drago RETURN r
# Parametri: {'origine': 'Sapore del Dune', 'destinazione': 'Galassia di Sapore Quantico', 'Polvere di Stelle': '1%', 'Carne di Drago': '1%'}
# ERRORE nel caricamento della relazione Sapore del Dune-[OFFERTA]->Evanescenza Quantica: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'di': expected an expression, '.' or '=' (line 5, column 38 (offset: 202))
# "                     SET r.Cristalli di Memoria = $Cristalli di Memoria, r.Petali di Eco = $Petali di Eco RETURN r"
#                                       ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Piatto {nome: $destinazione})
#                     MERGE (o)-[r:OFFERTA]->(d)
#                      SET r.Cristalli di Memoria = $Cristalli di Memoria, r.Petali di Eco = $Petali di Eco RETURN r
# Parametri: {'origine': 'Sapore del Dune', 'destinazione': 'Evanescenza Quantica', 'Cristalli di Memoria': '0.1%', 'Petali di Eco': '0.1%'}
# ERRORE nel caricamento della relazione Sapore del Dune-[OFFERTA]->Pioggia di Dimensioni Galattiche: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'di': expected an expression, '.' or '=' (line 5, column 36 (offset: 200))
# "                     SET r.Essenza di Vuoto = $Essenza di Vuoto, r.Nettare di Sirena = $Nettare di Sirena RETURN r"
#                                     ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Piatto {nome: $destinazione})
#                     MERGE (o)-[r:OFFERTA]->(d)
#                      SET r.Essenza di Vuoto = $Essenza di Vuoto, r.Nettare di Sirena = $Nettare di Sirena RETURN r
# Parametri: {'origine': 'Sapore del Dune', 'destinazione': 'Pioggia di Dimensioni Galattiche', 'Essenza di Vuoto': '3%', 'Nettare di Sirena': '0.1%'}
# ERRORE nel caricamento della relazione Sapore del Dune-[OFFERTA]->Sinfonia Galattica: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'dell': expected an expression, '.' or '=' (line 5, column 35 (offset: 199))
# "                     SET r.Funghi dell'Etere = $Funghi dell'Etere, r.Carne di Drago = $Carne di Drago RETURN r"
#                                    ^}
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Piatto {nome: $destinazione})
#                     MERGE (o)-[r:OFFERTA]->(d)
#                      SET r.Funghi dell'Etere = $Funghi dell'Etere, r.Carne di Drago = $Carne di Drago RETURN r
# Parametri: {'origine': 'Sapore del Dune', 'destinazione': 'Sinfonia Galattica', "Funghi dell'Etere": '2%', 'Carne di Drago': '2%'}
# Caricando 1 relazioni di tipo SITUATO...
# Relazione creata e confermata: Sapore del Dune-[SITUATO]->Dune
# Caricando 1 relazioni di tipo HA...
# Relazione creata e confermata: Sapore del Dune-[HA]->certificazione
#
# Riepilogo: create 19 entità e 18 relazioni
# Verifica finale dal database: 321 nodi e 89 relazioni presenti
#
# Esempi di nodi per tipo:
#   Tecnica: CucinaGravitazionale, FritturaSicura, SouffleOrbitale, MontareMaionese, PrincipioDiNonAlterazione
#   Licenza: Psionica, Temporale, Gravitazionale, Antimateria, Marinatura_Temporale_Sincronizzata
#   Pianeta: Andromeda, Pandora, Dune
#   Piatto: brasato, soufflé orbitale, maionese, soufflé, torte
#   Ristorante: MarinaturaSottoZeroaPolaritaInversa, Affumicatura, AffumicaturaaStratificazioneQuantica, AffumicaturaTemporaleRisonante, AffumicaturaPsionicaSensoriale
#   Ingrediente: crostaceo, lattosio, latte, burro, panna
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 0 entità di tipo Piatto...
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 1 entità di tipo Licenza...
# Creazione entità: certificazioni (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) RETURN e
# Entità creata e confermata: certificazioni di tipo Licenza
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 1 entità di tipo Pianeta...
# Creazione entità: Dune (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) RETURN e
# Entità creata e confermata: Dune di tipo Pianeta
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 0 entità di tipo Ingrediente...
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 1 entità di tipo Tecnica...
# Creazione entità: Cottura Sottovuoto Frugale Energeticamente Negativa (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Cottura Sottovuoto Frugale Energeticamente Negativa di tipo Tecnica
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 2 entità di tipo Ristorante...
# Creazione entità: Sapore del Dune (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.Chef = $Chef, e.Tecniche = $Tecniche, e.Voto = $Voto RETURN e
# Entità creata e confermata: Sapore del Dune di tipo Ristorante
# Creazione entità: taverna locale di Mos Eisley (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) RETURN e
# Entità creata e confermata: taverna locale di Mos Eisley di tipo Ristorante
# Caricando 0 relazioni di tipo CONTIENE...
# Caricando 1 relazioni di tipo PREPARATO...
# ERRORE: Nodo origine 'Sapore del Dune' di tipo Piatto non trovato
# Creazione automatica del nodo origine...
# Nodo origine 'Sapore del Dune' creato
# Relazione creata e confermata: Sapore del Dune-[PREPARATO]->Cottura Sottovuoto Frugale Energeticamente Negativa
# Caricando 0 relazioni di tipo OFFERTA...
# Caricando 1 relazioni di tipo SITUATO...
# Relazione creata e confermata: Sapore del Dune-[SITUATO]->Dune
# Caricando 1 relazioni di tipo HA...
# Relazione creata e confermata: Sapore del Dune-[HA]->certificazioni
#
# Riepilogo: create 5 entità e 3 relazioni
# Verifica finale dal database: 325 nodi e 91 relazioni presenti
#
# Esempi di nodi per tipo:
#   Tecnica: CucinaGravitazionale, FritturaSicura, SouffleOrbitale, MontareMaionese, PrincipioDiNonAlterazione
#   Licenza: Psionica, Temporale, Gravitazionale, Antimateria, Marinatura_Temporale_Sincronizzata
#   Pianeta: Andromeda, Pandora, Dune
#   Piatto: brasato, soufflé orbitale, maionese, soufflé, torte
#   Ristorante: MarinaturaSottoZeroaPolaritaInversa, Affumicatura, AffumicaturaaStratificazioneQuantica, AffumicaturaTemporaleRisonante, AffumicaturaPsionicaSensoriale
#   Ingrediente: crostaceo, lattosio, latte, burro, panna

# %%
import os
from pathlib import Path

# Percorso della cartella contenente i file PDF dei menu
menu_folder = "../Hackapizza Dataset/Menu/"

# Ottieni la lista di tutti i file PDF nella cartella
pdf_files = [f for f in os.listdir(menu_folder) if f.endswith('.pdf')]

# Per ogni file PDF nella cartella
for pdf_file in pdf_files:
    try:
        # Costruisci il percorso completo del file
        pdf_path = os.path.join(menu_folder, pdf_file)
        
        print(f"Elaborazione del file: {pdf_file}")
        
        # Estrai il testo dal PDF
        testo_menu = estrai_testo_pdf(pdf_path)
        
        risultati = estrai_relazioni(testo_menu, relazioni, llm, driver)
        carica_entita_e_relazioni_su_neo4j(risultati, relazioni, driver)
        
        print(f"Elaborazione di {pdf_file} completata con successo")
        print("-" * 50)
        
    except Exception as e:
        print(f"Errore durante l'elaborazione di {pdf_file}: {str(e)}")
        # Continua con il prossimo file anche in caso di errore
        continue
# Out:
# Elaborazione del file: L Essenza di Asgard.pdf
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 9 entità di tipo Piatto...
# Creazione entità: Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.INGREDIENTI = $INGREDIENTI, e.TECNICHE = $TECNICHE RETURN e
# Entità creata e confermata: Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni di tipo Piatto
# Creazione entità: Sinfonia Cosmica di Terre e Stelle (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.INGREDIENTI = $INGREDIENTI, e.TECNICHE = $TECNICHE RETURN e
# Entità creata e confermata: Sinfonia Cosmica di Terre e Stelle di tipo Piatto
# Creazione entità: Lumière Cosmica (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.INGREDIENTI = $INGREDIENTI, e.TECNICHE = $TECNICHE RETURN e
# Entità creata e confermata: Lumière Cosmica di tipo Piatto
# Creazione entità: Risveglio Cosmico: Un Viaggio nel Sapore Quantistico (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.INGREDIENTI = $INGREDIENTI, e.TECNICHE = $TECNICHE RETURN e
# Entità creata e confermata: Risveglio Cosmico: Un Viaggio nel Sapore Quantistico di tipo Piatto
# Creazione entità: L'Ascensione Siderale (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.INGREDIENTI = $INGREDIENTI, e.TECNICHE = $TECNICHE RETURN e
# Entità creata e confermata: L'Ascensione Siderale di tipo Piatto
# Creazione entità: Portale di Sapori Arcani (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.INGREDIENTI = $INGREDIENTI, e.TECNICHE = $TECNICHE RETURN e
# Entità creata e confermata: Portale di Sapori Arcani di tipo Piatto
# Creazione entità: Fenice sull'Orizzonte degli Eventi (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.INGREDIENTI = $INGREDIENTI, e.TECNICHE = $TECNICHE RETURN e
# Entità creata e confermata: Fenice sull'Orizzonte degli Eventi di tipo Piatto
# Creazione entità: Una Mucca e una Balena nella Singolarità (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.INGREDIENTI = $INGREDIENTI, e.TECNICHE = $TECNICHE RETURN e
# Entità creata e confermata: Una Mucca e una Balena nella Singolarità di tipo Piatto
# Creazione entità: Risotto Cosmico alla Draconia (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.INGREDIENTI = $INGREDIENTI, e.TECNICHE = $TECNICHE RETURN e
# Entità creata e confermata: Risotto Cosmico alla Draconia di tipo Piatto
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 3 entità di tipo Licenza...
# Creazione entità: Temporale (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.Livello = $Livello RETURN e
# Entità creata e confermata: Temporale di tipo Licenza
# Creazione entità: Antimateria (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.Livello = $Livello RETURN e
# Entità creata e confermata: Antimateria di tipo Licenza
# Creazione entità: Luce (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.Livello = $Livello RETURN e
# Entità creata e confermata: Luce di tipo Licenza
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 6 entità di tipo Pianeta...
# Creazione entità: Asgard (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) SET e.regno = $regno, e.bifrost = $bifrost, e.cielo = $cielo RETURN e
# Entità creata e confermata: Asgard di tipo Pianeta
# Creazione entità: Yggdrasil (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) SET e.ambientazione = $ambientazione, e.nasceDa = $nasceDa RETURN e
# Entità creata e confermata: Yggdrasil di tipo Pianeta
# Creazione entità: Hel (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) SET e.descrizione = $descrizione RETURN e
# Entità creata e confermata: Hel di tipo Pianeta
# Creazione entità: Namecciana (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) SET e.tipo = $tipo RETURN e
# Entità creata e confermata: Namecciana di tipo Pianeta
# Creazione entità: Nettuno (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) SET e.tipo = $tipo, e.ingrediente = $ingrediente RETURN e
# Entità creata e confermata: Nettuno di tipo Pianeta
# Creazione entità: Draconia (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) SET e.tipo = $tipo RETURN e
# Entità creata e confermata: Draconia di tipo Pianeta
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 43 entità di tipo Ingrediente...
# Creazione entità: Polvere di Stelle (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Polvere di Stelle di tipo Ingrediente
# Creazione entità: Foglie di Nebulosa (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Foglie di Nebulosa di tipo Ingrediente
# Creazione entità: Baccacedro (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Baccacedro di tipo Ingrediente
# Creazione entità: Foglie di Mandragora (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Foglie di Mandragora di tipo Ingrediente
# Creazione entità: Teste di Idra (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Teste di Idra di tipo Ingrediente
# Creazione entità: Pane di Luce (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Pane di Luce di tipo Ingrediente
# Creazione entità: Spaghi del Sole (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Spaghi del Sole di tipo Ingrediente
# Creazione entità: Gnocchi del Crepuscolo (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Gnocchi del Crepuscolo di tipo Ingrediente
# Creazione entità: Lacrime di Unicorno (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Lacrime di Unicorno di tipo Ingrediente
# Creazione entità: Sale Temporale (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Sale Temporale di tipo Ingrediente
# Creazione entità: Liane di Plasmodio (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Liane di Plasmodio di tipo Ingrediente
# Creazione entità: Fibra di Sintetex (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Fibra di Sintetex di tipo Ingrediente
# Creazione entità: Carne di Xenodonte (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Carne di Xenodonte di tipo Ingrediente
# Creazione entità: Pane degli Abissi (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Pane degli Abissi di tipo Ingrediente
# Creazione entità: Polvere di Pulsar (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Polvere di Pulsar di tipo Ingrediente
# Creazione entità: Radici di Gravità (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Radici di Gravità di tipo Ingrediente
# Creazione entità: Funghi Orbitali (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Funghi Orbitali di tipo Ingrediente
# Creazione entità: Essenza di Tachioni (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Essenza di Tachioni di tipo Ingrediente
# Creazione entità: Biscotti della Galassia (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Biscotti della Galassia di tipo Ingrediente
# Creazione entità: Amido di Stellarion (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Amido di Stellarion di tipo Ingrediente
# Creazione entità: Funghi dell’Etere (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Funghi dell’Etere di tipo Ingrediente
# Creazione entità: Salsa Szechuan (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Salsa Szechuan di tipo Ingrediente
# Creazione entità: Frammenti di Supernova (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Frammenti di Supernova di tipo Ingrediente
# Creazione entità: Carne di Balena spaziale (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Carne di Balena spaziale di tipo Ingrediente
# Creazione entità: Fusilli del Vento (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Fusilli del Vento di tipo Ingrediente
# Creazione entità: Muffa Lunare (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Muffa Lunare di tipo Ingrediente
# Creazione entità: Essenza di Speziaria (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Essenza di Speziaria di tipo Ingrediente
# Creazione entità: Radici di Singolarità (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Radici di Singolarità di tipo Ingrediente
# Creazione entità: Colonia di Mycoflora (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Colonia di Mycoflora di tipo Ingrediente
# Creazione entità: Carne di Drago (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Carne di Drago di tipo Ingrediente
# Creazione entità: Uova di Fenice (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Uova di Fenice di tipo Ingrediente
# Creazione entità: Lacrime di Andromeda (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Lacrime di Andromeda di tipo Ingrediente
# Creazione entità: Spezie Melange (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Spezie Melange di tipo Ingrediente
# Creazione entità: Polvere di Crononite (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Polvere di Crononite di tipo Ingrediente
# Creazione entità: Lattuga Namecciana (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Lattuga Namecciana di tipo Ingrediente
# Creazione entità: Carne di Kraken (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Carne di Kraken di tipo Ingrediente
# Creazione entità: Granuli di Nebbia Arcobaleno (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Granuli di Nebbia Arcobaleno di tipo Ingrediente
# Creazione entità: Farina di Nettuno (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Farina di Nettuno di tipo Ingrediente
# Creazione entità: Erba Pipa (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Erba Pipa di tipo Ingrediente
# Creazione entità: Carne di Mucca (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Carne di Mucca di tipo Ingrediente
# Creazione entità: Spore Quantiche (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Spore Quantiche di tipo Ingrediente
# Creazione entità: Cristalli di Nebulite (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Cristalli di Nebulite di tipo Ingrediente
# Creazione entità: Petali di Eco (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Petali di Eco di tipo Ingrediente
# Elaborazione per tipo: Tecnica
# Tipo di dato: list
# Caricando 20 entità di tipo Tecnica...
# Creazione entità: Amalgamazione Sintetica Molecolare (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Amalgamazione Sintetica Molecolare di tipo Tecnica
# Creazione entità: Fermentazione Quantica a Strati Multiversali (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Fermentazione Quantica a Strati Multiversali di tipo Tecnica
# Creazione entità: Grigliatura Eletro-Molecolare a Spaziatura Variabile (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Grigliatura Eletro-Molecolare a Spaziatura Variabile di tipo Tecnica
# Creazione entità: Fermentazione Psionica Energetica (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Fermentazione Psionica Energetica di tipo Tecnica
# Creazione entità: Affumicatura a Stratificazione Quantica (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Affumicatura a Stratificazione Quantica di tipo Tecnica
# Creazione entità: Affumicatura Psionica Sensoriale (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Affumicatura Psionica Sensoriale di tipo Tecnica
# Creazione entità: Cottura con Microonde Entropiche Sincronizzate (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Cottura con Microonde Entropiche Sincronizzate di tipo Tecnica
# Creazione entità: Lumière Cosmica (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Lumière Cosmica di tipo Tecnica
# Creazione entità: Bollitura Entropica Sincronizzata (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Bollitura Entropica Sincronizzata di tipo Tecnica
# Creazione entità: Bollitura Infrasonica Armonizzata (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Bollitura Infrasonica Armonizzata di tipo Tecnica
# Creazione entità: Portale di Sapori Arcani (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Portale di Sapori Arcani di tipo Tecnica
# Creazione entità: Idro-Cristallizzazione Sonora Quantistica (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Idro-Cristallizzazione Sonora Quantistica di tipo Tecnica
# Creazione entità: Cottura a Vapore Termocinetica Multipla (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Cottura a Vapore Termocinetica Multipla di tipo Tecnica
# Creazione entità: Decostruzione Interdimensionale Lovecraftiana (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Decostruzione Interdimensionale Lovecraftiana di tipo Tecnica
# Creazione entità: Congelazione Iperdimensionalmente Stratificata (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Congelazione Iperdimensionalmente Stratificata di tipo Tecnica
# Creazione entità: Cottura a Vapore con Flusso di Particelle Isoarmoniche (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Cottura a Vapore con Flusso di Particelle Isoarmoniche di tipo Tecnica
# Creazione entità: Affumicatura Temporale Risonante (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Affumicatura Temporale Risonante di tipo Tecnica
# Creazione entità: Portale Cosmico del Kraken (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Portale Cosmico del Kraken di tipo Tecnica
# Creazione entità: Fermentazione Quantico Biometrica (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Fermentazione Quantico Biometrica di tipo Tecnica
# Creazione entità: Risotto Cosmico alla Draconia (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Risotto Cosmico alla Draconia di tipo Tecnica
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 1 entità di tipo Ristorante...
# Creazione entità: L'Essenza di Asgard (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) RETURN e
# Entità creata e confermata: L'Essenza di Asgard di tipo Ristorante
# Caricando 68 relazioni di tipo CONTIENE...
# Relazione creata e confermata: Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[CONTIENE]->Polvere di Stelle
# Relazione creata e confermata: Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[CONTIENE]->Foglie di Nebulosa
# Relazione creata e confermata: Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[CONTIENE]->Baccacedro
# Relazione creata e confermata: Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[CONTIENE]->Foglie di Mandragora
# Relazione creata e confermata: Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[CONTIENE]->Teste di Idra
# Relazione creata e confermata: Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[CONTIENE]->Pane di Luce
# Relazione creata e confermata: Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[CONTIENE]->Spaghi del Sole
# Relazione creata e confermata: Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[CONTIENE]->Gnocchi del Crepuscolo
# Relazione creata e confermata: Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[CONTIENE]->Lacrime di Unicorno
# Relazione creata e confermata: Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[CONTIENE]->Sale Temporale
# Relazione creata e confermata: Sinfonia Cosmica di Terre e Stelle-[CONTIENE]->Baccacedro
# Relazione creata e confermata: Sinfonia Cosmica di Terre e Stelle-[CONTIENE]->Liane di Plasmodio
# Relazione creata e confermata: Sinfonia Cosmica di Terre e Stelle-[CONTIENE]->Fibra di Sintetex
# Relazione creata e confermata: Sinfonia Cosmica di Terre e Stelle-[CONTIENE]->Carne di Xenodonte
# Relazione creata e confermata: Sinfonia Cosmica di Terre e Stelle-[CONTIENE]->Pane di Luce
# Relazione creata e confermata: Sinfonia Cosmica di Terre e Stelle-[CONTIENE]->Pane degli Abissi
# Relazione creata e confermata: Lumière Cosmica-[CONTIENE]->Polvere di Pulsar
# Relazione creata e confermata: Lumière Cosmica-[CONTIENE]->Radici di Gravità
# Relazione creata e confermata: Lumière Cosmica-[CONTIENE]->Pane degli Abissi
# Relazione creata e confermata: Lumière Cosmica-[CONTIENE]->Funghi Orbitali
# Relazione creata e confermata: Lumière Cosmica-[CONTIENE]->Essenza di Tachioni
# Relazione creata e confermata: Risveglio Cosmico: Un Viaggio nel Sapore Quantistico-[CONTIENE]->Polvere di Stelle
# Relazione creata e confermata: Risveglio Cosmico: Un Viaggio nel Sapore Quantistico-[CONTIENE]->Liane di Plasmodio
# Relazione creata e confermata: Risveglio Cosmico: Un Viaggio nel Sapore Quantistico-[CONTIENE]->Biscotti della Galassia
# Relazione creata e confermata: Risveglio Cosmico: Un Viaggio nel Sapore Quantistico-[CONTIENE]->Amido di Stellarion
# Relazione creata e confermata: Risveglio Cosmico: Un Viaggio nel Sapore Quantistico-[CONTIENE]->Funghi dell’Etere
# Relazione creata e confermata: Risveglio Cosmico: Un Viaggio nel Sapore Quantistico-[CONTIENE]->Salsa Szechuan
# Relazione creata e confermata: L'Ascensione Siderale-[CONTIENE]->Frammenti di Supernova
# Relazione creata e confermata: L'Ascensione Siderale-[CONTIENE]->Foglie di Nebulosa
# Relazione creata e confermata: L'Ascensione Siderale-[CONTIENE]->Liane di Plasmodio
# Relazione creata e confermata: L'Ascensione Siderale-[CONTIENE]->Fibra di Sintetex
# Relazione creata e confermata: L'Ascensione Siderale-[CONTIENE]->Carne di Balena spaziale
# Relazione creata e confermata: L'Ascensione Siderale-[CONTIENE]->Fusilli del Vento
# Relazione creata e confermata: L'Ascensione Siderale-[CONTIENE]->Muffa Lunare
# Relazione creata e confermata: L'Ascensione Siderale-[CONTIENE]->Essenza di Speziaria
# Relazione creata e confermata: Portale di Sapori Arcani-[CONTIENE]->Shard di Prisma Stellare
# Relazione creata e confermata: Portale di Sapori Arcani-[CONTIENE]->Foglie di Mandragora
# Relazione creata e confermata: Portale di Sapori Arcani-[CONTIENE]->Carne di Balena spaziale
# Relazione creata e confermata: Portale di Sapori Arcani-[CONTIENE]->Carne di Kraken
# Relazione creata e confermata: Portale di Sapori Arcani-[CONTIENE]->Essenza di Tachioni
# Relazione creata e confermata: Fenice sull'Orizzonte degli Eventi-[CONTIENE]->Baccacedro
# Relazione creata e confermata: Fenice sull'Orizzonte degli Eventi-[CONTIENE]->Radici di Singolarità
# Relazione creata e confermata: Fenice sull'Orizzonte degli Eventi-[CONTIENE]->Colonia di Mycoflora
# Relazione creata e confermata: Fenice sull'Orizzonte degli Eventi-[CONTIENE]->Carne di Xenodonte
# Relazione creata e confermata: Fenice sull'Orizzonte degli Eventi-[CONTIENE]->Carne di Drago
# Relazione creata e confermata: Fenice sull'Orizzonte degli Eventi-[CONTIENE]->Uova di Fenice
# Relazione creata e confermata: Fenice sull'Orizzonte degli Eventi-[CONTIENE]->Pane di Luce
# Relazione creata e confermata: Fenice sull'Orizzonte degli Eventi-[CONTIENE]->Lacrime di Andromeda
# Relazione creata e confermata: Fenice sull'Orizzonte degli Eventi-[CONTIENE]->Spezie Melange
# Relazione creata e confermata: Una Mucca e una Balena nella Singolarità-[CONTIENE]->Polvere di Crononite
# Relazione creata e confermata: Una Mucca e una Balena nella Singolarità-[CONTIENE]->Lattuga Namecciana
# Relazione creata e confermata: Una Mucca e una Balena nella Singolarità-[CONTIENE]->Carne di Drago
# Relazione creata e confermata: Una Mucca e una Balena nella Singolarità-[CONTIENE]->Fibra di Sintetex
# Relazione creata e confermata: Una Mucca e una Balena nella Singolarità-[CONTIENE]->Carne di Kraken
# Relazione creata e confermata: Una Mucca e una Balena nella Singolarità-[CONTIENE]->Amido di Stellarion
# Relazione creata e confermata: Una Mucca e una Balena nella Singolarità-[CONTIENE]->Granuli di Nebbia Arcobaleno
# Relazione creata e confermata: Una Mucca e una Balena nella Singolarità-[CONTIENE]->Farina di Nettuno
# Relazione creata e confermata: Una Mucca e una Balena nella Singolarità-[CONTIENE]->Funghi Orbitali
# Relazione creata e confermata: Una Mucca e una Balena nella Singolarità-[CONTIENE]->Erba Pipa
# Relazione creata e confermata: Risotto Cosmico alla Draconia-[CONTIENE]->Cristalli di Nebulite
# Relazione creata e confermata: Risotto Cosmico alla Draconia-[CONTIENE]->Fibra di Sintetex
# Relazione creata e confermata: Risotto Cosmico alla Draconia-[CONTIENE]->Carne di Drago
# Relazione creata e confermata: Risotto Cosmico alla Draconia-[CONTIENE]->Carne di Mucca
# Relazione creata e confermata: Risotto Cosmico alla Draconia-[CONTIENE]->Fusilli del Vento
# Relazione creata e confermata: Risotto Cosmico alla Draconia-[CONTIENE]->Granuli di Nebbia Arcobaleno
# Relazione creata e confermata: Risotto Cosmico alla Draconia-[CONTIENE]->Biscotti della Galassia
# Relazione creata e confermata: Risotto Cosmico alla Draconia-[CONTIENE]->Muffa Lunare
# Relazione creata e confermata: Risotto Cosmico alla Draconia-[CONTIENE]->Petali di Eco
# Caricando 30 relazioni di tipo PREPARATO...
# ERRORE nel caricamento della relazione Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[PREPARATO]->Amalgamazione Sintetica Molecolare: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni', 'destinazione': 'Amalgamazione Sintetica Molecolare'}
# ERRORE nel caricamento della relazione Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[PREPARATO]->Fermentazione Quantica a Strati Multiversali: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni', 'destinazione': 'Fermentazione Quantica a Strati Multiversali'}
# ERRORE nel caricamento della relazione Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[PREPARATO]->Grigliatura Eletro-Molecolare a Spaziatura Variabile: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni', 'destinazione': 'Grigliatura Eletro-Molecolare a Spaziatura Variabile'}
# ERRORE nel caricamento della relazione Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[PREPARATO]->Fermentazione Psionica Energetica: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni', 'destinazione': 'Fermentazione Psionica Energetica'}
# ERRORE nel caricamento della relazione Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni-[PREPARATO]->Affumicatura a Stratificazione Quantica: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni', 'destinazione': 'Affumicatura a Stratificazione Quantica'}
# ERRORE nel caricamento della relazione Sinfonia Cosmica di Terre e Stelle-[PREPARATO]->Affumicatura Psionica Sensoriale: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Sinfonia Cosmica di Terre e Stelle', 'destinazione': 'Affumicatura Psionica Sensoriale'}
# ERRORE nel caricamento della relazione Sinfonia Cosmica di Terre e Stelle-[PREPARATO]->Cottura con Microonde Entropiche Sincronizzate: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Sinfonia Cosmica di Terre e Stelle', 'destinazione': 'Cottura con Microonde Entropiche Sincronizzate'}
# ERRORE nel caricamento della relazione Sinfonia Cosmica di Terre e Stelle-[PREPARATO]->Fermentazione Psionica Energetica: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Sinfonia Cosmica di Terre e Stelle', 'destinazione': 'Fermentazione Psionica Energetica'}
# ERRORE nel caricamento della relazione Sinfonia Cosmica di Terre e Stelle-[PREPARATO]->Lumière Cosmica: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Sinfonia Cosmica di Terre e Stelle', 'destinazione': 'Lumière Cosmica'}
# ERRORE nel caricamento della relazione Lumière Cosmica-[PREPARATO]->Fermentazione Psionica Energetica: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Lumière Cosmica', 'destinazione': 'Fermentazione Psionica Energetica'}
# ERRORE nel caricamento della relazione Lumière Cosmica-[PREPARATO]->Amalgamazione Sintetica Molecolare: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Lumière Cosmica', 'destinazione': 'Amalgamazione Sintetica Molecolare'}
# ERRORE nel caricamento della relazione Risveglio Cosmico: Un Viaggio nel Sapore Quantistico-[PREPARATO]->Fermentazione Psionica Energetica: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Risveglio Cosmico: Un Viaggio nel Sapore Quantistico', 'destinazione': 'Fermentazione Psionica Energetica'}
# ERRORE nel caricamento della relazione L'Ascensione Siderale-[PREPARATO]->Bollitura Entropica Sincronizzata: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': "L'Ascensione Siderale", 'destinazione': 'Bollitura Entropica Sincronizzata'}
# ERRORE nel caricamento della relazione L'Ascensione Siderale-[PREPARATO]->Bollitura Infrasonica Armonizzata: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': "L'Ascensione Siderale", 'destinazione': 'Bollitura Infrasonica Armonizzata'}
# ERRORE nel caricamento della relazione L'Ascensione Siderale-[PREPARATO]->Portale di Sapori Arcani: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': "L'Ascensione Siderale", 'destinazione': 'Portale di Sapori Arcani'}
# ERRORE nel caricamento della relazione Portale di Sapori Arcani-[PREPARATO]->Fermentazione Psionica Energetica: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Portale di Sapori Arcani', 'destinazione': 'Fermentazione Psionica Energetica'}
# ERRORE nel caricamento della relazione Portale di Sapori Arcani-[PREPARATO]->Cottura con Microonde Entropiche Sincronizzate: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Portale di Sapori Arcani', 'destinazione': 'Cottura con Microonde Entropiche Sincronizzate'}
# ERRORE nel caricamento della relazione Portale di Sapori Arcani-[PREPARATO]->Idro-Cristallizzazione Sonora Quantistica: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Portale di Sapori Arcani', 'destinazione': 'Idro-Cristallizzazione Sonora Quantistica'}
# ERRORE nel caricamento della relazione Portale di Sapori Arcani-[PREPARATO]->Cottura a Vapore Termocinetica Multipla: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Portale di Sapori Arcani', 'destinazione': 'Cottura a Vapore Termocinetica Multipla'}
# ERRORE nel caricamento della relazione Portale di Sapori Arcani-[PREPARATO]->Decostruzione Interdimensionale Lovecraftiana: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Portale di Sapori Arcani', 'destinazione': 'Decostruzione Interdimensionale Lovecraftiana'}
# ERRORE nel caricamento della relazione Fenice sull'Orizzonte degli Eventi-[PREPARATO]->Congelazione Iperdimensionalmente Stratificata: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': "Fenice sull'Orizzonte degli Eventi", 'destinazione': 'Congelazione Iperdimensionalmente Stratificata'}
# ERRORE nel caricamento della relazione Fenice sull'Orizzonte degli Eventi-[PREPARATO]->Cottura a Vapore con Flusso di Particelle Isoarmoniche: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': "Fenice sull'Orizzonte degli Eventi", 'destinazione': 'Cottura a Vapore con Flusso di Particelle Isoarmoniche'}
# ERRORE nel caricamento della relazione Fenice sull'Orizzonte degli Eventi-[PREPARATO]->Affumicatura Temporale Risonante: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': "Fenice sull'Orizzonte degli Eventi", 'destinazione': 'Affumicatura Temporale Risonante'}
# ERRORE nel caricamento della relazione Fenice sull'Orizzonte degli Eventi-[PREPARATO]->Portale Cosmico del Kraken: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': "Fenice sull'Orizzonte degli Eventi", 'destinazione': 'Portale Cosmico del Kraken'}
# ERRORE nel caricamento della relazione Una Mucca e una Balena nella Singolarità-[PREPARATO]->Cottura con Microonde Entropiche Sincronizzate: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Una Mucca e una Balena nella Singolarità', 'destinazione': 'Cottura con Microonde Entropiche Sincronizzate'}
# ERRORE nel caricamento della relazione Una Mucca e una Balena nella Singolarità-[PREPARATO]->Fermentazione Quantico Biometrica: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Una Mucca e una Balena nella Singolarità', 'destinazione': 'Fermentazione Quantico Biometrica'}
# ERRORE nel caricamento della relazione Risotto Cosmico alla Draconia-[PREPARATO]->Cottura a Vapore Termocinetica Multipla: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Risotto Cosmico alla Draconia', 'destinazione': 'Cottura a Vapore Termocinetica Multipla'}
# ERRORE nel caricamento della relazione Risotto Cosmico alla Draconia-[PREPARATO]->Bollitura Entropica Sincronizzata: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Risotto Cosmico alla Draconia', 'destinazione': 'Bollitura Entropica Sincronizzata'}
# ERRORE nel caricamento della relazione Risotto Cosmico alla Draconia-[PREPARATO]->Cottura con Microonde Entropiche Sincronizzate: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Risotto Cosmico alla Draconia', 'destinazione': 'Cottura con Microonde Entropiche Sincronizzate'}
# ERRORE nel caricamento della relazione Risotto Cosmico alla Draconia-[PREPARATO]->Congelazione Iperdimensionalmente Stratificata: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Piatto {nome: $origine})
#                     MATCH (d:Tecnica {nome: $destinazione})
#                     MERGE (o)-[r:PREPARATO]->(d)
#                      RETURN r
# Parametri: {'origine': 'Risotto Cosmico alla Draconia', 'destinazione': 'Congelazione Iperdimensionalmente Stratificata'}
# Caricando 9 relazioni di tipo OFFERTA...
# Relazione creata e confermata: L'Essenza di Asgard-[OFFERTA]->Quadrifonia Cosmica: Sinfonia di Sapori e Dimensioni
# Relazione creata e confermata: L'Essenza di Asgard-[OFFERTA]->Sinfonia Cosmica di Terre e Stelle
# Relazione creata e confermata: L'Essenza di Asgard-[OFFERTA]->Lumière Cosmica
# Relazione creata e confermata: L'Essenza di Asgard-[OFFERTA]->Risveglio Cosmico: Un Viaggio nel Sapore Quantistico
# Relazione creata e confermata: L'Essenza di Asgard-[OFFERTA]->L'Ascensione Siderale
# Relazione creata e confermata: L'Essenza di Asgard-[OFFERTA]->Portale di Sapori Arcani
# Relazione creata e confermata: L'Essenza di Asgard-[OFFERTA]->Fenice sull'Orizzonte degli Eventi
# Relazione creata e confermata: L'Essenza di Asgard-[OFFERTA]->Una Mucca e una Balena nella Singolarità
# Relazione creata e confermata: L'Essenza di Asgard-[OFFERTA]->Risotto Cosmico alla Draconia
# Caricando 1 relazioni di tipo SITUATO...
# ERRORE nel caricamento della relazione L'Essenza di Asgard-[SITUATO]->Asgard: 'list' object has no attribute 'items'
# Query:
#                     MATCH (o:Ristorante {nome: $origine})
#                     MATCH (d:Pianeta {nome: $destinazione})
#                     MERGE (o)-[r:SITUATO]->(d)
#                      RETURN r
# Parametri: {'origine': "L'Essenza di Asgard", 'destinazione': 'Asgard'}
# Caricando 3 relazioni di tipo HA...
# Relazione creata e confermata: L'Essenza di Asgard-[HA]->Temporale
# Relazione creata e confermata: L'Essenza di Asgard-[HA]->Antimateria
# Relazione creata e confermata: L'Essenza di Asgard-[HA]->Luce
#
# Riepilogo: create 82 entità e 80 relazioni
# Verifica finale dal database: 714 nodi e 1689 relazioni presenti
#
# Esempi di nodi per tipo:
#   Tecnica: Sinfonia Cosmica di Terracotta, Danza Luminosa del Multiverso, Bollitura infrasonica armonizzata, Decostruzione Ancestrale, Sinfonia di Stagioni Stellari
#   Licenza: Gradi_influenza_tecnologico, Psionica IV, Temporale II, Quantistica 5, Luce I
#   Pianeta: Cybertron, Ego, Klyntar, Terrafirma, Arrakis
#   Piatto: Sinfonia Cosmica di Terracotta, Galassie Riflesce: Sinfonia del Multiverso, Sinfonia Tempolare Galattica, Cosmopolis delle Galassie Perdute, Galassia Risvegliata
#   Ristorante: L'Eco dei Mondi, L'Eco di Pandora, L'Eredità Galattica, L'Essenza dell'Infinito, Il Firmamento
#   Ingrediente: Danza Luminosa del Multiverso, Cristalli di Nebulite, Taglio a Risonanza Sonica Rigenerativa, Decostruzione Ancestrale, Cottura a Forno Dinamico Inversionale
#   Content: Nessun nodo trovato
# Elaborazione di L Essenza di Asgard.pdf completata con successo
# --------------------------------------------------
# Elaborazione del file: L Etere del Gusto.pdf
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Connessione al database verificata con successo
# Elaborazione per tipo: Piatto
# Tipo di dato: list
# Caricando 10 entità di tipo Piatto...
# Creazione entità: Galassia di Sapori Eterei (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.base = $base, e.tecnicaCottura = $tecnicaCottura, e.aromatizzatoCon = $aromatizzatoCon, e.esplosione = $esplosione, e.ingredientiCentrali = $ingredientiCentrali, e.tecnicaPanatura = $tecnicaPanatura, e.tecnicaFriggeamento = $tecnicaFriggeamento RETURN e
# Entità creata e confermata: Galassia di Sapori Eterei di tipo Piatto
# Creazione entità: Il Risveglio del Drago Celeste (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.base = $base, e.tecnicaCottura = $tecnicaCottura, e.ingredienti = $ingredienti RETURN e
# Entità creata e confermata: Il Risveglio del Drago Celeste di tipo Piatto
# Creazione entità: L'Abbraccio del Cosmo (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.base = $base, e.tecnicaCottura = $tecnicaCottura, e.ingredientePrincipale = $ingredientePrincipale, e.tecniche = $tecniche, e.ingredienti = $ingredienti RETURN e
# Entità creata e confermata: L'Abbraccio del Cosmo di tipo Piatto
# Creazione entità: Cosmic Harmony Infusion (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.base = $base, e.tecniche = $tecniche, e.ingredienti = $ingredienti RETURN e
# Entità creata e confermata: Cosmic Harmony Infusion di tipo Piatto
# Creazione entità: Concordanza Cosmica - Sinfonia di Sapori Multidimensionali (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.base = $base, e.tecnicaCottura = $tecnicaCottura, e.ingredientePrincipale = $ingredientePrincipale, e.tecnicheGrigliatura = $tecnicheGrigliatura, e.ingredientiExtra = $ingredientiExtra RETURN e
# Entità creata e confermata: Concordanza Cosmica - Sinfonia di Sapori Multidimensionali di tipo Piatto
# Creazione entità: Universo Incantato: Sinfonia dei Gusti Cosmogonici (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.base = $base, e.ingredientePrincipale = $ingredientePrincipale, e.ingredienti = $ingredienti, e.tecniche = $tecniche RETURN e
# Entità creata e confermata: Universo Incantato: Sinfonia dei Gusti Cosmogonici di tipo Piatto
# Creazione entità: Eclissi Quantica: Viaggio nei Reami del Gusto (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.base = $base, e.tecnicaCottura = $tecnicaCottura, e.ingredienti = $ingredienti RETURN e
# Entità creata e confermata: Eclissi Quantica: Viaggio nei Reami del Gusto di tipo Piatto
# Creazione entità: Sinfonia Multiversale in Otto Movimenti (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.base = $base, e.ingredientePrincipale = $ingredientePrincipale, e.tecniche = $tecniche, e.ingredienti = $ingredienti RETURN e
# Entità creata e confermata: Sinfonia Multiversale in Otto Movimenti di tipo Piatto
# Creazione entità: La Sinfonia dell'Universo (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.base = $base, e.tecniche = $tecniche, e.ingredienti = $ingredienti RETURN e
# Entità creata e confermata: La Sinfonia dell'Universo di tipo Piatto
# Creazione entità: Sinfonia dell'Universo Morente (tipo: Piatto)
# Esecuzione query: MERGE (e:Piatto {nome: $nome}) SET e.base = $base, e.tecnicaBase = $tecnicaBase, e.ingredienti = $ingredienti, e.ingredientiExtra = $ingredientiExtra RETURN e
# Entità creata e confermata: Sinfonia dell'Universo Morente di tipo Piatto
# Elaborazione per tipo: Licenza
# Tipo di dato: list
# Caricando 4 entità di tipo Licenza...
# Creazione entità: Magnetica I (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.tipo = $tipo, e.grado = $grado RETURN e
# Entità creata e confermata: Magnetica I di tipo Licenza
# Creazione entità: Luce II (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.tipo = $tipo, e.grado = $grado RETURN e
# Entità creata e confermata: Luce II di tipo Licenza
# Creazione entità: Gravitazionale I (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.tipo = $tipo, e.grado = $grado RETURN e
# Entità creata e confermata: Gravitazionale I di tipo Licenza
# Creazione entità: Antimateria I (tipo: Licenza)
# Esecuzione query: MERGE (e:Licenza {nome: $nome}) SET e.tipo = $tipo, e.grado = $grado RETURN e
# Entità creata e confermata: Antimateria I di tipo Licenza
# Elaborazione per tipo: Pianeta
# Tipo di dato: list
# Caricando 5 entità di tipo Pianeta...
# Creazione entità: Pandora (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) SET e.descrizione = $descrizione, e.posizione = $posizione, e.satelliti = $satelliti RETURN e
# Entità creata e confermata: Pandora di tipo Pianeta
# Creazione entità: Ego (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) RETURN e
# Entità creata e confermata: Ego di tipo Pianeta
# Creazione entità: Cassandra (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) RETURN e
# Entità creata e confermata: Cassandra di tipo Pianeta
# Creazione entità: Nettuno (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) RETURN e
# Entità creata e confermata: Nettuno di tipo Pianeta
# Creazione entità: Nameccia (tipo: Pianeta)
# Esecuzione query: MERGE (e:Pianeta {nome: $nome}) RETURN e
# Entità creata e confermata: Nameccia di tipo Pianeta
# Elaborazione per tipo: Ingrediente
# Tipo di dato: list
# Caricando 34 entità di tipo Ingrediente...
# Creazione entità: Riso di Cassandra (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.colore = $colore, e.cottura = $cottura RETURN e
# Entità creata e confermata: Riso di Cassandra di tipo Ingrediente
# Creazione entità: Foglie di Nebulosa (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) SET e.note = $note RETURN e
# Entità creata e confermata: Foglie di Nebulosa di tipo Ingrediente
# Creazione entità: Polvere di Stelle (tipo: Ingrediente)
# Esecuzione query: MERGE (e:Ingrediente {nome: $nome}) RETURN e
# Entità creata e confermata: Polvere di Stelle di tipo Ingrediente
# ...
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.fumo = $fumo, e.plasmato = $plasmato RETURN e
# Entità creata e confermata: Affumicatura Psionica Sensoriale di tipo Tecnica
# Creazione entità: Decostruzione Interdimensionale Lovecraftiana (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Decostruzione Interdimensionale Lovecraftiana di tipo Tecnica
# Creazione entità: Decostruzione Magnetica Risonante (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Decostruzione Magnetica Risonante di tipo Tecnica
# Creazione entità: Taglio a Risonanza Sonica Rigenerativa (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.precisione = $precisione RETURN e
# Entità creata e confermata: Taglio a Risonanza Sonica Rigenerativa di tipo Tecnica
# Creazione entità: Marinatura Temporale Sincronizzata (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Marinatura Temporale Sincronizzata di tipo Tecnica
# Creazione entità: Cottura Sottovuoto Bioma Sintetico (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.metabolismo = $metabolismo RETURN e
# Entità creata e confermata: Cottura Sottovuoto Bioma Sintetico di tipo Tecnica
# Creazione entità: Cottura con Microonde Entropiche Sincronizzate (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Cottura con Microonde Entropiche Sincronizzate di tipo Tecnica
# Creazione entità: Ebollizione Magneto-Cinetica Pulsante (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.effetto = $effetto RETURN e
# Entità creata e confermata: Ebollizione Magneto-Cinetica Pulsante di tipo Tecnica
# Creazione entità: Sferificazione Filamentare a Molecole Vibrazionali (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.output = $output RETURN e
# Entità creata e confermata: Sferificazione Filamentare a Molecole Vibrazionali di tipo Tecnica
# Creazione entità: Congelazione Iperdimensionalmente Stratificata (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.effetto = $effetto RETURN e
# Entità creata e confermata: Congelazione Iperdimensionalmente Stratificata di tipo Tecnica
# Creazione entità: Marinatura Sotto Zero a Polarità Inversa (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.ingredienti = $ingredienti RETURN e
# Entità creata e confermata: Marinatura Sotto Zero a Polarità Inversa di tipo Tecnica
# Creazione entità: Impasto a Campi Magnetici Dualistici (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Impasto a Campi Magnetici Dualistici di tipo Tecnica
# Creazione entità: Fermentazione Psionica Energetica (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.tipo = $tipo RETURN e
# Entità creata e confermata: Fermentazione Psionica Energetica di tipo Tecnica
# Creazione entità: Bollitura Infrasonica Armonizzata (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Bollitura Infrasonica Armonizzata di tipo Tecnica
# Creazione entità: Affumicatura Temporale Risonante (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) SET e.fumo = $fumo, e.spettro = $spettro RETURN e
# Entità creata e confermata: Affumicatura Temporale Risonante di tipo Tecnica
# Creazione entità: Affumicatura Polarizzata a Freddo Iperbarico (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Affumicatura Polarizzata a Freddo Iperbarico di tipo Tecnica
# Creazione entità: Pulsazioni Quantistiche (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Pulsazioni Quantistiche di tipo Tecnica
# Creazione entità: Idro-Cristallizzazione Sonora Quantistica (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Idro-Cristallizzazione Sonora Quantistica di tipo Tecnica
# Creazione entità: Saltare in Padella Realtà Energetiche Parallele (tipo: Tecnica)
# Esecuzione query: MERGE (e:Tecnica {nome: $nome}) RETURN e
# Entità creata e confermata: Saltare in Padella Realtà Energetiche Parallele di tipo Tecnica
# Elaborazione per tipo: Ristorante
# Tipo di dato: list
# Caricando 1 entità di tipo Ristorante...
# Creazione entità: Universo Gastronomico di Namecc (tipo: Ristorante)
# Esecuzione query: MERGE (e:Ristorante {nome: $nome}) SET e.Luogo = $Luogo, e.Chef = $Chef, e.LicenzaQuantistica = $LicenzaQuantistica, e.LicenzaPsionica = $LicenzaPsionica, e.LicenzaTemporale = $LicenzaTemporale, e.LicenzaGravitazionale = $LicenzaGravitazionale, e.LicenzaMagnetica = $LicenzaMagnetica, e.LicenzaLuce = $LicenzaLuce, e.LTK = $LTK RETURN e
# Entità creata e confermata: Universo Gastronomico di Namecc di tipo Ristorante
# Caricando 55 relazioni di tipo CONTIENE...
# Relazione creata e confermata: Risotto dei Multiversi-[CONTIENE]->Riso di Cassandra
# Relazione creata e confermata: Risotto dei Multiversi-[CONTIENE]->Cristalli di Nebulite
# Relazione creata e confermata: Risotto dei Multiversi-[CONTIENE]->Lacrime di Unicorno
# Relazione creata e confermata: Risotto dei Multiversi-[CONTIENE]->Sale Temporale
# Relazione creata e confermata: Risotto dei Multiversi-[CONTIENE]->Spaghi del Sole
# Relazione creata e confermata: Panetto di Carne-[CONTIENE]->Panello di Nettuno
# Relazione creata e confermata: Panetto di Carne-[CONTIENE]->Funghi Orbitali
# Relazione creata e confermata: Panetto di Carne-[CONTIENE]->Pane di Luce
# Relazione creata e confermata: Panetto di Carne-[CONTIENE]->Carne di Kraken
# Relazione creata e confermata: Panetto di Carne-[CONTIENE]->Xenodonte
# Relazione creata e confermata: Panetto di Carne-[CONTIENE]->Cristalli di Nebulite
# Relazione creata e confermata: Panetto di Carne-[CONTIENE]->Pane degli Abissi
# Relazione creata e confermata: Cosmos Risotto Reale-[CONTIENE]->Carne di Kraken
# Relazione creata e confermata: Cosmos Risotto Reale-[CONTIENE]->Pane di Luce
# Relazione creata e confermata: Cosmos Risotto Reale-[CONTIENE]->Funghi Orbitali
# Relazione creata e confermata: Cosmos Risotto Reale-[CONTIENE]->Essenza di Vuoto
# Relazione creata e confermata: Cosmos Risotto Reale-[CONTIENE]->Ghiaccio di Criofenice
# Relazione creata e confermata: Cosmos Risotto Reale-[CONTIENE]->Vero Ghiaccio
# Relazione creata e confermata: La Balena incontra la Mandragora-[CONTIENE]->Vero Ghiaccio
# Relazione creata e confermata: La Balena incontra la Mandragora-[CONTIENE]->Radici di Singolarità
# Relazione creata e confermata: La Balena incontra la Mandragora-[CONTIENE]->Carne di BalenaSpaziale
# Relazione creata e confermata: La Balena incontra la Mandragora-[CONTIENE]->Muffa Lunare
# Relazione creata e confermata: La Balena incontra la Mandragora-[CONTIENE]->Foglie di Mandragora
# Relazione creata e confermata: La Balena incontra la Mandragora-[CONTIENE]->Pane di Luce
# Relazione creata e confermata: La Balena incontra la Mandragora-[CONTIENE]->Petali di Eco
# Relazione creata e confermata: Armonia Cosmica della Fenice-[CONTIENE]->Polvere di Stelle
# Relazione creata e confermata: Armonia Cosmica della Fenice-[CONTIENE]->Carne di Mucca
# Relazione creata e confermata: Armonia Cosmica della Fenice-[CONTIENE]->Uova di Fenice
# Relazione creata e confermata: Armonia Cosmica della Fenice-[CONTIENE]->Fibra di Sintetex
# Relazione creata e confermata: Armonia Cosmica della Fenice-[CONTIENE]->Lacrime di Unicorno
# Relazione creata e confermata: Armonia Cosmica della Fenice-[CONTIENE]->Essenza di Tachioni
# Relazione creata e confermata: Fenice Galattica-[CONTIENE]->Riso di Cassandra
# Relazione creata e confermata: Fenice Galattica-[CONTIENE]->Cristalli di Nebulite
# Relazione creata e confermata: Fenice Galattica-[CONTIENE]->Alghe Bioluminescenti
# Relazione creata e confermata: Fenice Galattica-[CONTIENE]->Lattuga Namecciana
# Relazione creata e confermata: Fenice Galattica-[CONTIENE]->Uova di Fenice
# Relazione creata e confermata: Fenice Galattica-[CONTIENE]->Muffa Lunare
# Relazione creata e confermata: Rapsodia Quantistica nel Cosmo-[CONTIENE]->Carne di BalenaSpaziale
# Relazione creata e confermata: Rapsodia Quantistica nel Cosmo-[CONTIENE]->Carne di Xenodonte
# Relazione creata e confermata: Rapsodia Quantistica nel Cosmo-[CONTIENE]->Cristalli di Nebulite
# Relazione creata e confermata: Rapsodia Quantistica nel Cosmo-[CONTIENE]->Fibra di Sintetex
# Relazione creata e confermata: Rapsodia Quantistica nel Cosmo-[CONTIENE]->Lacrime di Unicorno
# Relazione creata e confermata: Galassia di Sapore Quantum-[CONTIENE]->Fusilli del Vento
# Relazione creata e confermata: Galassia di Sapore Quantum-[CONTIENE]->Alghe Bioluminescenti
# Relazione creata e confermata: Galassia di Sapore Quantum-[CONTIENE]->Polvere di Crononite
# Relazione creata e confermata: Galassia di Sapore Quantum-[CONTIENE]->Biscotti della Galassia
# Relazione creata e confermata: Tris di Carne con Pane-[CONTIENE]->Pane di Luce
# Relazione creata e confermata: Tris di Carne con Pane-[CONTIENE]->Carne di Xenodonte
# Relazione creata e confermata: Tris di Carne con Pane-[CONTIENE]->Carne di Kraken
# Relazione creata e confermata: Tris di Carne con Pane-[CONTIENE]->Fusilli del Vento
# Relazione creata e confermata: Tris di Carne con Pane-[CONTIENE]->Carne di BalenaSpaziale
# Relazione creata e confermata: Tris di Carne con Pane-[CONTIENE]->Lacrime di Unicorno
# Relazione creata e confermata: Tris di Carne con Pane-[CONTIENE]->Cristalli di Memoria
# Relazione creata e confermata: Tris di Carne con Pane-[CONTIENE]->Pane degli Abissi
# Relazione creata e confermata: Tris di Carne con Pane-[CONTIENE]->Sale Temporale
# Caricando 34 relazioni di tipo PREPARATO...
# Relazione creata e confermata: Risotto dei Multiversi-[PREPARATO]->Decostruzione Interdimensionale Lovecraftiana
# Relazione creata e confermata: Risotto dei Multiversi-[PREPARATO]->Fermentazione Psionica Energetica
# Relazione creata e confermata: Risotto dei Multiversi-[PREPARATO]->Cottura Olografica Quantum Fluttuante
# Relazione creata e confermata: Risotto dei Multiversi-[PREPARATO]->Affumicatura Psionica Sensoriale
# Relazione creata e confermata: Panetto di Carne-[PREPARATO]->Sferificazione Filamentare a Molecole Vibrazionali
# Relazione creata e confermata: Panetto di Carne-[PREPARATO]->Affumicatura Temporale Risonante
# Relazione creata e confermata: Panetto di Carne-[PREPARATO]->Affumicatura Polarizzata a Freddo Iperbarico
# Relazione creata e confermata: Cosmos Risotto Reale-[PREPARATO]->Saltare in Padella Realtà Energetiche Parallele
# Relazione creata e confermata: Cosmos Risotto Reale-[PREPARATO]->Ebollizione Magneto-Cinetica Pulsante
# Relazione creata e confermata: Cosmos Risotto Reale-[PREPARATO]->Bollitura Infrasonica Armonizzata
# Relazione creata e confermata: Cosmos Risotto Reale-[PREPARATO]->Cottura Sottovuoto Bioma Sintetico
# Relazione creata e confermata: La Balena incontra la Mandragora-[PREPARATO]->Taglio a Risonanza Sonica Rigenerativa
# Relazione creata e confermata: La Balena incontra la Mandragora-[PREPARATO]->Marinatura Temporale Sincronizzata
# Relazione creata e confermata: La Balena incontra la Mandragora-[PREPARATO]->Affumicatura Polarizzata a Freddo Iperbarico
# Relazione creata e confermata: La Balena incontra la Mandragora-[PREPARATO]->Cottura con Microonde Entropiche Sincronizzate
# Relazione creata e confermata: La Balena incontra la Mandragora-[PREPARATO]->Cottura Sottovuoto Bioma Sintetico
# Relazione creata e confermata: Armonia Cosmica della Fenice-[PREPARATO]->Taglio a Risonanza Sonica Rigenerativa
# Relazione creata e confermata: Armonia Cosmica della Fenice-[PREPARATO]->Fermentazione Psionica Energetica
# Relazione creata e confermata: Armonia Cosmica della Fenice-[PREPARATO]->Decostruzione Magnetica Risonante
# Relazione creata e confermata: Armonia Cosmica della Fenice-[PREPARATO]->Decostruzione Interdimensionale Lovecraftiana
# Relazione creata e confermata: Armonia Cosmica della Fenice-[PREPARATO]->Cottura Sottovuoto Bioma Sintetico
# Relazione creata e confermata: Fenice Galattica-[PREPARATO]->Marinatura Temporale Sincronizzata
# Relazione creata e confermata: Fenice Galattica-[PREPARATO]->Cottura con Microonde Entropiche Sincronizzate
# Relazione creata e confermata: Fenice Galattica-[PREPARATO]->Cottura Sottovuoto Bioma Sintetico
# Relazione creata e confermata: Fenice Galattica-[PREPARATO]->Congelazione Iperdimensionalmente Stratificata
# Relazione creata e confermata: Rapsodia Quantistica nel Cosmo-[PREPARATO]->Taglio a Risonanza Sonica Rigenerativa
# Relazione creata e confermata: Rapsodia Quantistica nel Cosmo-[PREPARATO]->Pulsazioni Quantistiche
# Relazione creata e confermata: Rapsodia Quantistica nel Cosmo-[PREPARATO]->Marinatura Sotto Zero a Polarità Inversa
# Relazione creata e confermata: Galassia di Sapore Quantum-[PREPARATO]->Idro-Cristallizzazione Sonora Quantistica
# Relazione creata e confermata: Tris di Carne con Pane-[PREPARATO]->Impasto a Campi Magnetici Dualistici
# Relazione creata e confermata: Tris di Carne con Pane-[PREPARATO]->Decostruzione Magnetica Risonante
# Relazione creata e confermata: Tris di Carne con Pane-[PREPARATO]->Sferificazione Filamentare a Molecole Vibrazionali
# Relazione creata e confermata: Tris di Carne con Pane-[PREPARATO]->Ebollizione Magneto-Cinetica Pulsante
# Relazione creata e confermata: Tris di Carne con Pane-[PREPARATO]->Cottura Olografica Quantum Fluttuante
# Caricando 9 relazioni di tipo OFFERTA...
# Relazione creata e confermata: Universo Gastronomico di Namecc-[OFFERTA]->Risotto dei Multiversi
# Relazione creata e confermata: Universo Gastronomico di Namecc-[OFFERTA]->Panetto di Carne
# Relazione creata e confermata: Universo Gastronomico di Namecc-[OFFERTA]->Cosmos Risotto Reale
# Relazione creata e confermata: Universo Gastronomico di Namecc-[OFFERTA]->La Balena incontra la Mandragora
# Relazione creata e confermata: Universo Gastronomico di Namecc-[OFFERTA]->Armonia Cosmica della Fenice
# Relazione creata e confermata: Universo Gastronomico di Namecc-[OFFERTA]->Fenice Galattica
# Relazione creata e confermata: Universo Gastronomico di Namecc-[OFFERTA]->Rapsodia Quantistica nel Cosmo
# Relazione creata e confermata: Universo Gastronomico di Namecc-[OFFERTA]->Galassia di Sapore Quantum
# Relazione creata e confermata: Universo Gastronomico di Namecc-[OFFERTA]->Tris di Carne con Pane
# Caricando 1 relazioni di tipo SITUATO...
# Relazione creata e confermata: Universo Gastronomico di Namecc-[SITUATO]->Namecc
# Caricando 6 relazioni di tipo HA...
# Relazione creata e confermata: Universo Gastronomico di Namecc-[HA]->Quantistica15
# Relazione creata e confermata: Universo Gastronomico di Namecc-[HA]->PsionicaII
# Relazione creata e confermata: Universo Gastronomico di Namecc-[HA]->TemporaleI
# Relazione creata e confermata: Universo Gastronomico di Namecc-[HA]->GravitazionaleI
# Relazione creata e confermata: Universo Gastronomico di Namecc-[HA]->MagneticaI
# Relazione creata e confermata: Universo Gastronomico di Namecc-[HA]->LuceI
#
# Riepilogo: create 68 entità e 105 relazioni
# Verifica finale dal database: 1033 nodi e 3073 relazioni presenti
#
# Esempi di nodi per tipo:
#   Tecnica: Sinfonia Cosmica di Terracotta, Danza Luminosa del Multiverso, Sferificazione_a_Gravità_Psionica_Variabile, Bollitura infrasonica armonizzata, Decostruzione Ancestrale
#   Licenza: Gradi_influenza_tecnologico, Psionica IV, Temporale II, Quantistica 5, Luce I
#   Pianeta: Cybertron, Ego, Klyntar, Terrafirma, Arrakis
#   Piatto: Sinfonia Cosmica di Terracotta, Galassie Riflesce: Sinfonia del Multiverso, Sinfonia Tempolare Galattica, Cosmopolis delle Galassie Perdute, Galassia Risvegliata
#   Ristorante: L'Eco dei Mondi, L'Eco di Pandora, L'Eredità Galattica, L'Essenza dell'Infinito, Il Firmamento
#   Ingrediente: Danza Luminosa del Multiverso, Cristalli di Nebulite, Taglio a Risonanza Sonica Rigenerativa, Decostruzione Ancestrale, Cottura a Forno Dinamico Inversionale
#   Content: Nessun nodo trovato
# Elaborazione di Universo Gastronomico di Namecc.pdf completata con successo
# --------------------------------------------------
