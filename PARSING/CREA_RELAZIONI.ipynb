# %%
import pdfplumber
import re
import json
import os
import PyPDF2


from dotenv import load_dotenv
from neo4j import GraphDatabase
from py2neo import Graph, Node, Relationship
from langchain_openai import AzureChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from typing import List, Dict, Tuple

# %%
load_dotenv()
# Recupera endpoint e chiave dalle variabili d'ambiente
api_base = os.getenv("AZURE_OPENAI_API_BASE")
api_key = os.getenv("AZURE_OPENAI_API_KEY")

# neo4j first instance parameters
NEO4J_URI= "neo4j+s://0482640f.databases.neo4j.io"
NEO4J_USERNAME= "neo4j"
NEO4J_PASSWORD= "PNvdaZlk326-ja2hRD1K97ZUUMnD4mj0NsecZNu5-9k"
AURA_INSTANCEID= "0482640f"
AURA_INSTANCENAME= "Instance01"

driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %%
def crea_llm(api_key: str, api_base: str) -> AzureChatOpenAI:
    """
    Crea un'istanza del modello linguistico Azure OpenAI.
    
    Args:
        api_key (str): La chiave API di Azure
        api_base (str): L'URL base dell'API Azure
        
    Returns:
        AzureChatOpenAI: Istanza configurata del modello
    """
    return AzureChatOpenAI(
        openai_api_version="2024-08-01-preview",
        azure_deployment="o1-mini",
        azure_endpoint=api_base,
        api_key=api_key,
        temperature=1
    )

llm = crea_llm(api_key, api_base)

# %%
def leggi_dati_da_neo4j(tx) -> Tuple[Dict[str, str], List[str]]:
    """
    Legge macrotecniche e tecniche da Neo4j.
    
    Args:
        tx: Transazione Neo4j
        
    Returns:
        Tuple[Dict[str, str], List[str]]: 
            - Dizionario delle macrotecniche (nome -> descrizione)
            - Lista dei nomi delle tecniche
    """
    # Query per le macrotecniche
    query_macro = """
    MATCH (m:Macrotecnica)
    RETURN m.nome as nome, m.descrizione as descrizione
    """
    result_macro = tx.run(query_macro)
    macrotecniche = {record["nome"]: record["descrizione"] for record in result_macro}
    
    # Query per le tecniche
    query_tecniche = """
    MATCH (t:Tecnica)
    RETURN t.nome as nome
    """
    result_tecniche = tx.run(query_tecniche)
    tecniche = [record["nome"] for record in result_tecniche]
    
    return macrotecniche, tecniche

def associa_tecniche_a_macrotecniche(
    llm: AzureChatOpenAI,
    macrotecniche: Dict[str, str],
    tecniche: List[str]
) -> List[Tuple[str, str]]:
    """
    Associa ogni tecnica alla macrotecnica più simile semanticamente.
    
    Args:
        llm (AzureChatOpenAI): Istanza del modello linguistico
        macrotecniche (Dict[str, str]): Dizionario nome_macrotecnica -> descrizione
        tecniche (List[str]): Lista dei nomi delle tecniche
        
    Returns:
        List[Tuple[str, str]]: Lista di tuple (tecnica, macrotecnica_associata)
    """
    prompt = """
    Data la seguente lista di macrotecniche con le loro descrizioni:
    
    {macro_desc}
    
    E la seguente lista di tecniche:
    
    {tech_list}
    
    Analizza ogni tecnica e associala alla macrotecnica più appropriata basandoti sulla somiglianza semantica e sul contesto.
    Ogni tecnica deve essere associata a una e una sola macrotecnica.
    
    Restituisci un JSON array di oggetti, dove ogni oggetto ha:
    - "tecnica": nome della tecnica
    - "macrotecnica": nome della macrotecnica associata
    - "motivazione": breve spiegazione del perché questa associazione è la migliore
    
    Restituisci SOLO il JSON, senza formattazione markdown o decoratori.
    """
    
    # Formatta le macrotecniche per il prompt
    macro_desc = "\n".join([
        f"- {nome}: {descrizione}"
        for nome, descrizione in macrotecniche.items()
    ])
    
    # Formatta le tecniche per il prompt
    tech_list = "\n".join([f"- {t}" for t in tecniche])
    
    # Invoca il modello
    response = llm.invoke(
        prompt.format(macro_desc=macro_desc, tech_list=tech_list)
    )
    content = response.content.strip()
    
    # Pulizia del JSON
    if content.startswith('```') and content.endswith('```'):
        content = '\n'.join(content.split('\n')[1:-1])
    if content.startswith('json'):
        content = content[4:].strip()
    
    try:
        associazioni = json.loads(content)
    except json.JSONDecodeError:
        print("Errore nel parsing JSON delle associazioni:", content)
        return []
    
    # Estrai solo le coppie tecnica-macrotecnica
    return [(a['tecnica'], a['macrotecnica']) for a in associazioni]

def aggiorna_relazioni_neo4j(tx, associazioni: List[Tuple[str, str]]):
    """
    Aggiorna le relazioni tra tecniche e macrotecniche in Neo4j.
    
    Args:
        tx: Transazione Neo4j
        associazioni: Lista di tuple (tecnica, macrotecnica)
    """
    query = """
    // Prima rimuove tutte le relazioni esistenti per la tecnica
    MATCH (t:Tecnica {nome: $tecnica})-[r:APPARTIENE_A]->(m:Macrotecnica)
    DELETE r
    
    // Poi crea la nuova relazione
    WITH t
    MATCH (m:Macrotecnica {nome: $macrotecnica})
    MERGE (t)-[:APPARTIENE_A]->(m)
    """
    
    for tecnica, macrotecnica in associazioni:
        tx.run(query, tecnica=tecnica, macrotecnica=macrotecnica)

def esegui_matching_completo(driver, llm: AzureChatOpenAI) -> List[Tuple[str, str]]:
    """
    Esegue il processo completo di matching leggendo i dati da Neo4j.
    
    Args:
        driver: Driver Neo4j
        llm (AzureChatOpenAI): Istanza del modello linguistico
        
    Returns:
        List[Tuple[str, str]]: Lista delle associazioni create
    """
    with driver.session() as session:
        # Legge i dati
        macrotecniche, tecniche = session.execute_read(leggi_dati_da_neo4j)
        
        # Fa il matching
        associazioni = associa_tecniche_a_macrotecniche(llm, macrotecniche, tecniche)
        
        # Salva le relazioni
        session.execute_write(aggiorna_relazioni_neo4j, associazioni)
        
        return associazioni

# %%
def aggiorna_relazioni_neo4j(tx, associazioni: List[Tuple[str, str]]):
    """
    Aggiorna le relazioni tra tecniche e macrotecniche in Neo4j con verifica.
    
    Args:
        tx: Transazione Neo4j
        associazioni: Lista di tuple (tecnica, macrotecnica)
    """
    for tecnica, macrotecnica in associazioni:
        # Prima verifichiamo che entrambi i nodi esistano
        verifica_query = """
        MATCH (t:Tecnica {nome: $tecnica})
        MATCH (m:Macrotecnica {nome: $macrotecnica})
        RETURN count(t) as tecnica_exists, count(m) as macro_exists
        """
        
        result = tx.run(verifica_query, tecnica=tecnica, macrotecnica=macrotecnica)
        counts = result.single()
        
        if not counts or counts['tecnica_exists'] == 0 or counts['macro_exists'] == 0:
            print(f"ERRORE: Non trovo i nodi per {tecnica} -> {macrotecnica}")
            continue
            
        # Se esistono, procediamo con l'aggiornamento
        update_query = """
        MATCH (t:Tecnica {nome: $tecnica})
        MATCH (m:Macrotecnica {nome: $macrotecnica})
        // Rimuove relazioni esistenti
        OPTIONAL MATCH (t)-[r:APPARTIENE_A]->(:Macrotecnica)
        DELETE r
        // Crea la nuova relazione
        CREATE (t)-[:APPARTIENE_A]->(m)
        RETURN t.nome as tecnica, m.nome as macrotecnica
        """
        
        result = tx.run(update_query, tecnica=tecnica, macrotecnica=macrotecnica)
        record = result.single()
        if record:
            print(f"SUCCESS: Creata relazione {record['tecnica']} -> {record['macrotecnica']}")
        else:
            print(f"ERRORE: Fallita creazione relazione per {tecnica} -> {macrotecnica}")

def esegui_matching_completo(driver, llm: AzureChatOpenAI) -> List[Tuple[str, str]]:
    """
    Esegue il processo completo di matching con logging dettagliato.
    
    Args:
        driver: Driver Neo4j
        llm (AzureChatOpenAI): Istanza del modello linguistico
    """
    with driver.session() as session:
        # Legge i dati
        print("Lettura dati da Neo4j...")
        macrotecniche, tecniche = session.execute_read(leggi_dati_da_neo4j)
        
        print(f"Trovate {len(macrotecniche)} macrotecniche e {len(tecniche)} tecniche")
        print("\nMacrotecniche trovate:")
        for nome, desc in macrotecniche.items():
            print(f"- {nome}")
        
        print("\nTecniche trovate:")
        for t in tecniche:
            print(f"- {t}")
            
        # Fa il matching
        print("\nEsecuzione matching...")
        associazioni = associa_tecniche_a_macrotecniche(llm, macrotecniche, tecniche)
        
        print(f"\nCreate {len(associazioni)} associazioni:")
        for tecnica, macro in associazioni:
            print(f"- {tecnica} -> {macro}")
        
        # Salva le relazioni
        print("\nSalvataggio relazioni in Neo4j...")
        session.execute_write(aggiorna_relazioni_neo4j, associazioni)
        
        # Verifica finale
        print("\nVerifica delle relazioni create:")
        verifica_query = """
        MATCH (t:Tecnica)-[r:APPARTIENE_A]->(m:Macrotecnica)
        RETURN t.nome as tecnica, m.nome as macrotecnica
        """
        result = session.run(verifica_query)
        relazioni_esistenti = [(record["tecnica"], record["macrotecnica"]) for record in result]
        
        print(f"Trovate {len(relazioni_esistenti)} relazioni nel database:")
        for tecnica, macro in relazioni_esistenti:
            print(f"- {tecnica} -> {macro}")
            
        return associazioni

# Query di test utili:
"""
# Per vedere tutte le tecniche:
MATCH (t:Tecnica) RETURN t.nome

# Per vedere tutte le macrotecniche:
MATCH (m:Macrotecnica) RETURN m.nome, m.descrizione

# Per vedere tutte le relazioni esistenti:
MATCH (t:Tecnica)-[r:APPARTIENE_A]->(m:Macrotecnica)
RETURN t.nome as tecnica, m.nome as macrotecnica

# Per contare le relazioni:
MATCH (t:Tecnica)-[r:APPARTIENE_A]->(m:Macrotecnica)
RETURN count(r) as num_relazioni
"""
# Out:
# '\n# Per vedere tutte le tecniche:\nMATCH (t:Tecnica) RETURN t.nome\n\n# Per vedere tutte le macrotecniche:\nMATCH (m:Macrotecnica) RETURN m.nome, m.descrizione\n\n# Per vedere tutte le relazioni esistenti:\nMATCH (t:Tecnica)-[r:APPARTIENE_A]->(m:Macrotecnica)\nRETURN t.nome as tecnica, m.nome as macrotecnica\n\n# Per contare le relazioni:\nMATCH (t:Tecnica)-[r:APPARTIENE_A]->(m:Macrotecnica)\nRETURN count(r) as num_relazioni\n'

# %%
# Esegue l'intero processo
associazioni = esegui_matching_completo(driver, llm)

for tecnica, macro in associazioni:
    print(f"{tecnica} -> {macro}")
# Out:
# Lettura dati da Neo4j...
# Trovate 29 macrotecniche e 70 tecniche
#
# Macrotecniche trovate:
# - Fermentazione
# - Tecniche di Impasto
# - Surgelamento
# - Bollitura
# - Grigliare
# - Forno
# - Vapore
# - Sottovuoto
# - Saltare in Padella
# - Decostruzione
# - Decostruzione Atomica a Strati Energetici
# - Decostruzione Magnetica Risonante
# - Decostruzione Bio-Fotonica Emotiva
# - Decostruzione Ancestrale
# - Decostruzione Interdimensionale Lovecraftiana
# - Sferificazione
# - Sferificazione a Gravità Psionica Variabile
# - Sferificazione Filamentare a Molecole Vibrazionali
# - Sferificazione Cromatica Interdimensionale
# - Sferificazione con Campi Magnetici Entropici
# - Sferificazione tramite Matrici Biofotiche
# - Tecniche di Taglio
# - Taglio Dimensionale a Lame Fotofiliche
# - Taglio a Risonanza Sonica Rigenerativa
# - Affettamento a Pulsazioni Quantistiche
# - Taglio Sinaptico Biomimetico
# - Incisione Elettromagnetica Plasmica
# - Marinatura
# - Affumicatura
#
# Tecniche trovate:
# - Marinatura a Infusione Gravitazionale
# - Marinatura Temporale Sincronizzata
# - Marinatura Psionica
# - Marinatura tramite Reazioni d'Antimateria Diluite
# - Marinatura Sotto Zero a Polarità Inversa
# - Affumicatura a Stratificazione Quantica
# - Affumicatura Temporale Risonante
# - Affumicatura Psionica Sensoriale
# - Affumicatura tramite Big Bang Microcosmico
# - Affumicatura Polarizzata a Freddo Iperbarico
# - Fermentazione Quantica a Strati Multiversali
# - Fermentazione Temporale Sincronizzata
# - Fermentazione Psionica Energetica
# - Fermentazione tramite Singolarità
# - Fermentazione Quantico Biometrica
# - Impasto Gravitazionale Vorticoso
# - Amalgamazione Sintetica Molecolare
# - Impasto a Campi Magnetici Dualistici
# - Sinergia Elettro-Osmotica Programmabile
# - Modellatura Onirica Tetrazionale
# - Cryo-Tessitura Energetica Polarizzata
# - Congelamento Bio-Luminiscente Sincronico
# - Cristallizzazione Temporale Reversiva
# - Congelazione Iperdimensionalmente Stratificata
# - Surgelamento Antimaterico a Risonanza Inversa
# - Ebollizione Magneto-Cinetica Pulsante
# - Bollitura Infrasonica Armonizzata
# - Bollitura Termografica a Rotazione Veloce
# - Bollitura Entropica Sincronizzata
# - Idro-Cristallizzazione Sonora Quantistica
# - Grigliatura a Energia Stellare DiV
# - Grigliatura Plasma Sintetico Risonante
# - Grigliatura Eletro-Molecolare a Spaziatura Variabile
# - Grigliatura Tachionica Refrattaria
# - Grigliatura Psionica Dinamica Ritmica
# - Cottura al Forno con Paradosso Temporale Cronospeculare
# - Cottura con Microonde Entropiche Sincronizzate
# - Cottura a Forno Dinamico Inversionale
# - Cottura Olografica Quantum Fluttuante
# - Cottura Geomagnetica Psicosincronizzata
# - Cottura a Vapore con Flusso di Particelle Isoarmoniche
# - Cottura a Vapore Ecodinamico Bilanciato
# - Cottura a Vapore Risonante Simbiotico
# - Cottura a Vapore Termocinetica Multipla
# - Cottura Idrodinamica Autoregolante
# - Cottura Sottovuoto Antimateria
# - Cottura Sottovuoto Multirealità Collassante
# - Cottura Sottovuoto Frugale Energeticamente Negativa
# - Cottura Sottovuoto Pulsar Magnetica
# - Cottura Sottovuoto Bioma Sintetico
# - Saltare in Padella Big Bang Termico
# - Saltare in Padella Realtà Energetiche Parallele
# - Saltare in Padella Singolarità Inversa
# - Saltare in Padella Sinergia Psionica
# - Saltare in Padella Classica
# - Decostruzione Atomica a Strati Energetici
# - Decostruzione Magnetica Risonante
# - Decostruzione Bio-Fotonica Emotiva
# - Decostruzione Ancestrale
# - Decostruzione Interdimensionale Lovecraftiana
# - Sferificazione a Gravità Psionica Variabile
# - Sferificazione Filamentare a Molecole Vibrazionali
# - Sferificazione Cromatica Interdimensionale
# - Sferificazione con Campi Magnetici Entropici
# - Sferificazione tramite Matrici Biofotiche
# - Taglio Dimensionale a Lame Fotofiliche
# - Taglio a Risonanza Sonica Rigenerativa
# - Affettamento a Pulsazioni Quantistiche
# - Taglio Sinaptico Biomimetico
# - Incisione Elettromagnetica Plasmica
#
# Esecuzione matching...
#
# Create 70 associazioni:
# - Marinatura a Infusione Gravitazionale -> Marinatura
# - Marinatura Temporale Sincronizzata -> Marinatura
# - Marinatura Psionica -> Marinatura
# - Marinatura tramite Reazioni d'Antimateria Diluite -> Marinatura
# - Marinatura Sotto Zero a Polarità Inversa -> Marinatura
# - Affumicatura a Stratificazione Quantica -> Affumicatura
# - Affumicatura Temporale Risonante -> Affumicatura
# - Affumicatura Psionica Sensoriale -> Affumicatura
# - Affumicatura tramite Big Bang Microcosmico -> Affumicatura
# - Affumicatura Polarizzata a Freddo Iperbarico -> Affumicatura
# - Fermentazione Quantica a Strati Multiversali -> Fermentazione
# - Fermentazione Temporale Sincronizzata -> Fermentazione
# - Fermentazione Psionica Energetica -> Fermentazione
# - Fermentazione tramite Singolarità -> Fermentazione
# - Fermentazione Quantico Biometrica -> Fermentazione
# - Impasto Gravitazionale Vorticoso -> Tecniche di Impasto
# - Amalgamazione Sintetica Molecolare -> Tecniche di Impasto
# - Impasto a Campi Magnetici Dualistici -> Tecniche di Impasto
# - Sinergia Elettro-Osmotica Programmabile -> Tecniche di Impasto
# - Modellatura Onirica Tetrazionale -> Tecniche di Impasto
# - Cryo-Tessitura Energetica Polarizzata -> Surgelamento
# - Congelamento Bio-Luminiscente Sincronico -> Surgelamento
# - Cristallizzazione Temporale Reversiva -> Surgelamento
# - Congelazione Iperdimensionalmente Stratificata -> Surgelamento
# - Surgelamento Antimaterico a Risonanza Inversa -> Surgelamento
# - Ebollizione Magneto-Cinetica Pulsante -> Bollitura
# - Bollitura Infrasonica Armonizzata -> Bollitura
# - Bollitura Termografica a Rotazione Veloce -> Bollitura
# - Bollitura Entropica Sincronizzata -> Bollitura
# - Idro-Cristallizzazione Sonora Quantistica -> Surgelamento
# - Grigliatura a Energia Stellare DiV -> Grigliare
# - Grigliatura Plasma Sintetico Risonante -> Grigliare
# - Grigliatura Eletro-Molecolare a Spaziatura Variabile -> Grigliare
# - Grigliatura Tachionica Refrattaria -> Grigliare
# - Grigliatura Psionica Dinamica Ritmica -> Grigliare
# - Cottura al Forno con Paradosso Temporale Cronospeculare -> Forno
# - Cottura con Microonde Entropiche Sincronizzate -> Forno
# - Cottura a Forno Dinamico Inversionale -> Forno
# - Cottura Olografica Quantum Fluttuante -> Forno
# - Cottura Geomagnetica Psicosincronizzata -> Forno
# - Cottura a Vapore con Flusso di Particelle Isoarmoniche -> Vapore
# - Cottura a Vapore Ecodinamico Bilanciato -> Vapore
# - Cottura a Vapore Risonante Simbiotico -> Vapore
# - Cottura a Vapore Termocinetica Multipla -> Vapore
# - Cottura Idrodinamica Autoregolante -> Vapore
# - Cottura Sottovuoto Antimateria -> Sottovuoto
# - Cottura Sottovuoto Multirealità Collassante -> Sottovuoto
# - Cottura Sottovuoto Frugale Energeticamente Negativa -> Sottovuoto
# - Cottura Sottovuoto Pulsar Magnetica -> Sottovuoto
# - Cottura Sottovuoto Bioma Sintetico -> Sottovuoto
# - Saltare in Padella Big Bang Termico -> Saltare in Padella
# - Saltare in Padella Realtà Energetiche Parallele -> Saltare in Padella
# - Saltare in Padella Singolarità Inversa -> Saltare in Padella
# - Saltare in Padella Sinergia Psionica -> Saltare in Padella
# - Saltare in Padella Classica -> Saltare in Padella
# - Decostruzione Atomica a Strati Energetici -> Decostruzione
# - Decostruzione Magnetica Risonante -> Decostruzione
# - Decostruzione Bio-Fotonica Emotiva -> Decostruzione
# - Decostruzione Ancestrale -> Decostruzione
# - Decostruzione Interdimensionale Lovecraftiana -> Decostruzione
# - Sferificazione a Gravità Psionica Variabile -> Sferificazione
# - Sferificazione Filamentare a Molecole Vibrazionali -> Sferificazione
# - Sferificazione Cromatica Interdimensionale -> Sferificazione
# - Sferificazione con Campi Magnetici Entropici -> Sferificazione
# - Sferificazione tramite Matrici Biofotiche -> Sferificazione
# - Taglio Dimensionale a Lame Fotofiliche -> Tecniche di Taglio
# - Taglio a Risonanza Sonica Rigenerativa -> Tecniche di Taglio
# - Affettamento a Pulsazioni Quantistiche -> Tecniche di Taglio
# - Taglio Sinaptico Biomimetico -> Tecniche di Taglio
# - Incisione Elettromagnetica Plasmica -> Tecniche di Taglio
#
# Salvataggio relazioni in Neo4j...
# SUCCESS: Creata relazione Marinatura a Infusione Gravitazionale -> Marinatura
# SUCCESS: Creata relazione Marinatura Temporale Sincronizzata -> Marinatura
# SUCCESS: Creata relazione Marinatura Psionica -> Marinatura
# SUCCESS: Creata relazione Marinatura tramite Reazioni d'Antimateria Diluite -> Marinatura
# SUCCESS: Creata relazione Marinatura Sotto Zero a Polarità Inversa -> Marinatura
# SUCCESS: Creata relazione Affumicatura a Stratificazione Quantica -> Affumicatura
# SUCCESS: Creata relazione Affumicatura Temporale Risonante -> Affumicatura
# SUCCESS: Creata relazione Affumicatura Psionica Sensoriale -> Affumicatura
# SUCCESS: Creata relazione Affumicatura tramite Big Bang Microcosmico -> Affumicatura
# SUCCESS: Creata relazione Affumicatura Polarizzata a Freddo Iperbarico -> Affumicatura
# SUCCESS: Creata relazione Fermentazione Quantica a Strati Multiversali -> Fermentazione
# SUCCESS: Creata relazione Fermentazione Temporale Sincronizzata -> Fermentazione
# SUCCESS: Creata relazione Fermentazione Psionica Energetica -> Fermentazione
# SUCCESS: Creata relazione Fermentazione tramite Singolarità -> Fermentazione
# SUCCESS: Creata relazione Fermentazione Quantico Biometrica -> Fermentazione
# SUCCESS: Creata relazione Impasto Gravitazionale Vorticoso -> Tecniche di Impasto
# SUCCESS: Creata relazione Amalgamazione Sintetica Molecolare -> Tecniche di Impasto
# SUCCESS: Creata relazione Impasto a Campi Magnetici Dualistici -> Tecniche di Impasto
# SUCCESS: Creata relazione Sinergia Elettro-Osmotica Programmabile -> Tecniche di Impasto
# SUCCESS: Creata relazione Modellatura Onirica Tetrazionale -> Tecniche di Impasto
# SUCCESS: Creata relazione Cryo-Tessitura Energetica Polarizzata -> Surgelamento
# SUCCESS: Creata relazione Congelamento Bio-Luminiscente Sincronico -> Surgelamento
# SUCCESS: Creata relazione Cristallizzazione Temporale Reversiva -> Surgelamento
# SUCCESS: Creata relazione Congelazione Iperdimensionalmente Stratificata -> Surgelamento
# SUCCESS: Creata relazione Surgelamento Antimaterico a Risonanza Inversa -> Surgelamento
# SUCCESS: Creata relazione Ebollizione Magneto-Cinetica Pulsante -> Bollitura
# SUCCESS: Creata relazione Bollitura Infrasonica Armonizzata -> Bollitura
# SUCCESS: Creata relazione Bollitura Termografica a Rotazione Veloce -> Bollitura
# SUCCESS: Creata relazione Bollitura Entropica Sincronizzata -> Bollitura
# SUCCESS: Creata relazione Idro-Cristallizzazione Sonora Quantistica -> Surgelamento
# SUCCESS: Creata relazione Grigliatura a Energia Stellare DiV -> Grigliare
# SUCCESS: Creata relazione Grigliatura Plasma Sintetico Risonante -> Grigliare
# SUCCESS: Creata relazione Grigliatura Eletro-Molecolare a Spaziatura Variabile -> Grigliare
# SUCCESS: Creata relazione Grigliatura Tachionica Refrattaria -> Grigliare
# SUCCESS: Creata relazione Grigliatura Psionica Dinamica Ritmica -> Grigliare
# SUCCESS: Creata relazione Cottura al Forno con Paradosso Temporale Cronospeculare -> Forno
# SUCCESS: Creata relazione Cottura con Microonde Entropiche Sincronizzate -> Forno
# SUCCESS: Creata relazione Cottura a Forno Dinamico Inversionale -> Forno
# SUCCESS: Creata relazione Cottura Olografica Quantum Fluttuante -> Forno
# SUCCESS: Creata relazione Cottura Geomagnetica Psicosincronizzata -> Forno
# SUCCESS: Creata relazione Cottura a Vapore con Flusso di Particelle Isoarmoniche -> Vapore
# SUCCESS: Creata relazione Cottura a Vapore Ecodinamico Bilanciato -> Vapore
# SUCCESS: Creata relazione Cottura a Vapore Risonante Simbiotico -> Vapore
# SUCCESS: Creata relazione Cottura a Vapore Termocinetica Multipla -> Vapore
# SUCCESS: Creata relazione Cottura Idrodinamica Autoregolante -> Vapore
# SUCCESS: Creata relazione Cottura Sottovuoto Antimateria -> Sottovuoto
# SUCCESS: Creata relazione Cottura Sottovuoto Multirealità Collassante -> Sottovuoto
# SUCCESS: Creata relazione Cottura Sottovuoto Frugale Energeticamente Negativa -> Sottovuoto
# SUCCESS: Creata relazione Cottura Sottovuoto Pulsar Magnetica -> Sottovuoto
# SUCCESS: Creata relazione Cottura Sottovuoto Bioma Sintetico -> Sottovuoto
# SUCCESS: Creata relazione Saltare in Padella Big Bang Termico -> Saltare in Padella
# SUCCESS: Creata relazione Saltare in Padella Realtà Energetiche Parallele -> Saltare in Padella
# SUCCESS: Creata relazione Saltare in Padella Singolarità Inversa -> Saltare in Padella
# SUCCESS: Creata relazione Saltare in Padella Sinergia Psionica -> Saltare in Padella
# SUCCESS: Creata relazione Saltare in Padella Classica -> Saltare in Padella
# SUCCESS: Creata relazione Decostruzione Atomica a Strati Energetici -> Decostruzione
# SUCCESS: Creata relazione Decostruzione Magnetica Risonante -> Decostruzione
# SUCCESS: Creata relazione Decostruzione Bio-Fotonica Emotiva -> Decostruzione
# SUCCESS: Creata relazione Decostruzione Ancestrale -> Decostruzione
# SUCCESS: Creata relazione Decostruzione Interdimensionale Lovecraftiana -> Decostruzione
# SUCCESS: Creata relazione Sferificazione a Gravità Psionica Variabile -> Sferificazione
# SUCCESS: Creata relazione Sferificazione Filamentare a Molecole Vibrazionali -> Sferificazione
# SUCCESS: Creata relazione Sferificazione Cromatica Interdimensionale -> Sferificazione
# SUCCESS: Creata relazione Sferificazione con Campi Magnetici Entropici -> Sferificazione
# SUCCESS: Creata relazione Sferificazione tramite Matrici Biofotiche -> Sferificazione
# SUCCESS: Creata relazione Taglio Dimensionale a Lame Fotofiliche -> Tecniche di Taglio
# SUCCESS: Creata relazione Taglio a Risonanza Sonica Rigenerativa -> Tecniche di Taglio
# SUCCESS: Creata relazione Affettamento a Pulsazioni Quantistiche -> Tecniche di Taglio
# SUCCESS: Creata relazione Taglio Sinaptico Biomimetico -> Tecniche di Taglio
# SUCCESS: Creata relazione Incisione Elettromagnetica Plasmica -> Tecniche di Taglio
#
# Verifica delle relazioni create:
# Trovate 70 relazioni nel database:
# - Fermentazione Quantica a Strati Multiversali -> Fermentazione
# - Fermentazione Temporale Sincronizzata -> Fermentazione
# - Fermentazione Psionica Energetica -> Fermentazione
# - Fermentazione tramite Singolarità -> Fermentazione
# - Fermentazione Quantico Biometrica -> Fermentazione
# - Impasto Gravitazionale Vorticoso -> Tecniche di Impasto
# - Amalgamazione Sintetica Molecolare -> Tecniche di Impasto
# - Impasto a Campi Magnetici Dualistici -> Tecniche di Impasto
# - Sinergia Elettro-Osmotica Programmabile -> Tecniche di Impasto
# - Modellatura Onirica Tetrazionale -> Tecniche di Impasto
# - Cryo-Tessitura Energetica Polarizzata -> Surgelamento
# - Congelamento Bio-Luminiscente Sincronico -> Surgelamento
# - Cristallizzazione Temporale Reversiva -> Surgelamento
# - Congelazione Iperdimensionalmente Stratificata -> Surgelamento
# - Surgelamento Antimaterico a Risonanza Inversa -> Surgelamento
# - Idro-Cristallizzazione Sonora Quantistica -> Surgelamento
# - Ebollizione Magneto-Cinetica Pulsante -> Bollitura
# - Bollitura Infrasonica Armonizzata -> Bollitura
# - Bollitura Termografica a Rotazione Veloce -> Bollitura
# - Bollitura Entropica Sincronizzata -> Bollitura
# - Grigliatura a Energia Stellare DiV -> Grigliare
# - Grigliatura Plasma Sintetico Risonante -> Grigliare
# - Grigliatura Eletro-Molecolare a Spaziatura Variabile -> Grigliare
# - Grigliatura Tachionica Refrattaria -> Grigliare
# - Grigliatura Psionica Dinamica Ritmica -> Grigliare
# - Cottura al Forno con Paradosso Temporale Cronospeculare -> Forno
# - Cottura con Microonde Entropiche Sincronizzate -> Forno
# - Cottura a Forno Dinamico Inversionale -> Forno
# - Cottura Olografica Quantum Fluttuante -> Forno
# - Cottura Geomagnetica Psicosincronizzata -> Forno
# - Cottura a Vapore con Flusso di Particelle Isoarmoniche -> Vapore
# - Cottura a Vapore Ecodinamico Bilanciato -> Vapore
# - Cottura a Vapore Risonante Simbiotico -> Vapore
# - Cottura a Vapore Termocinetica Multipla -> Vapore
# - Cottura Idrodinamica Autoregolante -> Vapore
# - Cottura Sottovuoto Antimateria -> Sottovuoto
# - Cottura Sottovuoto Multirealità Collassante -> Sottovuoto
# - Cottura Sottovuoto Frugale Energeticamente Negativa -> Sottovuoto
# - Cottura Sottovuoto Pulsar Magnetica -> Sottovuoto
# - Cottura Sottovuoto Bioma Sintetico -> Sottovuoto
# - Saltare in Padella Big Bang Termico -> Saltare in Padella
# - Saltare in Padella Realtà Energetiche Parallele -> Saltare in Padella
# - Saltare in Padella Singolarità Inversa -> Saltare in Padella
# - Saltare in Padella Sinergia Psionica -> Saltare in Padella
# - Saltare in Padella Classica -> Saltare in Padella
# - Decostruzione Atomica a Strati Energetici -> Decostruzione
# - Decostruzione Magnetica Risonante -> Decostruzione
# - Decostruzione Bio-Fotonica Emotiva -> Decostruzione
# - Decostruzione Ancestrale -> Decostruzione
# - Decostruzione Interdimensionale Lovecraftiana -> Decostruzione
# - Sferificazione a Gravità Psionica Variabile -> Sferificazione
# - Sferificazione Filamentare a Molecole Vibrazionali -> Sferificazione
# - Sferificazione Cromatica Interdimensionale -> Sferificazione
# - Sferificazione con Campi Magnetici Entropici -> Sferificazione
# - Sferificazione tramite Matrici Biofotiche -> Sferificazione
# - Taglio Dimensionale a Lame Fotofiliche -> Tecniche di Taglio
# - Taglio a Risonanza Sonica Rigenerativa -> Tecniche di Taglio
# - Affettamento a Pulsazioni Quantistiche -> Tecniche di Taglio
# - Taglio Sinaptico Biomimetico -> Tecniche di Taglio
# - Incisione Elettromagnetica Plasmica -> Tecniche di Taglio
# - Marinatura a Infusione Gravitazionale -> Marinatura
# - Marinatura Temporale Sincronizzata -> Marinatura
# - Marinatura Psionica -> Marinatura
# - Marinatura tramite Reazioni d'Antimateria Diluite -> Marinatura
# - Marinatura Sotto Zero a Polarità Inversa -> Marinatura
# - Affumicatura a Stratificazione Quantica -> Affumicatura
# - Affumicatura Temporale Risonante -> Affumicatura
# - Affumicatura Psionica Sensoriale -> Affumicatura
# - Affumicatura tramite Big Bang Microcosmico -> Affumicatura
# - Affumicatura Polarizzata a Freddo Iperbarico -> Affumicatura
# Marinatura a Infusione Gravitazionale -> Marinatura
# Marinatura Temporale Sincronizzata -> Marinatura
# Marinatura Psionica -> Marinatura
# Marinatura tramite Reazioni d'Antimateria Diluite -> Marinatura
# Marinatura Sotto Zero a Polarità Inversa -> Marinatura
# Affumicatura a Stratificazione Quantica -> Affumicatura
# Affumicatura Temporale Risonante -> Affumicatura
# Affumicatura Psionica Sensoriale -> Affumicatura
# Affumicatura tramite Big Bang Microcosmico -> Affumicatura
# Affumicatura Polarizzata a Freddo Iperbarico -> Affumicatura
# Fermentazione Quantica a Strati Multiversali -> Fermentazione
# Fermentazione Temporale Sincronizzata -> Fermentazione
# Fermentazione Psionica Energetica -> Fermentazione
# Fermentazione tramite Singolarità -> Fermentazione
# Fermentazione Quantico Biometrica -> Fermentazione
# Impasto Gravitazionale Vorticoso -> Tecniche di Impasto
# Amalgamazione Sintetica Molecolare -> Tecniche di Impasto
# Impasto a Campi Magnetici Dualistici -> Tecniche di Impasto
# Sinergia Elettro-Osmotica Programmabile -> Tecniche di Impasto
# Modellatura Onirica Tetrazionale -> Tecniche di Impasto
# Cryo-Tessitura Energetica Polarizzata -> Surgelamento
# Congelamento Bio-Luminiscente Sincronico -> Surgelamento
# Cristallizzazione Temporale Reversiva -> Surgelamento
# Congelazione Iperdimensionalmente Stratificata -> Surgelamento
# Surgelamento Antimaterico a Risonanza Inversa -> Surgelamento
# Ebollizione Magneto-Cinetica Pulsante -> Bollitura
# Bollitura Infrasonica Armonizzata -> Bollitura
# Bollitura Termografica a Rotazione Veloce -> Bollitura
# Bollitura Entropica Sincronizzata -> Bollitura
# Idro-Cristallizzazione Sonora Quantistica -> Surgelamento
# Grigliatura a Energia Stellare DiV -> Grigliare
# Grigliatura Plasma Sintetico Risonante -> Grigliare
# Grigliatura Eletro-Molecolare a Spaziatura Variabile -> Grigliare
# Grigliatura Tachionica Refrattaria -> Grigliare
# Grigliatura Psionica Dinamica Ritmica -> Grigliare
# Cottura al Forno con Paradosso Temporale Cronospeculare -> Forno
# Cottura con Microonde Entropiche Sincronizzate -> Forno
# Cottura a Forno Dinamico Inversionale -> Forno
# Cottura Olografica Quantum Fluttuante -> Forno
# Cottura Geomagnetica Psicosincronizzata -> Forno
# Cottura a Vapore con Flusso di Particelle Isoarmoniche -> Vapore
# Cottura a Vapore Ecodinamico Bilanciato -> Vapore
# Cottura a Vapore Risonante Simbiotico -> Vapore
# Cottura a Vapore Termocinetica Multipla -> Vapore
# Cottura Idrodinamica Autoregolante -> Vapore
# Cottura Sottovuoto Antimateria -> Sottovuoto
# Cottura Sottovuoto Multirealità Collassante -> Sottovuoto
# Cottura Sottovuoto Frugale Energeticamente Negativa -> Sottovuoto
# Cottura Sottovuoto Pulsar Magnetica -> Sottovuoto
# Cottura Sottovuoto Bioma Sintetico -> Sottovuoto
# Saltare in Padella Big Bang Termico -> Saltare in Padella
# Saltare in Padella Realtà Energetiche Parallele -> Saltare in Padella
# Saltare in Padella Singolarità Inversa -> Saltare in Padella
# Saltare in Padella Sinergia Psionica -> Saltare in Padella
# Saltare in Padella Classica -> Saltare in Padella
# Decostruzione Atomica a Strati Energetici -> Decostruzione
# Decostruzione Magnetica Risonante -> Decostruzione
# Decostruzione Bio-Fotonica Emotiva -> Decostruzione
# Decostruzione Ancestrale -> Decostruzione
# Decostruzione Interdimensionale Lovecraftiana -> Decostruzione
# Sferificazione a Gravità Psionica Variabile -> Sferificazione
# Sferificazione Filamentare a Molecole Vibrazionali -> Sferificazione
# Sferificazione Cromatica Interdimensionale -> Sferificazione
# Sferificazione con Campi Magnetici Entropici -> Sferificazione
# Sferificazione tramite Matrici Biofotiche -> Sferificazione
# Taglio Dimensionale a Lame Fotofiliche -> Tecniche di Taglio
# Taglio a Risonanza Sonica Rigenerativa -> Tecniche di Taglio
# Affettamento a Pulsazioni Quantistiche -> Tecniche di Taglio
# Taglio Sinaptico Biomimetico -> Tecniche di Taglio
# Incisione Elettromagnetica Plasmica -> Tecniche di Taglio
