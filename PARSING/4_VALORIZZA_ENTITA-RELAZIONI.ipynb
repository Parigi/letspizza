# %% [markdown]
# ## CONFIG

# %%
import pdfplumber
import re
import json
import os
import html
import PyPDF2
import pandas as pd
from bs4 import BeautifulSoup



from collections import Counter

from dotenv import load_dotenv
from neo4j import GraphDatabase
from py2neo import Graph, Node, Relationship
from langchain_openai import AzureChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from typing import List, Dict, Tuple

# %%
codice_galattico = "../Hackapizza Dataset/Codice Galattico/Codice Galattico.pdf"
manuale_cucina = "../Hackapizza Dataset/Misc/Manuale di Cucina.pdf"

domande = "../Hackapizza Dataset/domande.csv"
piatti = "../Hackapizza Dataset/Misc/dish_mapping.json"
pianeti = "../Hackapizza Dataset/Misc/Distanze.csv"

blog_1 = "../Hackapizza Dataset/Blogpost/blog_etere_del_gusto.html"
blog_2 = "../Hackapizza Dataset/Blogpost/blog_sapore_del_dune.html"


load_dotenv()
# Recupera endpoint e chiave dalle variabili d'ambiente
api_base = os.getenv("AZURE_OPENAI_API_BASE")
api_key = os.getenv("AZURE_OPENAI_API_KEY")

# neo4j first instance parameters
NEO4J_URI= "neo4j+s://0482640f.databases.neo4j.io"
NEO4J_USERNAME= "neo4j"
NEO4J_PASSWORD= "PNvdaZlk326-ja2hRD1K97ZUUMnD4mj0NsecZNu5-9k"
AURA_INSTANCEID= "0482640f"
AURA_INSTANCENAME= "Instance01"

driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %%
def crea_llm(api_key: str, api_base: str) -> AzureChatOpenAI:
    """
    Crea un'istanza del modello linguistico Azure OpenAI.
    
    Args:
        api_key (str): La chiave API di Azure
        api_base (str): L'URL base dell'API Azure
        
    Returns:
        AzureChatOpenAI: Istanza configurata del modello
    """
    return AzureChatOpenAI(
        openai_api_version="2024-08-01-preview",
        azure_deployment="o1-mini",
        azure_endpoint=api_base,
        api_key=api_key,
        temperature=1
    )

llm = crea_llm(api_key, api_base)

# %%
def estrai_testo_pdf(percorso_pdf):
    with open(percorso_pdf, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        testo = ""
        for pagina in reader.pages:
            testo += pagina.extract_text()
    return testo

def estrai_testo_html(percorso_html):
    """Estrae il testo da un file HTML."""
    with open(percorso_html, "r", encoding="utf-8") as file:
        soup = BeautifulSoup(file, "html.parser")
        return soup.get_text(separator=" ", strip=True)

# %% [markdown]
# ## METODI

# %%
from json_repair import repair_json

def estrai_valorizzazioni(testo, categoria, llm, driver):
    """
    Estrae le valorizzazioni di entità di una specifica categoria dal testo.
    """
    # Genera un prompt basato sulle entità filtrate     
    prompt = f"""
    Contesto: questo testo rientra in una collezione di documenti che parlano di Ristoranti nello spazio (su Pianeti) e sui loro Menu, Piatti, Ingredienti, Tecniche e Licenze.
    
    Il testo che segue potrebbe contenere informazioni pertinenti a questa categoria: {categoria}
    In output voglio tutte le possibile istanze di questa categoria, come entità da caricare su neo4j.
    Per ogni istanza recupera:
        - NOME dell'istanza
        - eventuali PARAMETRI associati all'istanza. Il singolo PARAMETRO deve essere una STRINGA.
    Attento che i nomi delle chiavi devono essere identiche a quelle fornite.
    
    Restituisci SOLO il JSON valido e completo, senza formattazione markdown o decoratori.

    Il formato deve essere:
    [
      {{'NOME': 'nome', "PARAMETRI": {{...parametri...}}}},   
    ]  
    
    Testo:
    {testo}
    """
    
    # Chiamata al modello LLM per ottenere la valorizzazione delle entità
    response = llm.invoke(prompt)
    content = response.content.strip()
    
    # Pulizia del JSON
    if content.startswith('```') and content.endswith('```'):
        content = '\n'.join(content.split('\n')[1:-1])
    if content.startswith('```json'):
        content = content[7:].strip()
    elif content.startswith('json'):
        content = content[4:].strip()
    
    # Tentativo di riparare il JSON
    try:
        valorizzazioni = json.loads(content)
    except json.JSONDecodeError as e:
        print(f"Errore nel parsing JSON per entità {categoria}: {str(e)}")
        try:
            valorizzazioni = json.loads(repair_json(content))
        except Exception:
            # Fallback con richiesta all'LLM
            prompt_repair = f"Correggi questo JSON per Neo4j e assicurati che sia valido e completo:\n{content}"
            repaired = llm.invoke(prompt_repair).content.strip()
            
            # Pulizia del JSON riparato
            if repaired.startswith('```') and repaired.endswith('```'):
                repaired = '\n'.join(repaired.split('\n')[1:-1])
            if repaired.startswith('```json'):
                repaired = repaired[7:].strip()
            elif repaired.startswith('json'):
                repaired = repaired[4:].strip()
                
            try:
                valorizzazioni = json.loads(repaired)
            except:
                print(f"Impossibile riparare il JSON per le entità di tipo {categoria}")
                valorizzazioni = []
    
    # Assicurati che il risultato sia una lista
    if not isinstance(valorizzazioni, list):
        valorizzazioni = [valorizzazioni]
    
    return valorizzazioni

# %%
import json
from json_repair import repair_json

def estrai_relazioni(testo, relazioni_info, llm, driver):
    """
    Estrae entità e relazioni tra di esse da un testo.
    
    Args:
        testo: Il testo da cui estrarre le relazioni
        relazioni_info: Dizionario nella forma {'NOME_RELAZIONE': ['Tipo_Entità1', 'Tipo_Entità2']}
        llm: Modello di linguaggio da utilizzare
        driver: Driver Neo4j
        
    Returns:
        Dizionario contenente entità e relazioni estratte
    """
    risultati = {}
    entita_tipi = set()
    
    # Raccogli tutti i tipi di entità unici dalle relazioni
    for _, [tipo_entita1, tipo_entita2] in relazioni_info.items():
        entita_tipi.add(tipo_entita1)
        entita_tipi.add(tipo_entita2)
    
    # Estrai tutte le entità una sola volta per tipo
    for tipo_entita in entita_tipi:
        print(f"Estraendo entità di tipo '{tipo_entita}'...")
        entita = estrai_valorizzazioni(testo, tipo_entita, llm, driver)
        risultati[tipo_entita] = entita
    
    # Ora estrai le relazioni
    for nome_relazione, [tipo_entita1, tipo_entita2] in relazioni_info.items():
        print(f"Estraendo relazioni '{nome_relazione}' tra '{tipo_entita1}' e '{tipo_entita2}'...")
        
        # Estrai le relazioni tra entità1 e entità2
        relazioni = estrai_valorizzazioni_relazioni(
            testo, 
            nome_relazione, 
            tipo_entita1, 
            tipo_entita2, 
            risultati[tipo_entita1], 
            risultati[tipo_entita2], 
            llm, 
            driver
        )
        
        # Salva le relazioni nel risultato
        risultati[nome_relazione] = relazioni
        
    return risultati

# %%
def estrai_valorizzazioni_relazioni(testo, nome_relazione, tipo_entita1, tipo_entita2, entita1, entita2, llm, driver):
    """
    Estrae le relazioni specifiche tra entità di due tipi.
    """
    # Genera un prompt per estrarre le relazioni
    prompt = f"""
    Contesto: questo testo rientra in una collezione di documenti che parlano di Ristoranti nello spazio (su Pianeti) e sui loro Menu, Piatti, Ingredienti, Tecniche e Licenze.
    
    Il testo che segue potrebbe contenere informazioni su relazioni di tipo '{nome_relazione}' tra entità di tipo '{tipo_entita1}' e '{tipo_entita2}'.
    
    In output voglio tutte le relazioni di tipo '{nome_relazione}' come triple da caricare su neo4j.
    Per ogni relazione recupera:
        - ORIGINE: nome dell'entità di tipo '{tipo_entita1}'
        - DESTINAZIONE: nome dell'entità di tipo '{tipo_entita2}'
        - eventuali PARAMETRI associati alla relazione
    
    Ecco le entità di tipo '{tipo_entita1}' già identificate:
    {[e.get("NOME", "") for e in (entita1 if isinstance(entita1, list) else [entita1])]}
    
    Ecco le entità di tipo '{tipo_entita2}' già identificate:
    {[e.get("NOME", "") for e in (entita2 if isinstance(entita2, list) else [entita2])]}
    
    Restituisci SOLO il JSON valido e completo, senza formattazione markdown o decoratori.
    Il formato deve essere:
    [
      {{"ORIGINE": "nome_entita1", "DESTINAZIONE": "nome_entita2", "PARAMETRI": {{...parametri...}} }}
    ]
    
    
    Testo:
    {testo}
    """
    
    # Chiamata al modello LLM per ottenere la valorizzazione delle relazioni
    response = llm.invoke(prompt)
    content = response.content.strip()
    
    # Pulizia del JSON
    if content.startswith('```') and content.endswith('```'):
        content = '\n'.join(content.split('\n')[1:-1])
    if content.startswith('```json'):
        content = content[7:].strip()
    elif content.startswith('json'):
        content = content[4:].strip()
    
    # Tentativo di riparare il JSON
    try:
        relazioni = json.loads(content)
    except json.JSONDecodeError as e:
        print(f"Errore nel parsing JSON delle relazioni {nome_relazione}: {str(e)}")
        try:
            relazioni = json.loads(repair_json(content))
        except Exception:
            # Fallback con richiesta all'LLM
            prompt_repair = f"Correggi questo JSON per Neo4j e assicurati che sia valido e completo:\n{content}"
            repaired = llm.invoke(prompt_repair).content.strip()
            
            # Pulizia del JSON riparato
            if repaired.startswith('```') and repaired.endswith('```'):
                repaired = '\n'.join(repaired.split('\n')[1:-1])
            if repaired.startswith('```json'):
                repaired = repaired[7:].strip()
            elif repaired.startswith('json'):
                repaired = repaired[4:].strip()
                
            try:
                relazioni = json.loads(repaired)
            except:
                print(f"Impossibile riparare il JSON delle relazioni {nome_relazione}")
                relazioni = []
    
    # Assicurati che il risultato sia una lista
    if not isinstance(relazioni, list):
        relazioni = [relazioni]
    
    return relazioni

# %%
def carica_entita_e_relazioni_su_neo4j(risultati, relazioni_info, driver):
    """
    Carica entità e relazioni su Neo4j gestendo strutture dati nidificate
    
    Args:
        risultati: Dizionario contenente entità e relazioni
        relazioni_info: Dizionario delle relazioni come riferimento
        driver: Driver Neo4j
    """
    # Crea un set di tutti i tipi di relazione
    tipi_relazione = set(relazioni_info.keys())
    
    # Contatori per verifica
    entita_create = 0
    relazioni_create = 0
    
    # Verifica preliminare che il driver sia connesso
    try:
        with driver.session() as session:
            result = session.run("RETURN 1 AS test")
            test_value = result.single()["test"]
            if test_value != 1:
                print("ERRORE: Connessione al database non funzionante")
                return
            print("Connessione al database verificata con successo")
    except Exception as e:
        print(f"ERRORE: Impossibile connettersi al database: {str(e)}")
        return
    
    # Carica le entità
    for tipo_entita, entita_data in risultati.items():
        # Salta le chiavi che sono nomi di relazione
        if tipo_entita in tipi_relazione:
            continue
        
        print(f"Elaborazione per tipo: {tipo_entita}")
        print(f"Tipo di dato: {type(entita_data).__name__}")
        
        # Gestione speciale per struttura dati nidificata
        if isinstance(entita_data, dict) and tipo_entita in entita_data:
            print(f"Rilevata struttura nidificata per {tipo_entita}")
            if isinstance(entita_data[tipo_entita], list):
                entita_list = entita_data[tipo_entita]
            else:
                entita_list = [entita_data[tipo_entita]]
            print(f"Estratti {len(entita_list)} elementi dalla struttura nidificata")
        elif isinstance(entita_data, list):
            entita_list = entita_data
        elif isinstance(entita_data, dict) and "NOME" in entita_data:  # caso di singolo oggetto
            entita_list = [entita_data]
        else:
            print(f"ERRORE: Formato non supportato per {tipo_entita}: {entita_data}")
            continue
        
        print(f"Caricando {len(entita_list)} entità di tipo {tipo_entita}...")
        
        for entita in entita_list:
            nome = entita.get("NOME", "")
            if not nome:  
                print(f"ERRORE: Entità di tipo {tipo_entita} senza nome: {entita}")
                continue
                
            parametri = entita.get("PARAMETRI", {})
            
            print(f"Creazione entità: {nome} (tipo: {tipo_entita})")
            
            # Usa una transazione esplicita
            with driver.session() as session:
                tx = session.begin_transaction()
                try:
                    # Crea la query base
                    query = f"MERGE (e:{tipo_entita} {{nome: $nome}})"
                    
                    # Se ci sono parametri, aggiungi SET
                    if parametri:
                        query += " SET "
                        set_clauses = []
                        for k in parametri.keys():
                            # Gestione speciale per parametri che sono dizionari
                            if isinstance(parametri[k], dict):
                                # Converti sotto-dizionari in formato JSON o string
                                set_clauses.append(f"e.{k} = $param_{k}")
                            else:
                                set_clauses.append(f"e.{k} = ${k}")
                        query += ", ".join(set_clauses)
                    
                    query += " RETURN e"  # Ritorna il nodo per conferma
                    
                    # Prepara i parametri per la query
                    params = {"nome": nome}
                    for k, v in parametri.items():
                        if isinstance(v, dict):
                            params[f"param_{k}"] = v  # Neo4j supporta JSON per le proprietà
                        else:
                            params[k] = v
                    
                    print(f"Esecuzione query: {query}")
                    result = tx.run(query, **params)
                    record = result.single()
                    if record:
                        node = record.get("e")
                        print(f"Entità creata e confermata: {nome} di tipo {tipo_entita}")
                        entita_create += 1
                    else:
                        print(f"ATTENZIONE: Entità {nome} non confermata dopo l'esecuzione della query")
                    
                    # Esplicita conferma della transazione
                    tx.commit()
                except Exception as e:
                    tx.rollback()
                    print(f"ERRORE nel caricamento dell'entità {nome}: {str(e)}")
                    print(f"Query: {query}")
                    print(f"Parametri: {params}")
    
    # Carica le relazioni
    for tipo_relazione, relazioni in risultati.items():
        # Salta le chiavi che non sono tipi di relazione
        if tipo_relazione not in tipi_relazione:
            continue
            
        # Determina i tipi di entità coinvolti nella relazione
        tipo_origine, tipo_destinazione = relazioni_info[tipo_relazione]
        
        print(f"Caricando {len(relazioni)} relazioni di tipo {tipo_relazione}...")
        
        for relazione in relazioni:
            origine = relazione.get("ORIGINE", "")
            destinazione = relazione.get("DESTINAZIONE", "")
            
            if not origine or not destinazione:
                print(f"ERRORE: Relazione {tipo_relazione} incompleta: {relazione}")
                continue
                
            parametri = relazione.get("PARAMETRI", {})
            
            # Usa una transazione esplicita
            with driver.session() as session:
                # Prima verifica che i nodi esistano
                verify_query = f"""
                OPTIONAL MATCH (o:{tipo_origine} {{nome: $origine}})
                OPTIONAL MATCH (d:{tipo_destinazione} {{nome: $destinazione}})
                RETURN o, d
                """
                verify_result = session.run(verify_query, origine=origine, destinazione=destinazione)
                record = verify_result.single()
                
                origin_node = record.get("o")
                dest_node = record.get("d")
                
                if not origin_node:
                    print(f"ERRORE: Nodo origine '{origine}' di tipo {tipo_origine} non trovato")
                    print(f"Creazione automatica del nodo origine...")
                    try:
                        session.run(f"CREATE (n:{tipo_origine} {{nome: $nome}})", nome=origine)
                        print(f"Nodo origine '{origine}' creato")
                    except Exception as e:
                        print(f"ERRORE nella creazione automatica: {str(e)}")
                        continue
                
                if not dest_node:
                    print(f"ERRORE: Nodo destinazione '{destinazione}' di tipo {tipo_destinazione} non trovato")
                    print(f"Creazione automatica del nodo destinazione...")
                    try:
                        session.run(f"CREATE (n:{tipo_destinazione} {{nome: $nome}})", nome=destinazione)
                        print(f"Nodo destinazione '{destinazione}' creato")
                    except Exception as e:
                        print(f"ERRORE nella creazione automatica: {str(e)}")
                        continue
                
                # Crea la relazione
                tx = session.begin_transaction()
                try:
                    # Crea la query per la relazione
                    query = f"""
                    MATCH (o:{tipo_origine} {{nome: $origine}})
                    MATCH (d:{tipo_destinazione} {{nome: $destinazione}})
                    MERGE (o)-[r:{tipo_relazione}]->(d)
                    """
                    
                    # Se ci sono parametri, aggiungi SET
                    if parametri:
                        query += " SET "
                        set_clauses = []
                        for k in parametri.keys():
                            if isinstance(parametri[k], dict):
                                set_clauses.append(f"r.{k} = $param_{k}")
                            else:
                                set_clauses.append(f"r.{k} = ${k}")
                        query += ", ".join(set_clauses)
                    
                    query += " RETURN r"  # Ritorna la relazione per conferma
                    
                    # Prepara i parametri per la query
                    params = {
                        "origine": origine,
                        "destinazione": destinazione
                    }
                    for k, v in parametri.items():
                        if isinstance(v, dict):
                            params[f"param_{k}"] = v
                        else:
                            params[k] = v
                    
                    result = tx.run(query, **params)
                    rel = result.single()
                    if rel:
                        print(f"Relazione creata e confermata: {origine}-[{tipo_relazione}]->{destinazione}")
                        relazioni_create += 1
                    else:
                        print(f"ATTENZIONE: Relazione {origine}-[{tipo_relazione}]->{destinazione} non confermata")
                    
                    # Esplicita conferma della transazione
                    tx.commit()
                except Exception as e:
                    tx.rollback()
                    print(f"ERRORE nel caricamento della relazione {origine}-[{tipo_relazione}]->{destinazione}: {str(e)}")
                    print(f"Query: {query}")
                    print(f"Parametri: {params}")
    
    print(f"\nRiepilogo: create {entita_create} entità e {relazioni_create} relazioni")
    
    # Verifica finale: query per contare entità e relazioni
    try:
        with driver.session() as session:
            # Conta tutte le entità
            count_query = "MATCH (n) RETURN count(n) as count"
            count_result = session.run(count_query)
            node_count = count_result.single()["count"]
            
            # Conta tutte le relazioni
            rel_query = "MATCH ()-[r]->() RETURN count(r) as count"
            rel_result = session.run(rel_query)
            rel_count = rel_result.single()["count"]
            
            print(f"Verifica finale dal database: {node_count} nodi e {rel_count} relazioni presenti")
            
            # Elenca i primi 5 nodi per ogni tipo
            print("\nEsempi di nodi per tipo:")
            type_query = "CALL db.labels() YIELD label RETURN label"
            labels_result = session.run(type_query)
            for label_record in labels_result:
                label = label_record["label"]
                nodes_query = f"MATCH (n:{label}) RETURN n.nome as nome LIMIT 5"
                nodes_result = session.run(nodes_query)
                nodes = [record["nome"] for record in nodes_result]
                print(f"  {label}: {', '.join(nodes) if nodes else 'Nessun nodo trovato'}")
    except Exception as e:
        print(f"ERRORE nella verifica finale: {str(e)}")

# %%
import re

def chunk_text(text, max_chars=3000, overlap=300):
    """
    Divide un testo in chunk di massimo `max_chars` caratteri, con `overlap` tra i chunk.
    
    Args:
        text (str): Il testo da spezzare in chunk.
        max_chars (int): Numero massimo di caratteri per chunk.
        overlap (int): Numero di caratteri di sovrapposizione tra i chunk.
    
    Returns:
        list: Lista di chunk di testo.
    """
    # Pulizia del testo per evitare problemi di spazi extra
    text = re.sub(r'\n+', '\n', text.strip())

    chunks = []
    start = 0
    while start < len(text):
        end = start + max_chars
        chunk = text[start:end]
        chunks.append(chunk)
        start = end - overlap  # Sposta l'inizio del prossimo chunk per avere overlap
    
    return chunks

# %%
chunks = chunk_text(testo_menu, 3000, 400)

# %%
len(chunks)
# Out:
# 9

# %% [markdown]
# ## MAIN

# %%
# Esegui l'analisi del PDF
testo_manuale = estrai_testo_pdf(manuale_cucina)
# Esegui l'analisi del PDF
testo_codice = estrai_testo_pdf(codice_galattico)

# %%
capitoli_manuale = ["Cap" + t for t in testo_manuale.split("Cap")]
capitoli_manuale[0] = capitoli_manuale[0][3:]
capitoli_manuale
# Out:
# ['Introduzione\nIo sono il grande Sirius Cosmo, lo chef stellare per eccellenza. Se non mi conoscete ancora, preparatevi:\nil mio nome è sinonimo di cucina galattica. In questo manuale vi insegnerò tutto quello che serve per\ndiventare veri cuochi, da Alpha Centauri fino alla Nebulosa del Granchio (dove, a proposito, non hanno\nneanche un crostaceo decente). Impareremo insieme le licenze e le abilità fondamentali per cucinare\nnello spazio senza mandare in tilt lʼintero sistema di supporto vitale della nave — perché diciamocelo, un\nbuon brasato non vale una depressurizzazione dʼemergenza.\nVi guiderò passo passo tra tecniche di cucina gravitazionali, segreti per friggere senza far esplodere la\ncabina e trucchi per ottenere il perfetto soufflé orbitale.\nSpoiler: Sì, si può montare una maionese in assenza di gravità — basta avere il giusto polso e un poʼ di\npazienza, cose che non si insegnano nei manuali tecnici ma che io, Sirius Cosmo, sono qui per\ntrasmettervi.\nPronti a decollare? Mettete il grembiule, astronauti del sapore: si parte per un viaggio culinario!\n',
#  'Capitolo 1: Abilità e Licenze Richieste\nPrima di iniziare a cucinare nello spazio, è fondamentale ottenere le giuste autorizzazioni e raggiungere le\ngiuste abilità. Non ci si può semplicemente mettere ai fornelli gravitazionali senza essere certificati: ci\nsono normative severe che regolano ogni fase della preparazione e gestione del cibo a bordo di una nave\nspaziale. Ovviamente, non ho mai cucinato senza la giusta licenza (non lo farei mai per nessun motivo).\nVediamo insieme le principali categorie e le relative licenze richieste.\nPsionica (P)\nLivello 0: Posseduta da tutti se non diversamente specificato. Tipica degli esseri senzienti.\nLivello I: lettura pensiero, telecinesi e teletrasporto di oggetti di massa inferiore a 5 kg,\nprecognizione e visione del passato fino a 5 minuti\nLivello II: manipolazione della probabilità, telecinesi e teletrasporto di oggetti di massa inferiore a\n20 kg, manipolazione delle forze fondamentali dellʼuniverso\nLivello III: capacità di donare la coscienza e lʼintelletto ad oggetti, manipolazione della realtà\ncircoscritta a stanze, teletrasporto senza errore in qualsiasi dimensione temporale, comunione con\nentità di altri piani\nLivello IV: proiezione astrale, riscrittura di realtà circoscritta a piccole nazioni o asteroidi\nLivello V: riscrittura di realtà di intere linee temporali o galassie. Questo livello è equivalente al\nGrado di influenza di livello tecnologico III (LTK III)\nTemporale (t)\nLivello I: effetti temporali relativi al presente come dilatazione o accelerazione del tempo\nLivello II: Livello I + effetti temporali che riguardano linee temporali future\nLivello III: Livello II + effetti temporali che riguardano linee temporali passate\nGravitazionale (G)Livello 0: 5 < G ≤ 10, posseduta da tutti se non diversamente specificato\nLivello I: 0 < G ≤ 100\nLivello II: 0 < G ≤ 10^6\nLivello III: G > 10^6\nAntimateria (e+)\nLivello 0: particelle, posseduta da tutti se non diversamente specificato\nLivello I: antiparticelle\nMagnetica (Mx)\nLivello 0: Polo nord e sud, posseduta da tutti se non diversamente specificato\nLivello I: Mono-polo\nQuantistica (Q)\nLivello n: Numero di stati in superposizione dove n è il numero di stati\nLuce (c)\nLivello I: Solo colori primari (RGB)\nLivello II: Tutto lo spettro visibile umano\nLivello III: Tutte le frequenze\nLivello di Sviluppo Tecnologico (LTK)\nLivello I: Planetario\nLivello II: Sistema Stellare\nLivello III: Galassia\nLivello IV: Superamasso di Galassie\nLivello V: Intero Universo\nLivello VI: Universi multipli\nLivello VI+: Tutte le fonti energia\n',
#  'Capitolo 2: Gli Ordini\nQui di seguito vi illustro i diversi ordini presenti nel nostro universo. FONDAMENTALE leggere.\n🪐 Ordine della Galassia di Andromeda\nCari pionieri del gusto cosmico, preparatevi a una sfida da veri fuoriclasse: cucinare per gli abitanti di\nAndromeda! Qui non parliamo solo di tecnica stellare, ma di pura diplomazia culinaria intergalattica. La\nparticolarità? Ogni piatto devʼessere rigorosamente privo di lattosio — non un goccio, nemmeno lʼombra\ndi una molecola originaria della Via Lattea. Se pensate che il formaggio sia lʼunica via per la felicità, è\ntempo di ripensare il vostro approccio. Imparerete a creare sapori complessi senza latte, burro o panna,\nconquistando palati alieni con alternative che sfidano le leggi della gastronomia universale.\n🌱 Ordine dei NaturalistiPer gli adepti dellʼOrdine dei Naturalisti, la cucina è molto più che creatività: è un atto di riverenza verso\nla natura. Qui si celebra lʼessenza primordiale di ogni ingrediente, custodendone la purezza come un\nprezioso segreto galattico. Nessuna trasformazione drastica, niente manipolazioni invasive: solo il\n“Principio di Non Alterazione”. Questo significa che se una carota vuol essere una carota, dovrà restare\ntale, anche quando diventa arte culinaria. La sfida? Esaltare la semplicità con maestria, senza mai tradire\nlʼidentità autentica del cibo.\n🌈 Ordine degli Armonisti\nGli Armonisti sono più che semplici chef: sono veri maestri del flusso emozionale gastronomico. Il loro\ndono è trasformare il cibo in una sinfonia che risuona con lʼanima di chi lo assapora. Non si tratta solo di\nsapori, ma di vibrazioni sottili che si sintonizzano sullo stato dʼanimo degli ospiti. Un pranzo può calmare,\nispirare o persino risvegliare ricordi dimenticati. La missione? Creare piatti che parlano al cuore,\nadattandosi alle frequenze emotive del momento. Perché qui, il cibo non si gusta: si vive.\n',
#  "Capitolo 3: Tecniche di Preparazione\nNel vasto universo della cucina spaziale, la preparazione è la chiave per ogni grande piatto. In questo\ncapitolo, esploreremo le tecniche che trasformano gli ingredienti da semplici materie prime a protagonisti\ndi un'esperienza culinaria stellare. Ogni passaggio è fondamentale per creare la base perfetta per la\ncottura. Preparatevi a scoprire come l'arte della preparazione, nel cosmo, richieda precisione e ingegno,\nma soprattutto visione.\nMarinatura\nLa marinatura spaziale è un'arte che sfrutta il tempo e lo spazio, dove ogni condimento si mescola in\nperfetta armonia con gli ingredienti. In assenza di gravità, le molecole si distribuiscono in modo unico,\namplificando sapori e aromi. Imparare a marinare nel vuoto cosmico è fondamentale per ottenere piatti\nche sfidano ogni legge della fisica culinaria, rivelando gusti straordinari in ogni morso.\nMarinatura a Infusione Gravitazionale\nCome funziona: il cibo è collocato in una camera a gravità alternata, che intensifica lʼassorbimento della\nmarinata nei tessuti alimentari.\nVantaggi: il sapore penetra in profondità per una marinatura uniforme e intensa.\nSvantaggi: necessita di un “Grav-Infuser” di alta precisione, con un dispendio energetico significativo.\nMarinatura Temporale Sincronizzata\nCome funziona: sfrutta una bolla temporale sincronizzata per accelerare il processo di marinatura,\ncomprimendo ore in minuti.\nVantaggi: marinatura completa in un tempo minimo, senza compromessi sulla qualità.\nSvantaggi: rischi di interferenze temporali minori; vietata per uso domestico senza supervisione.\nMarinatura PsionicaCome funziona: uno chef telepate concentra la propria energia mentali per manipolare le molecole della\nmarinata, fondendole con l'alimento.\nVantaggi: sapori unici e personalizzati ottenuti attraverso la fusione creativa tra mente e ingredienti.\nSvantaggi: richiede chef con competenze psioniche avanzate\nMarinatura tramite Reazioni d'Antimateria Diluite\nCome funziona: micro-quantità di antimateria generano reazioni controllate che ionizzano la marinata,\nincrementando lʼassorbimento attraverso la tensione superficiale.\nVantaggi: penetrazione rapida della marinata anche negli alimenti più densi, con un caratteristico\nretrogusto “cosmico”.\nSvantaggi: manipolazione rischiosa che richiede per legge ambienti protetti.\nMarinatura Sotto Zero a Polarità Inversa\nCome funziona: gli alimenti sono immersi in soluzioni marinate a temperatura sub-critica, mentre una\npolarità magnetica inversa aiuta lʼassorbimento dei sapori.\nVantaggi: conserva al massimo i profumi e le caratteristiche volatili della marinata.\nSvantaggi: richiede tecnologia avanzata per regolare con precisione le condizioni polari.\nAffumicatura\nL'affumicatura è una tecnica che va ben oltre la semplice espressione di fumo. Qui, lʼarte di infondere\nsapore sfrutta il vuoto cosmico per distribuire il fumo in modo uniforme e affascinante, regalando ai piatti\nun aroma profondo che si espande in modo inaspettato. La gestione della temperatura e del flusso di\nfumo è fondamentale per ottenere un affumicato perfetto, che aggiunga una dimensione nuova e\nsorprendente a ogni ingrediente, senza alterarne la qualità. Un processo che, se eseguito correttamente,\nporta il cibo a nuove vette di complessità e intensità.\nAffumicatura a Stratificazione Quantica\nCome funziona: il cibo viene posizionato in una camera che alterna strati quantici, permettendo a\nparticelle di fumo quantisticamente compresse di penetrare attraverso i livelli molecolari dell'alimento.\nVantaggi: penetrazione uniforme del sapore affumicato, con un aroma che sembra provenire dall'interno\ndell'alimento stesso. Svantaggi: può causare una leggera variazione del sapore se non calibrato con\nprecisione, rendendo l'affumicatura imprevedibile senza un operatore esperto.\nAffumicatura Temporale Risonante\nCome funziona: sfrutta la risonanza temporale per infondere i sapori del fumo nel cibo attravers ...
#  "Capitolo 4: Tecniche di Cottura\nLa cottura è un campo dove la scienza e l'arte si incontrano in un perfetto equilibrio. Qui, le leggi della\nfisica possono essere tanto flessibili quanto il nostro approccio al calore e alla temperatura. In questo\ncapitolo, esploreremo le diverse tecniche di cottura, dal vapore al sottovuoto, dalla grigliatura alle\nmeraviglie della cottura al forno, adattate alle sfide uniche della gravità zero. Ogni metodo è progettato\nper ottenere piatti perfetti, mantenendo l'integrità degli ingredienti, ma spingendo le potenzialità del\ngusto e della consistenza verso nuove frontiere.\nBollitura\nLa bollitura è un'arte che va oltre l'acqua in ebollizione: è un processo di controllo preciso della\ntemperatura, che sfrutta l'assenza di gravità per ottenere risultati che sembrano impossibili sulla Terra.\nLa sfida è mantenere una temperatura costante e uniforme, riuscendo a cuocere ogni ingrediente al\npunto giusto, senza comprometterne sapore e consistenza. Unʼabilità fondamentale per ogni astronauta\ndel gusto.\nEbollizione Magneto-Cinetica Pulsante\nCome funziona: utilizza campi magnetici pulsanti che esaltano il movimento cinetico delle molecole\nd'acqua, generando un'ebollizione uniforme e controllata senza contatto diretto con la fonte di calore.\nVantaggi: assicura una distribuzione termica omogenea che preserva i sapori naturali degli ingredienti;\nideale per preparazioni delicate come infusi o brodi leggeri.\nSvantaggi: richiede un coordinamento preciso della frequenza dei campi magnetici per evitare\nturbolenze che potrebbero compromettere la consistenza.\nBollitura Infrasonica Armonizzata\nCome funziona: impiega onde sonore infrasoniche per eccitare risonanze molecolari nell'acqua,\ninducendo una bollitura ad elevata profondità sonora che infonde gli alimenti con vibrazioni nutrienti.\nVantaggi: produce un risultato aromatico particolarmente ricco che valorizza lʼessenza degli ingredienti\nsenza richiedere additivi esterni.\nSvantaggi: richiede ambienti schermati acusticamente per mantenere stabile la risonanza e prevenire\ninterferenze indesiderate.\nBollitura Termografica a Rotazione Veloce\nCome funziona: combina rotazioni rapide con mappature termografiche dinamiche per dirigere flussi di\ncalore concentrici, creando vortici di ebollizione che abbracciano il cibo in coreografie riscaldanti.\nVantaggi: permette una cottura precisa e scenografica, dove il controllo visivo del termogramma\ngarantisce risultati impeccabili anche per piatti complessi come zuppe dense o salse raffinate.\nSvantaggi: necessita di sensibili sistemi di rilevamento termico per mantenere lʼequilibrio vortex continuo\ned evitare zone di sovracottura.\nBollitura Entropica SincronizzataCome funziona: sincronizza flussi entropici modulati che manipolano il disordine a livello atomico\ngenerando microscopiche sacche di ebollizione progressiva in sequenza temporale calibrata.\nVantaggi: offre una metodologia rivoluzionaria che cucina a livelli subatomici preservando perfettamente\nle qualità nutritive; applicabile a pietanze ad alta quota o ambienti a pressione variabile.\nSvantaggi: richiede continua analisi entropica per monitorare variazioni reattive e prevenire collassi\nstrutturali.\nIdro-Cristallizzazione Sonora Quantistica\nCome funziona: integra impulsi sonori quantistici nei vapori dʼacqua per orchestrare reticoli cristallini\nche avvolgono ogni molecola culinaria in unʼarmoniosa danza bollente.\nVantaggi: conserva la consistenza ottimale anche negli elementi più delicati; adattabile alla creazione\nd'innovativi piatti gourmet che sfidano la tradizionale concezione della bollitura.\nSvantaggi: richiede sofisticate apparecchiature sincronizzate capillarmente al soundscape quantistico\nper evitare dissonanze destabilizzanti.\nGrigliare\nGrigliare nello spazio non è solo un atto di cuocere: è un'esperienza che sfrutta il calore radiante delle\nstelle o l'intensità dei campi elettromagnetici. Il risultato è un piatto p ...
#  "Capitolo 5: Tecniche AvanzateNel cuore della cucina, le tecniche avanzate sono quelle che separano i cuochi stellari dai semplici\nastronauti del sapore. In questo capitolo, esploreremo tecniche sofisticate come la decostruzione, la\nsferificazione e l'affumicatura spaziale, che richiedono abilità, creatività e una perfetta comprensione\ndelle leggi fisiche che regolano l'universo. Queste tecniche avanzate sono per chi ha già padroneggiato le\nbasi e ora desidera spingersi oltre, alla ricerca di nuove dimensioni di sapore e innovazione. Preparatevi a\nentrare nel futuro della cucina spaziale, dove ogni piatto è una scoperta.\nDecostruzione\nLa decostruzione è l'arte di smontare un piatto e ricomporlo in modo inaspettato. Nello spazio, dove la\ngravitazione può rendere instabile la presentazione, ogni componente deve essere pensato come una\nparte di un puzzle galattico. Ogni elemento del piatto è trattato separatamente, per poi essere ricostruito\nin un'armonia che trascende la semplice ricetta, offrendo unʼesperienza sensoriale unica e sorprendente.\nDecostruzione Atomica a Strati Energetici\nCome funziona: il cibo viene suddiviso a livello atomico utilizzando campi energetici concentrati che\nridistribuiscono gli atomi su geometrie alimentari innovative, mantenendo i legami molecolari intatti\nmentre cambiano la struttura.\nVantaggi: permette la creazione di texture e forme impossibili con metodi tradizionali, offrendo\nun'esperienza culinaria unica.\nSvantaggi: le alte energie coinvolte richiedono un uso responsabile per evitare reazioni indesiderate\ncome esplosioni culinarie.\nDecostruzione Magnetica Risonante\nCome funziona: utilizza campi magnetici a frequenze risonanti che separano e ricombinano i\ncomponenti del cibo attraverso vibrazioni microstrutturali, consentendo una dissezione granulare e\nprecisa.\nVantaggi: precisione estrema in ogni elemento sapore e consistenza, permettendo variazioni sottili ma\nsignificative per piatti sensorialmente armonizzati.\nSvantaggi: richiede una strumentazione complessa ed è sensibile ai disturbi elettromagnetici esterni.\nDecostruzione Bio-Fotonica Emotiva\nCome funziona: combinando biofotoni emessi dalle cellule alimentari con lʼinfluenza delle emozioni, si\nopera unʼanalisi destrutturante basata sullo stato emotivo del cliente.\nVantaggi: personalizzazione emotiva dei piatti, creando connessioni profonde tra l'esperienza gustativa\ne lo stato dʼanimo dei commensali.\nSvantaggi: richiede chef dotati di competenze empatiche elevate per guidare correttamente il processo\nsenza perdere coerenza gustativa.\nDecostruzione Ancestrale\nCome funziona: risveglia le essenze perdute dei cibi usando le memorie storiche degli antenati del\ncliente, ricontestualizzando sapori dimenticati lungo linee temporali passate.Vantaggi: fornisce accesso a sapori di epoche passate, riportando alla luce tradizioni culinarie\nscomparse.\nSvantaggi: ricordare le memorie ancestrali può provocare perdita della propria identità, si consiglia,\nsebbene non necessario, di avere un ancora emotiva vicino.\nDecostruzione Interdimensionale Lovecraftiana\nCome funziona: sfrutta aperture interdimensionali verso realtà oscure e oniriche, ispirate ai miti di\nCthulhu, per attirare frammenti elementali dai regni oltre il nostro concepimento umano nella de-\nstrutturazione degli ingredienti.\nVantaggi: produce profili gustativi alieni e inaspettati che evocano il terrore inconcepibile\ndell'indescrivibile.\nSvantaggi: ę̵͉͈̓̈̅̈l̶̜̮̥̠̉͐̀͝e̷̢͓̜̬̎̊̄v̵͇̻̲͗͛͂̾\na̷̠̟̪̅̇t̵͕̂̈́̍̎̒\nõ̶̧͈̠ ̸̗͓͚̤̲̔͂͌r̸̺̕ i̵̮̫͠s̴̯̅̏c̸̝̟̲̙̈̍͒̆h̵̦̭̠͑̅̈i̵̡͉͓̼͗̔́̋\no̵͚͌̔ ̸̘̫͇̻̈́̋̅d̴̼͒̉̆i̸̬̰̜̞͑̚ ̷̛̞͛m̸̰͛a̸̙̱̺͇̒n̸̟͎̩̓̏̏͗̅\ni̴͉̺͍̝͓͂̑͆͂͑\nf̶̢̦͙͖͆̋̄͛͘e̵̼̥̞̟̅̍̅͝s̸̬̟̩͠t̷̘̀̿̇͂͌\nȧ̴̩̻͇̘̓̃͛̑\nz̶̜̙̥͋̕͜į̶̪̺̇͜ͅọ̵̣͇͎̰͒͌̆ n̴̺̬̓̈̓ i̴̢̥͕͐̊ ̴̝̪͇̱̬̈́̑̍͌̄i̴̬͓̱̐͝n̴̟̻̬̐n̴̯̯͍̝̭͒͂̄å̶̤͎͜͝t̵͕͇̫̰͕̆͒̎u̸͎̰͆̇̑̏̈́\nr̵̉̏̄̃͝ͅa̵̭͕̩̯̍͜͝l̷̅̈͐̇ͅḯ̵͚̗͎̙̅̚ ̸͕̠̍̚e̶̗̜̙̮̒̒͂͜ ̷̥̫̟͚͆̂͋͝c̷̦̠͕̹̓̅́̎͝o̷̦̦͗̊͌̚ŗ̴̟̬͙͍̎̋̀r̸͎̰͕̜̒̚͘͜u̸͔̫͕̬̪͑̐̆̈z̵̨̢͇̫̎͑i̸͍͍̙̓́͂͝ọ̶̀ͅǹ̴̝̇͛ ẽ̷̙̀  ̶͈͎̲̀̃̚ d̵̘̱̺̟̄̂̆͝e̴̞̱̓ ļ̵͛̌̑  ...

# %%
import re

def split_string(input_string):    
    #pattern = r'(?<=\s|\n)\d(?=\s)' Nope
    #pattern = r'(?<="  ")\d(?=\s)' Nope
    pattern = r'(?<=  )\d(?= )' # Ding Ding !!
    return re.split(pattern, input_string)

split_string(testo_codice)
# Out:
# ['  Gazzetta u(iciale del Consiglio Intergalattico   789/12773  DECRETO SUPREMO 789/12773 DEL GRAN CONSIGLIO  del 67° Giorno del Ciclo Cosmico 789  sulla regolamentazione della sicurezza alimentare intergalattica    IL GRAN CONSIGLIO DELLA FEDERAZIONE INTERGALATTICA,  Nel rispetto delle diverse credenze e tradizioni alimentari,  Viste le necessità ﬁsiologiche di tutte le specie senzienti e non senzienti come deﬁnite dal regolamento 675/12,   Con particolare attenzione agli individui iscritti ai gruppi:  (1) I membri dell’Ordine della Galassia di Andromeda, deﬁniti nella sezione 1.1  (2) I membri dell’Ordine dei Naturalisti, le cui rigide prescrizioni alimentari vengono discusse nella sezione 1.2  (3) Gli individui all’Ordine degli Armonisti, la cui ﬁlosoﬁa è meglio indicata nella sezione 1.3  STABILISCE IL PRESENTE CODICE COME FONDAMENTO NORMATIVO PER L\'ESERCIZIO DELLE ATTIVITÀ DI RISTORAZIONE NEL TERRITORIO DELLA FEDERAZIONE.     \n789/12773     67° Giorno del Ciclo Cosmico 789 \n1 Deﬁnizioni e ambiti  1.1 Ordine della Galassia di Andromeda  Gli chef iscritti e operanti nel suddetto Ordine della Galassia di Andromeda sono tenuti a considerare e gestire una peculiare caratteristica ﬁsiologica della propria utenza: tutti gli abitanti di Andromeda manifestano infatti intolleranza al lattosio, ovvero intolleranza a qualsiasi forma nutritiva originaria della Via Lattea.   1.2 Ordine dei Naturalisti  L\'Ordine dei Naturalisti venera la purezza originaria del cibo. Il loro credo si basa su un principio semplice: ogni ingrediente ha una sua perfezione innata che deve essere preservata.  La regola fondamentale è il "Principio di Non Alterazione": un ingrediente può essere modiﬁcato solo ﬁno al punto in cui mantiene ancora riconoscibile la sua essenza originaria.   1.3 Ordine degli Armonisti   Gli chef iscritti all\'Ordine degli Armonisti sono dotati di una rara sensibilità che permette loro di preparare piatti in grado di entrare in sintonia con le frequenze emotive dei loro ospiti. La loro ﬁlosoﬁa si basa sul principio che il cibo non nutre solo il corpo, ma deve entrare in risonanza con lo stato emotivo di chi lo consuma.   ',
#  ' Sostanze regolamentate  Se non diversamente speciﬁcato, tutte le sostanze regolamentate nel presente documento sono soggette a un limite massimo del 5% in massa o volume rispetto alla preparazione totale, indipendentemente dalle loro categorie e proprietà speciﬁche.   Restrizioni più severe, come dettagliato nelle sezioni successive, si applicano in base ai coe(icienti caratteristici di ciascuna sostanza.  2.1 Macro-categorie  Le cinque macro-categorie di sostanze regolamentate sono così deﬁnite:  1. Sostanze Psicotrope e Psioniche: sostanze che interagiscono direttamente con i campi psionici e le strutture mentali dei consumatori, richiedendo particolare attenzione nella dosatura e nel monitoraggio degli e(etti.  789/12773     67° Giorno del Ciclo Cosmico 789 \n2. Ingredienti di Origine Mitica: sostanze derivate da creature leggendarie, la cui esistenza trascende le normali categorie biologiche e richiede considerazioni sia pratiche che etiche nella loro gestione.  3. Sostanze Xenobiologiche: materiali di origine biologica non terrestre che richiedono particolare attenzione nella manipolazione e conservazione, con potenziali interazioni con i sistemi biologici terrestri.  4. Sostanze Quantiche e Dimensionali: ingredienti che manifestano proprietà quantistiche o multi-dimensionali, necessitando di speciﬁche precauzioni per prevenire anomalie spazio-temporali.  5. Sostanze Spazio-Temporali: elementi che interagiscono con il tessuto spazio-temporale, richiedendo particolare attenzione per evitare distorsioni locali della realtà.   2.2 Tabella delle sostanze regolamentate  La presente tabella fornisce una panoramica delle principali categorie di sostanze regolamentate.   Sostanza Proprietà principali Sostanze Psicotrope e Psioniche Erba Pipa CRP: 0.89 IEI: 0.3 Cristalli di Memoria CRP: 0.92 CDT: 0.2 Petali di Eco CRP: 0.87 IPM: 0.6 Sostanze di Origine Mitica Carne di Drago IPM: 0.85 789/12773     67° Giorno del Ciclo Cosmico 789 \nIBX: 0.75 Uova di Fenice IPM: 0.98 CDT: 0.8 Lacrime di Unicorno IPM: 0.95 θ: 0.9 Sostanze Xenobiologiche Foglie di Mandragora IBX: 0.82 μ: 0.3 MuNa Lunare IBX: 0.78 μ: 0.6 CRP: 0.72 Nettare di Sirena IBX: 0.85 μ: 0.2 θ: 0.7 Sostanze Quantiche e Dimensionali Spore Quantiche δQ: 0.45 ID: 0.8 Essenza di Vuoto δQ: 0.16 ID: 0.95 Funghi dell’Etere δQ: 0.38 789/12773     67° Giorno del Ciclo Cosmico 789 \nID: 0.75 Sostanze Spazio-Temporali Sale Temporale CDT: 0.65 IEI: 0.4 Radici di Gravità CDT: 0.55 ID: 0.4 Polvere di Stelle CDT: 0.75 IPM: 0.88   ',
#  " Limiti quantitativi e restrizioni  Le sostanze con risonanza psionica che presentano un Coe(iciente di Risonanza Psionica (CRP) superiore a 0.90 sulla scala Klein-Shimamoto sono soggette a un limite massimo dello 0,5% della massa totale nelle preparazioni alimentari. Per sostanze con CRP tra 0.65 e 0.90, il limite si attesta all'1%.  Le sostanze di origine mitica che presentano un Indice di Purezza Mitica (IPM) superiore a 0.9 sono soggette a un limite massimo del 4% della massa totale nelle preparazioni alimentari.   Gli ingredienti con Indice di Bioattività Xeno (IBX) superiore a 0.7 sono limitati allo 0.25% in volume nelle preparazioni. Per sostanze con potenziale di mutazione superiore a μ = 0.5, il limite si attesta allo 0.1%.  Gli ingredienti quantici e dimensionali che manifestano ﬂuttuazioni quantiche superiori a δQ = 0.3 sulla scala di Heisenberg-Gamma richiedono una concentrazione non superiore al 3% del volume di preparazione.  Le sostanze spazio-temporali con Coe(iciente di Distorsione Temporale (CDT) superiore a 0.7 devono essere limitati al 2% della massa totale nelle preparazioni. Per sostanze con CDT inferiore, tale limite si attesta al 3%.   ",
#  ' Licenze e Tecniche di Preparazione  789/12773     67° Giorno del Ciclo Cosmico 789 \nAi sensi e per gli e(etti del decreto supremo n. 766/31098, si stabilisce che qualsiasi soggetto avente cittadinanza della Federazione Intergalattica che intraprenda attività professionale nel settore della preparazione e somministrazione di alimenti (d\'ora in avanti "attività culinaria"), acquisisce ope legis le seguenti autorizzazioni:  a) licenza di classe Psionica (P) di livello zero (0) b) licenza di classe Gravitazionale (G) di livello zero (0) c) licenza di classe Antimateria (e+) di livello zero (0) d) licenza di classe Magnetica (Mx) di livello zero (0) e) certiﬁcazione di grado tecnologico LTK di primo (I) livello  Le disposizioni di cui ai successivi articoli individuano e disciplinano, in via tassativa ed esaustiva, le metodologie di preparazione alimentare per le quali è richiesto il possesso di licenze diverse o di livello superiore rispetto a quelle conferite ope legis.   4.1 Marinatura  • La marinatura a infusione gravitazionale richiede una licenza gravitazionale (G) di livello II • La marinatura temporale sincronizzata richiede una licenza temporale (t) di livello I • La marinatura psionica richiede una licenza psionica (P) di terzo (III) livello • La marinatura tramite reazioni d’antimateria diluite richiede una licenza Antimateria (e+) di livello I • La marinatura sotto zero a polarità inversa richiede una licenza magnetica (Mx) di primo (I) livello e un grado tecnologico LTK di secondo (II) livello   4.2 A(umicatura  • L’a(umicatura a stratiﬁcazione quantica richiede una licenza quantistica (Q) di livello 3 e un grado tecnologico LTK di livello II • L’a(umicatura temporale risonante richiede una licenza temporale (t) di primo (I) livello e un grado tecnologico LTK di livello II • L’a(umicatura psionica sensoriale richiede una licenza psionica (P) di livello II e un grado tecnologico LTK di livello III • L’a(umicatura tramite big bang microcosmico richiede una licenza antimateria (e+) di primo (I) livello, una licenza quantistica (Q) di livello 10 e un grado tecnologico LTK di terzo (III) livello • L’a(umicatura polarizzata a freddo iperbarico richiede una licenza magnetica (Mx) di livello I e un grado tecnologico LTK di secondo (II) livello    4.3 Fermentazione  789/12773     67° Giorno del Ciclo Cosmico 789 \n• La fermentazione quantica a strati multiversali richiede una licenza quantistica (Q) di livello 5 e un grado tecnologico LTK di livello VI+ • La fermentazione temporale sincronizzata richiede una licenza temporale (t) di terzo (III) livello e un grado tecnologico LTK di terzo (III) livello  • La fermentazione psionica energetica richiede una licenza psionica (P) di livello I e un grado tecnologico LTK di terzo (III) livello • La fermentazione tramite singolarità richiede una licenza gravitazionale (G) di terzo (III) livello, una licenza antimateria (e+) di livello I, una licenza magnetica (Mx) di livello I e un grado tecnologico LTK di quarto (IV) livello • La fermentazione quantico biometrica richiede una licenza quantistica (Q) di livello 3 e un grado tecnologico LTK di secondo (II) livello   4.4 Decostruzione  • La decostruzione atomica a strati energetici richiede una licenza antimaterica (e+) di livello I, una licenza quantistica (Q) di livello 1 e un grado tecnologico LTK di terzo (II) livello • La decostruzione magnetica risonante richiede una licenza magnetica (Mx) di livello I e un grado tecnologico LTK di secondo (II) livello • La decostruzione bio-fotonica emotiva richiede una licenza psionica (P) di terzo (III) livello, una licenza luce (c) di terzo (III) livello e un grado tecnologico LTK di secondo (II) livello • La decostruzione ancestrale richiede una licenza temporale (t) di livello III e un grado tecnologico LTK di secondo (II) livello • La decostruzione interdimensionale Lovercraftiana richiede una licenza quantistica (Q) di livello 7 e un grado tecnologico LTK di sesto (VI) livello   4.5 Sfe ...
#  ' Sanzioni e Pene  Il sistema sanzionatorio previsto dal presente codice riﬂette la complessità delle interazioni tra le diverse normative sulla sicurezza alimentare.   La violazione dei limiti quantitativi stabiliti per le sostanze con risonanza psionica comporta l\'obbligo di sottoporsi a una valutazione psionica approfondita per veriﬁcare eventuali contaminazioni del personale addetto alla preparazione.  789/12773     67° Giorno del Ciclo Cosmico 789 \nLe pene previste per le violazioni che coinvolgono più categorie protette vengono calcolate secondo il principio del cumulo psionico, descritto in dettaglio nell\'Appendice "Calcolo delle Sanzioni Composite" .   La categorizzazione dei crimini alimentari segue una scala di gravità che tiene conto non solo degli e(etti immediati sulla salute dei consumatori, ma anche delle implicazioni culturali, religiose e conservazionistiche delle violazioni.   La falsiﬁcazione delle certiﬁcazioni dell\'Ordine dei Naturalisti costituisce un crimine di particolare gravità, in quanto mina non solo la sicurezza alimentare ma anche i principi fondamentali di una delle più antiche tradizioni gastronomiche della Federazione. Tale violazione comporta l\'obbligo di sottoporsi a un percorso di rieducazione sulla ﬁlosoﬁa del minimo intervento senziente.   ',
#  " Disposizioni ﬁnali  I ristoratori sono tenuti a completare l’implementazione delle disposizioni contenute nel presente codice entro 1 ciclo cosmico dalla sua entrata in vigore.  Le deroghe temporanee potranno essere concesse solo dal Consiglio Superiore per la Sicurezza Alimentare, previa consultazione con i rappresentanti dell'Ordine dei Naturalisti e delle altre categorie protette. Tale processo decisionale dovrà tenere conto delle interazioni tra le diverse normative e dei principi stabiliti in questo codice.  Gran Consiglio della Federazione Intergalattica  67° Giorno del Ciclo Cosmico 789         \n789/12773     67° Giorno del Ciclo Cosmico 789 \nAPPENDICE  CALCOLO DELLE SANZIONI COMPOSITE  La presente appendice deﬁnisce la metodologia per il calcolo delle sanzioni in caso di violazioni multiple. Il principio del cumulo prevede:  1. Valutazione base della singola violazione 2. Moltiplicatori basati su: • Numero di categorie protette coinvolte • Gravità degli e(etti sulla salute • Impatto ambientale • Violazione di principi religiosi o culturali  Il calcolo ﬁnale deve tenere conto delle interazioni tra diverse violazioni, con particolare attenzione ai casi che coinvolgono simultaneamente infrazioni delle norme sull'alimentazione vegetariana e dei principi dell'Ordine dei Naturalisti.  Tale calcolo è di competenza esclusiva del Dipartimento di Valutazione Penale Galattica (DVPG), operante sotto l'egida del Consiglio Supremo.      "]

# %%
estrai_relazioni(capitoli_manuale[0], relazioni, llm, driver)
# Out:
# Estraendo entità di tipo 'Licenza'...
# Estraendo entità di tipo 'Ristorante'...
# Estraendo entità di tipo 'Tecnica'...
# Estraendo entità di tipo 'Ingrediente'...
# Estraendo entità di tipo 'Piatto'...
# Estraendo entità di tipo 'Pianeta'...
# Estraendo relazioni 'CONTIENE' tra 'Piatto' e 'Ingrediente'...
# Estraendo relazioni 'PREPARATO' tra 'Piatto' e 'Tecnica'...
# Estraendo relazioni 'OFFERTA' tra 'Ristorante' e 'Piatto'...
# Estraendo relazioni 'SITUATO' tra 'Ristorante' e 'Pianeta'...
# Estraendo relazioni 'HA' tra 'Ristorante' e 'Licenza'...
# Errore nel parsing JSON delle relazioni HA: Extra data: line 2 column 1 (char 3)
# {'Licenza': [],
#  'Ristorante': [],
#  'Tecnica': [{'NOME': 'Cucina gravitazionale',
#    'PARAMETRI': {'tipo': 'gravitazionale'}},
#   {'NOME': 'Friggere senza far esplodere la cabina',
#    'PARAMETRI': {'contesto': 'evitare esplosione cabina'}},
#   {'NOME': 'Soufflé orbitale',
#    'PARAMETRI': {'condizione': 'orbitale', 'qualità': 'perfetto'}},
#   {'NOME': 'Montare maionese in assenza di gravità',
#    'PARAMETRI': {'tipo': 'maionese', 'condizione': 'assenza di gravità'}}],
#  'Ingrediente': [{'NOME': 'maionese', 'PARAMETRI': {}}],
#  'Piatto': [{'NOME': 'brasato',
#    'PARAMETRI': {'descrizione': "buono, non vale una depressurizzazione d'emergenza"}},
#   {'NOME': 'soufflé orbitale', 'PARAMETRI': {'descrizione': 'perfetto'}},
#   {'NOME': 'maionese',
#    'PARAMETRI': {'condizione': 'in assenza di gravità',
#     'note': "basta avere il giusto polso e un po' di pazienza"}}],
#  'Pianeta': [],
#  'CONTIENE': [{'ORIGINE': 'maionese',
#    'DESTINAZIONE': 'maionese',
#    'PARAMETRI': {}}],
#  'PREPARATO': [{'ORIGINE': 'brasato',
#    'DESTINAZIONE': 'Cucina gravitazionale',
#    'PARAMETRI': {}},
#   {'ORIGINE': 'soufflé orbitale',
#    'DESTINAZIONE': 'Soufflé orbitale',
#    'PARAMETRI': {}},
#   {'ORIGINE': 'maionese',
#    'DESTINAZIONE': 'Montare maionese in assenza di gravità',
#    'PARAMETRI': {}}],
#  'OFFERTA': [],
#  'SITUATO': [],
#  'HA': []}

# %%
# Carica il file CSV
df_domande = pd.read_csv(domande)
testo_domande = df_domande.to_string()  # Converti il CSV in testo

# Carica il file CSV
df_pianeti = pd.read_csv(pianeti)
testo_pianeti = df_pianeti.to_string()  # Converti il CSV in testo

# Esempio di utilizzo:
testo_blog1 = estrai_testo_html(blog_1)
# Esempio di utilizzo:
testo_blog2 = estrai_testo_html(blog_2)

# %%
relazioni = {'CONTIENE': ['Piatto', 'Ingrediente'], 'PREPARATO': ['Piatto', 'Tecnica'], 'OFFERTA': ['Ristorante', 'Piatto'], 'SITUATO': ['Ristorante', 'Pianeta'], 'HA': ['Ristorante', 'Licenza']}

# %%
# Estrai entità e relazioni
chunks = chunk_text(testo_manuale, 3000, 400)
for chunk in chunks:
    risultati = estrai_relazioni(chunk, relazioni, llm, driver)
    carica_entita_e_relazioni_su_neo4j(risultati, relazioni, driver)

# %%
# Estrai entità e relazioni
chunks = chunk_text(testo_codice, 3000, 400)
for chunk in chunks:
    risultati = estrai_relazioni(chunk, relazioni, llm, driver)
    carica_entita_e_relazioni_su_neo4j(risultati, relazioni, driver)

# %%
# Estrai entità e relazioni
chunks = chunk_text(testo_blog1, 3000, 400)
for chunk in chunks:
    risultati = estrai_relazioni(chunk, relazioni, llm, driver)
    carica_entita_e_relazioni_su_neo4j(risultati, relazioni, driver)

# %%
# Estrai entità e relazioni
chunks = chunk_text(testo_blog2, 3000, 400)
for chunk in chunks:
    risultati = estrai_relazioni(chunk, relazioni, llm, driver)
    carica_entita_e_relazioni_su_neo4j(risultati, relazioni, driver)

# %%
import os
from pathlib import Path

# Percorso della cartella contenente i file PDF dei menu
menu_folder = "../Hackapizza Dataset/Menu/"

# Ottieni la lista di tutti i file PDF nella cartella
pdf_files = [f for f in os.listdir(menu_folder) if f.endswith('.pdf')]

# Per ogni file PDF nella cartella
for pdf_file in pdf_files:
    try:
        # Costruisci il percorso completo del file
        pdf_path = os.path.join(menu_folder, pdf_file)
        
        print(f"Elaborazione del file: {pdf_file}")
        
        # Estrai il testo dal PDF
        testo_menu = estrai_testo_pdf(pdf_path)
        
        # Estrai entità e relazioni
        chunks = chunk_text(testo_menu, 3000, 400)
        for chunk in chunks:
            risultati = estrai_relazioni(chunk, relazioni, llm, driver)
            carica_entita_e_relazioni_su_neo4j(risultati, relazioni, driver)
        
        print(f"Elaborazione di {pdf_file} completata con successo")
        print("-" * 50)
        
    except Exception as e:
        print(f"Errore durante l'elaborazione di {pdf_file}: {str(e)}")
        # Continua con il prossimo file anche in caso di errore
        continue
# Out:
# Elaborazione del file: Anima Cosmica.pdf
#   Estrazione Tecnica da Anima Cosmica.pdf
#   Caricamento di 19 entità di tipo Tecnica
# Caricata entità Cottura a Vapore in categoria Tecnica
# Caricata entità Cottura a Vapore in categoria Tecnica
# Caricata entità Taglio a Risonanza Sonica in categoria Tecnica
# Caricata entità Cottura in categoria Tecnica
# Caricata entità Affumicatura in categoria Tecnica
# Caricata entità Cottura a Forno in categoria Tecnica
# Caricata entità Saltare in Padella in categoria Tecnica
# Caricata entità Marinatura in categoria Tecnica
# Caricata entità Congelamento in categoria Tecnica
# Caricata entità Sinergia Elettro-Osmotica in categoria Tecnica
# Caricata entità Bollitura Infrasonica in categoria Tecnica
# Caricata entità Marinatura in categoria Tecnica
# Caricata entità Grigliatura Eletro-Molecolare in categoria Tecnica
# Caricata entità Cottura a Vapore in categoria Tecnica
# Caricata entità Cottura Idrodinamica in categoria Tecnica
# Caricata entità Bollitura Termografica in categoria Tecnica
# Caricata entità Marinatura Temporale in categoria Tecnica
# Caricata entità Affumicatura Temporale in categoria Tecnica
# Caricata entità Impasto Gravitazionale in categoria Tecnica
# Entità della categoria Tecnica caricate correttamente in Neo4j.
#   Estrazione Licenza da Anima Cosmica.pdf
#   Caricamento di 1 entità di tipo Licenza
# Entità senza nome trovata in categoria Licenza, skip
# Entità della categoria Licenza caricate correttamente in Neo4j.
#   Estrazione Ordine da Anima Cosmica.pdf
#   Caricamento di 10 entità di tipo Ordine
# Caricata entità Nebulosa Celestiale alla Stellaris in categoria Ordine
# Caricata entità Sinfonia Cosmica ma Fatta Male in categoria Ordine
# Caricata entità Astro-Risotto alle Onde Temporali in categoria Ordine
# Caricata entità Sinfonia Galattica alla Griglia Cangiante in categoria Ordine
# Caricata entità Galassie Infiammate: Sinfonia Cosmica in Sei Dimensioni in categoria Ordine
# Caricata entità Galassie Sospese: Un Viaggio di Sapori Cosmogalattici in categoria Ordine
# Caricata entità Pioggia di Andromeda in categoria Ordine
# Caricata entità Sinfonia Cosmica ma Fatta Bene in categoria Ordine
# Caricata entità Odissea Cosmica di Nettuno in categoria Ordine
# Caricata entità Galassia Commovente di Stellari in categoria Ordine
# Entità della categoria Ordine caricate correttamente in Neo4j.
#   Estrazione Ingrediente da Anima Cosmica.pdf
#   Caricamento di 40 entità di tipo Ingrediente
# Caricata entità Shard di Materia Oscura in categoria Ingrediente
# Caricata entità Carne di Balena spaziale in categoria Ingrediente
# Caricata entità Carne di Mucca in categoria Ingrediente
# Caricata entità Teste di Idra in categoria Ingrediente
# Caricata entità Riso di Cassandra in categoria Ingrediente
# Caricata entità Biscotti della Galassia in categoria Ingrediente
# Caricata entità Pane di Luce in categoria Ingrediente
# Caricata entità Funghi dell’Etere in categoria Ingrediente
# Caricata entità Spezie Melange in categoria Ingrediente
# Caricata entità Polvere di Pulsar in categoria Ingrediente
# Caricata entità Radici di Singolarità in categoria Ingrediente
# Caricata entità Lattuga Namecciana in categoria Ingrediente
# Caricata entità Baccacedro in categoria Ingrediente
# Caricata entità Granuli di Nebbia Arcobaleno in categoria Ingrediente
# Caricata entità Erba Pipa in categoria Ingrediente
# Caricata entità Foglie di Nebulosa in categoria Ingrediente
# Caricata entità Sale Temporale in categoria Ingrediente
# Caricata entità Amido di Stellarion in categoria Ingrediente
# Caricata entità Fusilli del Vento in categoria Ingrediente
# Caricata entità Spore Quantiche in categoria Ingrediente
# Caricata entità Frammenti di Supernova in categoria Ingrediente
# Caricata entità Uova di Fenice in categoria Ingrediente
# Caricata entità Spaghi del Sole in categoria Ingrediente
# Caricata entità Lacrime di Unicorno in categoria Ingrediente
# Caricata entità Nduja Fritta Tanto in categoria Ingrediente
# Caricata entità Cristalli di Memoria in categoria Ingrediente
# Caricata entità Radici di Gravità in categoria Ingrediente
# Caricata entità Pane degli Abissi in categoria Ingrediente
# Caricata entità Lacrime di Andromeda in categoria Ingrediente
# Caricata entità Essenza di Speziaria in categoria Ingrediente
# Caricata entità Carne di Kraken in categoria Ingrediente
# Caricata entità Fibra di Sintetex in categoria Ingrediente
# Caricata entità Nettare di Sirena in categoria Ingrediente
# Caricata entità Petali di Eco in categoria Ingrediente
# Caricata entità Farina di Nettuno in categoria Ingrediente
# Caricata entità Essenza di Vuoto in categoria Ingrediente
# Caricata entità Polvere di Stelle in categoria Ingrediente
# Caricata entità Alghe Bioluminescenti in categoria Ingrediente
# Caricata entità Funghi Orbitali in categoria Ingrediente
# Caricata entità Essenza di Tachioni in categoria Ingrediente
# Entità della categoria Ingrediente caricate correttamente in Neo4j.
#   Estrazione Ristorante da Anima Cosmica.pdf
#   Caricamento di 1 entità di tipo Ristorante
# Entità senza nome trovata in categoria Ristorante, skip
# Entità della categoria Ristorante caricate correttamente in Neo4j.
# Elaborazione di Anima Cosmica.pdf completata con successo
# --------------------------------------------------
# Elaborazione del file: Armonia Universale.pdf
#   Estrazione Tecnica da Armonia Universale.pdf
#   Caricamento di 26 entità di tipo Tecnica
# Caricata entità Amalgamazione Sintetica Molecolare in categoria Tecnica
# Caricata entità Cottura a Vapore in categoria Tecnica
# Caricata entità Impasto Gravitazionale Vorticoso in categoria Tecnica
# Caricata entità Galassia di Sapore Interstellare in categoria Tecnica
# Caricata entità Impasto in categoria Tecnica
# Caricata entità Decostruzione Magnetica Risonante in categoria Tecnica
# Caricata entità Bollitura Infrasonica Armonizzata in categoria Tecnica
# Caricata entità Sinfonia Cosmica di Sapore in categoria Tecnica
# Caricata entità Idro-Cristallizzazione Sonora Quantistica in categoria Tecnica
# Caricata entità Saltare in Padella in categoria Tecnica
# Caricata entità Sferificazione in categoria Tecnica
# Caricata entità Affumicatura in categoria Tecnica
# Caricata entità Sferificazione in categoria Tecnica
# Caricata entità Sinfonia Cosmica in categoria Tecnica
# Caricata entità Ebollizione in categoria Tecnica
# Caricata entità Grigliatura Eletro-Molecolare in categoria Tecnica
# Caricata entità Sinfonia Cosmica in categoria Tecnica
# Caricata entità Saltare in Padella in categoria Tecnica
# Caricata entità Bollitura Termografica in categoria Tecnica
# Caricata entità Fermentazione Psionica in categoria Tecnica
# Caricata entità Affettamento in categoria Tecnica
# Caricata entità Cottura Sottovuoto in categoria Tecnica
# Caricata entità Marinatura Sotto Zero in categoria Tecnica
# Caricata entità Affumicatura Polarizzata in categoria Tecnica
# Caricata entità Cottura a Vapore in categoria Tecnica
# Caricata entità Congelamento Bio-Luminiscente in categoria Tecnica
# Entità della categoria Tecnica caricate correttamente in Neo4j.
#   Estrazione Licenza da Armonia Universale.pdf
#   Caricamento di 5 entità di tipo Licenza
# Caricata entità Psionica in categoria Licenza
# Caricata entità Gravitazionale in categoria Licenza
# Caricata entità Magnetica in categoria Licenza
# Caricata entità Quantistica in categoria Licenza
# Caricata entità Luce in categoria Licenza
# Entità della categoria Licenza caricate correttamente in Neo4j.
#   Estrazione Ordine da Armonia Universale.pdf
#   Nessuna entità di tipo Ordine trovata in Armonia Universale.pdf
#   Estrazione Ingrediente da Armonia Universale.pdf
#   Caricamento di 40 entità di tipo Ingrediente
# Caricata entità Polvere di Pulsar in categoria Ingrediente
# Caricata entità Radici di Gravità in categoria Ingrediente
# Caricata entità Radici di Singolarità in categoria Ingrediente
# Caricata entità Spaghi del Sole in categoria Ingrediente
# Caricata entità Riso di Cassandra in categoria Ingrediente
# Caricata entità Farina di Nettuno in categoria Ingrediente
# Caricata entità Funghi Orbitali in categoria Ingrediente
# Caricata entità Spezie Melange in categoria Ingrediente
# Caricata entità Cioccorane in categoria Ingrediente
# Caricata entità Frammenti di Supernova in categoria Ingrediente
# Caricata entità Colonia di Mycoflora in categoria Ingrediente
# Caricata entità Foglie di Nebulosa in categoria Ingrediente
# Caricata entità Carne di Mucca in categoria Ingrediente
# Caricata entità Fibra di Sintetex in categoria Ingrediente
# Caricata entità Carne di Kraken in categoria Ingrediente
# Caricata entità Nettare di Sirena in categoria Ingrediente
# Caricata entità Burrobirra in categoria Ingrediente
# Caricata entità Shard di Materia Oscura in categoria Ingrediente
# Caricata entità Carne di Xenodonte in categoria Ingrediente
# Caricata entità Granuli di Nebbia Arcobaleno in categoria Ingrediente
# Caricata entità Nduja Fritta Tanto in categoria Ingrediente
# Caricata entità Ravioli al Vaporeon in categoria Ingrediente
# Caricata entità Uova di Fenice in categoria Ingrediente
# Caricata entità Carne di Drago in categoria Ingrediente
# Caricata entità Amido di Stellarion in categoria Ingrediente
# Caricata entità Slurm in categoria Ingrediente
# Caricata entità Alghe Bioluminescenti in categoria Ingrediente
# Caricata entità Gnocchi del Crepuscolo in categoria Ingrediente
# Caricata entità Lacrime di Andromeda in categoria Ingrediente
# Caricata entità Plasma Vitale in categoria Ingrediente
# Caricata entità Essenza di Tachioni in categoria Ingrediente
# Caricata entità Polvere di Stelle in categoria Ingrediente
# Caricata entità Fusilli del Vento in categoria Ingrediente
# Caricata entità Pane degli Abissi in categoria Ingrediente
# Caricata entità Essenza di Vuoto in categoria Ingrediente
# Caricata entità Biscotti della Galassia in categoria Ingrediente
# Caricata entità Cristalli di Memoria in categoria Ingrediente
# Caricata entità Baccacedro in categoria Ingrediente
# Caricata entità Lattuga Namecciana in categoria Ingrediente
# Caricata entità Teste di Idra in categoria Ingrediente
# Entità della categoria Ingrediente caricate correttamente in Neo4j.
#   Estrazione Ristorante da Armonia Universale.pdf
#   Caricamento di 8 entità di tipo Ristorante
# Caricata entità Armonia Universale in categoria Ristorante
# Caricata entità Sinfonia Cosmica: Versione Pizza in categoria Ristorante
# Caricata entità Ravioli al Vaporeon in categoria Ristorante
# Caricata entità Sinfonia Cosmica: Versione Data in categoria Ristorante
# Caricata entità Sinfonia Cosmologica in categoria Ristorante
# Caricata entità Sinfonia Cosmica di Armonie Terrestri e Celesti in categoria Ristorante
# Caricata entità Portale Cosmico: Sinfonia di Gnocchi del Crepuscolo con Essenza di Tachioni e Sfumature di Fenice in categoria Ristorante
# Caricata entità Cosmo Sferico di Sogni Rigenerativi in categoria Ristorante
# Entità della categoria Ristorante caricate correttamente in Neo4j.
# Elaborazione di Armonia Universale.pdf completata con successo
# --------------------------------------------------
# Elaborazione del file: Cosmica Essenza.pdf
#   Estrazione Tecnica da Cosmica Essenza.pdf
#   Caricamento di 25 entità di tipo Tecnica
# Caricata entità Marinatura in categoria Tecnica
# Caricata entità Cryo-Tessitura in categoria Tecnica
# Caricata entità Saltare in Padella in categoria Tecnica
# Caricata entità Cottura Olografica in categoria Tecnica
# Caricata entità Idro-Cristallizzazione in categoria Tecnica
# Caricata entità Cottura Sottovuoto in categoria Tecnica
# Caricata entità Taglio in categoria Tecnica
# Caricata entità Bollitura Infrasonica in categoria Tecnica
# Caricata entità Sferificazione in categoria Tecnica
# Caricata entità Bollitura Termografica in categoria Tecnica
# Caricata entità Sinfonia Cosmica in categoria Tecnica
# Caricata entità Grigliatura Psionica in categoria Tecnica
# Caricata entità Cottura a Vapore in categoria Tecnica
# Caricata entità Cottura a Forno in categoria Tecnica
# Caricata entità Cottura a Vapore in categoria Tecnica
# Caricata entità Cottura Idrodinamica in categoria Tecnica
# Caricata entità Fermentazione Psionica in categoria Tecnica
# Caricata entità Affettamento in categoria Tecnica
# Caricata entità Decostruzione Atomica in categoria Tecnica
# Caricata entità Cottura con Microonde in categoria Tecnica
# Caricata entità Bollitura Entropica in categoria Tecnica
# Caricata entità Cottura Sottovuoto in categoria Tecnica
# Caricata entità Sinfonia Celeste in categoria Tecnica
# Caricata entità Sinergia Elettro-Osmotica in categoria Tecnica
# Caricata entità Marinatura in categoria Tecnica
# Entità della categoria Tecnica caricate correttamente in Neo4j.
#   Estrazione Licenza da Cosmica Essenza.pdf
#   Caricamento di 1 entità di tipo Licenza
# Entità senza nome trovata in categoria Licenza, skip
# Entità della categoria Licenza caricate correttamente in Neo4j.
#   Estrazione Ordine da Cosmica Essenza.pdf
#   Nessuna entità di tipo Ordine trovata in Cosmica Essenza.pdf
#   Estrazione Ingrediente da Cosmica Essenza.pdf
#   Caricamento di 40 entità di tipo Ingrediente
# Caricata entità Polvere di Pulsar in categoria Ingrediente
# Caricata entità Carne di Xenodonte in categoria Ingrediente
# Caricata entità Carne di Balena spaziale in categoria Ingrediente
# Caricata entità Teste di Idra in categoria Ingrediente
# Caricata entità Spaghi del Sole in categoria Ingrediente
# Caricata entità Riso di Cassandra in categoria Ingrediente
# Caricata entità Farina di Nettuno in categoria Ingrediente
# Caricata entità Lacrime di Andromeda in categoria Ingrediente
# Caricata entità Petali di Eco in categoria Ingrediente
# Caricata entità Shard di Prisma Stellare in categoria Ingrediente
# Caricata entità Foglie di Nebulosa in categoria Ingrediente
# Caricata entità Carne di Drago in categoria Ingrediente
# Caricata entità Carne di Mucca in categoria Ingrediente
# Caricata entità Fibra di Sintetex in categoria Ingrediente
# Caricata entità Lacrime di Unicorno in categoria Ingrediente
# Caricata entità Essenza di Tachioni in categoria Ingrediente
# Caricata entità Radici di Singolarità in categoria Ingrediente
# Caricata entità Colonia di Mycoflora in categoria Ingrediente
# Caricata entità Carne di Kraken in categoria Ingrediente
# Caricata entità Fusilli del Vento in categoria Ingrediente
# Caricata entità Biscotti della Galassia in categoria Ingrediente
# Caricata entità Spore Quantiche in categoria Ingrediente
# Caricata entità Essenza di Speziaria in categoria Ingrediente
# Caricata entità Foglie di Mandragora in categoria Ingrediente
# Caricata entità Lattuga Namecciana in categoria Ingrediente
# Caricata entità Amido di Stellarion in categoria Ingrediente
# Caricata entità Muffa Lunare in categoria Ingrediente
# Caricata entità Erba Pipa in categoria Ingrediente
# Caricata entità Shard di Materia Oscura in categoria Ingrediente
# Caricata entità Pane di Luce in categoria Ingrediente
# Caricata entità Pane degli Abissi in categoria Ingrediente
# Caricata entità Nduja Fritta Tanto in categoria Ingrediente
# Caricata entità Baccacedro in categoria Ingrediente
# Caricata entità Vero Ghiaccio in categoria Ingrediente
# Caricata entità Liane di Plasmodio in categoria Ingrediente
# Caricata entità Funghi dell’Etere in categoria Ingrediente
# Caricata entità Polvere di Crononite in categoria Ingrediente
# Caricata entità Uova di Fenice in categoria Ingrediente
# Caricata entità Spezie Melange in categoria Ingrediente
# Caricata entità Polvere di Stelle in categoria Ingrediente
# Entità della categoria Ingrediente caricate correttamente in Neo4j.
#   Estrazione Ristorante da Cosmica Essenza.pdf
#   Caricamento di 1 entità di tipo Ristorante
# Errore durante l'elaborazione di Cosmica Essenza.pdf: string indices must be integers, not 'str'
# Elaborazione del file: Datapizza.pdf
#   Estrazione Tecnica da Datapizza.pdf
#   Caricamento di 23 entità di tipo Tecnica
# Caricata entità Forno Dinamico Inversionale in categoria Tecnica
# Caricata entità Affettamento a Pulsazioni Quantistiche in categoria Tecnica
# Caricata entità Marinatura Temporale Sincronizzata in categoria Tecnica
# Caricata entità Fermentazione Quantico Biometrica in categoria Tecnica
# Caricata entità Ebollizione Magneto-Cinetica Pulsante in categoria Tecnica
# Caricata entità Sferificazione Filamentare a Molecole Vibrazionali in categoria Tecnica
# Caricata entità Affumicatura Temporale Risonante in categoria Tecnica
# Caricata entità Idro-Cristallizzazione Sonora Quantistica in categoria Tecnica
# Caricata entità Grigliatura Elettro-Molecolare a Spaziatura Variabile in categoria Tecnica
# Caricata entità Congelazione Iperdimensionalmente Stratificata in categoria Tecnica
# Caricata entità Decostruzione Magnetica Risonante in categoria Tecnica
# Caricata entità Affumicatura a Stratificazione Quantica in categoria Tecnica
# Caricata entità Sinergia Elettro-Osmotica Programmabile in categoria Tecnica
# Caricata entità Cottura a Vapore Ecodinamico Bilanciato in categoria Tecnica
# Caricata entità Marinatura Sotto Zero a Polarità Inversa in categoria Tecnica
# Caricata entità Bollitura Termografica a Rotazione Veloce in categoria Tecnica
# Caricata entità Bollitura Entropica Sincronizzata in categoria Tecnica
# Caricata entità Sferificazione con Campi Magnetici Entropici in categoria Tecnica
# Caricata entità Cottura a Vapore Termocinetica Multipla in categoria Tecnica
# Caricata entità Amalgamazione Sintetica Molecolare in categoria Tecnica
# Caricata entità Decostruzione Interdimensionale Lovecraftiana in categoria Tecnica
# Caricata entità Cryo-Tessitura Energetica Polarizzata in categoria Tecnica
# Caricata entità Taglio a Risonanza Sonica Rigenerativa in categoria Tecnica
# Entità della categoria Tecnica caricate correttamente in Neo4j.
#   Estrazione Licenza da Datapizza.pdf
#   Caricamento di 1 entità di tipo Licenza
# Entità senza nome trovata in categoria Licenza, skip
# Entità della categoria Licenza caricate correttamente in Neo4j.
#   Estrazione Ordine da Datapizza.pdf
#   Caricamento di 3 entità di tipo Ordine
# Caricata entità Ordine della Galassia di Andromeda in categoria Ordine
# Caricata entità Ordine dei Naturalisti in categoria Ordine
# Caricata entità Ordine degli Armonisti in categoria Ordine
# Entità della categoria Ordine caricate correttamente in Neo4j.
#   Estrazione Ingrediente da Datapizza.pdf
#   Caricamento di 41 entità di tipo Ingrediente
# Caricata entità Amido di Stellarion in categoria Ingrediente
# Caricata entità Fibra di Sintetex in categoria Ingrediente
# Caricata entità Vero Ghiaccio in categoria Ingrediente
# Caricata entità Radici di Gravità in categoria Ingrediente
# Caricata entità Baccacedro in categoria Ingrediente
# Caricata entità Lacrime di Unicorno in categoria Ingrediente
# Caricata entità Farina di Nettuno in categoria Ingrediente
# Caricata entità Salsa Szechuan in categoria Ingrediente
# Caricata entità Pane di Luce in categoria Ingrediente
# Caricata entità Cristalli di Memoria in categoria Ingrediente
# Caricata entità Lacrime di Andromeda in categoria Ingrediente
# Caricata entità Liane di Plasmodio in categoria Ingrediente
# Caricata entità Erba Pipa in categoria Ingrediente
# Caricata entità Essenza di Vuoto in categoria Ingrediente
# Caricata entità Polvere di Stelle in categoria Ingrediente
# Caricata entità Colonia di Mycoflora in categoria Ingrediente
# Caricata entità Funghi dellʼEtere in categoria Ingrediente
# Caricata entità Foglie di Mandragora in categoria Ingrediente
# Caricata entità Essenza di Speziaria in categoria Ingrediente
# Caricata entità Alghe Bioluminescenti in categoria Ingrediente
# Caricata entità Gnocchi del Crepuscolo in categoria Ingrediente
# Caricata entità Pane degli Abissi in categoria Ingrediente
# Caricata entità Funghi Orbitali in categoria Ingrediente
# Caricata entità Teste di Idra in categoria Ingrediente
# Caricata entità Riso di Cassandra in categoria Ingrediente
# Caricata entità Cialda di Farina di Nettuno in categoria Ingrediente
# Caricata entità Spore Quantiche in categoria Ingrediente
# Caricata entità Uova di Fenice in categoria Ingrediente
# Caricata entità Biscotti della Galassia in categoria Ingrediente
# Caricata entità Frammenti di Supernova in categoria Ingrediente
# Caricata entità Fusilli del Vento in categoria Ingrediente
# Caricata entità Granuli di Nebbia Arcobaleno in categoria Ingrediente
# Caricata entità Spaghi del Sole in categoria Ingrediente
# Caricata entità Carne di Balena Spaziale in categoria Ingrediente
# Caricata entità Spezie Melange in categoria Ingrediente
# Caricata entità Radici di Singolarità in categoria Ingrediente
# Caricata entità Carne di Drago in categoria Ingrediente
# Caricata entità Sale Temporale in categoria Ingrediente
# Caricata entità Carne di Xenodonte in categoria Ingrediente
# Caricata entità Lattuga Namecciana in categoria Ingrediente
# Caricata entità Polvere di Crononite in categoria Ingrediente
# Entità della categoria Ingrediente caricate correttamente in Neo4j.
#   Estrazione Ristorante da Datapizza.pdf
#   Caricamento di 2 entità di tipo Ristorante
# Caricata entità L'Infinito Sapore in categoria Ristorante
# Caricata entità Datapizza in categoria Ristorante
# Entità della categoria Ristorante caricate correttamente in Neo4j.
# Elaborazione di Datapizza.pdf completata con successo
# --------------------------------------------------
# Elaborazione del file: Eco di Pandora.pdf
#   Estrazione Tecnica da Eco di Pandora.pdf
#   Caricamento di 1 entità di tipo Tecnica
# Entità senza nome trovata in categoria Tecnica, skip
# Entità della categoria Tecnica caricate correttamente in Neo4j.
#   Estrazione Licenza da Eco di Pandora.pdf
#   Caricamento di 8 entità di tipo Licenza
# Caricata entità Psionica in categoria Licenza
# Caricata entità Temporale in categoria Licenza
# Caricata entità Gravitazionale in categoria Licenza
# Caricata entità Antimateria in categoria Licenza
# Caricata entità Magnetica in categoria Licenza
# Caricata entità Quantistica in categoria Licenza
# Caricata entità Luce in categoria Licenza
# Caricata entità Gradi di influenza di livello tecnologico in categoria Licenza
# Entità della categoria Licenza caricate correttamente in Neo4j.
#   Estrazione Ordine da Eco di Pandora.pdf
#   Caricamento di 8 entità di tipo Ordine
# Caricata entità Serenata del Multiverso in categoria Ordine
# Caricata entità Euforia Cosmica in categoria Ordine
# Caricata entità Galassie Riflesse: Sinfonia del Multiverso in categoria Ordine
# Caricata entità Sinfonia Cosmica di Terracotta in categoria Ordine
# Caricata entità Viaggio Cosmico nel Multiverso in categoria Ordine
# Caricata entità Dimensioni del Mare Stellato in categoria Ordine
# Caricata entità Nebulose Pensanti: Sinfonia del Multiverso in categoria Ordine
# Caricata entità Microcosmo in un Boccone in categoria Ordine
# Entità della categoria Ordine caricate correttamente in Neo4j.
#   Estrazione Ingrediente da Eco di Pandora.pdf
#   Caricamento di 35 entità di tipo Ingrediente
# Caricata entità Frammenti di Supernova in categoria Ingrediente
# Caricata entità Liane di Plasmodio in categoria Ingrediente
# Caricata entità Carne di Balena spaziale in categoria Ingrediente
# Caricata entità Fibra di Sintetex in categoria Ingrediente
# Caricata entità Nettare di Sirena in categoria Ingrediente
# Caricata entità Essenza di Speziaria in categoria Ingrediente
# Caricata entità Vero Ghiaccio in categoria Ingrediente
# Caricata entità Radici di Singolarità in categoria Ingrediente
# Caricata entità Alghe Bioluminescenti in categoria Ingrediente
# Caricata entità Carne di Drago in categoria Ingrediente
# Caricata entità Uova di Fenice in categoria Ingrediente
# Caricata entità Funghi dell’Etere in categoria Ingrediente
# Caricata entità Polvere di Pulsar in categoria Ingrediente
# Caricata entità Teste di Idra in categoria Ingrediente
# Caricata entità Carne di Mucca in categoria Ingrediente
# Caricata entità Pane di Luce in categoria Ingrediente
# Caricata entità Gnocchi del Crepuscolo in categoria Ingrediente
# Caricata entità Riso di Cassandra in categoria Ingrediente
# Caricata entità Polvere di Crononite in categoria Ingrediente
# Caricata entità Radici di Gravità in categoria Ingrediente
# Caricata entità Foglie di Mandragora in categoria Ingrediente
# Caricata entità Plasma Vitale in categoria Ingrediente
# Caricata entità Shard di Prisma Stellare in categoria Ingrediente
# Caricata entità Foglie di Nebulosa in categoria Ingrediente
# Caricata entità Carne di Kraken in categoria Ingrediente
# Caricata entità Carne di Xenodonte in categoria Ingrediente
# Caricata entità Cristalli di Memoria in categoria Ingrediente
# Caricata entità Baccacedro in categoria Ingrediente
# Caricata entità Biscotti della Galassia in categoria Ingrediente
# Caricata entità Granuli di Nebbia Arcobaleno in categoria Ingrediente
# Caricata entità Funghi Orbitali in categoria Ingrediente
# Caricata entità Polvere di Stelle in categoria Ingrediente
# Caricata entità Fusilli del Vento in categoria Ingrediente
# Caricata entità Muffa Lunare in categoria Ingrediente
# Caricata entità Farina di Nettuno in categoria Ingrediente
# Entità della categoria Ingrediente caricate correttamente in Neo4j.
#   Estrazione Ristorante da Eco di Pandora.pdf
#   Caricamento di 2 entità di tipo Ristorante
# Errore nel caricamento dell'entità L'Eco di Pandora in categoria Ristorante: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{Temporale -> String("I"), Gradi di influenza di livello tecnologico -> String("VI"), Psionica -> String("III"), Quantistica -> String("III"), Gravitazionale -> String("I"), Antimateria -> String("I"), Magnetica -> String("I"), Luce -> String("I")}.}
# Caricata entità L'Eco dei Mondi in categoria Ristorante
# Entità della categoria Ristorante caricate correttamente in Neo4j.
# Elaborazione di Eco di Pandora.pdf completata con successo
# --------------------------------------------------
# Elaborazione del file: Eredita Galattica.pdf
#   Estrazione Tecnica da Eredita Galattica.pdf
#   Caricamento di 23 entità di tipo Tecnica
# Caricata entità Bollitura in categoria Tecnica
# Caricata entità Fermentazione in categoria Tecnica
# Caricata entità Cottura in categoria Tecnica
# Caricata entità Cottura in categoria Tecnica
# Caricata entità Cryo-Tessitura in categoria Tecnica
# Caricata entità Taglio in categoria Tecnica
# Caricata entità Decostruzione in categoria Tecnica
# Caricata entità Cottura in categoria Tecnica
# Caricata entità Marinatura in categoria Tecnica
# Caricata entità Cottura in categoria Tecnica
# Caricata entità Idro-Cristallizzazione in categoria Tecnica
# Caricata entità Decostruzione in categoria Tecnica
# Caricata entità Affettamento in categoria Tecnica
# Caricata entità Cottura in categoria Tecnica
# Caricata entità Fermentazione in categoria Tecnica
# Caricata entità Sinfonia in categoria Tecnica
# Caricata entità Bollitura in categoria Tecnica
# Caricata entità Sinergia in categoria Tecnica
# Caricata entità Cottura in categoria Tecnica
# Caricata entità Marinatura in categoria Tecnica
# Caricata entità Grigliatura in categoria Tecnica
# Caricata entità Impasto in categoria Tecnica
# Caricata entità Sinfonia in categoria Tecnica
# Entità della categoria Tecnica caricate correttamente in Neo4j.
#   Estrazione Licenza da Eredita Galattica.pdf
#   Caricamento di 1 entità di tipo Licenza
# Entità senza nome trovata in categoria Licenza, skip
# Entità della categoria Licenza caricate correttamente in Neo4j.
#   Estrazione Ordine da Eredita Galattica.pdf
#   Caricamento di 5 entità di tipo Ordine
# Caricata entità Temporale in categoria Ordine
# Caricata entità Gravitazionale in categoria Ordine
# Caricata entità Antimateria in categoria Ordine
# Caricata entità Luce in categoria Ordine
# Caricata entità Gradi di influenza di livello tecnologico in categoria Ordine
# Entità della categoria Ordine caricate correttamente in Neo4j.
#   Estrazione Ingrediente da Eredita Galattica.pdf
#   Caricamento di 34 entità di tipo Ingrediente
# Caricata entità Polvere di Crononite in categoria Ingrediente
# Caricata entità Radici di Gravità in categoria Ingrediente
# Caricata entità Liane di Plasmodio in categoria Ingrediente
# Caricata entità Foglie di Nebulosa in categoria Ingrediente
# Caricata entità Carne di Kraken in categoria Ingrediente
# Caricata entità Carne di Mucca in categoria Ingrediente
# Caricata entità Spaghi del Sole in categoria Ingrediente
# Caricata entità Pane di Luce in categoria Ingrediente
# Caricata entità Amido di Stellarion in categoria Ingrediente
# Caricata entità Funghi Orbitali in categoria Ingrediente
# Caricata entità Erba Pipa in categoria Ingrediente
# Caricata entità Polvere di Stelle in categoria Ingrediente
# Caricata entità Colonia di Mycoflora in categoria Ingrediente
# Caricata entità Carne di Balena spaziale in categoria Ingrediente
# Caricata entità Carne di Drago in categoria Ingrediente
# Caricata entità Teste di Idra in categoria Ingrediente
# Caricata entità Farina di Nettuno in categoria Ingrediente
# Caricata entità Lacrime di Unicorno in categoria Ingrediente
# Caricata entità Spezie Melange in categoria Ingrediente
# Caricata entità Cristalli di Supernova in categoria Ingrediente
# Caricata entità Uova di Fenice in categoria Ingrediente
# Caricata entità Fibra di Sintetex in categoria Ingrediente
# Caricata entità Riso di Cassandra in categoria Ingrediente
# Caricata entità Nettare di Sirena in categoria Ingrediente
# Caricata entità Cristalli di Memoria in categoria Ingrediente
# Caricata entità Alghe Bioluminescenti in categoria Ingrediente
# Caricata entità Carne di Xenodonte in categoria Ingrediente
# Caricata entità Shard di Prisma Stellare in categoria Ingrediente
# Caricata entità Lattuga Namecciana in categoria Ingrediente
# Caricata entità Vero Ghiaccio in categoria Ingrediente
# Caricata entità Baccacedro in categoria Ingrediente
# Caricata entità Essenza di Tachioni in categoria Ingrediente
# Caricata entità Funghi dell’Etere in categoria Ingrediente
# Caricata entità Petali di Eco in categoria Ingrediente
# Entità della categoria Ingrediente caricate correttamente in Neo4j.
#   Estrazione Ristorante da Eredita Galattica.pdf
#   Caricamento di 1 entità di tipo Ristorante
# Errore nel caricamento dell'entità L'Eredità Galattica in categoria Ristorante: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{Gradi di influenza di livello tecnologico -> String("III"), Skill -> Map{Gravitazionale -> String("III"), Temporale -> String("III"), Antimateria -> String("I"), Luce -> String("II")}}.}
# Entità della categoria Ristorante caricate correttamente in Neo4j.
# Elaborazione di Eredita Galattica.pdf completata con successo
# --------------------------------------------------
# Elaborazione del file: Essenza dell Infinito.pdf
#   Estrazione Tecnica da Essenza dell Infinito.pdf
#   Caricamento di 16 entità di tipo Tecnica
# Caricata entità Taglio Sinaptico Biomimetico in categoria Tecnica
# Caricata entità Cottura a Vapore Termocinetica Multipla in categoria Tecnica
# Caricata entità Saltare in Padella Realtà Energetiche Parallele in categoria Tecnica
# Caricata entità Cottura a Vapore Risonante Simbiotico in categoria Tecnica
# Caricata entità Affumicatura Temporale Risonante in categoria Tecnica
# Caricata entità Affumicatura a Stratificazione Quantica in categoria Tecnica
# Caricata entità Affumicatura Psionica Sensoriale in categoria Tecnica
# Caricata entità Modellatura Onirica Tetrazionale in categoria Tecnica
# Caricata entità Fermentazione Quantico Biometrica in categoria Tecnica
# Caricata entità Mycoflora con Polvere di Stelle Sbagliato in categoria Tecnica
# Caricata entità Decostruzione Ancestrale in categoria Tecnica
# Caricata entità Amalgamazione Sintetica Molecolare in categoria Tecnica
# Caricata entità Bollitura Termografica a Rotazione Veloce in categoria Tecnica
# Caricata entità Idro-Cristallizzazione Sonora Quantistica in categoria Tecnica
# Caricata entità Saltare in Padella Classica in categoria Tecnica
# Caricata entità Fermentazione Psionica Energetica in categoria Tecnica
# Entità della categoria Tecnica caricate correttamente in Neo4j.
#   Estrazione Licenza da Essenza dell Infinito.pdf
#   Caricamento di 8 entità di tipo Licenza
# Caricata entità Psionica IV in categoria Licenza
# Caricata entità Temporale II in categoria Licenza
# Caricata entità Quantistica 5 in categoria Licenza
# Caricata entità Luce I in categoria Licenza
# Caricata entità Luce II in categoria Licenza
# Caricata entità Temporale III in categoria Licenza
# Caricata entità Quantistica 8 in categoria Licenza
# Caricata entità LTK V in categoria Licenza
# Entità della categoria Licenza caricate correttamente in Neo4j.
#   Estrazione Ordine da Essenza dell Infinito.pdf
#   Caricamento di 7 entità di tipo Ordine
# Caricata entità Psionica IV in categoria Ordine
# Caricata entità Temporale II in categoria Ordine
# Caricata entità Quantistica 5 in categoria Ordine
# Caricata entità Luce I in categoria Ordine
# Caricata entità Luce II in categoria Ordine
# Caricata entità Temporale III in categoria Ordine
# Caricata entità Quantistica 8 in categoria Ordine
# Entità della categoria Ordine caricate correttamente in Neo4j.
#   Estrazione Ingrediente da Essenza dell Infinito.pdf
#   Caricamento di 45 entità di tipo Ingrediente
# Caricata entità Frammenti di Supernova in categoria Ingrediente
# Caricata entità Alghe Bioluminescenti in categoria Ingrediente
# Caricata entità Radici di Singolarità in categoria Ingrediente
# Caricata entità Teste di Idra in categoria Ingrediente
# Caricata entità Uova di Fenice in categoria Ingrediente
# Caricata entità Amido di Stellarion in categoria Ingrediente
# Caricata entità Nettare di Sirena in categoria Ingrediente
# Caricata entità Frutti del Diavolo in categoria Ingrediente
# Caricata entità Shard di Materia Oscura in categoria Ingrediente
# Caricata entità Colonia di Mycoflora in categoria Ingrediente
# Caricata entità Pane di Luce in categoria Ingrediente
# Caricata entità Gnocchi del Crepuscolo in categoria Ingrediente
# Caricata entità Biscotti della Galassia in categoria Ingrediente
# Caricata entità Funghi Orbitali in categoria Ingrediente
# Caricata entità Essenza di Vuoto in categoria Ingrediente
# Caricata entità Sashimi di Magicarp in categoria Ingrediente
# Caricata entità Carne di Kraken in categoria Ingrediente
# Caricata entità Pane degli Abissi in categoria Ingrediente
# Caricata entità Farina di Nettuno in categoria Ingrediente
# Caricata entità Spaghi del Sole in categoria Ingrediente
# Caricata entità Sale Temporale in categoria Ingrediente
# Caricata entità Pickle Rick Croccante in categoria Ingrediente
# Caricata entità Foglie di Mandragora in categoria Ingrediente
# Caricata entità Foglie di Nebulosa in categoria Ingrediente
# Caricata entità Fibra di Sintetex in categoria Ingrediente
# Caricata entità Fusilli del Vento in categoria Ingrediente
# Caricata entità Muffa Lunare in categoria Ingrediente
# Caricata entità Chocobo Wings in categoria Ingrediente
# Caricata entità Cristalli di Nebulite in categoria Ingrediente
# Caricata entità Carne di Drago in categoria Ingrediente
# Caricata entità Carne di Balena spaziale in categoria Ingrediente
# Caricata entità Granuli di Nebbia Arcobaleno in categoria Ingrediente
# Caricata entità Essenza di Tachioni in categoria Ingrediente
# Caricata entità Latte+ in categoria Ingrediente
# Caricata entità Polvere di Stelle in categoria Ingrediente
# Caricata entità Lacrime di Andromeda in categoria Ingrediente
# Caricata entità Essenza di Speziaria in categoria Ingrediente
# Caricata entità Lattuga Namecciana in categoria Ingrediente
# Caricata entità Carne di Xenodonte in categoria Ingrediente
# Caricata entità Plasma Vitale in categoria Ingrediente
# Caricata entità Nduja Fritta Tanto in categoria Ingrediente
# Caricata entità Radici di Gravità in categoria Ingrediente
# Caricata entità Carne di Mucca in categoria Ingrediente
# Caricata entità Spezie Melange in categoria Ingrediente
# Caricata entità Cristalli di Memoria in categoria Ingrediente
# Entità della categoria Ingrediente caricate correttamente in Neo4j.
#   Estrazione Ristorante da Essenza dell Infinito.pdf
#   Caricamento di 1 entità di tipo Ristorante
# Errore nel caricamento dell'entità L'Essenza dell'Infinito in categoria Ristorante: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{Anno -> Long(2), Nome -> String("Psionica"), Livello -> String("IV")}.}
# Entità della categoria Ristorante caricate correttamente in Neo4j.
# Elaborazione di Essenza dell Infinito.pdf completata con successo
# --------------------------------------------------
# Elaborazione del file: Il Firmamento.pdf
#   Estrazione Tecnica da Il Firmamento.pdf
#   Caricamento di 18 entità di tipo Tecnica
# Caricata entità Bollitura Infrasonica Armonizzata in categoria Tecnica
# Caricata entità Impasto a Campi Magnetici Dualistici in categoria Tecnica
# Caricata entità Cottura a Vapore Ecodinamico Bilanciato in categoria Tecnica
# Caricata entità Bollitura Entropica Sincronizzata in categoria Tecnica
# Caricata entità Grigliatura Elettro-Molecolare a Spaziatura Variabile in categoria Tecnica
# Caricata entità Decostruzione Magnetica Risonante in categoria Tecnica
# Caricata entità Congelamento Bio-Luminiscente Sincronico in categoria Tecnica
# Caricata entità Cottura Sottovuoto Bioma Sintetico in categoria Tecnica
# Caricata entità Cottura Sottovuoto Pulsar Magnetica in categoria Tecnica
# Caricata entità Cryo-Tessitura Energetica Polarizzata in categoria Tecnica
# Caricata entità Decostruzione Atomica a Strati Energetici in categoria Tecnica
# Caricata entità Grigliatura Stratificata in categoria Tecnica
# Caricata entità Modellatura Onirica Tetrazionale in categoria Tecnica
# Caricata entità Surgelamento Bio-Luminiscente Sincronico in categoria Tecnica
# Caricata entità Affumicatura Psionica Sensoriale in categoria Tecnica
# Caricata entità Polarizzata a Freddo Iperbarico in categoria Tecnica
# Caricata entità Cottura a Vapore con Flusso di Particelle Isoarmoniche in categoria Tecnica
# Caricata entità Marinatura Psionica in categoria Tecnica
# Entità della categoria Tecnica caricate correttamente in Neo4j.
#   Estrazione Licenza da Il Firmamento.pdf
#   Caricamento di 2 entità di tipo Licenza
# Caricata entità Luce in categoria Licenza
# Caricata entità Quantistica in categoria Licenza
# Entità della categoria Licenza caricate correttamente in Neo4j.
#   Estrazione Ordine da Il Firmamento.pdf
#   Nessuna entità di tipo Ordine trovata in Il Firmamento.pdf
#   Estrazione Ingrediente da Il Firmamento.pdf
#   Caricamento di 30 entità di tipo Ingrediente
# Caricata entità Fusilli del Vento in categoria Ingrediente
# Caricata entità Nettare di Sirena in categoria Ingrediente
# Caricata entità Carne di Kraken in categoria Ingrediente
# Caricata entità Balena Spaziale in categoria Ingrediente
# Caricata entità Salsa Szechuan in categoria Ingrediente
# Caricata entità Farina di Nettunoviene in categoria Ingrediente
# Caricata entità Polvere di Crononite in categoria Ingrediente
# Caricata entità Fibra di Sintetex in categoria Ingrediente
# Caricata entità Vero Ghiaccio in categoria Ingrediente
# Caricata entità Lattuga Namecciana in categoria Ingrediente
# Caricata entità Muffa Lunare in categoria Ingrediente
# Caricata entità Carne di Drago in categoria Ingrediente
# Caricata entità Uovo di Fenice in categoria Ingrediente
# Caricata entità Biscotti della Galassia in categoria Ingrediente
# Caricata entità Carne delle Teste di Idra in categoria Ingrediente
# Caricata entità Radici di Gravità in categoria Ingrediente
# Caricata entità Foglie di Mandragora in categoria Ingrediente
# Caricata entità Lacrime di Unicorno in categoria Ingrediente
# Caricata entità Nduja Fritta Tanto in categoria Ingrediente
# Caricata entità Petali di Eco in categoria Ingrediente
# Caricata entità Riso di Cassandra in categoria Ingrediente
# Caricata entità Funghi Orbitali in categoria Ingrediente
# Caricata entità Essenza di Vuoto in categoria Ingrediente
# Caricata entità Radici di Singolarità in categoria Ingrediente
# Caricata entità Cristalli di Nebulite in categoria Ingrediente
# Caricata entità Spaghi del Sole in categoria Ingrediente
# Caricata entità Gnocchi del Crepuscolo in categoria Ingrediente
# Caricata entità Baccacedro in categoria Ingrediente
# Caricata entità Spezie Melange in categoria Ingrediente
# Caricata entità Lacrime di Andromeda in categoria Ingrediente
# Entità della categoria Ingrediente caricate correttamente in Neo4j.
#   Estrazione Ristorante da Il Firmamento.pdf
#   Caricamento di 1 entità di tipo Ristorante
# Entità senza nome trovata in categoria Ristorante, skip
# Entità della categoria Ristorante caricate correttamente in Neo4j.
# Elaborazione di Il Firmamento.pdf completata con successo
# --------------------------------------------------
# Elaborazione del file: L Architetto dell Universo.pdf
#   Estrazione Tecnica da L Architetto dell Universo.pdf
#   Caricamento di 19 entità di tipo Tecnica
# Caricata entità tecnologia avanzata in categoria Tecnica
# Caricata entità controllo temporale in categoria Tecnica
# Caricata entità Affettamento a Pulsazioni Quantistiche in categoria Tecnica
# Caricata entità manipolare i veli temporali in categoria Tecnica
# Caricata entità uso dello spettro luminoso in categoria Tecnica
# Caricata entità Congelamento Bio-Luminiscente Sincronico in categoria Tecnica
# Caricata entità Cottura Olografica Quantum Fluttuante in categoria Tecnica
# Caricata entità Bollitura Entropica Sincronizzata in categoria Tecnica
# Caricata entità Cottura a Vapore Termocinetica Multipla in categoria Tecnica
# Caricata entità Grigliatura Elettro-Molecolare a Spaziatura Variabile in categoria Tecnica
# Caricata entità Cottura al Forno con Paradosso Temporale Cronospeculare in categoria Tecnica
# Caricata entità Cristallizzazione Temporale Reversiva in categoria Tecnica
# Caricata entità Decostruzione Ancestrale in categoria Tecnica
# Caricata entità Fermentazione Quantico Biometrica in categoria Tecnica
# Caricata entità Manipolazione gravitazionale in categoria Tecnica
# Caricata entità Cottura Sottovuoto Frugale Energeticamente Negativa in categoria Tecnica
# Caricata entità Bollitura Termografica a Rotazione Veloce in categoria Tecnica
# Caricata entità Amalgamazione Sintetica Molecolare in categoria Tecnica
# Caricata entità Taglio a risonanza sonica rigenerativa in categoria Tecnica
# Entità della categoria Tecnica caricate correttamente in Neo4j.
#   Estrazione Licenza da L Architetto dell Universo.pdf
#   Caricamento di 1 entità di tipo Licenza
# Entità senza nome trovata in categoria Licenza, skip
# Entità della categoria Licenza caricate correttamente in Neo4j.
#   Estrazione Ordine da L Architetto dell Universo.pdf
#   Caricamento di 1 entità di tipo Ordine
# Entità senza nome trovata in categoria Ordine, skip
# Entità della categoria Ordine caricate correttamente in Neo4j.
#   Estrazione Ingrediente da L Architetto dell Universo.pdf
#   Caricamento di 35 entità di tipo Ingrediente
# Caricata entità Pane degli Abissi in categoria Ingrediente
# Caricata entità Foglie di Nebulosa in categoria Ingrediente
# Caricata entità Carne di Balena spaziale in categoria Ingrediente
# Caricata entità Colonia di Mycoflora in categoria Ingrediente
# Caricata entità Uova di Fenice in categoria Ingrediente
# Caricata entità Lacrime di Unicorno in categoria Ingrediente
# Caricata entità Petali di Eco in categoria Ingrediente
# Caricata entità Carne di drago in categoria Ingrediente
# Caricata entità Gnocchi del Crepuscolo in categoria Ingrediente
# Caricata entità Spore Quantiche in categoria Ingrediente
# Caricata entità Vero Ghiaccio in categoria Ingrediente
# Caricata entità Pane di Luce in categoria Ingrediente
# Caricata entità Spaghi del Sole in categoria Ingrediente
# Caricata entità Erba Pipa in categoria Ingrediente
# Caricata entità Cristalli di Nebulite in categoria Ingrediente
# Caricata entità Carne di Xenodonte in categoria Ingrediente
# Caricata entità Teste di Idra in categoria Ingrediente
# Caricata entità Funghi Orbitali in categoria Ingrediente
# Caricata entità Liane di Plasmodio in categoria Ingrediente
# Caricata entità Essenza di Tachioni in categoria Ingrediente
# Caricata entità Carne di Kraken in categoria Ingrediente
# Caricata entità Nebulite in categoria Ingrediente
# Caricata entità Nettare di Sirena in categoria Ingrediente
# Caricata entità Nduja Fritta Tanto in categoria Ingrediente
# Caricata entità Riso di Cassandra in categoria Ingrediente
# Caricata entità Polvere di Pulsar in categoria Ingrediente
# Caricata entità Spezie Melange in categoria Ingrediente
# Caricata entità Crema di Uova di Fenice in categoria Ingrediente
# Caricata entità Radici di Singolarità in categoria Ingrediente
# Caricata entità Pane di Farina di Nettuno in categoria Ingrediente
# Caricata entità Muffa Lunare in categoria Ingrediente
# Caricata entità Sale Temporale in categoria Ingrediente
# Caricata entità Biscotti della Galassia in categoria Ingrediente
# Caricata entità Funghi dell’Etere in categoria Ingrediente
# Caricata entità Amido di Stellarion in categoria Ingrediente
# Entità della categoria Ingrediente caricate correttamente in Neo4j.
#   Estrazione Ristorante da L Architetto dell Universo.pdf
#   Caricamento di 1 entità di tipo Ristorante
# Caricata entità L'Architetto dell'Universo in categoria Ristorante
# Entità della categoria Ristorante caricate correttamente in Neo4j.
# Elaborazione di L Architetto dell Universo.pdf completata con successo
# --------------------------------------------------
# Elaborazione del file: L Eco dei Sapori.pdf
#   Estrazione Tecnica da L Eco dei Sapori.pdf
#   Caricamento di 15 entità di tipo Tecnica
# Caricata entità Superposizione Culinaria Quantistica in categoria Tecnica
# Caricata entità Marinatura Temporale Sincronizzata in categoria Tecnica
# Caricata entità Sferificazione tramite Matrici Biofotiche in categoria Tecnica
# Caricata entità Incisione Elettromagnetica Plasmica in categoria Tecnica
# Caricata entità Cottura Idrodinamica Autoregolante in categoria Tecnica
# Caricata entità Decostruzione Magnetica Risonante in categoria Tecnica
# Caricata entità Fermentazione Quantico Biometrica in categoria Tecnica
# Caricata entità Cryo-Tessitura Energetica Polarizzata in categoria Tecnica
# Caricata entità Bollitura Infrasonica Armonizzata in categoria Tecnica
# Caricata entità Amalgamazione Sintetica Molecolare in categoria Tecnica
# Caricata entità Congelamento Bio-Luminiscente Sincronico in categoria Tecnica
# Caricata entità Cottura a Vapore con Flusso di Particelle Isoarmoniche in categoria Tecnica
# Caricata entità Stratificazione Quantica in categoria Tecnica
# Caricata entità Marinatura Sotto Zero a Polarità Inversa in categoria Tecnica
# Caricata entità Affumicatura Temporal Risonante in categoria Tecnica
# Entità della categoria Tecnica caricate correttamente in Neo4j.
#   Estrazione Licenza da L Eco dei Sapori.pdf
#   Caricamento di 1 entità di tipo Licenza
# Entità senza nome trovata in categoria Licenza, skip
# Entità della categoria Licenza caricate correttamente in Neo4j.
#   Estrazione Ordine da L Eco dei Sapori.pdf
#   Caricamento di 1 entità di tipo Ordine
# Entità senza nome trovata in categoria Ordine, skip
# Entità della categoria Ordine caricate correttamente in Neo4j.
#   Estrazione Ingrediente da L Eco dei Sapori.pdf
#   Caricamento di 36 entità di tipo Ingrediente
# Caricata entità Pane di Luce in categoria Ingrediente
# Caricata entità Spore Quantiche in categoria Ingrediente
# Caricata entità Essenza di Tachioni in categoria Ingrediente
# Caricata entità Farina di Nettuno in categoria Ingrediente
# Caricata entità Cristalli di Memoria in categoria Ingrediente
# Caricata entità Biscotti della Galassia in categoria Ingrediente
# Caricata entità zucchero cosmico in categoria Ingrediente
# Caricata entità carne di mucca in categoria Ingrediente
# Caricata entità Nettare di Sirena in categoria Ingrediente
# Caricata entità teste di idra in categoria Ingrediente
# Caricata entità Essenza di Speziaria in categoria Ingrediente
# Caricata entità Riso di Cassandra in categoria Ingrediente
# Caricata entità Granuli di Nebbia Arcobaleno in categoria Ingrediente
# Caricata entità Erba Pipa in categoria Ingrediente
# Caricata entità Polvere di Pulsar in categoria Ingrediente
# Caricata entità Amido di Stellarion in categoria Ingrediente
# Caricata entità Shard di Materia Oscura in categoria Ingrediente
# Caricata entità Funghi Orbitali in categoria Ingrediente
# Caricata entità Baccacedro in categoria Ingrediente
# Caricata entità Gnocchi del Crepuscolo in categoria Ingrediente
# Caricata entità Spezie celestiali in categoria Ingrediente
# Caricata entità Xenodonte in categoria Ingrediente
# Caricata entità Radici di Singolarità in categoria Ingrediente
# Caricata entità Colonia di Mycoflora in categoria Ingrediente
# ...
# Caricata entità Taglio a Risonanza Sonica Rigenerativa in categoria Ordine
# Caricata entità Marinatura Temporale Sincronizzata in categoria Ordine
# Caricata entità Grigliatura Elettro-Molecolare a Spaziatura Variabile in categoria Ordine
# Caricata entità Affumicatura a Stratificazione Quantica in categoria Ordine
# Caricata entità Cottura a Vapore Termocinetica Multipla in categoria Ordine
# Caricata entità Fermentazione Psionica Energetica in categoria Ordine
# Caricata entità Bollitura Infrasonica Armonizzata in categoria Ordine
# Caricata entità Sferificazione a Gravità Psionica Variabile in categoria Ordine
# Caricata entità Cottura Sottovuoto Bioma Sintetico in categoria Ordine
# Caricata entità Cottura Sottovuoto Frugale Energeticamente Negativa in categoria Ordine
# Caricata entità Cottura con Microonde Entropiche Sincronizzate in categoria Ordine
# Entità della categoria Ordine caricate correttamente in Neo4j.
#   Estrazione Ingrediente da L Essenza Cosmica.pdf
#   Caricamento di 35 entità di tipo Ingrediente
# Caricata entità Carne di Drago in categoria Ingrediente
# Caricata entità Pancetta di banshee in categoria Ingrediente
# Caricata entità Pane di Luce in categoria Ingrediente
# Caricata entità Amido di Stellarion in categoria Ingrediente
# Caricata entità Nettare di Sirena in categoria Ingrediente
# Caricata entità Salsa Szechuan in categoria Ingrediente
# Caricata entità Verdure stagionali in categoria Ingrediente
# Caricata entità Granuli di Nebbia Arcobaleno in categoria Ingrediente
# Caricata entità Foglie di Nebulosa in categoria Ingrediente
# Caricata entità Pane degli Abissi in categoria Ingrediente
# Caricata entità Mycoflora in categoria Ingrediente
# Caricata entità Essenza di Speziaria in categoria Ingrediente
# Caricata entità Shard di Prisma Stellare in categoria Ingrediente
# Caricata entità Alghe Bioluminescenti in categoria Ingrediente
# Caricata entità Fibra di Sintetex in categoria Ingrediente
# Caricata entità Lacrime di Andromeda in categoria Ingrediente
# Caricata entità Polvere di Crononite in categoria Ingrediente
# Caricata entità Carne di Kraken in categoria Ingrediente
# Caricata entità Muffa Lunare in categoria Ingrediente
# Caricata entità Sale Temporale in categoria Ingrediente
# Caricata entità Riso di Cassandra in categoria Ingrediente
# Caricata entità Farina di Nettuno in categoria Ingrediente
# Caricata entità Shard di Materia Oscura in categoria Ingrediente
# Caricata entità Petali di Eco in categoria Ingrediente
# Caricata entità Gnocchi del Crepuscolo in categoria Ingrediente
# Caricata entità Lattuga Namecciana in categoria Ingrediente
# Caricata entità Frammenti di Supernova in categoria Ingrediente
# Caricata entità Uovo di Fenice in categoria Ingrediente
# Caricata entità Filetti di Carne di Balena spaziale in categoria Ingrediente
# Caricata entità Lacrime di Unicorno in categoria Ingrediente
# Caricata entità Radici di Singolarità in categoria Ingrediente
# Caricata entità Essenza di Vuoto in categoria Ingrediente
# Caricata entità Polvere di Pulsar in categoria Ingrediente
# Caricata entità Bacaceodro in categoria Ingrediente
# Caricata entità Essenza di Ombra in categoria Ingrediente
# Entità della categoria Ingrediente caricate correttamente in Neo4j.
#   Estrazione Ristorante da L Essenza Cosmica.pdf
#   Caricamento di 1 entità di tipo Ristorante
# Entità senza nome trovata in categoria Ristorante, skip
# Entità della categoria Ristorante caricate correttamente in Neo4j.
# Elaborazione di L Essenza Cosmica.pdf completata con successo
# --------------------------------------------------
# Elaborazione del file: L Essenza del Multiverso su Pandora.pdf
#   Estrazione Tecnica da L Essenza del Multiverso su Pandora.pdf
#   Caricamento di 17 entità di tipo Tecnica
# Caricata entità Ebollizione in categoria Tecnica
# Caricata entità Incisione in categoria Tecnica
# Caricata entità Cottura Sottovuoto in categoria Tecnica
# Caricata entità Big Bang in categoria Tecnica
# Caricata entità Cottura Sottovuoto in categoria Tecnica
# Caricata entità Amalgamazione in categoria Tecnica
# Caricata entità Taglio a Risonanza Sonica in categoria Tecnica
# Caricata entità Grigliatura Elettro-Molecolare in categoria Tecnica
# Caricata entità Surgelamento Antimaterico in categoria Tecnica
# Caricata entità Congelazione in categoria Tecnica
# Caricata entità Cottura con Microonde Entropiche Sincronizzate in categoria Tecnica
# Caricata entità Grigliatura Plasma Sintetico in categoria Tecnica
# Caricata entità Affumicatura Polarizzata in categoria Tecnica
# Caricata entità Flusso di Particelle Isoarmoniche in categoria Tecnica
# Caricata entità Marinatura Temporale in categoria Tecnica
# Caricata entità Sferificazione in categoria Tecnica
# Caricata entità Cottura Sottovuoto in categoria Tecnica
# Entità della categoria Tecnica caricate correttamente in Neo4j.
#   Estrazione Licenza da L Essenza del Multiverso su Pandora.pdf
#   Caricamento di 6 entità di tipo Licenza
# Caricata entità Licenza Quantistica in categoria Licenza
# Caricata entità Licenza Temporale in categoria Licenza
# Caricata entità Licenza Antimateria in categoria Licenza
# Caricata entità Licenza Magnetismo in categoria Licenza
# Caricata entità Licenza Luce in categoria Licenza
# Caricata entità Licenza Gravitazionale in categoria Licenza
# Entità della categoria Licenza caricate correttamente in Neo4j.
#   Estrazione Ordine da L Essenza del Multiverso su Pandora.pdf
#   Caricamento di 10 entità di tipo Ordine
# Caricata entità Viaggio Gastronomico tra le Stelle in categoria Ordine
# Caricata entità Sinfonia del Cosmo Rigenerante in categoria Ordine
# Caricata entità Delizia Astrale all'Essenza del Multiverso in categoria Ordine
# Caricata entità Melodia del Multiverso Parallelo in categoria Ordine
# Caricata entità Portale Interdimensionale di Sapori in categoria Ordine
# Caricata entità Ode al Crepuscolo del Multiverso in categoria Ordine
# Caricata entità Sinfonia Interstellare di Fusilli del Vento con Nettare di Sirena in categoria Ordine
# Caricata entità La Voce del Vento in categoria Ordine
# Caricata entità Nebulose a Strati in categoria Ordine
# Caricata entità Sinfonia Aromatica del Multiverso in categoria Ordine
# Entità della categoria Ordine caricate correttamente in Neo4j.
#   Estrazione Ingrediente da L Essenza del Multiverso su Pandora.pdf
#   Caricamento di 42 entità di tipo Ingrediente
# Caricata entità Fusilli del Vento in categoria Ingrediente
# Caricata entità Vero Ghiaccio in categoria Ingrediente
# Caricata entità Carne di Balena Spaziale in categoria Ingrediente
# Caricata entità Radici di Singolarità in categoria Ingrediente
# Caricata entità Essenza di Tachioni in categoria Ingrediente
# Caricata entità Cristalli di Memoria in categoria Ingrediente
# Caricata entità Uova di Fenice in categoria Ingrediente
# Caricata entità Lacrime di Unicorno in categoria Ingrediente
# Caricata entità Biscotti della Galassia in categoria Ingrediente
# Caricata entità Sale Temporale in categoria Ingrediente
# Caricata entità Carne di Kraken in categoria Ingrediente
# Caricata entità Foglie di Nebulosa in categoria Ingrediente
# Caricata entità Granuli di Nebbia Arcobaleno in categoria Ingrediente
# Caricata entità Lacrime di Andromeda in categoria Ingrediente
# Caricata entità Alghe Bioluminescenti in categoria Ingrediente
# Caricata entità Carne di Mucca in categoria Ingrediente
# Caricata entità Nettare di Sirena in categoria Ingrediente
# Caricata entità Nduja Fritta Tanto in categoria Ingrediente
# Caricata entità Amido di Stellarion in categoria Ingrediente
# Caricata entità Pane degli Abissi in categoria Ingrediente
# Caricata entità Idra in categoria Ingrediente
# Caricata entità Polvere di Crononite in categoria Ingrediente
# Caricata entità Gnocchi del Crepuscolo in categoria Ingrediente
# Caricata entità Spezie celestiali in categoria Ingrediente
# Caricata entità Foglie di Mandragora in categoria Ingrediente
# Caricata entità Shard di Materia Oscura in categoria Ingrediente
# Caricata entità Riso di Cassandra in categoria Ingrediente
# Caricata entità Essenza di Vuoto in categoria Ingrediente
# Caricata entità Pane di Luce in categoria Ingrediente
# Caricata entità Teste di Idra in categoria Ingrediente
# Caricata entità Radici di Gravità in categoria Ingrediente
# Caricata entità Polvere di Pulsar in categoria Ingrediente
# Caricata entità Funghi dell’Etere in categoria Ingrediente
# Caricata entità Farina di Nettuno in categoria Ingrediente
# Caricata entità Essenza di Speziaria in categoria Ingrediente
# Caricata entità Colonia di Mycoflora in categoria Ingrediente
# Caricata entità Baccacedro in categoria Ingrediente
# Caricata entità Shard di Prisma Stellare in categoria Ingrediente
# Caricata entità Plasma Vitale in categoria Ingrediente
# Caricata entità Vegetali sublimati in categoria Ingrediente
# Caricata entità Lattuga Namecciana in categoria Ingrediente
# Caricata entità Spore Quantiche in categoria Ingrediente
# Entità della categoria Ingrediente caricate correttamente in Neo4j.
#   Estrazione Ristorante da L Essenza del Multiverso su Pandora.pdf
#   Caricamento di 1 entità di tipo Ristorante
# Caricata entità L'Essenza del Multiverso su Pandora in categoria Ristorante
# Entità della categoria Ristorante caricate correttamente in Neo4j.
# Elaborazione di L Essenza del Multiverso su Pandora.pdf completata con successo
# --------------------------------------------------
# Elaborazione del file: L Essenza delle Dune.pdf
#   Estrazione Tecnica da L Essenza delle Dune.pdf
#   Caricamento di 1 entità di tipo Tecnica
# Entità senza nome trovata in categoria Tecnica, skip
# Entità della categoria Tecnica caricate correttamente in Neo4j.
#   Estrazione Licenza da L Essenza delle Dune.pdf
#   Caricamento di 5 entità di tipo Licenza
# Caricata entità Licenza di III livello in categoria Licenza
# Caricata entità Magnetico I in categoria Licenza
# Caricata entità Temporale I in categoria Licenza
# Caricata entità Gravitazionale I in categoria Licenza
# Caricata entità Antimateria I in categoria Licenza
# Entità della categoria Licenza caricate correttamente in Neo4j.
#   Estrazione Ordine da L Essenza delle Dune.pdf
#   Caricamento di 3 entità di tipo Ordine
# Caricata entità Ordine della Galassia di Andromeda in categoria Ordine
# Caricata entità Ordine dei Naturalisti in categoria Ordine
# Caricata entità Ordine degli Armonisti in categoria Ordine
# Entità della categoria Ordine caricate correttamente in Neo4j.
#   Estrazione Ingrediente da L Essenza delle Dune.pdf
#   Caricamento di 1 entità di tipo Ingrediente
# Entità senza nome trovata in categoria Ingrediente, skip
# Entità della categoria Ingrediente caricate correttamente in Neo4j.
#   Estrazione Ristorante da L Essenza delle Dune.pdf
#   Caricamento di 1 entità di tipo Ristorante
# Caricata entità L'Essenza delle Dune in categoria Ristorante
# Entità della categoria Ristorante caricate correttamente in Neo4j.
# Elaborazione di L Essenza delle Dune.pdf completata con successo
# --------------------------------------------------
# Elaborazione del file: L Essenza di Asgard.pdf
#   Estrazione Tecnica da L Essenza di Asgard.pdf
#   Caricamento di 21 entità di tipo Tecnica
# Caricata entità Amalgamazione Sintetica Molecolare in categoria Tecnica
# Caricata entità Fermentazione Quantica a Strati Multiversali in categoria Tecnica
# Caricata entità Grigliatura Eletro-Molecolare a Spaziatura Variabile in categoria Tecnica
# Caricata entità Fermentazione Psionica Energetica in categoria Tecnica
# Caricata entità Affumicatura a Stratificazione Quantica in categoria Tecnica
# Caricata entità Affumicatura Psionica Sensoriale in categoria Tecnica
# Caricata entità Cottura con Microonde Entropiche Sincronizzate in categoria Tecnica
# Caricata entità Lumière Cosmica in categoria Tecnica
# Caricata entità Bollitura Termografica a Rotazione Veloce in categoria Tecnica
# Caricata entità Cottura a Vapore con Flusso di Particelle Isoarmoniche in categoria Tecnica
# Caricata entità Cottura a Forno Dinamico Inversionale in categoria Tecnica
# Caricata entità Bollitura Entropica Sincronizzata in categoria Tecnica
# Caricata entità Bollitura Infrasonica Armonizzata in categoria Tecnica
# Caricata entità Portale di Sapori Arcani in categoria Tecnica
# Caricata entità Idro-Cristallizzazione Sonora Quantistica in categoria Tecnica
# Caricata entità Cottura a Vapore Termocinetica Multipla in categoria Tecnica
# Caricata entità Decostruzione Interdimensionale Lovecraftiana in categoria Tecnica
# Caricata entità Congelazione Iperdimensionalmente Stratificata in categoria Tecnica
# Caricata entità Affumicatura Temporale Risonante in categoria Tecnica
# Caricata entità Portale Cosmico del Kraken in categoria Tecnica
# Caricata entità Fermentazione Quantico Biometrica in categoria Tecnica
# Entità della categoria Tecnica caricate correttamente in Neo4j.
#   Estrazione Licenza da L Essenza di Asgard.pdf
#   Caricamento di 3 entità di tipo Licenza
# Caricata entità Temporale in categoria Licenza
# Caricata entità Antimateria in categoria Licenza
# Caricata entità Luce in categoria Licenza
# Entità della categoria Licenza caricate correttamente in Neo4j.
#   Estrazione Ordine da L Essenza di Asgard.pdf
#   Caricamento di 1 entità di tipo Ordine
# Entità senza nome trovata in categoria Ordine, skip
# Entità della categoria Ordine caricate correttamente in Neo4j.
#   Estrazione Ingrediente da L Essenza di Asgard.pdf
#   Caricamento di 41 entità di tipo Ingrediente
# Caricata entità Polvere di Stelle in categoria Ingrediente
# Caricata entità Foglie di Nebulosa in categoria Ingrediente
# Caricata entità Baccacedro in categoria Ingrediente
# Caricata entità Foglie di Mandragora in categoria Ingrediente
# Caricata entità Teste di Idra in categoria Ingrediente
# Caricata entità Pane di Luce in categoria Ingrediente
# Caricata entità Spaghi del Sole in categoria Ingrediente
# Caricata entità Gnocchi del Crepuscolo in categoria Ingrediente
# Caricata entità Lacrime di Unicorno in categoria Ingrediente
# Caricata entità Sale Temporale in categoria Ingrediente
# Caricata entità Liane di Plasmodio in categoria Ingrediente
# Caricata entità Fibra di Sintetex in categoria Ingrediente
# Caricata entità Carne di Xenodonte in categoria Ingrediente
# Caricata entità Pane degli Abissi in categoria Ingrediente
# Caricata entità Polvere di Pulsar in categoria Ingrediente
# Caricata entità Radici di Gravità in categoria Ingrediente
# Caricata entità Funghi Orbitali in categoria Ingrediente
# Caricata entità Essenza di Tachioni in categoria Ingrediente
# Caricata entità Polvere di Crononite in categoria Ingrediente
# Caricata entità Lattuga Namecciana in categoria Ingrediente
# Caricata entità Carne di Drago in categoria Ingrediente
# Caricata entità Carne di Kraken in categoria Ingrediente
# Caricata entità Amido di Stellarion in categoria Ingrediente
# Caricata entità Granuli di Nebbia Arcobaleno in categoria Ingrediente
# Caricata entità Farina di Nettuno in categoria Ingrediente
# Caricata entità Erba Pipa in categoria Ingrediente
# Caricata entità Frammenti di Supernova in categoria Ingrediente
# Caricata entità Carne di Balena spaziale in categoria Ingrediente
# Caricata entità Fusilli del Vento in categoria Ingrediente
# Caricata entità Muffa Lunare in categoria Ingrediente
# Caricata entità Essenza di Speziaria in categoria Ingrediente
# Caricata entità Radici di Singolarità in categoria Ingrediente
# Caricata entità Colonia di Mycoflora in categoria Ingrediente
# Caricata entità Uova di Fenice in categoria Ingrediente
# Caricata entità Lacrime di Andromeda in categoria Ingrediente
# Caricata entità Spezie Melange in categoria Ingrediente
# Caricata entità Cristalli di Nebulite in categoria Ingrediente
# Caricata entità Carne di Mucca in categoria Ingrediente
# Caricata entità Biscotti della Galassia in categoria Ingrediente
# Caricata entità Petali di Eco in categoria Ingrediente
# Caricata entità Spore Quantiche in categoria Ingrediente
# Entità della categoria Ingrediente caricate correttamente in Neo4j.
#   Estrazione Ristorante da L Essenza di Asgard.pdf
#   Caricamento di 1 entità di tipo Ristorante
# Errore durante l'elaborazione di L Essenza di Asgard.pdf: string indices must be integers, not 'str'
# Elaborazione del file: L Etere del Gusto.pdf
#   Estrazione Tecnica da L Etere del Gusto.pdf
