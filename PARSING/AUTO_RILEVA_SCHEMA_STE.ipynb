# %%
import pdfplumber
import re
import json
import os
import html
import PyPDF2
import pandas as pd
from bs4 import BeautifulSoup



from collections import Counter

from dotenv import load_dotenv
from neo4j import GraphDatabase
from py2neo import Graph, Node, Relationship
from langchain_openai import AzureChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from typing import List, Dict, Tuple

# %% [markdown]
# ## METODI

# %%
codice_galattico = "../Hackapizza Dataset/Codice Galattico/Codice Galattico.pdf"
manuale_cucina = "../Hackapizza Dataset/Misc/Manuale di Cucina.pdf"
menu_esempio = "../Hackapizza Dataset/Menu/Anima Cosmica.pdf"

domande = "../Hackapizza Dataset/domande.csv"
piatti = "../Hackapizza Dataset/Misc/dish_mapping.json"
pianeti = "../Hackapizza Dataset/Misc/Distanze.csv"

blog_1 = "../Hackapizza Dataset/Blogpost/blog_etere_del_gusto.html"
blog_2 = "../Hackapizza Dataset/Blogpost/blog_sapore_del_dune.html"


load_dotenv()
# Recupera endpoint e chiave dalle variabili d'ambiente
api_base = os.getenv("AZURE_OPENAI_API_BASE")
api_key = os.getenv("AZURE_OPENAI_API_KEY")

# neo4j first instance parameters
NEO4J_URI= "neo4j+s://0482640f.databases.neo4j.io"
NEO4J_USERNAME= "neo4j"
NEO4J_PASSWORD= "PNvdaZlk326-ja2hRD1K97ZUUMnD4mj0NsecZNu5-9k"
AURA_INSTANCEID= "0482640f"
AURA_INSTANCENAME= "Instance01"

# instance parameters 2:
NEO4J_URI= "neo4j+s://26627e96.databases.neo4j.io"
NEO4J_USERNAME= "neo4j"
NEO4J_PASSWORD= "vTK9-vIQTWTaPyUL41EEfzY_8yB9bps3lz2fNvBv7sE"
AURA_INSTANCEID= "26627e96"
AURA_INSTANCENAME= "Instance01"

driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %%
def crea_llm(api_key: str, api_base: str) -> AzureChatOpenAI:
    """
    Crea un'istanza del modello linguistico Azure OpenAI.
    
    Args:
        api_key (str): La chiave API di Azure
        api_base (str): L'URL base dell'API Azure
        
    Returns:
        AzureChatOpenAI: Istanza configurata del modello
    """
    return AzureChatOpenAI(
        openai_api_version="2024-08-01-preview",
        azure_deployment="o1-mini",
        azure_endpoint=api_base,
        api_key=api_key,
        temperature=1
    )

llm = crea_llm(api_key, api_base)

# %%
def estrai_testo_pdf(percorso_pdf):
    with open(percorso_pdf, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        testo = ""
        for pagina in reader.pages:
            testo += pagina.extract_text()
    return testo

def estrai_testo_html(percorso_html):
    """Estrae il testo da un file HTML."""
    with open(percorso_html, "r", encoding="utf-8") as file:
        soup = BeautifulSoup(file, "html.parser")
        return soup.get_text(separator=" ", strip=True)

# %%
def estrai_schema(testo, llm):
    
    # Prompt migliorato per il modello AI
    prompt = f"""
    Contesto: questo testo rientra in una collezione di documenti che parlano di Ristoranti nello spazio (su Pianeti) e sui loro Menu, Piatti, Ingredienti e Tecniche. 
    
    Mi serve che analizzi il testo e identifichi le entità che meglio descrivono il contenuto (voglio che tu rimanga il più generale possibile).
    Un esempio di entità è Ristorante, un'altra Pianeta, un'altra Ingrediente. 

    Voglio che mi ritorni un JSON con:
    - La chiave come il nome della entità
    - Il valore float che mi indichi quanto è rilevante in percentuale l'entità nel testo in una scala da 1 a 100

    Restituisci SOLO il JSON, senza formattazione markdown o decoratori.

    Testo:
    {testo}
    """

    response = llm.invoke(prompt)
    content = response.content.strip()

    # Pulizia del JSON
    if content.startswith('```') and content.endswith('```'):
        content = '\n'.join(content.split('\n')[1:-1])
    if content.startswith('json'):
        content = content[4:].strip()

    try:
        sostanze = json.loads(content)
    except json.JSONDecodeError:
        print("Errore nel parsing JSON delle sostanze:", content)
        sostanze = {}

    return sostanze

# %%
# Carica il file CSV
df_domande = pd.read_csv(domande)
testo_domande = df_domande.to_string()  # Converti il CSV in testo
entita_domande = estrai_schema(testo=testo_domande, llm=llm)
print("Entità CSV:", entita_domande)
# Out:
# Entità CSV: {'Ingrediente': 30.0, 'Tecnica': 25.0, 'Ristorante': 20.0, 'Pianeta': 15.0, 'Licenza': 5.0, 'Chef': 3.0, 'Codice Galattico': 2.0}

# %%
# Carica il file CSV
df_pianeti = pd.read_csv(pianeti)
testo_pianeti = df_pianeti.to_string()  # Converti il CSV in testo
entita_pianeti = estrai_schema(testo=testo_pianeti, llm=llm)
print("Entità CSV:", entita_pianeti)
# Out:
# Entità CSV: {'Pianeta': 100.0}

# %%
# Esegui l'analisi del PDF
testo_manuale = estrai_testo_pdf(manuale_cucina)
entita_manuale = estrai_schema(testo=testo_manuale, llm=llm)
print("Entità PDF:", entita_manuale)
# Out:
# Entità PDF: {'Tecniche di Cucina': 40.0, 'Ingredienti': 20.0, 'Licenze e Abilità': 10.0, 'Ordini': 10.0, 'Piatti': 10.0, 'Menu': 5.0, 'Ristorante': 5.0}

# %%
# Esegui l'analisi del PDF
testo_codice = estrai_testo_pdf(codice_galattico)
entita_codice = estrai_schema(testo=testo_codice, llm=llm)
print("Entità PDF:", entita_codice)
# Out:
# Entità PDF: {'Legge': 25.0, 'Ristorante': 20.0, 'Ingrediente': 15.0, 'Tecnica Culinaria': 15.0, 'Ordine': 10.0, 'Licenza': 10.0, 'Sostanza': 3.0, 'Pianeta': 1.0, 'Sanzione': 1.0}

# %%
# Esegui l'analisi del PDF
testo_menu = estrai_testo_pdf(menu_esempio)
entita_menu = estrai_schema(testo=testo_menu, llm=llm)
print("Entità PDF:", entita_menu)
# Out:
# Entità PDF: {'Ristorante': 10.0, 'Pianeta': 5.0, 'Chef': 5.0, 'Menu': 15.0, 'Ingrediente': 35.0, 'Tecnica': 30.0}

# %%
# Esempio di utilizzo:
testo_blog1 = estrai_testo_html(blog_1)
entita_blog1 = estrai_schema(testo=testo_blog1, llm=llm)
print("Entità PDF:", entita_blog1)
# Out:
# Entità PDF: {'Ristorante': 25.0, 'Pianeta': 15.0, 'Piatti': 20.0, 'Ingrediente': 15.0, 'Tecnica': 10.0, 'Tecnologia': 5.0, 'Chef': 5.0, 'Critico': 5.0}

# %%
# Esempio di utilizzo:
testo_blog2 = estrai_testo_html(blog_2)
entita_blog2 = estrai_schema(testo=testo_blog2, llm=llm)
print("Entità PDF:", entita_blog2)
# Out:
# Entità PDF: {'Ristorante': 25.0, 'Piatto': 30.0, 'Ingrediente': 25.0, 'Tecnica di Cottura': 15.0, 'Chef': 5.0}

# %%
def combina_punteggi(json_list, llm):
    """Combina i punteggi delle entità da più JSON, normalizzando sinonimi tramite LLM."""
    punteggi_totali = {}
    conteggio = {}
    
    for entita_manuale in json_list:
        for entita, punteggio in entita_manuale.items():
            if entita in punteggi_totali:
                punteggi_totali[entita] += punteggio
                conteggio[entita] += 1
            else:
                punteggi_totali[entita] = punteggio
                conteggio[entita] = 1
    
    punteggi_medi = {entita: punteggi_totali[entita] / conteggio[entita] for entita in punteggi_totali}
    
    # Normalizzazione con LLM
    prompt = f"""
    Data la seguente lista di entità con punteggi, raggruppa sinonimi e varianti sotto un'unica entità comune.
    Restituisci il risultato come JSON con le entità normalizzate e i punteggi medi aggregati.
    Restituisci SOLO il JSON, senza formattazione markdown o decoratori.
    
    {json.dumps(punteggi_medi, indent=2, ensure_ascii=False)}
    """
    
    response = llm.invoke(prompt)
    content = response.content.strip()

    # Pulizia del JSON
    if content.startswith('```') and content.endswith('```'):
        content = '\n'.join(content.split('\n')[1:-1])
    if content.startswith('json'):
        content = content[4:].strip()

    try:
        sostanze = json.loads(content)
    except json.JSONDecodeError:
        print("Errore nel parsing JSON delle sostanze:", content)
        sostanze = {}

    return sostanze
    #entita_normalizzate = json.loads(response.strip())
    #return dict(sorted(entita_normalizzate.items(), key=lambda item: item[1], reverse=True))

# %%
json_list = [entita_codice, entita_domande, entita_manuale, entita_menu, entita_pianeti, entita_blog1, entita_blog2]
punteggi_combinati = combina_punteggi(json_list, llm)
print("Punteggi combinati:", punteggi_combinati)
# Out:
# Punteggi combinati: {'Legge': 25.0, 'Ristorante': 17.5, 'Ingrediente': 22.0, 'Tecnica Culinaria': 22.916666666666668, 'Ordine': 10.0, 'Licenza': 8.75, 'Sostanza': 3.0, 'Pianeta': 27.2, 'Sanzione': 1.0, 'Chef': 4.5, 'Codice Galattico': 2.0, 'Piatti': 22.5, 'Menu': 10.0, 'Tecnologia': 5.0, 'Critico': 5.0}

# %%
# Filtra le entità con punteggio superiore a 20
entita_filtrate = [entita for entita, punteggio in punteggi_combinati.items() if punteggio > 15]

print(entita_filtrate)
# Out:
# ['Legge', 'Ristorante', 'Ingrediente', 'Tecnica Culinaria', 'Pianeta', 'Piatti']

# %%
from json_repair import repair_json

def correggi_json(json_rotto):
    try:
        return json.loads(repair_json(json_rotto))
    except:
        # Fallback con richiesta all'LLM
        prompt = f"Correggi questo JSON per Neo4j:\n{json_rotto}"
        return llm.invoke(prompt).content


def estrai_valorizzazioni(testo, entita_filtrate, llm, driver):
    # Genera un prompt basato sulle entità filtrate
    entita_str = ', '.join(entita_filtrate)
    
    prompt = f"""
    Contesto: questo testo rientra in una collezione di documenti che parlano di Ristoranti nello spazio (su Pianeti) e sui loro Menu, Piatti, Ingredienti e Tecniche. 
    Il testo che segue potrebbe contenere informazioni pertinenti a queste entità: {entita_str}
    Voglio che tu estragga possibili valorizzazioni di queste entità e me le ritorni in un JSON.

    Testo:
    {testo}
    """

    # Chiamata al modello LLM per ottenere la valorizzazione delle entità
    response = llm.invoke(prompt)
    content = response.content.strip()

    # Pulizia del JSON
    if content.startswith('```') and content.endswith('```'):
        content = '\n'.join(content.split('\n')[1:-1])
    if content.startswith('json'):
        content = content[4:].strip()

    try:
        valorizzazioni = json.loads(content)
    except json.JSONDecodeError:
        print("Errore nel parsing JSON delle valorizzazioni:", content)
        #print(proviamo la correzione automatica:)
        return repair_json(content)
        return #valorizzazioni = {}
    
    return valorizzazioni

# %%
valori_manuale = estrai_valorizzazioni(testo_manuale, entita_filtrate, llm, driver)
#valorizzazioni
# Out:
# Errore nel parsing JSON delle valorizzazioni: {
#   "Legge": {
#     "LicenzeRichieste": [
#       {
#         "Tipo": "Psionica",
#         "Livelli": [
#           "Livello 0: Posseduta da tutti se non diversamente specificato.",
#           "Livello I: Lettura del pensiero, telecinesi, teletrasporto di oggetti < 5 kg, precognizione, visione del passato fino a 5 minuti.",
#           "Livello II: Manipolazione della probabilità, telecinesi, teletrasporto di oggetti < 20 kg, manipolazione delle forze fondamentali dell'universo.",
#           "Livello III: Capacità di donare coscienza e intelletto ad oggetti, manipolazione della realtà circoscritta a stanze, teletrasporto senza errore in qualsiasi dimensione temporale, comunione con entità di altri piani.",
#           "Livello IV: Proiezione astrale, riscrittura di realtà circoscritta a piccole nazioni o asteroidi.",
#           "Livello V: Riscrittura di realtà di intere linee temporali o galassie. Equivalente al Grado di influenza di livello tecnologico III (LTK III)."
#         ]
#       },
#       {
#         "Tipo": "Temporale",
#         "Livelli": [
#           "Livello I: Effetti temporali relativi al presente come dilatazione o accelerazione del tempo.",
#           "Livello II: Livello I + effetti temporali riguardanti linee temporali future.",
#           "Livello III: Livello II + effetti temporali riguardanti linee temporali passate."
#         ]
#       },
#       {
#         "Tipo": "Gravitazionale",
#         "Livelli": [
#           "Livello 0: 5 < G ≤ 10, posseduta da tutti se non diversamente specificato.",
#           "Livello I: 0 < G ≤ 100.",
#           "Livello II: 0 < G ≤ 10^6.",
#           "Livello III: G > 10^6."
#         ]
#       },
#       {
#         "Tipo": "Antimateria",
#         "Livelli": [
#           "Livello 0: Particelle, posseduta da tutti se non diversamente specificato.",
#           "Livello I: Antiparticelle."
#         ]
#       },
#       {
#         "Tipo": "Magnetica",
#         "Livelli": [
#           "Livello 0: Polo nord e sud, posseduta da tutti se non diversamente specificato.",
#           "Livello I: Mono-polo."
#         ]
#       },
#       {
#         "Tipo": "Quantistica",
#         "Livelli": [
#           "Livello n: Numero di stati in superposizione dove n è il numero di stati."
#         ]
#       },
#       {
#         "Tipo": "Luce",
#         "Livelli": [
#           "Livello I: Solo colori primari (RGB).",
#           "Livello II: Tutto lo spettro visibile umano.",
#           "Livello III: Tutte le frequenze."
#         ]
#       },
#       {
#         "Tipo": "Livello di Sviluppo Tecnologico (LTK)",
#         "Livelli": [
#           "Livello I: Planetario.",
#           "Livello II: Sistema Stellare.",
#           "Livello III: Galassia.",
#           "Livello IV: Superamasso di Galassie.",
#           "Livello V: Intero Universo.",
#           "Livello VI: Universi multipli.",
#           "Livello VI+: Tutte le fonti di energia."
#         ]
#       }
#     ],
#     "Normative": [
#       "Normative severe che regolano ogni fase della preparazione e gestione del cibo a bordo di una nave spaziale."
#     ]
#   },
#   "Ristorante": {
#     "Ordini": [
#       {
#         "Nome": "Ordine della Galassia di Andromeda",
#         "Descrizione": "Cucina priva di lattosio, utilizza alternative al latte, burro e panna per conquistare palati alieni."
#       },
#       {
#         "Nome": "Ordine dei Naturalisti",
#         "Descrizione": "Celebra l'essenza primordiale di ogni ingrediente, applicando il 'Principio di Non Alterazione'."
#       },
#       {
#         "Nome": "Ordine degli Armonisti",
#         "Descrizione": "Trasforma il cibo in una sinfonia emozionale, adattandosi alle frequenze emotive degli ospiti."
#       }
#     ]
#   },
#   "Ingrediente": {
#     "Esempi": [
#       "Carota",
#       "Formaggio",
#       "Burro",
#       "Panna",
#       "Crostaceo",
#       "Farina",
#       "Proteine",
#       "Verdure",
#       "Pesce",
#       "Cereali integrali"
#     ]
#   },
#   "TecnicaCulinaria": {
#     "Marinatura": [
#       "Marinatura a Infusione Gravitazionale",
#       "Marinatura Temporale Sincronizzata",
#       "Marinatura Psionica",
#       "Marinatura tramite Reazioni d'Antimateria Diluite",
#       "Marinatura Sotto Zero a Polarità Inversa"
#     ],
#     "Affumicatura": [
#       "Affumicatura a Stratificazione Quantica",
#       "Affumicatura Temporale Risonante",
#       "Affumicatura Psionica Sensoriale",
#       "Affumicatura tramite Big Bang Microcosmico",
#       "Affumicatura Polarizzata a Freddo Iperbarico"
#     ],
#     "Fermentazione": [
#       "Fermentazione Quantica a Strati Multiversali",
#       "Fermentazione Temporale Sincronizzata",
#       "Fermentazione Psionica Energetica",
#       "Fermentazione tramite Singolarità",
#       "Fermentazione Quantico Biometrica"
#     ],
#     "TecnicheDiImpasto": [
#       "Impasto Gravitazionale Vorticoso",
#       "Amalgamazione Sintetica Molecolare",
#       "Impasto a Campi Magnetici Dualistici",
#       "Sinergia Elettro-Osmotica Programmabile",
#       "Modellatura Onirica Tetrazionale"
#     ],
#     "Surgelamento": [
#       "Cryo-Tessitura Energetica Polarizzata",
#       "Congelamento Bio-Luminiscente Sincronico",
#       "Cristallizzazione Temporale Reversiva",
#       "Congelazione Iperdimensionalmente Stratificata",
#       "Surgelamento Antimaterico a Risonanza Inversa"
#     ],
#     "TecnicheDiCottura": {
#       "Bollitura": [
#         "Ebollizione Magneto-Cinetica Pulsante",
#         "Bollitura Infrasonica Armonizzata",
#         "Bollitura Termografica a Rotazione Veloce",
#         "Bollitura Entropica Sincronizzata",
#         "Idro-Cristallizzazione Sonora Quantistica"
#       ],
#       "Grigliare": [
#         "Grigliatura a Energia Stellare DiV",
#         "Grigliatura Plasma Sintetico Risonante",
#         "Grigliatura Eletro-Molecolare a Spaziatura Variabile",
#         "Grigliatura Tachionica Refrattaria",
#         "Grigliatura Psionica Dinamica Ritmica"
#       ],
#       "Forno": [
#         "Cottura al Forno con Paradosso Temporale Cronospeculare",
#         "Cottura con Microonde Entropiche Sincronizzate",
#         "Cottura a Forno Dinamico Inversionale",
#         "Cottura Olografica Quantum Fluttuante",
#         "Cottura Geomagnetica Psicosincronizzata"
#       ],
#       "Vapore": [
#         "Cottura a Vapore con Flusso di Particelle Isoarmoniche",
#         "Cottura a Vapore Ecodinamico Bilanciato",
#         "Cottura a Vapore Risonante Simbiotico",
#         "Cottura a Vapore Termocinetica Multipla",
#         "Cottura Idrodinamica Autoregolante"
#       ],
#       "Sottovuoto": [
#         "Cottura Sottovuoto Antimateria",
#         "Cottura Sottovuoto Multirealità Collassante",
#         "Cottura Sottovuoto Frugale Energeticamente Negativa",
#         "Cottura Sottovuoto Pulsar Magnetica",
#         "Cottura Sottovuoto Bioma Sintetico"
#       ],
#       "SaltareInPadella": [
#         "Saltare in Padella Big Bang Termico",
#         "Saltare in Padella Realtà Energetiche Parallele",
#         "Saltare in Padella Singolarità Inversa",
#         "Saltare in Padella Sinergia Psionica",
#         "Saltare in Padella Classica"
#       }
#     },
#     "TecnicheAvanzate": [
#       "Decostruzione",
#       "Sferificazione",
#       "Tecniche di Taglio"
#     ],
#     "Decostruzione": [
#       "Decostruzione Atomica a Strati Energetici",
#       "Decostruzione Magnetica Risonante",
#       "Decostruzione Bio-Fotonica Emotiva",
#       "Decostruzione Ancestrale",
#       "Decostruzione Interdimensionale Lovecraftiana"
#     ],
#     "Sferificazione": [
#       "Sferificazione a Gravità Psionica Variabile",
#       "Sferificazione Filamentare a Molecole Vibrazionali",
#       "Sferificazione Cromatica Interdimensionale",
#       "Sferificazione con Campi Magnetici Entropici",
#       "Sferificazione tramite Matrici Biofotiche"
#     ],
#     "TecnicheDiTaglio": [
#       "Taglio Dimensionale a Lame Fotofiliche",
#       "Taglio a Risonanza Sonica Rigenerativa",
#       "Affettamento a Pulsazioni Quantistiche",
#       "Taglio Sinaptico Biomimetico",
#       "Incisione Elettromagnetica Plasmica"
#     ]
#   },
#   "Pianeta": [
#     "Alpha Centauri",
#     "Nebulosa del Granchio",
#     "Andromeda",
#     "Via Lattea"
#   ],
#   "Piatti": [
#     "Brasato",
#     "Soufflé Orbitale",
#     "Zuppe",
#     "Salse",
#     "Paste",
#     "Dumpling Ripieni",
#     "Involtini Primaverili",
#     "Lasagne a più livelli",
#     "Pizza",
#     "Brioche",
#     "Calzoni",
#     "Terrine",
#     "Millefoglie Salate"
#   ]
# }

# %%
print(valori_manuale)
# Out:
# {"Legge": {"LicenzeRichieste": [{"Tipo": "Psionica", "Livelli": ["Livello 0: Posseduta da tutti se non diversamente specificato.", "Livello I: Lettura del pensiero, telecinesi, teletrasporto di oggetti < 5 kg, precognizione, visione del passato fino a 5 minuti.", "Livello II: Manipolazione della probabilit\u00e0, telecinesi, teletrasporto di oggetti < 20 kg, manipolazione delle forze fondamentali dell'universo.", "Livello III: Capacit\u00e0 di donare coscienza e intelletto ad oggetti, manipolazione della realt\u00e0 circoscritta a stanze, teletrasporto senza errore in qualsiasi dimensione temporale, comunione con entit\u00e0 di altri piani.", "Livello IV: Proiezione astrale, riscrittura di realt\u00e0 circoscritta a piccole nazioni o asteroidi.", "Livello V: Riscrittura di realt\u00e0 di intere linee temporali o galassie. Equivalente al Grado di influenza di livello tecnologico III (LTK III)."]}, {"Tipo": "Temporale", "Livelli": ["Livello I: Effetti temporali relativi al presente come dilatazione o accelerazione del tempo.", "Livello II: Livello I + effetti temporali riguardanti linee temporali future.", "Livello III: Livello II + effetti temporali riguardanti linee temporali passate."]}, {"Tipo": "Gravitazionale", "Livelli": ["Livello 0: 5 < G \u2264 10, posseduta da tutti se non diversamente specificato.", "Livello I: 0 < G \u2264 100.", "Livello II: 0 < G \u2264 10^6.", "Livello III: G > 10^6."]}, {"Tipo": "Antimateria", "Livelli": ["Livello 0: Particelle, posseduta da tutti se non diversamente specificato.", "Livello I: Antiparticelle."]}, {"Tipo": "Magnetica", "Livelli": ["Livello 0: Polo nord e sud, posseduta da tutti se non diversamente specificato.", "Livello I: Mono-polo."]}, {"Tipo": "Quantistica", "Livelli": ["Livello n: Numero di stati in superposizione dove n \u00e8 il numero di stati."]}, {"Tipo": "Luce", "Livelli": ["Livello I: Solo colori primari (RGB).", "Livello II: Tutto lo spettro visibile umano.", "Livello III: Tutte le frequenze."]}, {"Tipo": "Livello di Sviluppo Tecnologico (LTK)", "Livelli": ["Livello I: Planetario.", "Livello II: Sistema Stellare.", "Livello III: Galassia.", "Livello IV: Superamasso di Galassie.", "Livello V: Intero Universo.", "Livello VI: Universi multipli.", "Livello VI+: Tutte le fonti di energia."]}], "Normative": ["Normative severe che regolano ogni fase della preparazione e gestione del cibo a bordo di una nave spaziale."]}, "Ristorante": {"Ordini": [{"Nome": "Ordine della Galassia di Andromeda", "Descrizione": "Cucina priva di lattosio, utilizza alternative al latte, burro e panna per conquistare palati alieni."}, {"Nome": "Ordine dei Naturalisti", "Descrizione": "Celebra l'essenza primordiale di ogni ingrediente, applicando il 'Principio di Non Alterazione'."}, {"Nome": "Ordine degli Armonisti", "Descrizione": "Trasforma il cibo in una sinfonia emozionale, adattandosi alle frequenze emotive degli ospiti."}]}, "Ingrediente": {"Esempi": ["Carota", "Formaggio", "Burro", "Panna", "Crostaceo", "Farina", "Proteine", "Verdure", "Pesce", "Cereali integrali"]}, "TecnicaCulinaria": {"Marinatura": ["Marinatura a Infusione Gravitazionale", "Marinatura Temporale Sincronizzata", "Marinatura Psionica", "Marinatura tramite Reazioni d'Antimateria Diluite", "Marinatura Sotto Zero a Polarit\u00e0 Inversa"], "Affumicatura": ["Affumicatura a Stratificazione Quantica", "Affumicatura Temporale Risonante", "Affumicatura Psionica Sensoriale", "Affumicatura tramite Big Bang Microcosmico", "Affumicatura Polarizzata a Freddo Iperbarico"], "Fermentazione": ["Fermentazione Quantica a Strati Multiversali", "Fermentazione Temporale Sincronizzata", "Fermentazione Psionica Energetica", "Fermentazione tramite Singolarit\u00e0", "Fermentazione Quantico Biometrica"], "TecnicheDiImpasto": ["Impasto Gravitazionale Vorticoso", "Amalgamazione Sintetica Molecolare", "Impasto a Campi Magnetici Dualistici", "Sinergia Elettro-Osmotica Programmabile", "Modellatura Onirica Tetrazionale"], "Surgelamento": ["Cryo-Tessitura E ...

# %%
valori_codice = estrai_valorizzazioni(testo_codice, entita_filtrate, llm, driver)

# %%
valori_codice
# Out:
# {'Legge': [{'Numero': '789/12773',
#    'Tipo': 'Decreto Supremo',
#    'Autorità': 'Gran Consiglio della Federazione Intergalattica',
#    'Data': '67° Giorno del Ciclo Cosmico 789',
#    'Titolo': 'Regolamentazione della sicurezza alimentare intergalattica',
#    'Descrizione': "Stabilisce il codice normativo per l'esercizio delle attività di ristorazione nel territorio della Federazione, includendo definizioni, sostanze regolamentate, limiti quantitativi, restrizioni, licenze e tecniche di preparazione."},
#   {'Numero': '675/12',
#    'Tipo': 'Regolamento',
#    'Descrizione': 'Definisce le necessità fisiologiche di tutte le specie senzienti e non senzienti.'},
#   {'Numero': '766/31098',
#    'Tipo': 'Decreto Supremo',
#    'Descrizione': 'Stabiliscono le autorizzazioni necessarie per le attività professionali nel settore della preparazione e somministrazione di alimenti.'}],
#  'Ristorante': [{'Descrizione': 'Qualsiasi soggetto avente cittadinanza della Federazione Intergalattica che intraprenda attività professionale nel settore della preparazione e somministrazione di alimenti.'}],
#  'Ingrediente': {'Sostanze_Psicotrope_e_Psioniche': ['Erba Pipa',
#    'Cristalli di Memoria',
#    'Petali di Eco'],
#   'Sostanze_di_Origine_Mitica': ['Carne di Drago',
#    'Uova di Fenice',
#    'Lacrime di Unicorno'],
#   'Sostanze_Xenobiologiche': ['Foglie di Mandragora',
#    'MuNa Lunare',
#    'Nettare di Sirena'],
#   'Sostanze_Quantiche_e_Dimensionali': ['Spore Quantiche',
#    'Essenza di Vuoto',
#    'Funghi dell’Etere'],
#   'Sostanze_Spazio-Temporali': ['Sale Temporale',
#    'Radici di Gravità',
#    'Polvere di Stelle']},
#  'Tecnica_Culinaria': {'Marinatura': [{'Tipo': 'Infusione Gravitazionale',
#     'Licenze_Richieste': ['Licenza Gravitazionale (G) di livello II']},
#    {'Tipo': 'Temporale Sincronizzata',
#     'Licenze_Richieste': ['Licenza Temporale (t) di livello I']},
#    {'Tipo': 'Psionica',
#     'Licenze_Richieste': ['Licenza Psionica (P) di livello III']},
#    {'Tipo': 'Reazioni d’Antimateria Diluite',
#     'Licenze_Richieste': ['Licenza Antimateria (e+) di livello I']},
#    {'Tipo': 'Sotto Zero a Polarità Inversa',
#     'Licenze_Richieste': ['Licenza Magnetica (Mx) di livello I',
#      'Certificazione LTK di livello II']}],
#   'Aumicatura': [{'Tipo': 'Stratificazione Quantica',
#     'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 3',
#      'Certificazione LTK di livello II']},
#    {'Tipo': 'Temporale Risonante',
#     'Licenze_Richieste': ['Licenza Temporale (t) di livello I',
#      'Certificazione LTK di livello II']},
#    {'Tipo': 'Psionica Sensoriale',
#     'Licenze_Richieste': ['Licenza Psionica (P) di livello II',
#      'Certificazione LTK di livello III']},
#    {'Tipo': 'Big Bang Microcosmico',
#     'Licenze_Richieste': ['Licenza Antimateria (e+) di livello I',
#      'Licenza Quantistica (Q) di livello 10',
#      'Certificazione LTK di livello III']},
#    {'Tipo': 'Polarizzata a Freddo Iperbarico',
#     'Licenze_Richieste': ['Licenza Magnetica (Mx) di livello I',
#      'Certificazione LTK di livello II']}],
#   'Fermentazione': [{'Tipo': 'Quantica a Strati Multiversali',
#     'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 5',
#      'Certificazione LTK di livello VI+']},
#    {'Tipo': 'Temporale Sincronizzata',
#     'Licenze_Richieste': ['Licenza Temporale (t) di livello III',
#      'Certificazione LTK di livello III']},
#    {'Tipo': 'Psionica Energetica',
#     'Licenze_Richieste': ['Licenza Psionica (P) di livello I',
#      'Certificazione LTK di livello III']},
#    {'Tipo': 'Singolarità',
#     'Licenze_Richieste': ['Licenza Gravitazionale (G) di livello III',
#      'Licenza Antimateria (e+) di livello I',
#      'Licenza Magnetica (Mx) di livello I',
#      'Certificazione LTK di livello IV']},
#    {'Tipo': 'Quantico Biometrica',
#     'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 3',
#      'Certificazione LTK di livello II']}],
#   'Decostruzione': [{'Tipo': 'Atomica a Strati Energetici',
#     'Licenze_Richieste': ['Licenza Antimaterica (e+) di livello I',
#      'Licenza Quantistica (Q) di livello 1',
#      'Certificazione LTK di livello II']},
#    {'Tipo': 'Magnetica Risonante',
#     'Licenze_Richieste': ['Licenza Magnetica (Mx) di livello I',
#      'Certificazione LTK di livello II']},
#    {'Tipo': 'Bio-fotonica Emotiva',
#     'Licenze_Richieste': ['Licenza Psionica (P) di livello III',
#      'Licenza Luce (c) di livello III',
#      'Certificazione LTK di livello II']},
#    {'Tipo': 'Ancestrale',
#     'Licenze_Richieste': ['Licenza Temporale (t) di livello III',
#      'Certificazione LTK di livello II']},
#    {'Tipo': 'Interdimensionale Lovecraftiana',
#     'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 7',
#      'Certificazione LTK di livello VI']}],
#   'Sferificazione': [{'Tipo': 'Gravità Psionica Variabile',
#     'Licenze_Richieste': ['Licenza Psionica (P) di livello IV',
#      'Licenza Gravitazionale (G) di livello I',
#      'Certificazione LTK di livello III']},
#    {'Tipo': 'Filamentare a Molecole Vibrazionali',
#     'Licenze_Richieste': ['Licenza Magnetica (Mx) di livello I',
#      'Licenza Quantistica (Q) di livello 4',
#      'Certificazione LTK di livello II']},
#    {'Tipo': 'Cromatica Interdimensionale',
#     'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 6',
#      'Licenza Luce (c) di livello III',
#      'Certificazione LTK di livello III']},
#    {'Tipo': 'Con Campi Magnetici Entropici',
#     'Licenze_Richieste': ['Licenza Magnetica (Mx) di livello I',
#      'Certificazione LTK di livello II']},
#    {'Tipo': 'Tramite Matrici Biofotiche',
#     'Licenze_Richieste': ['Licenza Magnetica (Mx) di livello I',
#      'Licenza Quantistica (Q) di livello 3',
#      'Licenza Luce (c) di livello II',
#      'Certificazione LTK di livello II']}],
#   'Tecniche_di_Taglio': [{'Tipo': 'Dimensionale a Lame Fotofiliche',
#     'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 6',
#      'Licenza Luce (c) di livello III',
#      'Certificazione LTK di livello IV']},
#    {'Tipo': 'Aettamento a Pulsazioni Quantistiche',
#     'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 4',
#      'Certificazione LTK di livello III']},
#    {'Tipo': 'Taglio Sinaptico Biomimetico',
#     'Licenze_Richieste': ['Licenza Psionica (P) di livello IV',
#      'Certificazione LTK di livello III']},
#    {'Tipo': 'Incisione Elettromagnetica Plasmica',
#     'Licenze_Richieste': ['Licenza Antimateria (e+) di livello I',
#      'Licenza Magnetica (Mx) di livello I',
#      'Certificazione LTK di livello II']}],
#   'Tecniche_di_Impasto': [{'Tipo': 'Gravitazionale Vorticoso',
#     'Licenze_Richieste': ['Licenza Gravitazionale (G) di livello I']},
#    {'Tipo': 'Amalgamazione Sintetica Molecolare',
#     'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 3']},
#    {'Tipo': 'Campi Magnetici Dualistici',
#     'Licenze_Richieste': ['Licenza Magnetica (Mx) di livello I']},
#    {'Tipo': 'Sinergia Elettro-Osmotica Programmabile',
#     'Licenze_Richieste': ['Licenza Antimateria (e+) di livello I']},
#    {'Tipo': 'Modellatura Onirica Tetrazionale',
#     'Licenze_Richieste': ['Licenza Psionica (P) di livello IV',
#      'Licenza Quantistica (Q) di livello 4',
#      'Certificazione LTK di livello IV']}],
#   'Surgelamento': [{'Tipo': 'Cryo-tessitura Energetica Polarizzata',
#     'Licenze_Richieste': ['Licenza Antimateria (e+) di livello I']},
#    {'Tipo': 'Congelamento Bio-Luminiscente Sincronico',
#     'Licenze_Richieste': ['Licenza Luce (c) di livello II',
#      'Certificazione LTK di livello II']},
#    {'Tipo': 'Cristallizzazione Temporale Reversiva',
#     'Licenze_Richieste': ['Licenza Temporale (t) di livello III',
#      'Certificazione LTK di livello III']},
#    {'Tipo': 'Congelazione Iperdimensionalmente Stratificata',
#     'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 5',
#      'Certificazione LTK di livello IV']},
#    {'Tipo': 'Surgelamento Antimaterico a Risonanza Inversa',
#     'Licenze_Richieste': ['Licenza Antimateria (e+) di livello I',
#      'Licenza Magnetica (Mx) di livello I',
#      'Licenza Quantistica (Q) di livello 3',
#      'Certificazione LTK di livello III']}],
#   'Cottura': {'Bollitura': [{'Tipo': 'Magneto-Cinetica Pulsante',
#      'Licenze_Richieste': ['Licenza Magnetica (Mx) di livello I']},
#     {'Tipo': 'Infrasonica Armonizzata',
#      'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 3']},
#     {'Tipo': 'Termografica a Rotazione Veloce',
#      'Licenze_Richieste': ['Licenza Luce (c) di livello I']},
#     {'Tipo': 'Entropica Sincronizzata',
#      'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 4',
#       'Certificazione LTK di livello III']},
#     {'Tipo': 'Idro-Cristallizzazione Sonora Quantistica',
#      'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 5',
#       'Certificazione LTK di livello III']}],
#    'Grigliatura': [{'Tipo': 'A Energia Stellare DiV',
#      'Licenze_Richieste': ['Licenza Luce (c) di livello III',
#       'Certificazione LTK di livello II']},
#     {'Tipo': 'Plasma Sintetico Risonante',
#      'Licenze_Richieste': ['Licenza Antimateria (e+) di livello I',
#       'Licenza Magnetica (Mx) di livello I',
#       'Certificazione LTK di livello III']},
#     {'Tipo': 'Eletro-Molecolare a Spaziatura Variabile',
#      'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 3']},
#     {'Tipo': 'Tachionica Refrattaria',
#      'Licenze_Richieste': ['Licenza Temporale (t) di livello II',
#       'Licenza Luce (c) di livello III',
#       'Certificazione LTK di livello V']},
#     {'Tipo': 'Psionica Dinamica Ritmica',
#      'Licenze_Richieste': ['Licenza Psionica (P) di livello III',
#       'Certificazione LTK di livello III']}],
#    'Cottura_al_Forno': [{'Tipo': 'Con Paradosso Temporale Cronospeculare',
#      'Licenze_Richieste': ['Licenza Temporale (t) di livello III',
#       'Licenza Quantistica (Q) di livello 1',
#       'Certificazione LTK di livello III']},
#     {'Tipo': 'Con Microonde Entropiche Sincronizzate',
#      'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 4']},
#     {'Tipo': 'A Forno Dinamico Inversionale',
#      'Licenze_Richieste': ['Licenza Antimateria (e+) di livello I']},
#     {'Tipo': 'Olografica Quantum Fluttuante',
#      'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 5',
#       'Certificazione LTK di livello III']},
#     {'Tipo': 'Geomagnetica Psicosincronizzata',
#      'Licenze_Richieste': ['Licenza Psionica (P) di livello V',
#       'Licenza Magnetica (Mx) di livello I',
#       'Certificazione LTK di livello IV']}],
#    'Cottura_al_Vapore': [{'Tipo': 'Risonante Simbiotico',
#      'Licenze_Richieste': ['Licenza Psionica (P) di livello III',
#       'Certificazione LTK di livello III']},
#     {'Tipo': 'Idrodinamica Autoregolante',
#      'Licenze_Richieste': ['Licenza Antimateria (e+) di livello I',
#       'Certificazione LTK di livello II']}],
#    'Cottura_Sottovuoto': [{'Tipo': 'Antimateria',
#      'Licenze_Richieste': ['Licenza Gravitazionale (G) di livello I',
#       'Licenza Antimateria (e+) di livello I',
#       'Certificazione LTK di livello III']},
#     {'Tipo': 'Multirealità Collassante',
#      'Licenze_Richieste': ['Licenza Gravitazionale (G) di livello I',
#       'Licenza Quantistica (Q) di livello 5',
#       'Certificazione LTK di livello VI']},
#     {'Tipo': 'Frugale Energeticamente Negativa',
#      'Licenze_Richieste': ['Licenza Gravitazionale (G) di livello I',
#       'Licenza Quantistica (Q) di livello 3',
#       'Certificazione LTK di livello II']},
#     {'Tipo': 'Pulsar Magnetica',
#      'Licenze_Richieste': ['Licenza Gravitazionale (G) di livello I',
#       'Licenza Magnetica (Mx) di livello I',
#       'Certificazione LTK di livello III']},
#     {'Tipo': 'Bioma Sintetico',
#      'Licenze_Richieste': ['Licenza Psionica (P) di livello II',
#       'Licenza Gravitazionale (G) di livello I',
#       'Certificazione LTK di livello III']}],
#    'Cottura_al_Salto': [{'Tipo': 'Big Bang Termico',
#      'Licenze_Richieste': ['Licenza Gravitazionale (G) di livello III',
#       'Licenza Antimateria (e+) di livello I',
#       'Certificazione LTK di livello V']},
#     {'Tipo': 'Realtà Energetiche Parallele',
#      'Licenze_Richieste': ['Licenza Quantistica (Q) di livello 6',
#       'Certificazione LTK di livello IV']},
#     {'Tipo': 'Singolarità Inversa',
#      'Licenze_Richieste': ['Licenza Gravitazionale (G) di livello III',
#       'Licenza Antimateria (e+) di livello I',
#       'Certificazione LTK di livello IV']},
#     {'Tipo': 'Sinergia Psionica',
#      'Licenze_Richieste': ['Licenza Psionica (P) di livello V',
#       'Certificazione LTK di livello III']}]}},
#  'Pianeta': [{'Nome': 'Andromeda',
#    'Descrizione': 'Abitanti manifestano intolleranza al lattosio e a qualsiasi forma nutritiva originaria della Via Lattea.'}],
#  'Piatti': []}

# %%
# Funzione per caricare i dati in Neo4j
def carica_neo4j(valorizzazioni):
    with driver.session() as session:
        for entita, valore in valorizzazioni.items():
            session.run("""
                MERGE (e:Entita {nome: $entita})
                SET e.valore = $valore
            """, entita=entita, valore=valore)

# Carica le valorizzazioni su Neo4j
carica_neo4j(valori_manuale)
carica_neo4j(valori_codice)
# Out:
# ---------------------------------------------------------------------------
# GqlError                                  Traceback (most recent call last)
# GqlError: {gql_status: 22N01} {gql_status_description: error: data exception - invalid type. Expected the value Map{Numero -> String("789/12773"), Tipo -> String("Decreto Supremo"), Titolo -> String("Regolamentazione della sicurezza alimentare intergalattica"), Descrizione -> String("Stabilisce il codice normativo per l'esercizio delle attività di ristorazione nel territorio della Federazione, includendo definizioni, sostanze regolamentate, limiti quantitativi, restrizioni, licenze e tecniche di preparazione."), Data -> String("67° Giorno del Ciclo Cosmico 789"), Autorità -> String("Gran Consiglio della Federazione Intergalattica")} to be of type BOOLEAN, STRING, INTEGER, FLOAT, DATE, LOCAL TIME, ZONED TIME, LOCAL DATETIME, ZONED DATETIME, DURATION, POINT, NODE or RELATIONSHIP, but was of type MAP.} {message: 22N01: Expected the value Map{Numero -> String("789/12773"), Tipo -> String("Decreto Supremo"), Titolo -> String("Regolamentazione della sicurezza alimentare intergalattica"), Descrizione -> String("Stabilisce il codice normativo per l'esercizio delle attività di ristorazione nel territorio della Federazione, includendo definizioni, sostanze regolamentate, limiti quantitativi, restrizioni, licenze e tecniche di preparazione."), Data -> String("67° Giorno del Ciclo Cosmico 789"), Autorità -> String("Gran Consiglio della Federazione Intergalattica")} to be of type BOOLEAN, STRING, INTEGER, FLOAT, DATE, LOCAL TIME, ZONED TIME, LOCAL DATETIME, ZONED DATETIME, DURATION, POINT, NODE or RELATIONSHIP, but was of type MAP.} {diagnostic_record: {'_classification': 'CLIENT_ERROR', 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}} {raw_classification: CLIENT_ERROR}
#
# The above exception was the direct cause of the following exception:
#
# CypherTypeError                           Traceback (most recent call last)
# Cell In[60], line 12
#       5             session.run("""
#       6                 MERGE (e:Entita {nome: $entita})
#       7                 SET e.valore = $valore
#       8             """, entita=entita, valore=valore)
#      10 # Carica le valorizzazioni su Neo4j
#      11 #carica_neo4j(valori_manuale)
# ---> 12 carica_neo4j(valori_codice)
#
# Cell In[60], line 5, in carica_neo4j(valorizzazioni)
#       3 with driver.session() as session:
#       4     for entita, valore in valorizzazioni.items():
# ----> 5         session.run("""
#       6             MERGE (e:Entita {nome: $entita})
#       7             SET e.valore = $valore
#       8         """, entita=entita, valore=valore)
#
# File c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Lib\site-packages\neo4j\_sync\work\session.py:328, in Session.run(self, query, parameters, **kwargs)
#     326 bookmarks = self._get_bookmarks()
#     327 parameters = dict(parameters or {}, **kwargs)
# --> 328 self._auto_result._run(
#     329     query,
#     330     parameters,
#     331     self._config.database,
#     332     self._config.impersonated_user,
#     333     self._config.default_access_mode,
#     334     bookmarks,
#     335     self._config.notifications_min_severity,
#     336     self._config.notifications_disabled_classifications,
#     337 )
#     339 return self._auto_result
#
# File c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Lib\site-packages\neo4j\_sync\work\result.py:236, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     234 self._pull()
#     235 self._connection.send_all()
# --> 236 self._attach()
#
# File c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Lib\site-packages\neo4j\_sync\work\result.py:430, in Result._attach(self)
#     428 if self._exhausted is False:
#     429     while self._attached is False:
# --> 430         self._connection.fetch_message()
#
# File c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Lib\site-packages\neo4j\_sync\io\_common.py:184, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     182 def inner(*args, **kwargs):
#     183     try:
# --> 184         func(*args, **kwargs)
#     185     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     186         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Lib\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_message(self)
#     860 # Receive exactly one message
#     861 tag, fields = self.inbox.pop(
#     862     hydration_hooks=self.responses[0].hydration_hooks
#     863 )
# --> 864 res = self._process_message(tag, fields)
#     865 self.idle_since = monotonic()
#     866 return res
#
# File c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Lib\site-packages\neo4j\_sync\io\_bolt5.py:1208, in Bolt5x7._process_message(self, tag, fields)
#    1206 self._enrich_error_diagnostic_record(summary_metadata)
#    1207 try:
# -> 1208     response.on_failure(summary_metadata or {})
#    1209 except (ServiceUnavailable, DatabaseUnavailable):
#    1210     if self.pool:
#
# File c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Lib\site-packages\neo4j\_sync\io\_common.py:254, in Response.on_failure(self, metadata)
#     252 handler = self.handlers.get("on_summary")
#     253 Util.callback(handler)
# --> 254 raise self._hydrate_error(metadata)
#
# CypherTypeError: {code: Neo.ClientError.Statement.TypeError} {message: Property values can only be of primitive types or arrays thereof. Encountered: Map{Numero -> String("789/12773"), Tipo -> String("Decreto Supremo"), Titolo -> String("Regolamentazione della sicurezza alimentare intergalattica"), Descrizione -> String("Stabilisce il codice normativo per l'esercizio delle attività di ristorazione nel territorio della Federazione, includendo definizioni, sostanze regolamentate, limiti quantitativi, restrizioni, licenze e tecniche di preparazione."), Data -> String("67° Giorno del Ciclo Cosmico 789"), Autorità -> String("Gran Consiglio della Federazione Intergalattica")}.}

# %%
def valida_struttura_neo4j(dati_grezzi: dict, llm: AzureChatOpenAI) -> dict:
    """
    Valida e trasforma i dati estratti in una struttura compatibile con Neo4j,
    identificando nodi e relazioni tramite LLM.
    """
    prompt = f"""
    Converti il seguente JSON in una struttura per Neo4j rispettando queste regole:
    1. Ogni entità diventa un nodo con label specifica (es: Ristorante, Pianeta)
    2. Le proprietà devono essere valori primitivi (stringa, numero, booleano)
    3. Le relazioni devono avere tipo e direzione espliciti
    
    Esempio input: 
    {{"Regolamentazione": {{
        "Numero": "789/12773",
        "Tipo": "Decreto Supremo"
    }}}}

    Esempio output:
    {{
        "nodi": {{
            "Regolamentazione_789/12773": {{
                "label": "Regolamentazione",
                "properties": {{
                    "Numero": "789/12773",
                    "Tipo": "Decreto Supremo"
                }}
            }}
        }},
        "relazioni": []
    }}

    Input da convertire:
    {json.dumps(dati_grezzi, indent=2, ensure_ascii=False)}
    """

    response = llm.invoke(prompt)
    content = response.content.strip()

    # Pulizia del JSON
    if content.startswith('``````'):
        content = '\n'.join(content.split('\n')[1:-1])
    if content.startswith('json'):
        content = content[4:].strip()

    try:
        return json.loads(content)
    except json.JSONDecodeError as e:
        print(f"Errore validazione JSON: {e}\nContenuto: {content}")
        return repair_json(content)
        return {"nodi": {}, "relazioni": []}

def carica_neo4j_aggiornata(dati_validati: dict):
    """
    Carica i dati validati in Neo4j creando nodi e relazioni
    """
    with driver.session() as session:
        # Creazione nodi
        for node_id, node_data in dati_validati.get("nodi", {}).items():
            session.run(
                """MERGE (n:{label} {{id: $id}})
                   SET n += $properties""",
                id=node_id,
                label=node_data["label"],
                properties=node_data.get("properties", {})
            )
        
        # Creazione relazioni
        for rel in dati_validati.get("relazioni", []):
            session.run(
                """MATCH (a:{label_a} {{id: $id_a}})
                   MATCH (b:{label_b} {{id: $id_b}})
                   MERGE (a)-[r:{type}]->(b)
                   SET r += $properties""",
                label_a=rel["from"]["label"],
                id_a=rel["from"]["id"],
                label_b=rel["to"]["label"],
                id_b=rel["to"]["id"],
                type=rel["type"],
                properties=rel.get("properties", {})
            )


dati_grezzi = estrai_valorizzazioni(testo_codice, entita_filtrate, llm, driver)

dati_validati = valida_struttura_neo4j(dati_grezzi, llm)
# Out:
# Errore validazione JSON: Expecting value: line 1 column 1 (char 0)
# Contenuto: ```json
# {
#   "nodi": {
#     "Legge_789/12773": {
#       "label": "Legge",
#       "properties": {
#         "numero": "789/12773",
#         "tipo": "Decreto Supremo",
#         "ente_emittente": "Gran Consiglio della Federazione Intergalattica",
#         "data_emissione": "67° Giorno del Ciclo Cosmico 789",
#         "oggetto": "Regolamentazione della sicurezza alimentare intergalattica"
#       }
#     },
#     "Articolo_1_Legge_789/12773": {
#       "label": "Articolo",
#       "properties": {
#         "articolo": "1",
#         "titolo": "Definizioni e ambiti",
#         "contenuto": "Definizione degli ordini e delle loro prescrizioni alimentari."
#       }
#     },
#     "Articolo_2_Legge_789/12773": {
#       "label": "Articolo",
#       "properties": {
#         "articolo": "2",
#         "titolo": "Sostanze regolamentate",
#         "contenuto": "Classificazione e limiti delle sostanze alimentari."
#       }
#     },
#     "Articolo_3_Legge_789/12773": {
#       "label": "Articolo",
#       "properties": {
#         "articolo": "3",
#         "titolo": "Limiti quantitativi e restrizioni",
#         "contenuto": "Dettaglio dei limiti per varie sostanze regolamentate."
#       }
#     },
#     "Articolo_4_Legge_789/12773": {
#       "label": "Articolo",
#       "properties": {
#         "articolo": "4",
#         "titolo": "Licenze e Tecniche di Preparazione",
#         "contenuto": "Autorizzazioni necessarie per le attività culinarie e le tecniche di preparazione."
#       }
#     },
#     "Articolo_5_Legge_789/12773": {
#       "label": "Articolo",
#       "properties": {
#         "articolo": "5",
#         "titolo": "Sanzioni e Pene",
#         "contenuto": "Regole per le sanzioni in caso di violazioni delle normative."
#       }
#     },
#     "Articolo_6_Legge_789/12773": {
#       "label": "Articolo",
#       "properties": {
#         "articolo": "6",
#         "titolo": "Disposizioni finali",
#         "contenuto": "Tempi di attuazione e procedure per deroghe."
#       }
#     },
#     "Appendice_Calcolo delle Sanzioni Composite_Legge_789/12773": {
#       "label": "Appendice",
#       "properties": {
#         "titolo": "Calcolo delle Sanzioni Composite",
#         "contenuto": "Metodologia per il calcolo delle sanzioni in caso di violazioni multiple."
#       }
#     },
#     "Legge_675/12": {
#       "label": "Legge",
#       "properties": {
#         "numero": "675/12",
#         "tipo": "Regolamento",
#         "oggetto": "Definizione delle necessità fisiologiche di tutte le specie senzienti e non senzienti."
#       }
#     },
#     "Legge_766/31098": {
#       "label": "Legge",
#       "properties": {
#         "numero": "766/31098",
#         "tipo": "Decreto Supremo",
#         "oggetto": "Autorizzazioni per l'attività culinaria nella Federazione Intergalattica"
#       }
#     },
#     "Ristorante_Esercizio delle attività di ristorazione_Federazione": {
#       "label": "Ristorante",
#       "properties": {
#         "descrizione": "Esercizio delle attività di ristorazione nel territorio della Federazione.",
#         "regolamentazione": "Stabilito dal Decreto Supremo 789/12773.",
#         "obblighi": "Implementazione delle disposizioni entro 1 ciclo cosmico dall'entrata in vigore."
#       }
#     },
#     "Licenza_Psionica_P_0_Ristorante_Esercizio delle attività di ristorazione_Federazione": {
#       "label": "Licenza",
#       "properties": {
#         "tipo": "Psionica",
#         "livello": "0"
#       }
#     },
#     "Licenza_Gravitazionale_G_0_Ristorante_Esercizio delle attività di ristorazione_Federazione": {
#       "label": "Licenza",
#       "properties": {
#         "tipo": "Gravitazionale",
#         "livello": "0"
#       }
#     },
#     "Licenza_Antimateria_e+_0_Ristorante_Esercizio delle attività di ristorazione_Federazione": {
#       "label": "Licenza",
#       "properties": {
#         "tipo": "Antimateria",
#         "livello": "e+",
#         "livello_numero": 0
#       }
#     },
#     "Licenza_Magnetica_Mx_0_Ristorante_Esercizio delle attività di ristorazione_Federazione": {
#       "label": "Licenza",
#       "properties": {
#         "tipo": "Magnetica",
#         "livello": "Mx",
#         "livello_numero": 0
#       }
#     },
#     "Certificazione_Tecnologica_LTK_I_Ristorante_Esercizio delle attività di ristorazione_Federazione": {
#       "label": "Certificazione",
#       "properties": {
#         "grado": "LTK",
#         "livello": "I"
#       }
#     },
#     "Categoria_Sostanze_Psicotrope_e_Psioniche": {
#       "label": "Categoria",
#       "properties": {
#         "nome": "Sostanze Psicotrope e Psioniche"
#       }
#     },
#     "Ingrediente_Erba_Pipa_Sostanze_Psicotrope_e_Psioniche": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "Erba Pipa",
#         "CRP": 0.89,
#         "IEI": 0.3
#       }
#     },
#     "Ingrediente_Cristalli_di_Memoria_Sostanze_Psicotrope_e_Psioniche": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "Cristalli di Memoria",
#         "CRP": 0.92,
#         "CDT": 0.2
#       }
#     },
#     "Ingrediente_Petali_di_Eco_Sostanze_Psicotrope_e_Psioniche": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "Petali di Eco",
#         "CRP": 0.87,
#         "IPM": 0.6
#       }
#     },
#     "Categoria_Sostanze_di_Origine_Mitica": {
#       "label": "Categoria",
#       "properties": {
#         "nome": "Sostanze di Origine Mitica"
#       }
#     },
#     "Ingrediente_Carne_di_Drago_Sostanze_di_Origine_Mitica": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "Carne di Drago",
#         "IPM": 0.85
#       }
#     },
#     "Ingrediente_Uova_di_Fenice_Sostanze_di_Origine_Mitica": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "Uova di Fenice",
#         "IPM": 0.98,
#         "CDT": 0.8
#       }
#     },
#     "Ingrediente_Lacrime_di_Unicorno_Sostanze_di_Origine_Mitica": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "Lacrime di Unicorno",
#         "IPM": 0.95,
#         "θ": 0.9
#       }
#     },
#     "Categoria_Sostanze_Xenobiologiche": {
#       "label": "Categoria",
#       "properties": {
#         "nome": "Sostanze Xenobiologiche"
#       }
#     },
#     "Ingrediente_Foglie_di_Mandragora_Sostanze_Xenobiologiche": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "Foglie di Mandragora",
#         "IBX": 0.82,
#         "μ": 0.3
#       }
#     },
#     "Ingrediente_MuNa_Lunare_Sostanze_Xenobiologiche": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "MuNa Lunare",
#         "IBX": 0.78,
#         "μ": 0.6,
#         "CRP": 0.72
#       }
#     },
#     "Ingrediente_Nettare_di_Sirena_Sostanze_Xenobiologiche": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "Nettare di Sirena",
#         "IBX": 0.85,
#         "μ": 0.2,
#         "θ": 0.7
#       }
#     },
#     "Categoria_Sostanze_Quantiche_e_Dimensionali": {
#       "label": "Categoria",
#       "properties": {
#         "nome": "Sostanze Quantiche e Dimensionali"
#       }
#     },
#     "Ingrediente_Spore_Quantiche_Sostanze_Quantiche_e_Dimensionali": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "Spore Quantiche",
#         "δQ": 0.45,
#         "ID": 0.8
#       }
#     },
#     "Ingrediente_Essenza_di_Vuoto_Sostanze_Quantiche_e_Dimensionali": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "Essenza di Vuoto",
#         "δQ": 0.16,
#         "ID": 0.95
#       }
#     },
#     "Ingrediente_Funghi_dell’Etere_Sostanze_Quantiche_e_Dimensionali": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "Funghi dell’Etere",
#         "δQ": 0.38,
#         "ID": 0.75
#       }
#     },
#     "Categoria_Sostanze_Spazio-Temporali": {
#       "label": "Categoria",
#       "properties": {
#         "nome": "Sostanze Spazio-Temporali"
#       }
#     },
#     "Ingrediente_Sale_Temporale_Sostanze_Spazio-Temporali": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "Sale Temporale",
#         "CDT": 0.65,
#         "IEI": 0.4
#       }
#     },
#     "Ingrediente_Radici_di_Gravità_Sostanze_Spazio-Temporali": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "Radici di Gravità",
#         "CDT": 0.55,
#         "ID": 0.4
#       }
#     },
#     "Ingrediente_Polvere_di_Stelle_Sostanze_Spazio-Temporali": {
#       "label": "Ingrediente",
#       "properties": {
#         "nome": "Polvere di Stelle",
#         "CDT": 0.75,
#         "IPM": 0.88
#       }
#     },
#     "TecnicaCulinaria_Marinatura": {
#       "label": "TecnicaCulinaria",
#       "properties": {
#         "categoria": "Marinatura"
#       }
#     },
#     "TecnicaCulinaria_Subtipo_Marinatura_a_infusione_gravitazionale_Marinatura": {
#       "label": "TecnicaCulinariaSubtipo",
#       "properties": {
#         "nome": "Marinatura a infusione gravitazionale"
#       }
#     },
#     "TecnicaCulinaria_Subtipo_Marinatura_temporale_sincronizzata_Marinatura": {
#       "label": "TecnicaCulinariaSubtipo",
#       "properties": {
#         "nome": "Marinatura temporale sincronizzata"
#       }
#     },
#     "TecnicaCulinaria_Subtipo_Marinatura_psionica_Marinatura": {
#       "label": "TecnicaCulinariaSubtipo",
#       "properties": {
#         "nome": "Marinatura psionica"
#       }
#     },
#     "TecnicaCulinaria_Subtipo_Marinatura_tramite_reazioni_d_antimateria_diluite_Marinatura": {
#       "label": "TecnicaCulinariaSubtipo",
#       "properties": {
#         "nome": "Marinatura tramite reazioni d’antimateria diluite"
#       }
#     },
#     "TecnicaCulinaria_Subtipo_Marinatura_sotto_zero_a_polarità_inversa_Marinatura": {
#       "label": "TecnicaCulinariaSubtipo",
#       "properties": {
#         "nome": "Marinatura sotto zero a polarità inversa"
#       }
#     },
#     "TecnicaCulinaria_Marinatura_a_infusione_gravitazionale_Licenza_Gravitazionale_II": {
#       "label": "Relazione",
#       "tipo": "NEEDS_LICENSE",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Subtipo_Marinatura_a_infusione_gravitazionale_Marinatura",
#       "end_node": "Licenza_Gravitazionale_G_II"
#     },
#     "TecnicaCulinaria_Marinatura_temporale_sincronizzata_Licenza_Temporale_I": {
#       "label": "Relazione",
#       "tipo": "NEEDS_LICENSE",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Subtipo_Marinatura_temporale_sincronizzata_Marinatura",
#       "end_node": "Licenza_Temporale_I"
#     },
#     "TecnicaCulinaria_Marinatura_psionica_Licenza_Psionica_III": {
#       "label": "Relazione",
#       "tipo": "NEEDS_LICENSE",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Subtipo_Marinatura_psionica_Marinatura",
#       "end_node": "Licenza_Psionica_III"
#     },
#     "TecnicaCulinaria_Marinatura_tramite_reazioni_d_antimateria_diluite_Licenza_Antimateria_I": {
#       "label": "Relazione",
#       "tipo": "NEEDS_LICENSE",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Subtipo_Marinatura_tramite_reazioni_d_antimateria_diluite_Marinatura",
#       "end_node": "Licenza_Antimateria_I"
#     },
#     "TecnicaCulinaria_Marinatura_sotto_zero_a_polarità_inversa_Licenza_Magnetica_I": {
#       "label": "Relazione",
#       "tipo": "NEEDS_LICENSE",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Subtipo_Marinatura_sotto_zero_a_polarità_inversa_Marinatura",
#       "end_node": "Licenza_Magnetica_I"
#     },
#     "TecnicaCulinaria_Marinatura_sotto_zero_a_polarità_inversa_Licenza_Certificazione_Tecnologica_LTK_II": {
#       "label": "Relazione",
#       "tipo": "NEEDS_LICENSE",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Subtipo_Marinatura_sotto_zero_a_polarità_inversa_Marinatura",
#       "end_node": "Certificazione_Tecnologica_LTK_I"
#     },
#     "Pianeta_Andromeda": {
#       "label": "Pianeta",
#       "properties": {
#         "nome": "Andromeda",
#         "caratteristiche": "Tutti gli abitanti manifestano intolleranza al lattosio, ovvero qualsiasi forma nutritiva originaria della Via Lattea."
#       }
#     },
#     "Ordine_Speciale_Ordine_della_Galassia_di_Andromeda_Pianeta_Andromeda": {
#       "label": "OrdineSpeciale",
#       "properties": {
#         "nome": "Ordine della Galassia di Andromeda",
#         "descrizione": "Chef iscritti devono gestire le peculiarità fisiologiche degli abitanti di Andromeda."
#       }
#     },
#     "Sanzione_Violazione_Limitazioni_sulle_sostanze_psioniche": {
#       "label": "Sanzione",
#       "properties": {
#         "categoria": "Limitazioni sulle sostanze psioniche",
#         "conseguenze": "Obbligo di sottoporsi a valutazione psionica approfondita per verificare contaminazioni."
#       }
#     },
#     "Sanzione_Violazione_Violazioni_multiple": {
#       "label": "Sanzione",
#       "properties": {
#         "categoria": "Violazioni multiple",
#         "descrizione": "Calcolate secondo il principio del cumulo psionico."
#       }
#     },
#     "Fattore_Numero_categorie_protette_Violazioni_multiple": {
#       "label": "Fattore",
#       "properties": {
#         "nome": "Numero di categorie protette coinvolte"
#       }
#     },
#     "Fattore_Gravità_effetti_salute_Violazioni_multiple": {
#       "label": "Fattore",
#       "properties": {
#         "nome": "Gravità degli effetti sulla salute"
#       }
#     },
#     "Fattore_Impatto_ambientale_Violazioni_multiple": {
#       "label": "Fattore",
#       "properties": {
#         "nome": "Impatto ambientale"
#       }
#     },
#     "Fattore_Violazione_principi_religiosi_o_culturali_Violazioni_multiple": {
#       "label": "Fattore",
#       "properties": {
#         "nome": "Violazione di principi religiosi o culturali"
#       }
#     },
#     "Sanzione_Violazione_Falsificazione_delle_certificazioni": {
#       "label": "Sanzione",
#       "properties": {
#         "categoria": "Falsificazione delle certificazioni",
#         "descrizione": "Crimine di particolare gravità che mina la sicurezza alimentare e le tradizioni gastronomiche.",
#         "conseguenze": "Obbligo di sottoporsi a un percorso di rieducazione sulla filosofia del minimo intervento senziente."
#       }
#     }
#   },
#   "relazioni": [
#     {
#       "tipo": "CONTAINS_ARTICOLO",
#       "direzione": "FROM",
#       "start_node": "Legge_789/12773",
#       "end_node": "Articolo_1_Legge_789/12773"
#     },
#     {
#       "tipo": "CONTAINS_ARTICOLO",
#       "direzione": "FROM",
#       "start_node": "Legge_789/12773",
#       "end_node": "Articolo_2_Legge_789/12773"
#     },
#     {
#       "tipo": "CONTAINS_ARTICOLO",
#       "direzione": "FROM",
#       "start_node": "Legge_789/12773",
#       "end_node": "Articolo_3_Legge_789/12773"
#     },
#     {
#       "tipo": "CONTAINS_ARTICOLO",
#       "direzione": "FROM",
#       "start_node": "Legge_789/12773",
#       "end_node": "Articolo_4_Legge_789/12773"
#     },
#     {
#       "tipo": "CONTAINS_ARTICOLO",
#       "direzione": "FROM",
#       "start_node": "Legge_789/12773",
#       "end_node": "Articolo_5_Legge_789/12773"
#     },
#     {
#       "tipo": "CONTAINS_ARTICOLO",
#       "direzione": "FROM",
#       "start_node": "Legge_789/12773",
#       "end_node": "Articolo_6_Legge_789/12773"
#     },
#     {
#       "tipo": "HAS_APPENDICE",
#       "direzione": "FROM",
#       "start_node": "Legge_789/12773",
#       "end_node": "Appendice_Calcolo delle Sanzioni Composite_Legge_789/12773"
#     },
#     {
#       "tipo": "RELATED_TO",
#       "direzione": "FROM",
#       "start_node": "Ristorante_Esercizio delle attività di ristorazione_Federazione",
#       "end_node": "Legge_789/12773"
#     },
#     {
#       "tipo": "INCLUDES_LICENSE",
#       "direzione": "FROM",
#       "start_node": "Ristorante_Esercizio delle attività di ristorazione_Federazione",
#       "end_node": "Licenza_Psionica_P_0_Ristorante_Esercizio delle attività di ristorazione_Federazione"
#     },
#     {
#       "tipo": "INCLUDES_LICENSE",
#       "direzione": "FROM",
#       "start_node": "Ristorante_Esercizio delle attività di ristorazione_Federazione",
#       "end_node": "Licenza_Gravitazionale_G_0_Ristorante_Esercizio delle attività di ristorazione_Federazione"
#     },
#     {
#       "tipo": "INCLUDES_LICENSE",
#       "direzione": "FROM",
#       "start_node": "Ristorante_Esercizio delle attività di ristorazione_Federazione",
#       "end_node": "Licenza_Antimateria_e+_0_Ristorante_Esercizio delle attività di ristorazione_Federazione"
#     },
#     {
#       "tipo": "INCLUDES_LICENSE",
#       "direzione": "FROM",
#       "start_node": "Ristorante_Esercizio delle attività di ristorazione_Federazione",
#       "end_node": "Licenza_Magnetica_Mx_0_Ristorante_Esercizio delle attività di ristorazione_Federazione"
#     },
#     {
#       "tipo": "INCLUDES_CERTIFICATION",
#       "direzione": "FROM",
#       "start_node": "Ristorante_Esercizio delle attività di ristorazione_Federazione",
#       "end_node": "Certificazione_Tecnologica_LTK_I_Ristorante_Esercizio delle attività di ristorazione_Federazione"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_Erba_Pipa_Sostanze_Psicotrope_e_Psioniche",
#       "end_node": "Categoria_Sostanze_Psicotrope_e_Psioniche"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_Cristalli_di_Memoria_Sostanze_Psicotrope_e_Psioniche",
#       "end_node": "Categoria_Sostanze_Psicotrope_e_Psioniche"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_Petali_di_Eco_Sostanze_Psicotrope_e_Psioniche",
#       "end_node": "Categoria_Sostanze_Psicotrope_e_Psioniche"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_Carne_di_Drago_Sostanze_di_Origine_Mitica",
#       "end_node": "Categoria_Sostanze_di_Origine_Mitica"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_Uova_di_Fenice_Sostanze_di_Origine_Mitica",
#       "end_node": "Categoria_Sostanze_di_Origine_Mitica"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_Lacrime_di_Unicorno_Sostanze_di_Origine_Mitica",
#       "end_node": "Categoria_Sostanze_di_Origine_Mitica"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_Foglie_di_Mandragora_Sostanze_Xenobiologiche",
#       "end_node": "Categoria_Sostanze_Xenobiologiche"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_MuNa_Lunare_Sostanze_Xenobiologiche",
#       "end_node": "Categoria_Sostanze_Xenobiologiche"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_Nettare_di_Sirena_Sostanze_Xenobiologiche",
#       "end_node": "Categoria_Sostanze_Xenobiologiche"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_Spore_Quantiche_Sostanze_Quantiche_e_Dimensionali",
#       "end_node": "Categoria_Sostanze_Quantiche_e_Dimensionali"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_Essenza_di_Vuoto_Sostanze_Quantiche_e_Dimensionali",
#       "end_node": "Categoria_Sostanze_Quantiche_e_Dimensionali"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_Funghi_dell’Etere_Sostanze_Quantiche_e_Dimensionali",
#       "end_node": "Categoria_Sostanze_Quantiche_e_Dimensionali"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_Sale_Temporale_Sostanze_Spazio-Temporali",
#       "end_node": "Categoria_Sostanze_Spazio-Temporali"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_Radici_di_Gravità_Sostanze_Spazio-Temporali",
#       "end_node": "Categoria_Sostanze_Spazio-Temporali"
#     },
#     {
#       "tipo": "BELONGS_TO",
#       "direzione": "FROM",
#       "start_node": "Ingrediente_Polvere_di_Stelle_Sostanze_Spazio-Temporali",
#       "end_node": "Categoria_Sostanze_Spazio-Temporali"
#     },
#     {
#       "tipo": "HAS_SUBTIPO",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Marinatura",
#       "end_node": "TecnicaCulinaria_Subtipo_Marinatura_a_infusione_gravitazionale_Marinatura"
#     },
#     {
#       "tipo": "HAS_SUBTIPO",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Marinatura",
#       "end_node": "TecnicaCulinaria_Subtipo_Marinatura_temporale_sincronizzata_Marinatura"
#     },
#     {
#       "tipo": "HAS_SUBTIPO",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Marinatura",
#       "end_node": "TecnicaCulinaria_Subtipo_Marinatura_psionica_Marinatura"
#     },
#     {
#       "tipo": "HAS_SUBTIPO",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Marinatura",
#       "end_node": "TecnicaCulinaria_Subtipo_Marinatura_tramite_reazioni_d_antimateria_diluite_Marinatura"
#     },
#     {
#       "tipo": "HAS_SUBTIPO",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Marinatura",
#       "end_node": "TecnicaCulinaria_Subtipo_Marinatura_sotto_zero_a_polarità_inversa_Marinatura"
#     },
#     {
#       "tipo": "USES_LICENSE",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Subtipo_Marinatura_a_infusione_gravitazionale_Marinatura",
#       "end_node": "Licenza_Gravitazionale_G_II"
#     },
#     {
#       "tipo": "USES_LICENSE",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Subtipo_Marinatura_temporale_sincronizzata_Marinatura",
#       "end_node": "Licenza_Temporale_I"
#     },
#     {
#       "tipo": "USES_LICENSE",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Subtipo_Marinatura_psionica_Marinatura",
#       "end_node": "Licenza_Psionica_III"
#     },
#     {
#       "tipo": "USES_LICENSE",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Subtipo_Marinatura_tramite_reazioni_d_antimateria_diluite_Marinatura",
#       "end_node": "Licenza_Antimateria_I"
#     },
#     {
#       "tipo": "USES_LICENSE",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Subtipo_Marinatura_sotto_zero_a_polarità_inversa_Marinatura",
#       "end_node": "Licenza_Magnetica_I"
#     },
#     {
#       "tipo": "USES_CERTIFICATION",
#       "direzione": "FROM",
#       "start_node": "TecnicaCulinaria_Subtipo_Marinatura_sotto_zero_a_polarità_inversa_Marinatura",
#       "end_node": "Certificazione_Tecnologica_LTK_II"
#     },
#     {
#       "tipo": "HAS_ORDINE_SPECIALE",
#       "direzione": "FROM",
#       "start_node": "Pianeta_Andromeda",
#       "end_node": "Ordine_Speciale_Ordine_della_Galassia_di_Andromeda_Pianeta_Andromeda"
#     },
#     {
#       "tipo": "HAS_VIOLAZIONE",
#       "direzione": "FROM",
#       "start_node": "Sanzione_Violazione_Limitazioni_sulle_sostanze_psioniche",
#       "end_node": "Fattore_Numero_categorie_protette_Violazioni_multiple"
#     },
#     {
#       "tipo": "HAS_VIOLAZIONE",
#       "direzione": "FROM",
#       "start_node": "Sanzione_Violazione_Limitazioni_sulle_sostanze_psioniche",
#       "end_node": "Fattore_Gravità_effetti_salute_Violazioni_multiple"
#     },
#     {
#       "tipo": "HAS_VIOLAZIONE",
#       "direzione": "FROM",
#       "start_node": "Sanzione_Violazione_Limitazioni_sulle_sostanze_psioniche",
#       "end_node": "Fattore_Impatto_ambientale_Violazioni_multiple"
#     },
#     {
#       "tipo": "HAS_VIOLAZIONE",
#       "direzione": "FROM",
#       "start_node": "Sanzione_Violazione_Limitazioni_sulle_sostanze_psioniche",
#       "end_node": "Fattore_Violazione_principi_religiosi_o_culturali_Violazioni_multiple"
#     }
#   ]
# }
# ```
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 87
#      83 dati_grezzi = estrai_valorizzazioni(testo_codice, entita_filtrate, llm, driver)
#      85 dati_validati = valida_struttura_neo4j(dati_grezzi, llm)
# ---> 87 carica_neo4j_aggiornata(dati_validati)
#      89 print("Struttura generata:", json.dumps(dati_validati, indent=2))
#
# Cell In[71], line 58, in carica_neo4j_aggiornata(dati_validati)
#      53 """
#      54 Carica i dati validati in Neo4j creando nodi e relazioni
#      55 """
#      56 with driver.session() as session:
#      57     # Creazione nodi
# ---> 58     for node_id, node_data in dati_validati.get("nodi", {}).items():
#      59         session.run(
#      60             """MERGE (n:{label} {{id: $id}})
#      61                SET n += $properties""",
#    (...)
#      64             properties=node_data.get("properties", {})
#      65         )
#      67     # Creazione relazioni
#
# AttributeError: 'str' object has no attribute 'get'

# %%
repair_json(dati_validati)
# Out:
# '{"nodi": {"Legge_789/12773": {"label": "Legge", "properties": {"numero": "789/12773", "tipo": "Decreto Supremo", "ente_emittente": "Gran Consiglio della Federazione Intergalattica", "data_emissione": "67\\u00b0 Giorno del Ciclo Cosmico 789", "oggetto": "Regolamentazione della sicurezza alimentare intergalattica"}}, "Articolo_1_Legge_789/12773": {"label": "Articolo", "properties": {"articolo": "1", "titolo": "Definizioni e ambiti", "contenuto": "Definizione degli ordini e delle loro prescrizioni alimentari."}}, "Articolo_2_Legge_789/12773": {"label": "Articolo", "properties": {"articolo": "2", "titolo": "Sostanze regolamentate", "contenuto": "Classificazione e limiti delle sostanze alimentari."}}, "Articolo_3_Legge_789/12773": {"label": "Articolo", "properties": {"articolo": "3", "titolo": "Limiti quantitativi e restrizioni", "contenuto": "Dettaglio dei limiti per varie sostanze regolamentate."}}, "Articolo_4_Legge_789/12773": {"label": "Articolo", "properties": {"articolo": "4", "titolo": "Licenze e Tecniche di Preparazione", "contenuto": "Autorizzazioni necessarie per le attivit\\u00e0 culinarie e le tecniche di preparazione."}}, "Articolo_5_Legge_789/12773": {"label": "Articolo", "properties": {"articolo": "5", "titolo": "Sanzioni e Pene", "contenuto": "Regole per le sanzioni in caso di violazioni delle normative."}}, "Articolo_6_Legge_789/12773": {"label": "Articolo", "properties": {"articolo": "6", "titolo": "Disposizioni finali", "contenuto": "Tempi di attuazione e procedure per deroghe."}}, "Appendice_Calcolo delle Sanzioni Composite_Legge_789/12773": {"label": "Appendice", "properties": {"titolo": "Calcolo delle Sanzioni Composite", "contenuto": "Metodologia per il calcolo delle sanzioni in caso di violazioni multiple."}}, "Legge_675/12": {"label": "Legge", "properties": {"numero": "675/12", "tipo": "Regolamento", "oggetto": "Definizione delle necessit\\u00e0 fisiologiche di tutte le specie senzienti e non senzienti."}}, "Legge_766/31098": {"label": "Legge", "properties": {"numero": "766/31098", "tipo": "Decreto Supremo", "oggetto": "Autorizzazioni per l\'attivit\\u00e0 culinaria nella Federazione Intergalattica"}}, "Ristorante_Esercizio delle attivit\\u00e0 di ristorazione_Federazione": {"label": "Ristorante", "properties": {"descrizione": "Esercizio delle attivit\\u00e0 di ristorazione nel territorio della Federazione.", "regolamentazione": "Stabilito dal Decreto Supremo 789/12773.", "obblighi": "Implementazione delle disposizioni entro 1 ciclo cosmico dall\'entrata in vigore."}}, "Licenza_Psionica_P_0_Ristorante_Esercizio delle attivit\\u00e0 di ristorazione_Federazione": {"label": "Licenza", "properties": {"tipo": "Psionica", "livello": "0"}}, "Licenza_Gravitazionale_G_0_Ristorante_Esercizio delle attivit\\u00e0 di ristorazione_Federazione": {"label": "Licenza", "properties": {"tipo": "Gravitazionale", "livello": "0"}}, "Licenza_Antimateria_e+_0_Ristorante_Esercizio delle attivit\\u00e0 di ristorazione_Federazione": {"label": "Licenza", "properties": {"tipo": "Antimateria", "livello": "e+", "livello_numero": 0}}, "Licenza_Magnetica_Mx_0_Ristorante_Esercizio delle attivit\\u00e0 di ristorazione_Federazione": {"label": "Licenza", "properties": {"tipo": "Magnetica", "livello": "Mx", "livello_numero": 0}}, "Certificazione_Tecnologica_LTK_I_Ristorante_Esercizio delle attivit\\u00e0 di ristorazione_Federazione": {"label": "Certificazione", "properties": {"grado": "LTK", "livello": "I"}}, "Categoria_Sostanze_Psicotrope_e_Psioniche": {"label": "Categoria", "properties": {"nome": "Sostanze Psicotrope e Psioniche"}}, "Ingrediente_Erba_Pipa_Sostanze_Psicotrope_e_Psioniche": {"label": "Ingrediente", "properties": {"nome": "Erba Pipa", "CRP": 0.89, "IEI": 0.3}}, "Ingrediente_Cristalli_di_Memoria_Sostanze_Psicotrope_e_Psioniche": {"label": "Ingrediente", "properties": {"nome": "Cristalli di Memoria", "CRP": 0.92, "CDT": 0.2}}, "Ingrediente_Petali_di_Eco_Sostanze_Psicotrope_e_Psioniche": {"label": "Ingrediente", "properties": {"n ...

# %%
carica_neo4j_aggiornata(json.loads(dati_validati))

print("Struttura generata:", json.dumps(dati_validati, indent=2))
# Out:
# ---------------------------------------------------------------------------
# CypherSyntaxError                         Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 carica_neo4j_aggiornata(json.loads(dati_validati))
#       3 print("Struttura generata:", json.dumps(dati_validati, indent=2))
#
# Cell In[71], line 59, in carica_neo4j_aggiornata(dati_validati)
#      56 with driver.session() as session:
#      57     # Creazione nodi
#      58     for node_id, node_data in dati_validati.get("nodi", {}).items():
# ---> 59         session.run(
#      60             """MERGE (n:{label} {{id: $id}})
#      61                SET n += $properties""",
#      62             id=node_id,
#      63             label=node_data["label"],
#      64             properties=node_data.get("properties", {})
#      65         )
#      67     # Creazione relazioni
#      68     for rel in dati_validati.get("relazioni", []):
#
# File c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Lib\site-packages\neo4j\_sync\work\session.py:328, in Session.run(self, query, parameters, **kwargs)
#     326 bookmarks = self._get_bookmarks()
#     327 parameters = dict(parameters or {}, **kwargs)
# --> 328 self._auto_result._run(
#     329     query,
#     330     parameters,
#     331     self._config.database,
#     332     self._config.impersonated_user,
#     333     self._config.default_access_mode,
#     334     bookmarks,
#     335     self._config.notifications_min_severity,
#     336     self._config.notifications_disabled_classifications,
#     337 )
#     339 return self._auto_result
#
# File c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Lib\site-packages\neo4j\_sync\work\result.py:236, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     234 self._pull()
#     235 self._connection.send_all()
# --> 236 self._attach()
#
# File c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Lib\site-packages\neo4j\_sync\work\result.py:430, in Result._attach(self)
#     428 if self._exhausted is False:
#     429     while self._attached is False:
# --> 430         self._connection.fetch_message()
#
# File c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Lib\site-packages\neo4j\_sync\io\_common.py:184, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     182 def inner(*args, **kwargs):
#     183     try:
# --> 184         func(*args, **kwargs)
#     185     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     186         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Lib\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_message(self)
#     860 # Receive exactly one message
#     861 tag, fields = self.inbox.pop(
#     862     hydration_hooks=self.responses[0].hydration_hooks
#     863 )
# --> 864 res = self._process_message(tag, fields)
#     865 self.idle_since = monotonic()
#     866 return res
#
# File c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Lib\site-packages\neo4j\_sync\io\_bolt5.py:1208, in Bolt5x7._process_message(self, tag, fields)
#    1206 self._enrich_error_diagnostic_record(summary_metadata)
#    1207 try:
# -> 1208     response.on_failure(summary_metadata or {})
#    1209 except (ServiceUnavailable, DatabaseUnavailable):
#    1210     if self.pool:
#
# File c:\Users\smancone\OneDrive - BUSINESS INTEGRATION PARTNERS SPA\Desktop\progetti\2402_PRYSMIAN\.conda\Lib\site-packages\neo4j\_sync\io\_common.py:254, in Response.on_failure(self, metadata)
#     252 handler = self.handlers.get("on_summary")
#     253 Util.callback(handler)
# --> 254 raise self._hydrate_error(metadata)
#
# CypherSyntaxError: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '{': expected a node label/relationship type name, '$', '%' or '(' (line 1, column 10 (offset: 9))
# "MERGE (n:{label} {{id: $id}})"
#           ^}

# %% [markdown]
# ## MAIN

# %% [markdown]
# ### SOSTANZE

# %%
sostanze = estrai_sostanze(llm, file_path)

# %%
print(sostanze)
# Out:
# {'Erba Pipa': 'CRP: 0.89, IEI: 0.3', 'Cristalli di Memoria': 'CRP: 0.92, CDT: 0.2', 'Petali di Eco': 'CRP: 0.87, IPM: 0.6', 'Carne di Drago': 'IPM: 0.85, IBX: 0.75', 'Uova di Fenice': 'IPM: 0.98, CDT: 0.8', 'Lacrime di Unicorno': 'IPM: 0.95, θ: 0.9', 'Foglie di Mandragora': 'IBX: 0.82, μ: 0.3', 'MuNa Lunare': 'IBX: 0.78, μ: 0.6, CRP: 0.72', 'Nettare di Sirena': 'IBX: 0.85, μ: 0.2, θ: 0.7', 'Spore Quantiche': 'δQ: 0.45, ID: 0.8', 'Essenza di Vuoto': 'δQ: 0.16, ID: 0.95', 'Funghi dell’Etere': 'δQ: 0.38, ID: 0.75', 'Sale Temporale': 'CDT: 0.65, IEI: 0.4', 'Radici di Gravità': 'CDT: 0.55, ID: 0.4', 'Polvere di Stelle': 'CDT: 0.75, IPM: 0.88'}

# %%
with driver.session() as session:
        for nome, proprieta in sostanze.items():
            session.execute_write(aggiungi_sostanza, nome, proprieta)
# Out:
# C:\Users\lparigi\AppData\Local\Temp\ipykernel_29264\3805961789.py:3: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(aggiungi_sostanza, nome, proprieta)

# %% [markdown]
# ### CREA RELAZIONI TECNICA RICHIEDE LICENZA

# %%
def estrai_testo_capitolo_4(pdf_path: str) -> str:
    """
    Estrae il testo della sezione 4 del PDF che contiene le descrizioni delle tecniche e licenze.

    Args:
        pdf_path (str): Percorso al file PDF.

    Returns:
        str: Il testo del capitolo 4.
    """
    testo_capitolo_4 = ""

    with pdfplumber.open(pdf_path) as doc:
        for page in doc.pages:
            testo = page.extract_text()
            if testo and "4." in testo:  # Cerca il capitolo 4
                testo_capitolo_4 += testo

    if not testo_capitolo_4:
        print("Sezione 4 non trovata nel PDF.")
    return testo_capitolo_4

testo = estrai_testo_capitolo_4(file_path)
print(testo)
# Out:
# 789/12773 67° Giorno del Ciclo Cosmico 789
# 2. Ingredienti di Origine Mitica: sostanze derivate da creature leggendarie, la cui
# esistenza trascende le normali categorie biologiche e richiede considerazioni sia
# pratiche che etiche nella loro gestione.
# 3. Sostanze Xenobiologiche: materiali di origine biologica non terrestre che richiedono
# particolare attenzione nella manipolazione e conservazione, con potenziali
# interazioni con i sistemi biologici terrestri.
# 4. Sostanze Quantiche e Dimensionali: ingredienti che manifestano proprietà
# quantistiche o multi-dimensionali, necessitando di specifiche precauzioni per
# prevenire anomalie spazio-temporali.
# 5. Sostanze Spazio-Temporali: elementi che interagiscono con il tessuto spazio-
# temporale, richiedendo particolare attenzione per evitare distorsioni locali della
# realtà.
# 2.2 Tabella delle sostanze regolamentate
# La presente tabella fornisce una panoramica delle principali categorie di sostanze
# regolamentate.
# Sostanza Proprietà principali
# Sostanze Psicotrope e Psioniche
# CRP: 0.89
# Erba Pipa
# IEI: 0.3
# CRP: 0.92
# Cristalli di
# Memoria
# CDT: 0.2
# CRP: 0.87
# Petali di Eco
# IPM: 0.6
# Sostanze di Origine Mitica
# Carne di Drago IPM: 0.85789/12773 67° Giorno del Ciclo Cosmico 789
# Ai sensi e per gli e(etti del decreto supremo n. 766/31098, si stabilisce che qualsiasi
# soggetto avente cittadinanza della Federazione Intergalattica che intraprenda attività
# professionale nel settore della preparazione e somministrazione di alimenti (d'ora in
# avanti "attività culinaria"), acquisisce ope legis le seguenti autorizzazioni:
# a) licenza di classe Psionica (P) di livello zero (0)
# b) licenza di classe Gravitazionale (G) di livello zero (0)
# c) licenza di classe Antimateria (e+) di livello zero (0)
# d) licenza di classe Magnetica (Mx) di livello zero (0)
# e) certificazione di grado tecnologico LTK di primo (I) livello
# Le disposizioni di cui ai successivi articoli individuano e disciplinano, in via tassativa ed
# esaustiva, le metodologie di preparazione alimentare per le quali è richiesto il possesso
# di licenze diverse o di livello superiore rispetto a quelle conferite ope legis.
# 4.1 Marinatura
# • La marinatura a infusione gravitazionale richiede una licenza gravitazionale (G) di
# livello II
# • La marinatura temporale sincronizzata richiede una licenza temporale (t) di
# livello I
# • La marinatura psionica richiede una licenza psionica (P) di terzo (III) livello
# • La marinatura tramite reazioni d’antimateria diluite richiede una licenza
# Antimateria (e+) di livello I
# • La marinatura sotto zero a polarità inversa richiede una licenza magnetica (Mx) di
# primo (I) livello e un grado tecnologico LTK di secondo (II) livello
# 4.2 A(umicatura
# • L’a(umicatura a stratificazione quantica richiede una licenza quantistica (Q) di
# livello 3 e un grado tecnologico LTK di livello II
# • L’a(umicatura temporale risonante richiede una licenza temporale (t) di primo (I)
# livello e un grado tecnologico LTK di livello II
# • L’a(umicatura psionica sensoriale richiede una licenza psionica (P) di livello II e
# un grado tecnologico LTK di livello III
# • L’a(umicatura tramite big bang microcosmico richiede una licenza antimateria
# (e+) di primo (I) livello, una licenza quantistica (Q) di livello 10 e un grado
# tecnologico LTK di terzo (III) livello
# • L’a(umicatura polarizzata a freddo iperbarico richiede una licenza magnetica
# (Mx) di livello I e un grado tecnologico LTK di secondo (II) livello
# 4.3 Fermentazione789/12773 67° Giorno del Ciclo Cosmico 789
# • La fermentazione quantica a strati multiversali richiede una licenza quantistica
# (Q) di livello 5 e un grado tecnologico LTK di livello VI+
# • La fermentazione temporale sincronizzata richiede una licenza temporale (t) di
# terzo (III) livello e un grado tecnologico LTK di terzo (III) livello
# • La fermentazione psionica energetica richiede una licenza psionica (P) di livello I
# e un grado tecnologico LTK di terzo (III) livello
# • La fermentazione tramite singolarità richiede una licenza gravitazionale (G) di
# terzo (III) livello, una licenza antimateria (e+) di livello I, una licenza magnetica
# (Mx) di livello I e un grado tecnologico LTK di quarto (IV) livello
# • La fermentazione quantico biometrica richiede una licenza quantistica (Q) di
# livello 3 e un grado tecnologico LTK di secondo (II) livello
# 4.4 Decostruzione
# • La decostruzione atomica a strati energetici richiede una licenza antimaterica
# (e+) di livello I, una licenza quantistica (Q) di livello 1 e un grado tecnologico LTK
# di terzo (II) livello
# • La decostruzione magnetica risonante richiede una licenza magnetica (Mx) di
# livello I e un grado tecnologico LTK di secondo (II) livello
# • La decostruzione bio-fotonica emotiva richiede una licenza psionica (P) di terzo
# (III) livello, una licenza luce (c) di terzo (III) livello e un grado tecnologico LTK di
# secondo (II) livello
# • La decostruzione ancestrale richiede una licenza temporale (t) di livello III e un
# grado tecnologico LTK di secondo (II) livello
# • La decostruzione interdimensionale Lovercraftiana richiede una licenza
# quantistica (Q) di livello 7 e un grado tecnologico LTK di sesto (VI) livello
# 4.5 Sferificazione
# • La sferificazione a gravità psionica variabile richiede una licenza psionica (P) di
# livello IV, una licenza gravitazionale (G) di livello I e un grado tecnologico LTK di
# terzo (III) livello
# • La sferificazione filamentare a molecole vibrazionali richiede una licenza
# magnetica (Mx) di livello I, una licenza quantistica (Q) di livello 4 e un grado
# tecnologico LTK di livello II
# • La sferificazione cromatica interdimensionale richiede una licenza quantistica
# (Q) di livello 6, una licenza luce (c) di terzo (III) livello e un grado tecnologico LTK
# di livello III
# • La sferificazione con campi magnetici entropici richiede una licenza magnetica
# (Mx) di primo (I) livello e un grado tecnologico LTK di secondo (II) livello
# • La sferificazione tramite matrici biofotiche richiede una licenza magnetica (Mx) di
# livello I, una licenza quantistica (Q) di livello 3, una licenza luce (c) di livello II e un
# grado tecnologico LTK di livello II789/12773 67° Giorno del Ciclo Cosmico 789
# 4.6 Tecniche di Taglio
# • Il taglio dimensionale a lame fotofilliche richiede una licenza quantistica (Q) di
# livello 6, una licenza luce (c) di livello III e un grado tecnologico LTK di quarto (IV)
# livello
# • L'a(ettamento a pulsazioni quantistiche richiede una licenza quantistica (Q) di
# livello 4 e un grado tecnologico LTK di livello III
# • Il taglio sinaptico biomimetico richiede una licenza psionica (P) di livello IV e un
# grado tecnologico LTK di livello III
# • L'incisione elettromagnetica plasmica richiede una licenza antimateria (e+) di
# livello I, una licenza magnetica (Mx) di livello I e un grado tecnologico LTK di livello
# II
# 4.7 Tecniche di Impasto
# • L'impasto gravitazionale vorticoso richiede una licenza gravitazionale (G) di livello
# I
# • L'amalgamazione sintetica molecolare richiede una licenza quantistica (Q) di
# livello 3
# • L'impasto a campi magnetici dualistici richiede una licenza magnetica (Mx) di
# livello I
# • La sinergia elettro-osmotica programmabile richiede una licenza antimateria (e+)
# di livello I
# • La modellatura onirica tetrazionale richiede una licenza psionica (P) di livello IV,
# una licenza quantistica (Q) di livello 4 e un grado tecnologico LTK di livello IV
# 4.8 Surgelamento
# • La cryo-tessitura energetica polarizzata richiede una licenza antimateria (e+) di
# livello I
# • Il congelamento bio-luminiscente sincronico richiede una licenza luce (c) di
# livello II e un grado tecnologico LTK di livello II
# • La cristallizzazione temporale reversiva richiede una licenza temporale (t) di
# livello III e un grado tecnologico LTK di livello III
# • La congelazione iperdimensionalmente stratificata richiede una licenza
# quantistica (Q) di livello 5 e un grado tecnologico LTK di livello IV
# • Il surgelamento antimaterico a risonanza inversa richiede una licenza
# antimateria (e+) di livello I, una licenza magnetica (Mx) di livello I, una licenza
# quantistica (Q) di livello 3 e un grado tecnologico LTK di livello III
# 4.9 Cottura
# 4.9.1 Bollitura789/12773 67° Giorno del Ciclo Cosmico 789
# • L'ebollizione magneto-cinetica pulsante richiede una licenza magnetica (Mx) di
# livello I
# • La bollitura infrasonica armonizzata richiede una licenza quantistica (Q) di livello
# 3
# • La bollitura termografica a rotazione veloce richiede una licenza luce (c) di livello
# I
# • La bollitura entropica sincronizzata richiede una licenza quantistica (Q) di livello
# 4 e un grado tecnologico LTK di livello III
# • L'idro-cristallizzazione sonora quantistica richiede una licenza quantistica (Q) di
# livello 5 e un grado tecnologico LTK di livello III
# 4.9.2 Grigliatura
# • La grigliatura a energia stellare DiV richiede una licenza luce (c) di livello III e un
# grado tecnologico LTK di livello II
# • La grigliatura plasma sintetico risonante richiede una licenza antimateria (e+) di
# livello I, una licenza magnetica (Mx) di livello I e un grado tecnologico LTK di livello
# III
# • La grigliatura eletro-molecolare a spaziatura variabile richiede una licenza
# quantistica (Q) di livello 3
# • La grigliatura tachionica refrattaria richiede una licenza temporale (t) di livello II,
# una licenza luce (c) di livello III e un grado tecnologico LTK di livello V
# • La grigliatura psionica dinamica ritmica richiede una licenza psionica (P) di livello
# III e un grado tecnologico LTK di livello III
# 4.9.3 Cottura al forno
# • La cottura al forno con paradosso temporale cronospeculare richiede una
# licenza temporale (t) di livello III, una licenza quantistica (Q) di livello 1 e un grado
# tecnologico LTK di livello III
# • La cottura con microonde entropiche sincronizzate richiede una licenza
# quantistica (Q) di livello 4
# • La cottura a forno dinamico inversionale richiede una licenza antimateria (e+) di
# livello I
# • La cottura olografica quantum fluttuante richiede una licenza quantistica (Q) di
# livello 5 e un grado tecnologico LTK di livello III
# • La cottura geomagnetica psicosincronizzata richiede una licenza psionica (P) di
# livello V, una licenza magnetica (Mx) di livello I e un grado tecnologico LTK di
# livello IV
# 4.9.4 Cottura al vapore789/12773 67° Giorno del Ciclo Cosmico 789
# • La cottura a vapore risonante simbiotico richiede una licenza psionica (P) di
# livello III e un grado tecnologico LTK di livello III
# • La cottura idrodinamica autoregolante richiede una licenza antimateria (e+) di
# livello I e un grado tecnologico LTK di livello II
# 4.9.5 Cottura sottovuoto
# • La cottura sottovuoto antimateria richiede una licenza gravitazionale (G) di livello
# I, una licenza antimateria (e+) di livello I e un grado tecnologico LTK di livello III
# • La cottura sottovuoto multirealità collassante richiede una licenza gravitazionale
# (G) di livello I, una licenza quantistica (Q) di livello 5 e un grado tecnologico LTK di
# livello VI
# • La cottura sottovuoto frugale energeticamente negativa richiede una licenza
# gravitazionale (G) di livello I, una licenza quantistica (Q) di livello 3 e un grado
# tecnologico LTK di livello II
# • La cottura sottovuoto pulsar magnetica richiede una licenza gravitazionale (G) di
# livello I, una licenza magnetica (Mx) di livello I e un grado tecnologico LTK di livello
# III
# • La cottura sottovuoto bioma sintetico richiede una licenza psionica (P) di livello
# II, una licenza gravitazionale (G) di livello I e un grado tecnologico LTK di livello III
# 4.9.6 Cottura al salto
# • Il saltare in padella Big Bang termico richiede una licenza gravitazionale (G) di
# livello III, una licenza antimateria (e+) di livello I e un grado tecnologico LTK di
# livello V
# • Il saltare in padella realtà energetiche parallele richiede una licenza quantistica
# (Q) di livello 6 e un grado tecnologico LTK di livello IV
# • Il saltare in padella singolarità inversa richiede una licenza gravitazionale (G) di
# livello III, una licenza antimateria (e+) di livello I e un grado tecnologico LTK di
# livello IV
# • Il saltare in padella sinergia psionica richiede una licenza psionica (P) di livello V
# e un grado tecnologico LTK di livello III
# 5 Sanzioni e Pene
# Il sistema sanzionatorio previsto dal presente codice riflette la complessità delle
# interazioni tra le diverse normative sulla sicurezza alimentare.
# La violazione dei limiti quantitativi stabiliti per le sostanze con risonanza psionica
# comporta l'obbligo di sottoporsi a una valutazione psionica approfondita per verificare
# eventuali contaminazioni del personale addetto alla preparazione.

# %%
def estrai_tecniche_licenze(testo: str) -> list:
    """
    Estrae le tecniche e le licenze dal testo per la sezione del PDF riguardante la marinatura.

    Args:
        testo (str): Il testo contenente le tecniche e le licenze.

    Returns:
        list: Una lista di tuple contenenti il nome della tecnica e la licenza.
    """
    # Espressione regolare per estrarre la tecnica, la licenza e il livello
    pattern = r"\s*([A-Za-z\s]+(?:[a-zA-Z\s]+))\s*richiede\s*una\s*licenza\s*([A-Za-z]+)\s*\([a-zA-Z\+\-]+\)\s*di\s*livello\s*(I{1,3}|IV|[1-9]+)"

    tecniche_licenze = re.findall(pattern, testo)

    # Processa i risultati per formattare correttamente la tecnica e la licenza
    tecniche_licenze_formattate = []
    for tecnica, licenza, livello in tecniche_licenze:
        # Rimuovi l'articolo "La" dalla tecnica
        tecnica = tecnica.strip().replace("La ", "")
        
        # Capitalizza correttamente la tecnica (ogni parola inizia con una lettera maiuscola)
        tecnica = ' '.join([parola.capitalize() for parola in tecnica.split()])

        # Crea la licenza nel formato "Licenza livello X"
        licenza_formattata = f"{licenza.capitalize()} livello {livello}"

        tecniche_licenze_formattate.append((tecnica, licenza_formattata))

    return tecniche_licenze_formattate



tecniche_licenze = estrai_tecniche_licenze(testo)

# %%
print(tecniche_licenze)
# Out:
# [('Marinatura A Infusione Gravitazionale', 'Gravitazionale livello II'), ('Marinatura Temporale Sincronizzata', 'Temporale livello I'), ('Antimateria Diluite', 'Antimateria livello I'), ('Umicatura A Stratificazione Quantica', 'Quantistica livello 3'), ('Umicatura Psionica Sensoriale', 'Psionica livello II'), ('Umicatura Polarizzata A Freddo Iperbarico', 'Magnetica livello I'), ('Fermentazione Quantica A Strati Multiversali', 'Quantistica livello 5'), ('Fermentazione Psionica Energetica', 'Psionica livello I'), ('Fermentazione Quantico Biometrica', 'Quantistica livello 3'), ('Decostruzione Atomica A Strati Energetici', 'Antimaterica livello I'), ('Decostruzione Magnetica Risonante', 'Magnetica livello I'), ('Decostruzione Ancestrale', 'Temporale livello III'), ('Decostruzione Interdimensionale Lovercraftiana', 'Quantistica livello 7'), ('Psionica Variabile', 'Psionica livello I'), ('Sferificazione Filamentare A Molecole Vibrazionali', 'Magnetica livello I'), ('Sferificazione Cromatica Interdimensionale', 'Quantistica livello 6'), ('Sferificazione Tramite Matrici Biofotiche', 'Magnetica livello I'), ('Il Taglio Dimensionale A Lame Fotofilliche', 'Quantistica livello 6'), ('Ettamento A Pulsazioni Quantistiche', 'Quantistica livello 4'), ('Il Taglio Sinaptico Biomimetico', 'Psionica livello I'), ('Incisione Elettromagnetica Plasmica', 'Antimateria livello I'), ('Impasto Gravitazionale Vorticoso', 'Gravitazionale livello I'), ('Amalgamazione Sintetica Molecolare', 'Quantistica livello 3'), ('Impasto A Campi Magnetici Dualistici', 'Magnetica livello I'), ('Osmotica Programmabile', 'Antimateria livello I'), ('Modellatura Onirica Tetrazionale', 'Psionica livello I'), ('Tessitura Energetica Polarizzata', 'Antimateria livello I'), ('Luminiscente Sincronico', 'Luce livello II'), ('Cristallizzazione Temporale Reversiva', 'Temporale livello III'), ('Congelazione Iperdimensionalmente Stratificata', 'Quantistica livello 5'), ('Il Surgelamento Antimaterico A Risonanza Inversa', 'Antimateria livello I'), ('Cinetica Pulsante', 'Magnetica livello I'), ('Bollitura Infrasonica Armonizzata', 'Quantistica livello 3'), ('Bollitura Termografica A Rotazione Veloce', 'Luce livello I'), ('Bollitura Entropica Sincronizzata', 'Quantistica livello 4'), ('Cristallizzazione Sonora Quantistica', 'Quantistica livello 5'), ('Grigliatura A Energia Stellare Div', 'Luce livello III'), ('Grigliatura Plasma Sintetico Risonante', 'Antimateria livello I'), ('Molecolare A Spaziatura Variabile', 'Quantistica livello 3'), ('Grigliatura Tachionica Refrattaria', 'Temporale livello II'), ('Grigliatura Psionica Dinamica Ritmica', 'Psionica livello III'), ('Cottura Al Forno Con Paradosso Temporale Cronospeculare', 'Temporale livello III'), ('Cottura Con Microonde Entropiche Sincronizzate', 'Quantistica livello 4'), ('Cottura A Forno Dinamico Inversionale', 'Antimateria livello I'), ('Cottura Olografica Quantum Fluttuante', 'Quantistica livello 5'), ('Cottura A Vapore Risonante Simbiotico', 'Psionica livello III'), ('Cottura Idrodinamica Autoregolante', 'Antimateria livello I'), ('Cottura Sottovuoto Antimateria', 'Gravitazionale livello I'), ('Collassante', 'Gravitazionale livello I'), ('Cottura Sottovuoto Frugale Energeticamente Negativa', 'Gravitazionale livello I'), ('Cottura Sottovuoto Pulsar Magnetica', 'Gravitazionale livello I'), ('Cottura Sottovuoto Bioma Sintetico', 'Psionica livello II'), ('Il Saltare In Padella Big Bang Termico', 'Gravitazionale livello III'), ('Energetiche Parallele', 'Quantistica livello 6'), ('Inversa', 'Gravitazionale livello III')]

# %%
def aggiungi_relazione_licenza(tx, tecnica: str, licenza: str):
    """
    Aggiunge una relazione RICHIEDE_LICENZA tra una tecnica e la licenza nel database Neo4j.

    Args:
        tx: Transazione Neo4j
        tecnica (str): Nome della tecnica
        licenza (str): Nome della licenza
    """
    query = """
    MATCH (t:Tecnica {nome: $tecnica}), (l:Licenza {nome: $licenza})
    MERGE (t)-[:RICHIEDE_LICENZA]->(l)
    """
    tx.run(query, tecnica=tecnica, licenza=licenza)

# %%
with driver.session() as session:
    for tecnica, licenza in tecniche_licenze:
        session.execute_write(aggiungi_relazione_licenza, tecnica, licenza)

# %% [markdown]
# ### CREA PIANETI

# %%
def carica_pianeti_e_distanze(file_csv: str):
    """
    Carica i pianeti come nodi e le distanze tra di loro come relazioni nel database Neo4j.
    
    Args:
        file_csv (str): Percorso del file CSV contenente le distanze tra i pianeti.
        uri (str): URI del database Neo4j.
        user (str): Nome utente per Neo4j.
        password (str): Password per Neo4j.
    """
    
    # Carica il file CSV usando pandas
    df = pd.read_csv(file_csv, index_col=0)
    
    with driver.session() as session:
        # Crea i nodi per i pianeti
        pianeti = df.columns.tolist()  # Estrae i nomi dei pianeti
        
        for pianeta in pianeti:
            # Crea un nodo per ciascun pianeta
            query = "MERGE (p:Pianeta {nome: $nome})"
            session.run(query, nome=pianeta)
        
        # Crea le relazioni DISTANZA tra i pianeti
        for i, pianeta1 in enumerate(pianeti):
            for j, pianeta2 in enumerate(pianeti):
                if i < j:  # Evita di creare relazioni duplicate (ad esempio tra Tatooine e Asgard e viceversa)
                    distanza = df.at[pianeta1, pianeta2]
                    # Crea una relazione con la distanza tra i pianeti
                    query = """
                    MATCH (p1:Pianeta {nome: $pianeta1}), (p2:Pianeta {nome: $pianeta2})
                    MERGE (p1)-[:DISTANZA {km: $distanza}]->(p2)
                    """
                    session.run(query, pianeta1=pianeta1, pianeta2=pianeta2, distanza=distanza)
        
        print("Pianeti e distanze caricate correttamente in Neo4j.")

# Esegui il codice passando il percorso del file CSV e le credenziali di Neo4j
file_csv = '../Hackapizza Dataset/Misc/Distanze.csv'  # Percorso al tuo file CSV

carica_pianeti_e_distanze(file_csv)
# Out:
# <>:39: SyntaxWarning: invalid escape sequence '\M'
# <>:39: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\lparigi\AppData\Local\Temp\ipykernel_29264\567156097.py:39: SyntaxWarning: invalid escape sequence '\M'
#   file_csv = '../Hackapizza Dataset\Misc\Distanze.csv'  # Percorso al tuo file CSV
# Pianeti e distanze caricate correttamente in Neo4j.

# %%
def carica_piatti(file_json: str):
    """
    Carica i piatti e i numeri associati come nodi nel database Neo4j.
    
    Args:
        file_json (str): Percorso del file JSON contenente i piatti e i numeri.
        uri (str): URI del database Neo4j.
        user (str): Nome utente per Neo4j.
        password (str): Password per Neo4j.
    """
    
    # Carica il file JSON
    with open(file_json, 'r', encoding='utf-8') as f:
        piatti_data = json.load(f)
    
    with driver.session() as session:
        for piatto, numero in piatti_data.items():
            # Decodifica i caratteri speciali (ad esempio per trattare le sequenze \u00e0)
            piatto_decodificato = html.unescape(piatto)
            
            # Crea un nodo per ciascun piatto
            query = """
            MERGE (p:Piatto {nome: $nome})
            SET p.numero = $numero
            """
            session.run(query, nome=piatto_decodificato, numero=numero)
        
        print("Piatti caricati correttamente in Neo4j.")

# Esegui il codice passando il percorso del file JSON e le credenziali di Neo4j
file_json = '../Hackapizza Dataset/Misc/dish_mapping.json'  # Percorso al tuo file JSON

carica_piatti(file_json)
# Out:
# Piatti caricati correttamente in Neo4j.
