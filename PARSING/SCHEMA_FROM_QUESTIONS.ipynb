# %%
import pdfplumber
import re
import json
import os
import PyPDF2


from dotenv import load_dotenv
from neo4j import GraphDatabase
from py2neo import Graph, Node, Relationship
from langchain_openai import AzureChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from typing import List, Dict, Tuple

# %%
load_dotenv()
# Recupera endpoint e chiave dalle variabili d'ambiente
api_base = os.getenv("AZURE_OPENAI_API_BASE")
api_key = os.getenv("AZURE_OPENAI_API_KEY")

# neo4j first instance parameters
NEO4J_URI= "neo4j+s://0482640f.databases.neo4j.io"
NEO4J_USERNAME= "neo4j"
NEO4J_PASSWORD= "PNvdaZlk326-ja2hRD1K97ZUUMnD4mj0NsecZNu5-9k"
AURA_INSTANCEID= "0482640f"
AURA_INSTANCENAME= "Instance01"

driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %%
def crea_llm(api_key: str, api_base: str) -> AzureChatOpenAI:
    """
    Crea un'istanza del modello linguistico Azure OpenAI.
    
    Args:
        api_key (str): La chiave API di Azure
        api_base (str): L'URL base dell'API Azure
        
    Returns:
        AzureChatOpenAI: Istanza configurata del modello
    """
    return AzureChatOpenAI(
        openai_api_version="2024-08-01-preview",
        azure_deployment="o1-mini",
        azure_endpoint=api_base,
        api_key=api_key,
        temperature=1
    )

llm = crea_llm(api_key, api_base)

# %%
import csv
import json
import re
from typing import Dict, Set, Tuple

def estrai_schema_da_domanda(llm: AzureChatOpenAI, domanda: str) -> Dict:
    """
    Analizza una domanda utilizzando il modello LLM per estrarre entità e relazioni.
    """
    prompt = f"""
    Analizza la seguente domanda e determina:
    - Le entità principali (es. Piatto, Ristorante, Pianeta, Tecnica)
    - Le relazioni tra di esse (es. Piatto PREPARATO_CON Tecnica, Ristorante SERVE Piatto)
    
    Domanda: "{domanda}"
    
    Rispondi in JSON nel formato:
    {{
        "entità": ["..."],
        "relazioni": [{{"soggetto": "...", "relazione": "...", "oggetto": "..."}}]
    }}
    """

    response = llm.predict(prompt)

    # Debugging: Stampiamo la risposta grezza del modello
    print(f"DEBUG - Risposta LLM per la domanda:\n{domanda}\n{response}\n")

    # Se la risposta è vuota
    if not response or response.strip() == "":
        print("⚠️ ERRORE: Risposta vuota dal modello!")
        return {"entità": [], "relazioni": []}

    # 1. Rimuove blocchi Markdown tipo ```json ... ```
    match = re.search(r"```json\s*(.*?)\s*```", response, re.DOTALL)
    if match:
        response = match.group(1).strip()

    # 2. Rimuove caratteri speciali residui che potrebbero disturbare il parsing
    response = response.replace("\n", "").replace("\t", "").strip()

    # 3. Prova a decodificare il JSON
    try:
        return json.loads(response)
    except json.JSONDecodeError as e:
        print(f"⚠️ ERRORE: Il modello ha restituito un JSON non valido. Errore: {e}")

        # Se fallisce, proviamo a correggerlo rimuovendo caratteri extra
        try:
            response = re.sub(r"[^\x20-\x7E]+", "", response)  # Rimuove caratteri non ASCII
            return json.loads(response)
        except json.JSONDecodeError:
            print("⚠️ ERRORE: Correzione fallita. Scartiamo questa risposta.")
            return {"entità": [], "relazioni": []}

def genera_schema_grafo(csv_path: str, llm: AzureChatOpenAI) -> Dict:
    """
    Legge un file CSV di domande, analizza le entità e relazioni per generare uno schema di grafo.
    """
    schema = {"entità": set(), "relazioni": set()}

    with open(csv_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            domanda = row[0]
            risultato_json = estrai_schema_da_domanda(llm, domanda)
            
            schema["entità"].update(risultato_json["entità"])
            for relazione in risultato_json["relazioni"]:
                schema["relazioni"].add((relazione["soggetto"], relazione["relazione"], relazione["oggetto"]))

    return schema

# Esempio di utilizzo
csv_file = "C:/Users/lparigi/Downloads/letspizza/Hackapizza Dataset/domande.csv"
schema_grafo = genera_schema_grafo(csv_file, llm)

# Stampa dello schema estratto
print("Entità identificate:")
print(schema_grafo["entità"])

print("\nRelazioni identificate:")
for r in schema_grafo["relazioni"]:
    print(f"{r[0]} -[{r[1]}]-> {r[2]}")
# Out:
# DEBUG - Risposta LLM per la domanda:
# domanda
# Sembra che tu non abbia fornito una domanda specifica da analizzare. Per favore, inserisci la domanda che desideri analizzare.
#
# ⚠️ ERRORE: Il modello ha restituito un JSON non valido. Errore: Expecting value: line 1 column 1 (char 0)
# ⚠️ ERRORE: Correzione fallita. Scartiamo questa risposta.
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti che includono le Chocobo Wings come ingrediente?
# ```json
# {
#     "entità": ["Piatti", "Chocobo Wings"],
#     "relazioni": [
#         {
#             "soggetto": "Piatti",
#             "relazione": "INCLUDONO",
#             "oggetto": "Chocobo Wings"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti dovrei scegliere per un banchetto a tema magico che includa le celebri Cioccorane?
# ```json
# {
#     "entità": ["Piatto", "Banchetto", "Tema Magico", "Cioccorane"],
#     "relazioni": [
#         {"soggetto": "Piatto", "relazione": "SCEGLIERE_PER", "oggetto": "Banchetto"},
#         {"soggetto": "Banchetto", "relazione": "HA_TEMA", "oggetto": "Tema Magico"},
#         {"soggetto": "Banchetto", "relazione": "INCLUDERE", "oggetto": "Cioccorane"}
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti della galassia che contengono Latte+?
# ```json
# {
#     "entità": ["Piatto", "Galassia", "Latte+"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "appartiene a",
#             "oggetto": "Galassia"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "contiene",
#             "oggetto": "Latte+"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti contengono i Ravioli al Vaporeon?
# ```json
# {
#     "entità": ["Piatto", "Ravioli al Vaporeon"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "CONTIENE",
#             "oggetto": "Ravioli al Vaporeon"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti che includono i Sashimi di Magikarp?
# ```json
# {
#     "entità": ["Piatto", "Sashimi di Magikarp"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "INCLUDE",
#             "oggetto": "Sashimi di Magikarp"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono accompagnati dai misteriosi Frutti del Diavolo, che donano poteri speciali a chi li consuma?
# ```json
# {
#     "entità": ["Piatto", "Frutti del Diavolo", "Poteri Speciali"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "ACCOMPAGNA",
#             "oggetto": "Frutti del Diavolo"
#         },
#         {
#             "soggetto": "Frutti del Diavolo",
#             "relazione": "DONANO",
#             "oggetto": "Poteri Speciali"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti preparati con la tecnica Grigliatura a Energia Stellare DiV?
# ```json
# {
#     "entità": ["Piatto", "Tecnica"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Grigliatura a Energia Stellare DiV"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono preparati utilizzando la tecnica della Sferificazione a Gravità Psionica Variabile?
# ```json
# {
#     "entità": ["Piatto", "Tecnica"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Tecnica"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono preparati sia con la Marinatura Temporale Sincronizzata che con il Congelamento Bio-Luminiscente Sincronico?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Marinatura Temporale Sincronizzata",
#         "Congelamento Bio-Luminiscente Sincronico"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Marinatura Temporale Sincronizzata"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Congelamento Bio-Luminiscente Sincronico"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti eterei sono preparati usando sia la Cottura Olografica Quantum Fluttuante che la Decostruzione Interdimensionale Lovecraftiana?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Cottura Olografica Quantum Fluttuante",
#         "Decostruzione Interdimensionale Lovecraftiana"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_USANDO",
#             "oggetto": "Cottura Olografica Quantum Fluttuante"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_USANDO",
#             "oggetto": "Decostruzione Interdimensionale Lovecraftiana"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti che combinano la saggezza del Riso di Cassandra e l'intrigante tocco della Polvere di Crononite?
# ```json
# {
#     "entità": ["Piatto", "Riso di Cassandra", "Polvere di Crononite"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "COMBINA",
#             "oggetto": "Riso di Cassandra"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "COMBINA",
#             "oggetto": "Polvere di Crononite"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti che riescono a fondere la misteriosa Shard di Prisma Stellare con l'intrigante Sale Temporale, creando un'esperienza culinaria al di là del tempo e dello spazio?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Shard di Prisma Stellare",
#         "Sale Temporale",
#         "Esperienza culinaria",
#         "Tempo",
#         "Spazio"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "FONDE",
#             "oggetto": "Shard di Prisma Stellare"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "FONDE",
#             "oggetto": "Sale Temporale"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "CREA",
#             "oggetto": "Esperienza culinaria"
#         },
#         {
#             "soggetto": "Esperienza culinaria",
#             "relazione": "È al di là di",
#             "oggetto": "Tempo"
#         },
#         {
#             "soggetto": "Esperienza culinaria",
#             "relazione": "È al di là di",
#             "oggetto": "Spazio"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti nel nostro repertorio includono le misteriose Teste di Idra e utilizzano la leggendaria tecnica di Cottura Sottovuoto Multirealità Collassante nella loro preparazione?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Teste di Idra",
#         "Tecnica di Cottura Sottovuoto Multirealità Collassante"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "INCLUDE",
#             "oggetto": "Teste di Idra"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Tecnica di Cottura Sottovuoto Multirealità Collassante"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti preparati con la Fermentazione Quantico Biometrica includono Erba Pipa tra gli ingredienti?
# ```json
# {
#     "entità": ["Piatto", "Fermentazione Quantico Biometrica", "Erba Pipa"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Fermentazione Quantico Biometrica"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "INCLUDE",
#             "oggetto": "Erba Pipa"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti prepari utilizzando esclusivamente la Sferificazione Filamentare a Molecole Vibrazionali e evitando completamente l'Amalgamazione Sintetica Molecolare?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Sferificazione Filamentare a Molecole Vibrazionali",
#         "Amalgamazione Sintetica Molecolare"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Sferificazione Filamentare a Molecole Vibrazionali"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "EVITA",
#             "oggetto": "Amalgamazione Sintetica Molecolare"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti usano la Sferificazione Filamentare a Molecole Vibrazionali, ma evitano la Decostruzione Magnetica Risonante?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Sferificazione Filamentare",
#         "Molecole Vibrazionali",
#         "Decostruzione Magnetica Risonante"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "usa",
#             "oggetto": "Sferificazione Filamentare a Molecole Vibrazionali"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "evita",
#             "oggetto": "Decostruzione Magnetica Risonante"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti della nostra collezione sono creati utilizzando la tecnica di Sferificazione con Campi Magnetici Entropici e non contengono Spezie Melange?
# ```json
# {
#     "entità": [
#         "Piatti",
#         "Collezione",
#         "Tecnica di Sferificazione con Campi Magnetici Entropici",
#         "Spezie Melange"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatti",
#             "relazione": "appartengono_a",
#             "oggetto": "Collezione"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "sono_creati_utilizzando",
#             "oggetto": "Tecnica di Sferificazione con Campi Magnetici Entropici"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "non_contengono",
#             "oggetto": "Spezie Melange"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono preparati usando la tecnica Surgelamento Antimaterico a Risonanza Inversa senza impiegare Foglie di Mandragora?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Tecnica Surgelamento Antimaterico a Risonanza Inversa",
#         "Foglie di Mandragora"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_USANDO",
#             "oggetto": "Tecnica Surgelamento Antimaterico a Risonanza Inversa"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "NON_IMPIEGA",
#             "oggetto": "Foglie di Mandragora"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti leggendari dell'universo utilizzano Foglie di Nebulosa, Amido di Stellarion e Uova di Fenice nella loro preparazione?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Foglie di Nebulosa",
#         "Amido di Stellarion",
#         "Uova di Fenice"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Foglie di Nebulosa"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Amido di Stellarion"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Uova di Fenice"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti della galassia posso preparare che combinano la Carne di Balena spaziale, l'Essenza di Tachioni e le Alghe Bioluminescenti?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Galassia",
#         "Carne di Balena spaziale",
#         "Essenza di Tachioni",
#         "Alghe Bioluminescenti"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "DELLE_DI",
#             "oggetto": "Galassia"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "COMBINA",
#             "oggetto": "Carne di Balena spaziale"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "COMBINA",
#             "oggetto": "Essenza di Tachioni"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "COMBINA",
#             "oggetto": "Alghe Bioluminescenti"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti nel nostro universo galattico includono Erba Pipa, Funghi Orbitali e sono preparati con la Bollitura Infrasonica Armonizzata?
# ```json
# {
#     "entità": ["Piatto", "Ingrediente", "Tecnica"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "INCLUDE",
#             "oggetto": "Erba Pipa"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "INCLUDE",
#             "oggetto": "Funghi Orbitali"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Bollitura Infrasonica Armonizzata"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti del vostro pianeta utilizzano la Cottura a Vapore con Flusso di Particelle Isoarmoniche, combinando Riso di Cassandra e Foglie di Nebulosa?
# ```json
# {
#     "entità": [
#         "Piatti",
#         "Pianeta",
#         "Cottura a Vapore con Flusso di Particelle Isoarmoniche",
#         "Riso di Cassandra",
#         "Foglie di Nebulosa"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatti",
#             "relazione": "appartiene_a",
#             "oggetto": "Pianeta"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "utilizza",
#             "oggetto": "Cottura a Vapore con Flusso di Particelle Isoarmoniche"
#         },
#         {
#             "soggetto": "Cottura a Vapore con Flusso di Particelle Isoarmoniche",
#             "relazione": "combina",
#             "oggetto": "Riso di Cassandra"
#         },
#         {
#             "soggetto": "Cottura a Vapore con Flusso di Particelle Isoarmoniche",
#             "relazione": "combina",
#             "oggetto": "Foglie di Nebulosa"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti che combinano la Carne di Balena spaziale con la Bollitura Entropica Sincronizzata e l'Affettamento a Pulsazioni Quantistiche?
# ```json
# {
#     "entità": [
#         "Piatti",
#         "Carne di Balena Spaziale",
#         "Bollitura Entropica Sincronizzata",
#         "Affettamento a Pulsazioni Quantistiche"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatti",
#             "relazione": "COMBINA",
#             "oggetto": "Carne di Balena Spaziale"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "UTILIZZA_TECNICA",
#             "oggetto": "Bollitura Entropica Sincronizzata"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "UTILIZZA_TECNICA",
#             "oggetto": "Affettamento a Pulsazioni Quantistiche"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti, nella nostra tradizione culinaria magica, richiedono l'uso delle Lacrime di Unicorno e sono preparati sia con la tecnica del Taglio Sinaptico Biomimetico che con l'Idro-Cristallizzazione Sonora Quantistica?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Lacrime di Unicorno",
#         "Taglio Sinaptico Biomimetico",
#         "Idro-Cristallizzazione Sonora Quantistica"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "RICHIEDE",
#             "oggetto": "Lacrime di Unicorno"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Taglio Sinaptico Biomimetico"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Idro-Cristallizzazione Sonora Quantistica"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti utilizzano sia la Cottura a Vapore Risonante Simbiotico che la doppia Fermentazione Quantico Biometrica nella loro preparazione?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Cottura a Vapore Risonante Simbiotico",
#         "doppia Fermentazione Quantico Biometrica"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Cottura a Vapore Risonante Simbiotico"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "doppia Fermentazione Quantico Biometrica"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti deliziosi utilizzano sia la tecnica di Taglio a Risonanza Sonica Rigenerativa sia la doppia applicazione della Cottura a Vapore Ecodinamico Bilanciato nella loro preparazione?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Tecnica di Taglio a Risonanza Sonica Rigenerativa",
#         "Cottura a Vapore Ecodinamico Bilanciato"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Tecnica di Taglio a Risonanza Sonica Rigenerativa"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Cottura a Vapore Ecodinamico Bilanciato"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti includono Lattuga Namecciana e Carne di Mucca ma non contengono Teste di Idra?
# ```json
# {
#     "entità": ["Piatto", "Lattuga Namecciana", "Carne di Mucca", "Teste di Idra"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "includono",
#             "oggetto": "Lattuga Namecciana"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "includono",
#             "oggetto": "Carne di Mucca"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "non contengono",
#             "oggetto": "Teste di Idra"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti includono Essenza di Tachioni e Carne di Mucca, ma non utilizzano Muffa Lunare?
# ```json
# {
#     "entità": ["Piatto", "Essenza di Tachioni", "Carne di Mucca", "Muffa Lunare"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "include",
#             "oggetto": "Essenza di Tachioni"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "include",
#             "oggetto": "Carne di Mucca"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "esclude",
#             "oggetto": "Muffa Lunare"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti strepitosi si possono preparare che utilizzano Funghi Orbitali e la raffinata tecnica della Marinatura Psionica, senza impiegare Shard di Materia Oscura?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Funghi Orbitali",
#         "Marinatura Psionica",
#         "Shard di Materia Oscura"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Funghi Orbitali"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Marinatura Psionica"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "NON_UTILIZZA",
#             "oggetto": "Shard di Materia Oscura"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti, escludendo quelli che usano il Plasma Vitale, includono i Funghi dell’Etere e utilizzano la tecnica dell'Impasto Gravitazionale Vorticoso nella loro preparazione?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Plasma Vitale",
#         "Funghi dell’Etere",
#         "Tecnica dell'Impasto Gravitazionale Vorticoso"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "ESCLUDE_USA",
#             "oggetto": "Plasma Vitale"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "INCLUDE",
#             "oggetto": "Funghi dell’Etere"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Tecnica dell'Impasto Gravitazionale Vorticoso"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti che combinano Funghi dell’Etere e Erba Pipa senza utilizzare la tecnica della Decostruzione Magnetica Risonante nella loro preparazione?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Funghi dell’Etere",
#         "Erba Pipa",
#         "Tecnica della Decostruzione Magnetica Risonante"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "COMBINA",
#             "oggetto": "Funghi dell’Etere"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "COMBINA",
#             "oggetto": "Erba Pipa"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "NON_UTILIZZA",
#             "oggetto": "Tecnica della Decostruzione Magnetica Risonante"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono quei piatti che combinano la deliziosa Salsa Szechuan con i mistici Granuli di Nebbia Arcobaleno, evitando però di utilizzare la tecnica di Affumicatura a Stratificazione Quantica?
# ```json
# {
#     "entità": [
#         "Piatti",
#         "Salsa Szechuan",
#         "Granuli di Nebbia Arcobaleno",
#         "Tecnica di Affumicatura a Stratificazione Quantica"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatti",
#             "relazione": "combina",
#             "oggetto": "Salsa Szechuan"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "combina",
#             "oggetto": "Granuli di Nebbia Arcobaleno"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "evita di utilizzare",
#             "oggetto": "Tecnica di Affumicatura a Stratificazione Quantica"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti, preparati senza usare Funghi Orbitali, sfruttano sia l’Affumicatura tramite Big Bang Microcosmico sia l’Affettamento a Pulsazioni Quantistiche?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Funghi Orbitali",
#         "Affumicatura tramite Big Bang Microcosmico",
#         "Affettamento a Pulsazioni Quantistiche"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_SENZA",
#             "oggetto": "Funghi Orbitali"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "SFRUTTA",
#             "oggetto": "Affumicatura tramite Big Bang Microcosmico"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "SFRUTTA",
#             "oggetto": "Affettamento a Pulsazioni Quantistiche"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono preparati usando sia l'Incisione Elettromagnetica Plasmica che la Bollitura Entropica Sincronizzata, ma non utilizzano Cristalli di Memoria?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Incisione Elettromagnetica Plasmica",
#         "Bollitura Entropica Sincronizzata",
#         "Cristalli di Memoria"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Incisione Elettromagnetica Plasmica"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Bollitura Entropica Sincronizzata"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "NON_UTILIZZA",
#             "oggetto": "Cristalli di Memoria"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti utilizzano la Polvere di Crononite e la tecnica di Incisione Elettromagnetica Plasmica, ma non impiegano la Decostruzione Atomica a Strati Energetici nella loro preparazione?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Polvere di Crononite",
#         "Tecnica di Incisione Elettromagnetica Plasmica",
#         "Decostruzione Atomica a Strati Energetici"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Polvere di Crononite"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Tecnica di Incisione Elettromagnetica Plasmica"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "NON_IMPIEGA",
#             "oggetto": "Decostruzione Atomica a Strati Energetici"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti utilizzano le Alghe Bioluminescenti e la tecnica di Idro-Cristallizzazione Sonora Quantistica, ma evitano la Marinatura Temporale Sincronizzata?
# ```json
# {
#     "entità": [
#         "Piatti",
#         "Alghe Bioluminescenti",
#         "Tecnica di Idro-Cristallizzazione Sonora Quantistica",
#         "Marinatura Temporale Sincronizzata"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatti",
#             "relazione": "UTILIZZANO",
#             "oggetto": "Alghe Bioluminescenti"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "UTILIZZANO",
#             "oggetto": "Tecnica di Idro-Cristallizzazione Sonora Quantistica"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "EVITANO",
#             "oggetto": "Marinatura Temporale Sincronizzata"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono preparati senza usare la Cottura a Vapore Termocinetica Multipla, ma utilizzano la Congelazione Iperdimensionalmente Stratificata e la Fermentazione Quantico Biometrica?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Cottura a Vapore Termocinetica Multipla",
#         "Congelazione Iperdimensionalmente Stratificata",
#         "Fermentazione Quantico Biometrica"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_SENZA",
#             "oggetto": "Cottura a Vapore Termocinetica Multipla"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Congelazione Iperdimensionalmente Stratificata"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Fermentazione Quantico Biometrica"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti che non impiegano la Fermentazione Quantico Biometrica, ma utilizzano sia l'Affumicatura tramite Big Bang Microcosmico sia la Cottura Sottovuoto Frugale Energeticamente Negativa?
# ```json
# {
#     "entità": [
#         "Piatti",
#         "Fermentazione Quantico Biometrica",
#         "Affumicatura tramite Big Bang Microcosmico",
#         "Cottura Sottovuoto Frugale Energeticamente Negativa"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatti",
#             "relazione": "NON_IMPIEGANO",
#             "oggetto": "Fermentazione Quantico Biometrica"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "UTILIZZANO",
#             "oggetto": "Affumicatura tramite Big Bang Microcosmico"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "UTILIZZANO",
#             "oggetto": "Cottura Sottovuoto Frugale Energeticamente Negativa"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti escludono l'uso di Cristalli di Nebulite e Funghi dell’Etere, ma vengono preparati utilizzando la Marinatura tramite Reazioni d'Antimateria Diluite?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Cristalli di Nebulite",
#         "Funghi dell’Etere",
#         "Marinatura tramite Reazioni d'Antimateria Diluite"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "ESCLUDE_USO_DI",
#             "oggetto": "Cristalli di Nebulite"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "ESCLUDE_USO_DI",
#             "oggetto": "Funghi dell’Etere"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_USANDO",
#             "oggetto": "Marinatura tramite Reazioni d'Antimateria Diluite"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti vengono preparati utilizzando la Congelazione Iperdimensionalmente Stratificata, escludendo quelli che contengono Fibra di Sintetex o Funghi Orbitali?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Congelazione Iperdimensionalmente Stratificata",
#         "Fibra di Sintetex",
#         "Funghi Orbitali"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Congelazione Iperdimensionalmente Stratificata"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "CONTENERE",
#             "oggetto": "Fibra di Sintetex"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "CONTENERE",
#             "oggetto": "Funghi Orbitali"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono preparati utilizzando la tecnica di Grigliatura Psionica Dinamica Ritmica, escludendo quelli che fanno uso del Pane degli Abissi o della Cottura Olografica Quantum Fluttuante?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Tecnica di Grigliatura Psionica Dinamica Ritmica",
#         "Pane degli Abissi",
#         "Cottura Olografica Quantum Fluttuante"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Tecnica di Grigliatura Psionica Dinamica Ritmica"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "NON_UTILIZZA",
#             "oggetto": "Pane degli Abissi"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "NON_UTILIZZA",
#             "oggetto": "Cottura Olografica Quantum Fluttuante"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono preparati con la tecnica del Taglio Sinaptico Biomimetico, senza l'uso della Lattuga Namecciana e non coinvolgendo la Cottura Sottovuoto Bioma Sintetico?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Taglio Sinaptico Biomimetico",
#         "Lattuga Namecciana",
#         "Cottura Sottovuoto Bioma Sintetico"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Taglio Sinaptico Biomimetico"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "NON_USA",
#             "oggetto": "Lattuga Namecciana"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "NON_COINVOLGE",
#             "oggetto": "Cottura Sottovuoto Bioma Sintetico"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti vengono preparati attraverso la Decostruzione Ancestrale senza l'uso della Cottura a Vapore Termocinetica Multipla o della Marinatura a Infusione Gravitazionale?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Decostruzione Ancestrale",
#         "Cottura a Vapore Termocinetica Multipla",
#         "Marinatura a Infusione Gravitazionale"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Decostruzione Ancestrale"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "NON_USA",
#             "oggetto": "Cottura a Vapore Termocinetica Multipla"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "NON_USA",
#             "oggetto": "Marinatura a Infusione Gravitazionale"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti nella galassia sono preparati esclusivamente con la tecnica di Affumicatura Polarizzata a Freddo Iperbarico, evitando del tutto Fermentazione Psionica Energetica e Congelamento Bio-Luminiscente Sincronico?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Galassia",
#         "Tecnica di Affumicatura Polarizzata a Freddo Iperbarico",
#         "Fermentazione Psionica Energetica",
#         "Congelamento Bio-Luminiscente Sincronico"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Tecnica di Affumicatura Polarizzata a Freddo Iperbarico"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "EVITA",
#             "oggetto": "Fermentazione Psionica Energetica"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "EVITA",
#             "oggetto": "Congelamento Bio-Luminiscente Sincronico"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti che combinano Carne di Balena spaziale, Teste di Idra, Spaghi del Sole e Carne di Xenodonte nella loro preparazione?
# ```json
# {
#     "entità": [
#         "Piatti",
#         "Carne di Balena spaziale",
#         "Teste di Idra",
#         "Spaghi del Sole",
#         "Carne di Xenodonte"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatti",
#             "relazione": "COMBINA",
#             "oggetto": "Carne di Balena spaziale"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "COMBINA",
#             "oggetto": "Teste di Idra"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "COMBINA",
#             "oggetto": "Spaghi del Sole"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "COMBINA",
#             "oggetto": "Carne di Xenodonte"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti che utilizzano Cristalli di Memoria, Essenza di Tachioni e Carne di Kraken nelle loro ricette?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Cristalli di Memoria",
#         "Essenza di Tachioni",
#         "Carne di Kraken"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Cristalli di Memoria"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Essenza di Tachioni"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Carne di Kraken"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono preparati utilizzando il Vero Ghiaccio e le tecniche di Cottura Sottovuoto Frugale Energeticamente Negativa e Cottura Sottovuoto Bioma Sintetico?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Vero Ghiaccio",
#         "Cottura Sottovuoto Frugale Energeticamente Negativa",
#         "Cottura Sottovuoto Bioma Sintetico"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_UTILIZZANDO",
#             "oggetto": "Vero Ghiaccio"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_UTILIZZANDO",
#             "oggetto": "Cottura Sottovuoto Frugale Energeticamente Negativa"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_UTILIZZANDO",
#             "oggetto": "Cottura Sottovuoto Bioma Sintetico"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti combinano la potenza dello Shard di Materia Oscura con le misteriose Uova di Fenice, utilizzando sia l'Affumicatura Polarizzata a Freddo Iperbarico che la Cottura a Vapore Ecodinamico Bilanciato?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Shard di Materia Oscura",
#         "Uova di Fenice",
#         "Affumicatura Polarizzata a Freddo Iperbarico",
#         "Cottura a Vapore Ecodinamico Bilanciato"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "COMBINA_CON",
#             "oggetto": "Shard di Materia Oscura"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "COMBINA_CON",
#             "oggetto": "Uova di Fenice"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Affumicatura Polarizzata a Freddo Iperbarico"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Cottura a Vapore Ecodinamico Bilanciato"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono preparati nel ristorante di Asgard utilizzando Essenza di Speziaria?
# ```json
# {
#     "entità": ["Piatto", "Ristorante di Asgard", "Essenza di Speziaria"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_NEL",
#             "oggetto": "Ristorante di Asgard"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Essenza di Speziaria"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti preparati in un ristorante su Asgard che utilizzano il misterioso Pane di Luce?
# ```json
# {
#     "entità": ["Piatti", "Ristorante", "Asgard", "Pane di Luce"],
#     "relazioni": [
#         {
#             "soggetto": "Piatti",
#             "relazione": "PREPARATO_IN",
#             "oggetto": "Ristorante"
#         },
#         {
#             "soggetto": "Ristorante",
#             "relazione": "SI_TROVA_SU",
#             "oggetto": "Asgard"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "UTILIZZA",
#             "oggetto": "Pane di Luce"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti deliziosi possiamo gustare su Krypton che sfruttano la rivoluzionaria Cryo-Tessitura Energetica Polarizzata?
# ```json
# {
#     "entità": ["Piatto", "Krypton", "Cryo-Tessitura Energetica Polarizzata"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Cryo-Tessitura Energetica Polarizzata"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "SERVITO_SU",
#             "oggetto": "Krypton"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti preparati su Krypton usando la Cottura Sottovuoto Bioma Sintetico?
# ```json
# {
#     "entità": ["Piatto", "Pianeta", "Tecnica"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_SU",
#             "oggetto": "Pianeta"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Tecnica"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti del ristorante L'Etere del Gusto sono preparati usando la tecnica Decostruzione Atomica a Strati Energetici?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Ristorante L'Etere del Gusto",
#         "Tecnica Decostruzione Atomica a Strati Energetici"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Ristorante L'Etere del Gusto",
#             "relazione": "SERVE",
#             "oggetto": "Piatto"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_USANDO",
#             "oggetto": "Tecnica Decostruzione Atomica a Strati Energetici"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono preparati al ristorante Stelle dell'Infinito Celestiale usando la tecnica del Congelamento Bio-Luminiscente Sincronico?
# ```json
# {
#     "entità": ["Piatto", "Ristorante", "Tecnica"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_USANDO",
#             "oggetto": "Tecnica"
#         },
#         {
#             "soggetto": "Ristorante",
#             "relazione": "PREPARA",
#             "oggetto": "Piatto"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti preparati al ristorante L'Universo in Cucina contengono i pregiati Funghi Orbitali?
# ```json
# {
#     "entità": ["Piatto", "Ristorante", "Funghi Orbitali"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_AL",
#             "oggetto": "Ristorante L'Universo in Cucina"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "CONTIENE",
#             "oggetto": "Funghi Orbitali"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti preparati al ristorante L'Oasi delle Dune Stellari che utilizzano la Lattuga Namecciana?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Ristorante",
#         "L'Oasi delle Dune Stellari",
#         "Lattuga Namecciana"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Ristorante",
#             "relazione": "PREPARA",
#             "oggetto": "Piatto"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Lattuga Namecciana"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti preparati da chef con licenza LTK di grado 7 o superiore che utilizzano le Spezie Melange come ingrediente?
# ```json
# {
#     "entità": ["Piatto", "Chef", "Licenza LTK", "Spezie Melange"],
#     "relazioni": [
#         {
#             "soggetto": "Chef",
#             "relazione": "PREPARA",
#             "oggetto": "Piatto"
#         },
#         {
#             "soggetto": "Chef",
#             "relazione": "POSSEDE",
#             "oggetto": "Licenza LTK"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Spezie Melange"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali deliziosi piatti possiamo gustare creati da uno chef con la prestigiosa licenza Q di grado 15 che includono la speziata Nduja Fritta Tanto?
# ```json
# {
#     "entità": [
#         "piatto",
#         "chef",
#         "licenza Q di grado 15",
#         "Nduja Fritta Tanto"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "piatto",
#             "relazione": "CREATO_DA",
#             "oggetto": "chef"
#         },
#         {
#             "soggetto": "chef",
#             "relazione": "POSSEDE",
#             "oggetto": "licenza Q di grado 15"
#         },
#         {
#             "soggetto": "piatto",
#             "relazione": "INCLUDE",
#             "oggetto": "Nduja Fritta Tanto"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti creati da chef con licenza t di grado 2 che utilizzano la Cottura Idrodinamica Autoregolante?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Chef",
#         "Licenza T di Grado 2",
#         "Cottura Idrodinamica Autoregolante"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Chef",
#             "relazione": "CREA",
#             "oggetto": "Piatto"
#         },
#         {
#             "soggetto": "Chef",
#             "relazione": "POSSEDE",
#             "oggetto": "Licenza T di Grado 2"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Cottura Idrodinamica Autoregolante"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono stati creati dallo chef con almeno una licenza Luce di grado 3 utilizzando la tecnica della Cottura Sottovuoto Multirealità Collassante?
# ```json
# {
#     "entità": [
#         "Piatti",
#         "Chef",
#         "Licenza Luce di grado 3",
#         "Tecnica Cottura Sottovuoto Multirealità Collassante"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Chef",
#             "relazione": "POSSEDE",
#             "oggetto": "Licenza Luce di grado 3"
#         },
#         {
#             "soggetto": "Chef",
#             "relazione": "CREA",
#             "oggetto": "Piatti"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "UTILIZZANO",
#             "oggetto": "Tecnica Cottura Sottovuoto Multirealità Collassante"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti preparati al ristorante L'Essenza dell'Infinito utilizzano Fibra di Sintetex o Essenza di Vuoto?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Ristorante",
#         "L'Essenza dell'Infinito",
#         "Fibra di Sintetex",
#         "Essenza di Vuoto"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "L'Essenza dell'Infinito",
#             "relazione": "SERVE",
#             "oggetto": "Piatto"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Fibra di Sintetex"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Essenza di Vuoto"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti del ristorante Le Dimensioni del Gusto sono preparati con Petali di Eco o Uova di Fenice?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Ristorante Le Dimensioni del Gusto",
#         "Petali di Eco",
#         "Uova di Fenice"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Ristorante Le Dimensioni del Gusto",
#             "relazione": "serve",
#             "oggetto": "Piatto"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "preparato_con",
#             "oggetto": "Petali di Eco"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "preparato_con",
#             "oggetto": "Uova di Fenice"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti serviti al ristorante L'Universo in Cucina che utilizzano Frammenti di Supernova o la tecnica di Fermentazione Psionica Energetica?
# ```json
# {
#     "entità": [
#         "Piatti",
#         "Ristorante L'Universo in Cucina",
#         "Frammenti di Supernova",
#         "Tecnica di Fermentazione Psionica Energetica"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Ristorante L'Universo in Cucina",
#             "relazione": "SERVE",
#             "oggetto": "Piatti"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "UTILIZZANO",
#             "oggetto": "Frammenti di Supernova"
#         },
#         {
#             "soggetto": "Piatti",
#             "relazione": "UTILIZZANO",
#             "oggetto": "Tecnica di Fermentazione Psionica Energetica"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti del ristorante Cosmica Essenza sono preparati utilizzando i Funghi dell’Etere o la tecnica di Marinatura Temporale Sincronizzata?
# ```json
# {
#     "entità": [
#         "Ristorante",
#         "Piatto",
#         "Funghi dell’Etere",
#         "Marinatura Temporale Sincronizzata"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Ristorante",
#             "relazione": "SERVE",
#             "oggetto": "Piatto"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Funghi dell’Etere"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Marinatura Temporale Sincronizzata"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti preparati su un ristorante sul pianeta Klyntar che utilizzano Alghe Bioluminescenti o Amido di Stellarion?
# ```json
# {
#     "entità": ["Piatto", "Ristorante", "Pianeta", "Alghe Bioluminescenti", "Amido di Stellarion"],
#     "relazioni": [
#         {"soggetto": "Ristorante", "relazione": "SERVE", "oggetto": "Piatto"},
#         {"soggetto": "Piatto", "relazione": "PREPARATO_CON", "oggetto": "Alghe Bioluminescenti"},
#         {"soggetto": "Piatto", "relazione": "PREPARATO_CON", "oggetto": "Amido di Stellarion"},
#         {"soggetto": "Ristorante", "relazione": "si trova su", "oggetto": "Pianeta Klyntar"}
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti, serviti su un ristorante su Asgard, includono Essenza di Vuoto o Carne di Xenodonte?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Ristorante",
#         "Asgard",
#         "Essenza di Vuoto",
#         "Carne di Xenodonte"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Ristorante",
#             "relazione": "SERVE",
#             "oggetto": "Piatto"
#         },
#         {
#             "soggetto": "Ristorante",
# ...
#             "oggetto": "Cottura a Vapore con Flusso di Particelle Isoarmoniche"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali sono i piatti serviti su Namecc che utilizzano la Grigliatura Plasma Sintetico Risonante o l'Affumicatura Polarizzata a Freddo Iperbarico?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Namecc",
#         "Grigliatura Plasma Sintetico Risonante",
#         "Affumicatura Polarizzata a Freddo Iperbarico"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "SERVITO_SU",
#             "oggetto": "Namecc"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Grigliatura Plasma Sintetico Risonante"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Affumicatura Polarizzata a Freddo Iperbarico"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti possono essere trovati, preparati da uno chef con almeno la licenza P di grado 5, che includono Teste di Idra o che sono realizzati utilizzando la tecnica della Bollitura Entropica Sincronizzata?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Chef",
#         "Licenza P di grado 5",
#         "Teste di Idra",
#         "Tecnica della Bollitura Entropica Sincronizzata"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Chef",
#             "relazione": "HA_LICENZA",
#             "oggetto": "Licenza P di grado 5"
#         },
#         {
#             "soggetto": "Chef",
#             "relazione": "PREPARA",
#             "oggetto": "Piatto"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "INCLUDE",
#             "oggetto": "Teste di Idra"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA_TECNICA",
#             "oggetto": "Tecnica della Bollitura Entropica Sincronizzata"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono creati da uno chef con almeno la licenza LTK di grado 6 che utilizza Polvere di Pulsar o la tecnica di Cottura al Forno con Paradosso Temporale Cronospeculare?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Chef",
#         "Licenza LTK di grado 6",
#         "Polvere di Pulsar",
#         "Tecnica di Cottura al Forno con Paradosso Temporale Cronospeculare"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Chef",
#             "relazione": "HA",
#             "oggetto": "Licenza LTK di grado 6"
#         },
#         {
#             "soggetto": "Chef",
#             "relazione": "UTILIZZA",
#             "oggetto": "Polvere di Pulsar"
#         },
#         {
#             "soggetto": "Chef",
#             "relazione": "UTILIZZA",
#             "oggetto": "Tecnica di Cottura al Forno con Paradosso Temporale Cronospeculare"
#         },
#         {
#             "soggetto": "Chef",
#             "relazione": "CREA",
#             "oggetto": "Piatto"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono stati creati da uno chef con almeno la licenza Q di grado 9, utilizzando la tecnica Affumicatura Psionica Sensoriale oppure la tecnica Cottura Sottovuoto Multirealità Collassante?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Chef",
#         "Licenza Q di grado 9",
#         "Tecnica Affumicatura Psionica Sensoriale",
#         "Tecnica Cottura Sottovuoto Multirealità Collassante"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "CREATO_DA",
#             "oggetto": "Chef"
#         },
#         {
#             "soggetto": "Chef",
#             "relazione": "POSSEDE",
#             "oggetto": "Licenza Q di grado 9"
#         },
#         {
#             "soggetto": "Chef",
#             "relazione": "UTILIZZA",
#             "oggetto": "Tecnica Affumicatura Psionica Sensoriale"
#         },
#         {
#             "soggetto": "Chef",
#             "relazione": "UTILIZZA",
#             "oggetto": "Tecnica Cottura Sottovuoto Multirealità Collassante"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti, preparati da chef con almeno una licenza Mx di grado 1, utilizzano la tecnica della Congelazione Iperdimensionalmente Stratificata o la Cristallizzazione Temporale Reversiva?
# ```json
# {
#     "entità": ["Piatto", "Chef", "Licenza Mx", "Tecnica"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_DA",
#             "oggetto": "Chef"
#         },
#         {
#             "soggetto": "Chef",
#             "relazione": "POSSEDI",
#             "oggetto": "Licenza Mx di grado 1"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Tecnica della Congelazione Iperdimensionalmente Stratificata"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Tecnica della Cristallizzazione Temporale Reversiva"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti contengono almeno 2 ingredienti tra Spore Quantiche, Latte+ e Radici di Singolarità
# ```json
# {
#     "entità": ["Piatto", "Spore Quantiche", "Latte+", "Radici di Singolarità"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "CONTIENE",
#             "oggetto": "Spore Quantiche"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "CONTIENE",
#             "oggetto": "Latte+"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "CONTIENE",
#             "oggetto": "Radici di Singolarità"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti contengono almeno 2 ingredienti tra Ravioli al Vaporeon, Spaghi del Sole e Nettare di Sirena?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Ingrediente",
#         "Ravioli al Vaporeon",
#         "Spaghi del Sole",
#         "Nettare di Sirena"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "contiene",
#             "oggetto": "Ravioli al Vaporeon"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "contiene",
#             "oggetto": "Spaghi del Sole"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "contiene",
#             "oggetto": "Nettare di Sirena"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti contengono almeno 2 ingredienti tra Polvere di Crononite, Nduja Fritta Tanto, Spezie di Melange e Polvere di Stelle?
# ```json
# {
#     "entità": ["Piatto", "Ingrediente"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "CONTIENE",
#             "oggetto": "Ingrediente"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti contengono almeno 2 ingredienti tra Carne di Drago, Chocobo Wings, Foglie di Mandragora e Burrobirra?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Carne di Drago",
#         "Chocobo Wings",
#         "Foglie di Mandragora",
#         "Burrobirra"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "CONTIENE",
#             "oggetto": "Carne di Drago"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "CONTIENE",
#             "oggetto": "Chocobo Wings"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "CONTIENE",
#             "oggetto": "Foglie di Mandragora"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "CONTIENE",
#             "oggetto": "Burrobirra"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti includono gli Spaghi del Sole e sono preparati utilizzando almeno una tecnica di Surgelamento del di Sirius Cosmo?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Spaghi del Sole",
#         "Tecnica di Surgelamento",
#         "Sirius Cosmo"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "INCLUDE",
#             "oggetto": "Spaghi del Sole"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_USANDO",
#             "oggetto": "Tecnica di Surgelamento"
#         },
#         {
#             "soggetto": "Tecnica di Surgelamento",
#             "relazione": "PROPRIETA_DI",
#             "oggetto": "Sirius Cosmo"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti, realizzati utilizzando almeno una tecnica di taglio descritta nel di Sirius Cosmo, includono i Fusilli del Vento nella preparazione?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Tecnica di taglio",
#         "Sirius Cosmo",
#         "Fusilli del Vento"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "REALIZZATO_CON",
#             "oggetto": "Tecnica di taglio"
#         },
#         {
#             "soggetto": "Tecnica di taglio",
#             "relazione": "DESCRITTO_IN",
#             "oggetto": "Sirius Cosmo"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "INCLUDE",
#             "oggetto": "Fusilli del Vento"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti preparati su Asgard richiedono la licenza temporale superiore a 0 e includono Farina di Nettuno?
# ```json
# {
#     "entità": ["Piatto", "Asgard", "Licenza temporale", "Farina di Nettuno"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_SU",
#             "oggetto": "Asgard"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "RICHIEDE",
#             "oggetto": "Licenza temporale superiore a 0"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "INCLUDE",
#             "oggetto": "Farina di Nettuno"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti, preparati in un ristorante su Asgard, richiedono la licenza LTK non base e utilizzano Carne di Xenodonte?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Ristorante",
#         "Asgard",
#         "Licenza LTK non base",
#         "Carne di Xenodonte"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_IN",
#             "oggetto": "Ristorante"
#         },
#         {
#             "soggetto": "Ristorante",
#             "relazione": "SI_TROVA_SU",
#             "oggetto": "Asgard"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "RICHIEDE",
#             "oggetto": "Licenza LTK non base"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "UTILIZZA",
#             "oggetto": "Carne di Xenodonte"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti, che necessitano almeno della licenza P di grado 2 per essere preparati, serviti in un ristorante su Pandora, utilizzano Spore Quantiche?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Licenza P grado 2",
#         "Ristorante",
#         "Pandora",
#         "Spore Quantiche"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "necessita_di",
#             "oggetto": "Licenza P grado 2"
#         },
#         {
#             "soggetto": "Ristorante",
#             "relazione": "serve",
#             "oggetto": "Piatto"
#         },
#         {
#             "soggetto": "Ristorante",
#             "relazione": "si_trova_su",
#             "oggetto": "Pandora"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "utilizza",
#             "oggetto": "Spore Quantiche"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti che necessitano della licenza e+ con un grado minimo di 1 sono serviti su Arrakis e utilizzano l'ingrediente Riso di Cassandra?
# ```json
# {
#     "entità": ["Piatto", "Licenza e+", "Arrakis", "Riso di Cassandra"],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "REQUIRES",
#             "oggetto": "Licenza e+"
#         },
#         {
#             "soggetto": "Licenza e+",
#             "relazione": "HAS_MINIMUM_GRADE",
#             "oggetto": "1"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "SERVED_ON",
#             "oggetto": "Arrakis"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "USES",
#             "oggetto": "Riso di Cassandra"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono preparati utilizzando almeno una tecnica di taglio e una di surgelamento secondo il di Sirius Cosmo, ma senza l'uso di Polvere di Crononite?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Tecnica di taglio",
#         "Tecnica di surgelamento",
#         "Sirius Cosmo",
#         "Polvere di Crononite"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Tecnica di taglio"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Tecnica di surgelamento"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "SEGUE_LE_LINEE_DI",
#             "oggetto": "Sirius Cosmo"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "NON_USA",
#             "oggetto": "Polvere di Crononite"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti sono preparati utilizzando sia tecniche di impasto che di taglio, ma senza l'uso di Shard di Prisma Stellare?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Tecnica di impasto",
#         "Tecnica di taglio",
#         "Shard di Prisma Stellare"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Tecnica di impasto"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "PREPARATO_CON",
#             "oggetto": "Tecnica di taglio"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "NON_USA",
#             "oggetto": "Shard di Prisma Stellare"
#         }
#     ]
# }
# ```
#
# DEBUG - Risposta LLM per la domanda:
# Quali piatti creati con almeno una tecnica di taglio dal Manuale di Cucina di Sirius Cosmo e che necessitano della licenza t non base per la preparazione, escludendo quelli con Fusilli del Vento, sono serviti?
# ```json
# {
#     "entità": [
#         "Piatto",
#         "Tecnica di taglio",
#         "Manuale di Cucina di Sirius Cosmo",
#         "Licenza",
#         "Fusilli del Vento"
#     ],
#     "relazioni": [
#         {
#             "soggetto": "Piatto",
#             "relazione": "CREATO_CON",
#             "oggetto": "Tecnica di taglio"
#         },
#         {
#             "soggetto": "Tecnica di taglio",
#             "relazione": "PRESENTE_IN",
#             "oggetto": "Manuale di Cucina di Sirius Cosmo"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "RICHIEDE",
#             "oggetto": "Licenza non base"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "ESCLUDE",
#             "oggetto": "Fusilli del Vento"
#         },
#         {
#             "soggetto": "Piatto",
#             "relazione": "SERVITO"
#         }
#     ]
# }
# ```
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 76
#      74 # Esempio di utilizzo
#      75 csv_file = "C:/Users/lparigi/Downloads/letspizza/Hackapizza Dataset/domande.csv"
# ---> 76 schema_grafo = genera_schema_grafo(csv_file, llm)
#      78 # Stampa dello schema estratto
#      79 print("Entità identificate:")
#
# Cell In[5], line 70, in genera_schema_grafo(csv_path, llm)
#      68         schema["entità"].update(risultato_json["entità"])
#      69         for relazione in risultato_json["relazioni"]:
# ---> 70             schema["relazioni"].add((relazione["soggetto"], relazione["relazione"], relazione["oggetto"]))
#      72 return schema
#
# KeyError: 'oggetto'
